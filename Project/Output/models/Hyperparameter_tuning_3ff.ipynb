# %%
# %%capture
# %run Data_Cleaning.ipynb

# %%
# #### Calculate the metrics RMSE and MAPE ####
# def calculate_rmse(y_true, y_pred):
#     """
#     Calculate the Root Mean Squared Error (RMSE)
#     """
#     rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))
#     return rmse


# def calculate_mape(y_true, y_pred):
#     """
#     Calculate the Mean Absolute Percentage Error (MAPE) %
#     """
#     y_pred, y_true = np.array(y_pred), np.array(y_true)
#     mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
#     return mape

# %% [markdown]
# ## Model config

# %%
random_seed = 42
training_size = 0.85
validation_size = 0.1

# Get unique month periods
month_periods = sorted(three_ff_cleaned_df['Date'].dt.to_period('M').unique())
# Split size calculation
total_periods = three_ff_cleaned_df['Date'].dt.to_period('M').nunique()
train_size = int(total_periods * training_size)
val_size = int(total_periods * validation_size)
test_size = total_periods - train_size - val_size

# print(month_periods)
print("train_size is :", train_size, "months")
print("val_size is :", val_size, "months")
print("test_size is :", test_size, "months")

# ElasticNet
l1_ratios = [0.1, 0.5, 0.9]

# SVR
svr_C_values = [0.1, 1, 10]
svr_epsilons = [0.01, 0.1]

# XGboost
xgb_params = [(50, 0.1), (100, 0.05), (200, 0.01)]  # (n_estimators, learning_rate))

# DecisionTreeRegressor
tree_depths = [2, 4, 6, 8, 10]

print("##################################")
print("####### Hyperparameters ##########")
print("For Ridge: alphas = [0.01, 0.1, 1.0, 10.0, 100.0]")
print("For Lasso: alphas = [0.01, 0.1, 1.0, 10.0, 100.0]")
print("For ElasticNet: l1_ratios =", l1_ratios)
print("For SVR - svr_C_values:", svr_C_values)
print("For SVR - svr_epsilons:", svr_epsilons)
print("For Xgboost - n_estimators and learning rate", xgb_params)
print("For DecisionTreeRegressor", tree_depths)
# Out:
# train_size is : 182 months
# val_size is : 21 months
# test_size is : 12 months
# ##################################
# ####### Hyperparameters ##########
# For Ridge: alphas = [0.01, 0.1, 1.0, 10.0, 100.0]
# For Lasso: alphas = [0.01, 0.1, 1.0, 10.0, 100.0]
# For ElasticNet: l1_ratios = [0.1, 0.5, 0.9]
# For SVR - svr_C_values: [0.1, 1, 10]
# For SVR - svr_epsilons: [0.01, 0.1]
# For Xgboost - n_estimators and learning rate [(50, 0.1), (100, 0.05), (200, 0.01)]
# For DecisionTreeRegressor [2, 4, 6, 8, 10]

# %% [markdown]
# ## 3 Factor Fama French Modelling

# %%
# Convert all columns except 'Date' to float
three_ff_cleaned_df = three_ff_cleaned_df.sort_values(by='Date').reset_index(drop=True)
three_ff_cleaned_df.head(4)
# Out:
#         Date     AAPL.O     NVDA.O    MSFT.O     AMZN.O       LLY       WMT  \
# 0 2007-02-28  -1.315037   1.135388 -9.120327   3.828094 -2.867782  1.291682
# 1 2007-03-31   9.357873  -7.430645 -1.070674   1.647066  2.107322 -2.855538
# 2 2007-04-30   7.153685  13.348787  7.164454  43.265350  9.613921  2.044975
# 3 2007-05-31  19.419975   5.181152  2.474475  11.986431 -0.866247 -0.670016
#
#         XOM         MA       UNH  ...     ASTI.O      AWH.O     SUNE.O  \
# 0 -3.320376  -3.996326 -0.153198  ...  36.080434 -27.996003   4.710145
# 1  5.125842  -0.880898  1.502644  ...  66.263841   7.410797  -1.991531
# 2  5.077626   4.993695  0.169763  ...  12.778380   2.817088   7.561204
# 3  4.664026  29.199315  3.171925  ... -26.859959 -20.763936 -13.074411
#
#      TCRT.O     WINT.O     DGLY.O  Mkt-RF   SMB   HML    RF
# 0 -0.564442 -13.182539 -16.907633   -1.96  1.19 -0.14  0.38
# 1 -3.650742   7.443259  14.090545    0.68  0.16 -0.97  0.43
# 2  4.776457  22.567200  31.585295    3.49 -2.16 -1.45  0.44
# 3 -1.125715  13.226797  -0.417537    3.24  0.24 -0.65  0.41
#
# [4 rows x 980 columns]

# %% [markdown]
# ### Hyperparameter Tuning - Ridge Regression

# %%
# Define the Fama-French factor columns
ff_3_factors = ['Date', 'Mkt-RF', 'SMB', 'HML', 'RF']

# Get list of stock columns (everything except the FF factors and 'Period')
stock_columns = [col for col in three_ff_cleaned_df.columns if col not in ff_3_factors]

# Start global timer
start_all = time.time()

# ------------------ Initialize storage ------------------
all_ridge_results = []             # List of dicts with best model info per stock
best_ridge_models = {}             # Dict of best Ridge model per stock

# ------------------ Model Selection Loop ------------------
# Loop through each stock
for idx, stock in enumerate(stock_columns):
    print(f"\n🟠 Ridge - Stock {idx + 1}/{len(stock_columns)}: {stock}")
    start_time = time.time()
    # Subset and process
    df_subset = three_ff_cleaned_df[ff_3_factors + [stock]].copy()
    df_subset['Stock_Return'] = df_subset[[stock]]
    df_subset['Excess_Mkt_Return'] = df_subset['Mkt-RF'] - df_subset['RF']
    df_subset = df_subset[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
    
    # Shift return behind by 1 to align predictors at t with return at t+1
    df_subset['Stock_Return_Shifted'] = df_subset['Stock_Return'].shift(-1)
    # Drop the first row which now has NaN in 'Stock_Return_Shifted'
    df_subset = df_subset.dropna()

    # Standardize the predictors
    scaler = StandardScaler()
    df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']] = scaler.fit_transform(df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']])

    ridge_results = []
    alphas = [0.01, 0.1, 1.0, 10.0, 100.0]

    # loop each hyperparameter for each stock
    for alpha in alphas:

        model = Ridge(alpha=alpha, random_state = random_seed)

        val_rmse_list = []

        for i in range(train_size, train_size + val_size - 3):
            train_end_month = month_periods[i - 1]
            val_start_month = month_periods[i]
            val_end_month = month_periods[i + 2]
            
#             print("train_end_month")
#             print(train_end_month)
#             print("val_start_month")
#             print(val_start_month)
#             print("val_end_month")
#             print(val_end_month)

            train_mask = df_subset['Date'].dt.to_period('M') <= train_end_month
            val_mask = (df_subset['Date'].dt.to_period('M') >= val_start_month) & \
                       (df_subset['Date'].dt.to_period('M') <= val_end_month)

            X_train = df_subset.loc[train_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_train = df_subset.loc[train_mask, 'Stock_Return_Shifted']
            X_val = df_subset.loc[val_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_val = df_subset.loc[val_mask, 'Stock_Return_Shifted']

            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)

            rmse = np.sqrt(mean_squared_error(y_val, y_pred))
            val_rmse_list.append(rmse)

        avg_val_rmse = np.mean(val_rmse_list)

        ridge_results.append({
            'Stock': stock,
            'Alpha': alpha,
            'Avg_Validation_RMSE': avg_val_rmse,
            'Model': model
        })

    # Sort and pick best model for this stock
    ridge_results = sorted(ridge_results, key=lambda x: x['Avg_Validation_RMSE'])
    best_result = ridge_results[0] #lowest RMSE

    # Store best model and result
    all_ridge_results.append(best_result)
    best_ridge_models[stock] = best_result['Model']
    
    elapsed = time.time() - start_time
    print(f"✅ Finished stock {stock} | Time: {elapsed:.2f}s")

# End global timer
end_all = time.time()
print(f"\n🟩 Finished all stocks | Total Time: {end_all - start_all:.2f} seconds")
# Out:
# 🟠 Ridge - Stock 1/975: AAPL.O
# ✅ Finished stock AAPL.O | Time: 0.21s
#
# 🟠 Ridge - Stock 2/975: NVDA.O
# ✅ Finished stock NVDA.O | Time: 0.23s
#
# 🟠 Ridge - Stock 3/975: MSFT.O
# ✅ Finished stock MSFT.O | Time: 0.23s
#
# 🟠 Ridge - Stock 4/975: AMZN.O
# ✅ Finished stock AMZN.O | Time: 0.27s
#
# 🟠 Ridge - Stock 5/975: LLY
# ✅ Finished stock LLY | Time: 0.23s
#
# 🟠 Ridge - Stock 6/975: WMT
# ✅ Finished stock WMT | Time: 0.23s
#
# 🟠 Ridge - Stock 7/975: XOM
# ✅ Finished stock XOM | Time: 0.22s
#
# 🟠 Ridge - Stock 8/975: MA
# ✅ Finished stock MA | Time: 0.24s
#
# 🟠 Ridge - Stock 9/975: UNH
# ✅ Finished stock UNH | Time: 0.23s
#
# 🟠 Ridge - Stock 10/975: ORCL.K
# ✅ Finished stock ORCL.K | Time: 0.22s
#
# 🟠 Ridge - Stock 11/975: COST.O
# ✅ Finished stock COST.O | Time: 0.23s
#
# 🟠 Ridge - Stock 12/975: NFLX.O
# ✅ Finished stock NFLX.O | Time: 0.26s
#
# 🟠 Ridge - Stock 13/975: HD
# ✅ Finished stock HD | Time: 0.21s
#
# 🟠 Ridge - Stock 14/975: CVX
# ✅ Finished stock CVX | Time: 0.23s
#
# 🟠 Ridge - Stock 15/975: CRM
# ✅ Finished stock CRM | Time: 0.25s
#
# 🟠 Ridge - Stock 16/975: CSCO.O
# ✅ Finished stock CSCO.O | Time: 0.20s
#
# 🟠 Ridge - Stock 17/975: MRK
# ✅ Finished stock MRK | Time: 0.26s
#
# 🟠 Ridge - Stock 18/975: ABT
# ✅ Finished stock ABT | Time: 0.22s
#
# 🟠 Ridge - Stock 19/975: MCD
# ✅ Finished stock MCD | Time: 0.22s
#
# 🟠 Ridge - Stock 20/975: TMO
# ✅ Finished stock TMO | Time: 0.22s
#
# 🟠 Ridge - Stock 21/975: ISRG.O
# ✅ Finished stock ISRG.O | Time: 0.22s
#
# 🟠 Ridge - Stock 22/975: RTX
# ✅ Finished stock RTX | Time: 0.21s
#
# 🟠 Ridge - Stock 23/975: QCOM.O
# ✅ Finished stock QCOM.O | Time: 0.22s
#
# 🟠 Ridge - Stock 24/975: ADBE.O
# ✅ Finished stock ADBE.O | Time: 0.20s
#
# 🟠 Ridge - Stock 25/975: AMGN.O
# ✅ Finished stock AMGN.O | Time: 0.21s
#
# 🟠 Ridge - Stock 26/975: INTU.O
# ✅ Finished stock INTU.O | Time: 0.20s
#
# 🟠 Ridge - Stock 27/975: AMD.O
# ✅ Finished stock AMD.O | Time: 0.24s
#
# 🟠 Ridge - Stock 28/975: CAT
# ✅ Finished stock CAT | Time: 0.22s
#
# 🟠 Ridge - Stock 29/975: TXN.O
# ✅ Finished stock TXN.O | Time: 0.22s
#
# 🟠 Ridge - Stock 30/975: NEE
# ✅ Finished stock NEE | Time: 0.23s
#
# 🟠 Ridge - Stock 31/975: DHR
# ✅ Finished stock DHR | Time: 0.21s
#
# 🟠 Ridge - Stock 32/975: PFE
# ✅ Finished stock PFE | Time: 0.20s
#
# 🟠 Ridge - Stock 33/975: BLK
# ✅ Finished stock BLK | Time: 0.29s
#
# 🟠 Ridge - Stock 34/975: UNP
# ✅ Finished stock UNP | Time: 0.28s
#
# 🟠 Ridge - Stock 35/975: BSX
# ✅ Finished stock BSX | Time: 0.33s
#
# 🟠 Ridge - Stock 36/975: SYK
# ✅ Finished stock SYK | Time: 0.31s
#
# 🟠 Ridge - Stock 37/975: GILD.O
# ✅ Finished stock GILD.O | Time: 0.29s
#
# 🟠 Ridge - Stock 38/975: HON.O
# ✅ Finished stock HON.O | Time: 0.30s
#
# 🟠 Ridge - Stock 39/975: CMCSA.O
# ✅ Finished stock CMCSA.O | Time: 0.29s
#
# 🟠 Ridge - Stock 40/975: VRTX.O
# ✅ Finished stock VRTX.O | Time: 0.31s
#
# 🟠 Ridge - Stock 41/975: DE
# ✅ Finished stock DE | Time: 0.29s
#
# 🟠 Ridge - Stock 42/975: TJX
# ✅ Finished stock TJX | Time: 0.27s
#
# 🟠 Ridge - Stock 43/975: COP
# ✅ Finished stock COP | Time: 0.27s
#
# 🟠 Ridge - Stock 44/975: LOW
# ✅ Finished stock LOW | Time: 0.27s
#
# 🟠 Ridge - Stock 45/975: BA
# ✅ Finished stock BA | Time: 0.27s
#
# 🟠 Ridge - Stock 46/975: FI
# ✅ Finished stock FI | Time: 0.29s
#
# 🟠 Ridge - Stock 47/975: BMY
# ✅ Finished stock BMY | Time: 0.27s
#
# 🟠 Ridge - Stock 48/975: ADP.O
# ✅ Finished stock ADP.O | Time: 0.28s
#
# 🟠 Ridge - Stock 49/975: MMC
# ✅ Finished stock MMC | Time: 0.33s
#
# 🟠 Ridge - Stock 50/975: MU.O
# ✅ Finished stock MU.O | Time: 0.26s
#
# 🟠 Ridge - Stock 51/975: NKE
# ✅ Finished stock NKE | Time: 0.26s
#
# 🟠 Ridge - Stock 52/975: INTC.O
# ✅ Finished stock INTC.O | Time: 0.29s
#
# 🟠 Ridge - Stock 53/975: ADI.O
# ✅ Finished stock ADI.O | Time: 0.28s
#
# 🟠 Ridge - Stock 54/975: LRCX.O
# ✅ Finished stock LRCX.O | Time: 0.32s
#
# 🟠 Ridge - Stock 55/975: ELV
# ✅ Finished stock ELV | Time: 0.31s
#
# 🟠 Ridge - Stock 56/975: KLAC.O
# ✅ Finished stock KLAC.O | Time: 0.36s
#
# 🟠 Ridge - Stock 57/975: DUK
# ✅ Finished stock DUK | Time: 0.40s
#
# 🟠 Ridge - Stock 58/975: CI
# ✅ Finished stock CI | Time: 0.35s
#
# 🟠 Ridge - Stock 59/975: AJG
# ✅ Finished stock AJG | Time: 0.29s
#
# 🟠 Ridge - Stock 60/975: CVS
# ✅ Finished stock CVS | Time: 0.27s
#
# 🟠 Ridge - Stock 61/975: MMM
# ✅ Finished stock MMM | Time: 0.35s
#
# 🟠 Ridge - Stock 62/975: MCK
# ✅ Finished stock MCK | Time: 0.31s
#
# 🟠 Ridge - Stock 63/975: APH
# ✅ Finished stock APH | Time: 0.32s
#
# 🟠 Ridge - Stock 64/975: ORLY.O
# ✅ Finished stock ORLY.O | Time: 0.29s
#
# 🟠 Ridge - Stock 65/975: REGN.O
# ✅ Finished stock REGN.O | Time: 0.28s
#
# 🟠 Ridge - Stock 66/975: CL
# ✅ Finished stock CL | Time: 0.27s
#
# 🟠 Ridge - Stock 67/975: RSG
# ✅ Finished stock RSG | Time: 0.34s
#
# 🟠 Ridge - Stock 68/975: NOC
# ✅ Finished stock NOC | Time: 0.36s
#
# 🟠 Ridge - Stock 69/975: WMB
# ✅ Finished stock WMB | Time: 0.30s
#
# 🟠 Ridge - Stock 70/975: MSI
# ✅ Finished stock MSI | Time: 0.29s
#
# 🟠 Ridge - Stock 71/975: SNPS.O
# ✅ Finished stock SNPS.O | Time: 0.35s
#
# 🟠 Ridge - Stock 72/975: EOG
# ✅ Finished stock EOG | Time: 0.27s
#
# 🟠 Ridge - Stock 73/975: CDNS.O
# ✅ Finished stock CDNS.O | Time: 0.30s
#
# 🟠 Ridge - Stock 74/975: CMG
# ✅ Finished stock CMG | Time: 0.27s
#
# 🟠 Ridge - Stock 75/975: MAR.O
# ✅ Finished stock MAR.O | Time: 0.28s
#
# 🟠 Ridge - Stock 76/975: BDX
# ✅ Finished stock BDX | Time: 0.29s
#
# 🟠 Ridge - Stock 77/975: ROP.O
# ✅ Finished stock ROP.O | Time: 0.26s
#
# 🟠 Ridge - Stock 78/975: OKE
# ✅ Finished stock OKE | Time: 0.22s
#
# 🟠 Ridge - Stock 79/975: AZO
# ✅ Finished stock AZO | Time: 0.22s
#
# 🟠 Ridge - Stock 80/975: MRVL.O
# ✅ Finished stock MRVL.O | Time: 0.22s
#
# 🟠 Ridge - Stock 81/975: BK
# ✅ Finished stock BK | Time: 0.21s
#
# 🟠 Ridge - Stock 82/975: CSX.O
# ✅ Finished stock CSX.O | Time: 0.20s
#
# 🟠 Ridge - Stock 83/975: SLB
# ✅ Finished stock SLB | Time: 0.22s
#
# 🟠 Ridge - Stock 84/975: MET
# ✅ Finished stock MET | Time: 0.23s
#
# 🟠 Ridge - Stock 85/975: ADSK.O
# ✅ Finished stock ADSK.O | Time: 0.22s
#
# 🟠 Ridge - Stock 86/975: TFC
# ✅ Finished stock TFC | Time: 0.28s
#
# 🟠 Ridge - Stock 87/975: PCAR.O
# ✅ Finished stock PCAR.O | Time: 0.29s
#
# 🟠 Ridge - Stock 88/975: COR
# ✅ Finished stock COR | Time: 0.29s
#
# 🟠 Ridge - Stock 89/975: LNG
# ✅ Finished stock LNG | Time: 0.31s
#
# 🟠 Ridge - Stock 90/975: TGT
# ✅ Finished stock TGT | Time: 0.37s
#
# 🟠 Ridge - Stock 91/975: KR
# ✅ Finished stock KR | Time: 0.29s
#
# 🟠 Ridge - Stock 92/975: D
# ✅ Finished stock D | Time: 0.32s
#
# 🟠 Ridge - Stock 93/975: HES
# ✅ Finished stock HES | Time: 0.30s
#
# 🟠 Ridge - Stock 94/975: FICO.K
# ✅ Finished stock FICO.K | Time: 0.30s
#
# 🟠 Ridge - Stock 95/975: OXY
# ✅ Finished stock OXY | Time: 0.26s
#
# 🟠 Ridge - Stock 96/975: BKR.O
# ✅ Finished stock BKR.O | Time: 0.28s
#
# 🟠 Ridge - Stock 97/975: ROST.O
# ✅ Finished stock ROST.O | Time: 0.26s
#
# 🟠 Ridge - Stock 98/975: EW
# ✅ Finished stock EW | Time: 0.27s
#
# 🟠 Ridge - Stock 99/975: VLO
# ✅ Finished stock VLO | Time: 0.29s
#
# 🟠 Ridge - Stock 100/975: AME
# ✅ Finished stock AME | Time: 0.31s
#
# 🟠 Ridge - Stock 101/975: GLW
# ✅ Finished stock GLW | Time: 0.33s
#
# 🟠 Ridge - Stock 102/975: DHI
# ✅ Finished stock DHI | Time: 0.35s
#
# 🟠 Ridge - Stock 103/975: LHX
# ✅ Finished stock LHX | Time: 0.29s
#
# 🟠 Ridge - Stock 104/975: CTSH.O
# ✅ Finished stock CTSH.O | Time: 0.30s
#
# 🟠 Ridge - Stock 105/975: PWR
# ✅ Finished stock PWR | Time: 0.29s
#
# 🟠 Ridge - Stock 106/975: F
# ✅ Finished stock F | Time: 0.30s
#
# 🟠 Ridge - Stock 107/975: EA.O
# ✅ Finished stock EA.O | Time: 0.32s
#
# 🟠 Ridge - Stock 108/975: TTWO.O
# ✅ Finished stock TTWO.O | Time: 0.36s
#
# 🟠 Ridge - Stock 109/975: A
# ✅ Finished stock A | Time: 0.29s
#
# 🟠 Ridge - Stock 110/975: ODFL.O
# ✅ Finished stock ODFL.O | Time: 0.30s
#
# 🟠 Ridge - Stock 111/975: BRO
# ✅ Finished stock BRO | Time: 0.29s
#
# 🟠 Ridge - Stock 112/975: IDXX.O
# ✅ Finished stock IDXX.O | Time: 0.32s
#
# 🟠 Ridge - Stock 113/975: CSGP.O
# ✅ Finished stock CSGP.O | Time: 0.28s
#
# 🟠 Ridge - Stock 114/975: ALNY.O
# ✅ Finished stock ALNY.O | Time: 0.30s
#
# 🟠 Ridge - Stock 115/975: HEI
# ✅ Finished stock HEI | Time: 0.34s
#
# 🟠 Ridge - Stock 116/975: LVS
# ✅ Finished stock LVS | Time: 0.28s
#
# 🟠 Ridge - Stock 117/975: CAH
# ✅ Finished stock CAH | Time: 0.31s
#
# 🟠 Ridge - Stock 118/975: WAB
# ✅ Finished stock WAB | Time: 0.35s
#
# 🟠 Ridge - Stock 119/975: HUM
# ✅ Finished stock HUM | Time: 0.33s
#
# 🟠 Ridge - Stock 120/975: NUE
# ✅ Finished stock NUE | Time: 0.32s
#
# 🟠 Ridge - Stock 121/975: EBAY.O
# ✅ Finished stock EBAY.O | Time: 0.34s
#
# 🟠 Ridge - Stock 122/975: TPL
# ✅ Finished stock TPL | Time: 0.35s
#
# 🟠 Ridge - Stock 123/975: EQT
# ✅ Finished stock EQT | Time: 0.29s
#
# 🟠 Ridge - Stock 124/975: ROK
# ✅ Finished stock ROK | Time: 0.29s
#
# 🟠 Ridge - Stock 125/975: MPWR.O
# ✅ Finished stock MPWR.O | Time: 0.30s
#
# 🟠 Ridge - Stock 126/975: MCHP.O
# ✅ Finished stock MCHP.O | Time: 0.28s
#
# 🟠 Ridge - Stock 127/975: ANSS.O
# ✅ Finished stock ANSS.O | Time: 0.28s
#
# 🟠 Ridge - Stock 128/975: DTE
# ✅ Finished stock DTE | Time: 0.29s
#
# 🟠 Ridge - Stock 129/975: DXCM.O
# ✅ Finished stock DXCM.O | Time: 0.32s
#
# 🟠 Ridge - Stock 130/975: IP
# ✅ Finished stock IP | Time: 0.28s
#
# 🟠 Ridge - Stock 131/975: AEE
# ✅ Finished stock AEE | Time: 0.30s
#
# 🟠 Ridge - Stock 132/975: PPG
# ✅ Finished stock PPG | Time: 0.28s
#
# 🟠 Ridge - Stock 133/975: PPL
# ✅ Finished stock PPL | Time: 0.30s
#
# 🟠 Ridge - Stock 134/975: MTD
# ✅ Finished stock MTD | Time: 0.29s
#
# 🟠 Ridge - Stock 135/975: WBD.O
# ✅ Finished stock WBD.O | Time: 0.35s
#
# 🟠 Ridge - Stock 136/975: TYL
# ✅ Finished stock TYL | Time: 0.28s
#
# 🟠 Ridge - Stock 137/975: EL
# ✅ Finished stock EL | Time: 0.29s
#
# 🟠 Ridge - Stock 138/975: ATO
# ✅ Finished stock ATO | Time: 0.29s
#
# 🟠 Ridge - Stock 139/975: GPN
# ✅ Finished stock GPN | Time: 0.29s
#
# 🟠 Ridge - Stock 140/975: TDY
# ✅ Finished stock TDY | Time: 0.30s
#
# 🟠 Ridge - Stock 141/975: VRSN.O
# ✅ Finished stock VRSN.O | Time: 0.27s
#
# 🟠 Ridge - Stock 142/975: DVN
# ✅ Finished stock DVN | Time: 0.35s
#
# 🟠 Ridge - Stock 143/975: WAT
# ✅ Finished stock WAT | Time: 0.33s
#
# 🟠 Ridge - Stock 144/975: ERIE.O
# ✅ Finished stock ERIE.O | Time: 0.29s
#
# 🟠 Ridge - Stock 145/975: ZBH
# ✅ Finished stock ZBH | Time: 0.33s
#
# 🟠 Ridge - Stock 146/975: DRI
# ✅ Finished stock DRI | Time: 0.29s
#
# 🟠 Ridge - Stock 147/975: HAL
# ✅ Finished stock HAL | Time: 0.28s
#
# 🟠 Ridge - Stock 148/975: NVR
# ✅ Finished stock NVR | Time: 0.30s
#
# 🟠 Ridge - Stock 149/975: TSN
# ✅ Finished stock TSN | Time: 0.26s
#
# 🟠 Ridge - Stock 150/975: CTRA.K
# ✅ Finished stock CTRA.K | Time: 0.27s
#
# 🟠 Ridge - Stock 151/975: PHM
# ✅ Finished stock PHM | Time: 0.30s
#
# 🟠 Ridge - Stock 152/975: TROW.O
# ✅ Finished stock TROW.O | Time: 0.35s
#
# 🟠 Ridge - Stock 153/975: LII
# ✅ Finished stock LII | Time: 0.28s
#
# 🟠 Ridge - Stock 154/975: BIIB.O
# ✅ Finished stock BIIB.O | Time: 0.29s
#
# 🟠 Ridge - Stock 155/975: LH
# ✅ Finished stock LH | Time: 0.29s
#
# 🟠 Ridge - Stock 156/975: STLD.O
# ✅ Finished stock STLD.O | Time: 0.27s
#
# 🟠 Ridge - Stock 157/975: NRG
# ✅ Finished stock NRG | Time: 0.29s
#
# 🟠 Ridge - Stock 158/975: DGX
# ✅ Finished stock DGX | Time: 0.29s
#
# 🟠 Ridge - Stock 159/975: LUV
# ✅ Finished stock LUV | Time: 0.29s
#
# 🟠 Ridge - Stock 160/975: PTC.O
# ✅ Finished stock PTC.O | Time: 0.30s
#
# 🟠 Ridge - Stock 161/975: NTAP.O
# ✅ Finished stock NTAP.O | Time: 0.32s
#
# 🟠 Ridge - Stock 162/975: ON.O
# ✅ Finished stock ON.O | Time: 0.29s
#
# 🟠 Ridge - Stock 163/975: CLX
# ✅ Finished stock CLX | Time: 0.27s
#
# 🟠 Ridge - Stock 164/975: DECK.K
# ✅ Finished stock DECK.K | Time: 0.27s
#
# 🟠 Ridge - Stock 165/975: FNF
# ✅ Finished stock FNF | Time: 0.25s
#
# 🟠 Ridge - Stock 166/975: BAX
# ✅ Finished stock BAX | Time: 0.29s
#
# 🟠 Ridge - Stock 167/975: EME
# ✅ Finished stock EME | Time: 0.27s
#
# 🟠 Ridge - Stock 168/975: TRMB.O
# ✅ Finished stock TRMB.O | Time: 0.26s
#
# 🟠 Ridge - Stock 169/975: GPC
# ✅ Finished stock GPC | Time: 0.27s
#
# 🟠 Ridge - Stock 170/975: GEN.O
# ✅ Finished stock GEN.O | Time: 0.30s
#
# 🟠 Ridge - Stock 171/975: WST
# ✅ Finished stock WST | Time: 0.29s
#
# 🟠 Ridge - Stock 172/975: HRL
# ✅ Finished stock HRL | Time: 0.29s
#
# 🟠 Ridge - Stock 173/975: COO.O
# ✅ Finished stock COO.O | Time: 0.31s
#
# 🟠 Ridge - Stock 174/975: EXPD.K
# ✅ Finished stock EXPD.K | Time: 0.35s
#
# 🟠 Ridge - Stock 175/975: WDC.O
# ✅ Finished stock WDC.O | Time: 0.34s
#
# 🟠 Ridge - Stock 176/975: BBY
# ✅ Finished stock BBY | Time: 0.29s
#
# 🟠 Ridge - Stock 177/975: FFIV.O
# ✅ Finished stock FFIV.O | Time: 0.27s
#
# 🟠 Ridge - Stock 178/975: RS
# ✅ Finished stock RS | Time: 0.29s
#
# 🟠 Ridge - Stock 179/975: RPM
# ✅ Finished stock RPM | Time: 0.30s
#
# 🟠 Ridge - Stock 180/975: JBL
# ✅ Finished stock JBL | Time: 0.31s
#
# 🟠 Ridge - Stock 181/975: ENTG.O
# ✅ Finished stock ENTG.O | Time: 0.28s
#
# 🟠 Ridge - Stock 182/975: BALL.K
# ✅ Finished stock BALL.K | Time: 0.26s
#
# 🟠 Ridge - Stock 183/975: BLDR.K
# ✅ Finished stock BLDR.K | Time: 0.30s
#
# 🟠 Ridge - Stock 184/975: FSLR.O
# ✅ Finished stock FSLR.O | Time: 0.29s
#
# 🟠 Ridge - Stock 185/975: GGG
# ✅ Finished stock GGG | Time: 0.29s
#
# 🟠 Ridge - Stock 186/975: TER.O
# ✅ Finished stock TER.O | Time: 0.28s
#
# 🟠 Ridge - Stock 187/975: UNM
# ✅ Finished stock UNM | Time: 0.27s
#
# 🟠 Ridge - Stock 188/975: DLTR.O
# ✅ Finished stock DLTR.O | Time: 0.27s
#
# 🟠 Ridge - Stock 189/975: INSM.O
# ✅ Finished stock INSM.O | Time: 0.28s
#
# 🟠 Ridge - Stock 190/975: UTHR.O
# ✅ Finished stock UTHR.O | Time: 0.29s
#
# 🟠 Ridge - Stock 191/975: HOLX.O
# ✅ Finished stock HOLX.O | Time: 0.31s
#
# 🟠 Ridge - Stock 192/975: ILMN.O
# ✅ Finished stock ILMN.O | Time: 0.38s
#
# 🟠 Ridge - Stock 193/975: RVTY.K
# ✅ Finished stock RVTY.K | Time: 0.31s
#
# 🟠 Ridge - Stock 194/975: BMRN.O
# ✅ Finished stock BMRN.O | Time: 0.32s
#
# 🟠 Ridge - Stock 195/975: FLEX.O
# ✅ Finished stock FLEX.O | Time: 0.30s
#
# 🟠 Ridge - Stock 196/975: INCY.O
# ✅ Finished stock INCY.O | Time: 0.31s
#
# 🟠 Ridge - Stock 197/975: JKHY.O
# ✅ Finished stock JKHY.O | Time: 0.40s
#
# 🟠 Ridge - Stock 198/975: MORN.O
# ✅ Finished stock MORN.O | Time: 0.43s
#
# 🟠 Ridge - Stock 199/975: ALGN.O
# ✅ Finished stock ALGN.O | Time: 0.37s
#
# 🟠 Ridge - Stock 200/975: EWBC.O
# ✅ Finished stock EWBC.O | Time: 0.41s
#
# 🟠 Ridge - Stock 201/975: AKAM.O
# ✅ Finished stock AKAM.O | Time: 0.37s
#
# 🟠 Ridge - Stock 202/975: FIX
# ✅ Finished stock FIX | Time: 0.37s
#
# 🟠 Ridge - Stock 203/975: JNPR.K
# ✅ Finished stock JNPR.K | Time: 0.32s
#
# 🟠 Ridge - Stock 204/975: SJM
# ✅ Finished stock SJM | Time: 0.31s
#
# 🟠 Ridge - Stock 205/975: JLL
# ✅ Finished stock JLL | Time: 0.30s
#
# 🟠 Ridge - Stock 206/975: NDSN.O
# ✅ Finished stock NDSN.O | Time: 0.28s
#
# 🟠 Ridge - Stock 207/975: CHRW.O
# ✅ Finished stock CHRW.O | Time: 0.28s
#
# 🟠 Ridge - Stock 208/975: THC
# ✅ Finished stock THC | Time: 0.29s
#
# 🟠 Ridge - Stock 209/975: JEF
# ✅ Finished stock JEF | Time: 0.27s
#
# 🟠 Ridge - Stock 210/975: COKE.O
# ✅ Finished stock COKE.O | Time: 0.29s
#
# 🟠 Ridge - Stock 211/975: TXRH.O
# ✅ Finished stock TXRH.O | Time: 0.27s
#
# 🟠 Ridge - Stock 212/975: SWKS.O
# ✅ Finished stock SWKS.O | Time: 0.30s
#
# 🟠 Ridge - Stock 213/975: NBIX.O
# ✅ Finished stock NBIX.O | Time: 0.31s
#
# 🟠 Ridge - Stock 214/975: ITT
# ✅ Finished stock ITT | Time: 0.28s
#
# 🟠 Ridge - Stock 215/975: VTRS.O
# ✅ Finished stock VTRS.O | Time: 0.27s
#
# 🟠 Ridge - Stock 216/975: SNX
# ✅ Finished stock SNX | Time: 0.27s
#
# 🟠 Ridge - Stock 217/975: AIZ
# ✅ Finished stock AIZ | Time: 0.28s
#
# 🟠 Ridge - Stock 218/975: RBC
# ✅ Finished stock RBC | Time: 0.28s
#
# 🟠 Ridge - Stock 219/975: OVV
# ✅ Finished stock OVV | Time: 0.29s
#
# 🟠 Ridge - Stock 220/975: MANH.O
# ✅ Finished stock MANH.O | Time: 0.28s
#
# 🟠 Ridge - Stock 221/975: EMN
# ✅ Finished stock EMN | Time: 0.34s
#
# 🟠 Ridge - Stock 222/975: CCK
# ✅ Finished stock CCK | Time: 0.30s
#
# 🟠 Ridge - Stock 223/975: TOL
# ✅ Finished stock TOL | Time: 0.30s
#
# 🟠 Ridge - Stock 224/975: CLH
# ✅ Finished stock CLH | Time: 0.31s
#
# 🟠 Ridge - Stock 225/975: GME
# ✅ Finished stock GME | Time: 0.29s
#
# 🟠 Ridge - Stock 226/975: EXEL.O
# ✅ Finished stock EXEL.O | Time: 0.31s
#
# 🟠 Ridge - Stock 227/975: RGLD.O
# ✅ Finished stock RGLD.O | Time: 0.33s
#
# 🟠 Ridge - Stock 228/975: COHR.K
# ✅ Finished stock COHR.K | Time: 0.27s
#
# 🟠 Ridge - Stock 229/975: DOX.O
# ✅ Finished stock DOX.O | Time: 0.33s
#
# 🟠 Ridge - Stock 230/975: IPG
# ✅ Finished stock IPG | Time: 0.28s
#
# 🟠 Ridge - Stock 231/975: TECH.O
# ✅ Finished stock TECH.O | Time: 0.29s
#
# 🟠 Ridge - Stock 232/975: ATR
# ✅ Finished stock ATR | Time: 0.28s
#
# 🟠 Ridge - Stock 233/975: WBA.O
# ✅ Finished stock WBA.O | Time: 0.27s
#
# 🟠 Ridge - Stock 234/975: MTZ
# ✅ Finished stock MTZ | Time: 0.29s
#
# 🟠 Ridge - Stock 235/975: SRPT.O
# ✅ Finished stock SRPT.O | Time: 0.26s
#
# 🟠 Ridge - Stock 236/975: SAIA.O
# ✅ Finished stock SAIA.O | Time: 0.26s
#
# 🟠 Ridge - Stock 237/975: SEIC.O
# ✅ Finished stock SEIC.O | Time: 0.31s
#
# 🟠 Ridge - Stock 238/975: RRC
# ✅ Finished stock RRC | Time: 0.36s
#
# 🟠 Ridge - Stock 239/975: WYNN.O
# ✅ Finished stock WYNN.O | Time: 0.32s
#
# 🟠 Ridge - Stock 240/975: CRS
# ✅ Finished stock CRS | Time: 0.28s
#
# 🟠 Ridge - Stock 241/975: CIEN.K
# ✅ Finished stock CIEN.K | Time: 0.28s
#
# 🟠 Ridge - Stock 242/975: ALB
# ✅ Finished stock ALB | Time: 0.27s
#
# 🟠 Ridge - Stock 243/975: X
# ✅ Finished stock X | Time: 0.26s
#
# 🟠 Ridge - Stock 244/975: HSIC.O
# ✅ Finished stock HSIC.O | Time: 0.27s
#
# 🟠 Ridge - Stock 245/975: LNW.O
# ✅ Finished stock LNW.O | Time: 0.27s
#
# 🟠 Ridge - Stock 246/975: CHE
# ✅ Finished stock CHE | Time: 0.29s
#
# 🟠 Ridge - Stock 247/975: CRL
# ✅ Finished stock CRL | Time: 0.27s
#
# 🟠 Ridge - Stock 248/975: DRS.O
# ✅ Finished stock DRS.O | Time: 0.33s
#
# 🟠 Ridge - Stock 249/975: RGEN.O
# ✅ Finished stock RGEN.O | Time: 0.28s
#
# 🟠 Ridge - Stock 250/975: LSCC.O
# ✅ Finished stock LSCC.O | Time: 0.42s
#
# 🟠 Ridge - Stock 251/975: EXAS.O
# ✅ Finished stock EXAS.O | Time: 0.44s
#
# 🟠 Ridge - Stock 252/975: HAS.O
# ✅ Finished stock HAS.O | Time: 0.36s
#
# 🟠 Ridge - Stock 253/975: PARA.O
# ✅ Finished stock PARA.O | Time: 0.54s
#
# 🟠 Ridge - Stock 254/975: DCI
# ✅ Finished stock DCI | Time: 0.56s
#
# 🟠 Ridge - Stock 255/975: CHDN.O
# ✅ Finished stock CHDN.O | Time: 0.41s
#
# 🟠 Ridge - Stock 256/975: MKTX.O
# ✅ Finished stock MKTX.O | Time: 0.47s
#
# 🟠 Ridge - Stock 257/975: NYT
# ✅ Finished stock NYT | Time: 0.51s
#
# 🟠 Ridge - Stock 258/975: WCC
# ✅ Finished stock WCC | Time: 0.60s
#
# 🟠 Ridge - Stock 259/975: DLB
# ✅ Finished stock DLB | Time: 0.43s
#
# 🟠 Ridge - Stock 260/975: EVR
# ✅ Finished stock EVR | Time: 0.38s
#
# 🟠 Ridge - Stock 261/975: TTEK.O
# ✅ Finished stock TTEK.O | Time: 0.35s
#
# 🟠 Ridge - Stock 262/975: RRX
# ✅ Finished stock RRX | Time: 0.40s
#
# 🟠 Ridge - Stock 263/975: SIRI.O
# ✅ Finished stock SIRI.O | Time: 0.38s
#
# 🟠 Ridge - Stock 264/975: HALO.O
# ✅ Finished stock HALO.O | Time: 0.44s
#
# 🟠 Ridge - Stock 265/975: GAP
# ✅ Finished stock GAP | Time: 0.38s
#
# 🟠 Ridge - Stock 266/975: EXLS.O
# ✅ Finished stock EXLS.O | Time: 0.38s
#
# 🟠 Ridge - Stock 267/975: ATI
# ✅ Finished stock ATI | Time: 0.38s
#
# 🟠 Ridge - Stock 268/975: TTC
# ✅ Finished stock TTC | Time: 0.44s
#
# 🟠 Ridge - Stock 269/975: ZION.O
# ✅ Finished stock ZION.O | Time: 0.45s
#
# 🟠 Ridge - Stock 270/975: BIO
# ✅ Finished stock BIO | Time: 0.44s
#
# 🟠 Ridge - Stock 271/975: MHK
# ✅ Finished stock MHK | Time: 0.42s
#
# 🟠 Ridge - Stock 272/975: APA.O
# ✅ Finished stock APA.O | Time: 0.39s
#
# 🟠 Ridge - Stock 273/975: CVLT.O
# ✅ Finished stock CVLT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 274/975: AGCO.K
# ✅ Finished stock AGCO.K | Time: 0.39s
#
# 🟠 Ridge - Stock 275/975: BRKR.O
# ✅ Finished stock BRKR.O | Time: 0.36s
#
# 🟠 Ridge - Stock 276/975: RLI
# ✅ Finished stock RLI | Time: 0.36s
#
# 🟠 Ridge - Stock 277/975: IVZ
# ✅ Finished stock IVZ | Time: 0.39s
#
# 🟠 Ridge - Stock 278/975: ONTO.K
# ✅ Finished stock ONTO.K | Time: 0.40s
#
# 🟠 Ridge - Stock 279/975: CWST.O
# ✅ Finished stock CWST.O | Time: 0.40s
#
# 🟠 Ridge - Stock 280/975: QRVO.O
# ✅ Finished stock QRVO.O | Time: 0.54s
#
# 🟠 Ridge - Stock 281/975: AAON.O
# ✅ Finished stock AAON.O | Time: 0.44s
#
# 🟠 Ridge - Stock 282/975: ALK
# ✅ Finished stock ALK | Time: 0.41s
#
# 🟠 Ridge - Stock 283/975: UFPI.O
# ✅ Finished stock UFPI.O | Time: 0.40s
#
# 🟠 Ridge - Stock 284/975: FLS
# ✅ Finished stock FLS | Time: 0.36s
#
# 🟠 Ridge - Stock 285/975: SNV
# ✅ Finished stock SNV | Time: 0.40s
#
# 🟠 Ridge - Stock 286/975: TGTX.O
# ✅ Finished stock TGTX.O | Time: 0.41s
#
# 🟠 Ridge - Stock 287/975: TFX
# ✅ Finished stock TFX | Time: 0.40s
#
# 🟠 Ridge - Stock 288/975: CELH.O
# ✅ Finished stock CELH.O | Time: 0.49s
#
# 🟠 Ridge - Stock 289/975: EAT
# ✅ Finished stock EAT | Time: 0.56s
#
# 🟠 Ridge - Stock 290/975: PEGA.O
# ✅ Finished stock PEGA.O | Time: 0.54s
#
# 🟠 Ridge - Stock 291/975: OSK
# ✅ Finished stock OSK | Time: 0.52s
#
# 🟠 Ridge - Stock 292/975: LNC
# ✅ Finished stock LNC | Time: 0.50s
#
# 🟠 Ridge - Stock 293/975: AWI
# ✅ Finished stock AWI | Time: 0.48s
#
# 🟠 Ridge - Stock 294/975: CHH
# ✅ Finished stock CHH | Time: 0.41s
#
# 🟠 Ridge - Stock 295/975: WEX
# ✅ Finished stock WEX | Time: 0.45s
#
# 🟠 Ridge - Stock 296/975: CORT.O
# ✅ Finished stock CORT.O | Time: 0.44s
#
# 🟠 Ridge - Stock 297/975: MSA
# ✅ Finished stock MSA | Time: 0.45s
#
# 🟠 Ridge - Stock 298/975: RMBS.O
# ✅ Finished stock RMBS.O | Time: 0.50s
#
# 🟠 Ridge - Stock 299/975: FCN
# ✅ Finished stock FCN | Time: 0.52s
#
# 🟠 Ridge - Stock 300/975: BMI
# ✅ Finished stock BMI | Time: 0.48s
#
# 🟠 Ridge - Stock 301/975: MMSI.O
# ✅ Finished stock MMSI.O | Time: 0.48s
#
# 🟠 Ridge - Stock 302/975: MKSI.O
# ✅ Finished stock MKSI.O | Time: 0.38s
#
# 🟠 Ridge - Stock 303/975: CACC.O
# ✅ Finished stock CACC.O | Time: 0.46s
#
# 🟠 Ridge - Stock 304/975: BYD
# ✅ Finished stock BYD | Time: 0.42s
#
# 🟠 Ridge - Stock 305/975: DDS
# ✅ Finished stock DDS | Time: 0.40s
#
# 🟠 Ridge - Stock 306/975: IDCC.O
# ✅ Finished stock IDCC.O | Time: 0.42s
#
# 🟠 Ridge - Stock 307/975: ACIW.O
# ✅ Finished stock ACIW.O | Time: 0.45s
#
# 🟠 Ridge - Stock 308/975: USM
# ✅ Finished stock USM | Time: 0.42s
#
# 🟠 Ridge - Stock 309/975: CROX.O
# ✅ Finished stock CROX.O | Time: 0.40s
#
# 🟠 Ridge - Stock 310/975: GNTX.O
# ✅ Finished stock GNTX.O | Time: 0.45s
#
# 🟠 Ridge - Stock 311/975: CRVL.O
# ✅ Finished stock CRVL.O | Time: 0.41s
#
# 🟠 Ridge - Stock 312/975: ARW
# ✅ Finished stock ARW | Time: 0.37s
#
# 🟠 Ridge - Stock 313/975: NOV
# ✅ Finished stock NOV | Time: 0.39s
#
# 🟠 Ridge - Stock 314/975: RHI
# ✅ Finished stock RHI | Time: 0.37s
#
# 🟠 Ridge - Stock 315/975: SKY
# ✅ Finished stock SKY | Time: 0.36s
#
# 🟠 Ridge - Stock 316/975: CRK
# ✅ Finished stock CRK | Time: 0.36s
#
# 🟠 Ridge - Stock 317/975: OPCH.O
# ✅ Finished stock OPCH.O | Time: 0.39s
#
# 🟠 Ridge - Stock 318/975: CGNX.O
# ✅ Finished stock CGNX.O | Time: 0.38s
#
# 🟠 Ridge - Stock 319/975: LSTR.O
# ✅ Finished stock LSTR.O | Time: 0.36s
#
# 🟠 Ridge - Stock 320/975: CRUS.O
# ✅ Finished stock CRUS.O | Time: 0.37s
#
# 🟠 Ridge - Stock 321/975: CMC
# ✅ Finished stock CMC | Time: 0.36s
#
# 🟠 Ridge - Stock 322/975: CYTK.O
# ✅ Finished stock CYTK.O | Time: 0.35s
#
# 🟠 Ridge - Stock 323/975: QXO
# ✅ Finished stock QXO | Time: 0.36s
#
# 🟠 Ridge - Stock 324/975: IONS.O
# ✅ Finished stock IONS.O | Time: 0.37s
#
# 🟠 Ridge - Stock 325/975: TKR
# ✅ Finished stock TKR | Time: 0.46s
#
# 🟠 Ridge - Stock 326/975: LFUS.O
# ✅ Finished stock LFUS.O | Time: 0.51s
#
# 🟠 Ridge - Stock 327/975: NXST.O
# ✅ Finished stock NXST.O | Time: 0.50s
#
# 🟠 Ridge - Stock 328/975: LAZ
# ✅ Finished stock LAZ | Time: 0.52s
#
# 🟠 Ridge - Stock 329/975: MTH
# ✅ Finished stock MTH | Time: 0.47s
#
# 🟠 Ridge - Stock 330/975: TXNM.K
# ✅ Finished stock TXNM.K | Time: 0.42s
#
# 🟠 Ridge - Stock 331/975: LUMN.K
# ✅ Finished stock LUMN.K | Time: 0.37s
#
# 🟠 Ridge - Stock 332/975: POR
# ✅ Finished stock POR | Time: 0.36s
#
# 🟠 Ridge - Stock 333/975: AMKR.O
# ✅ Finished stock AMKR.O | Time: 0.45s
#
# 🟠 Ridge - Stock 334/975: NSIT.O
# ✅ Finished stock NSIT.O | Time: 0.45s
#
# 🟠 Ridge - Stock 335/975: AMG
# ✅ Finished stock AMG | Time: 0.53s
#
# 🟠 Ridge - Stock 336/975: ITRI.O
# ✅ Finished stock ITRI.O | Time: 0.46s
#
# 🟠 Ridge - Stock 337/975: FSS
# ✅ Finished stock FSS | Time: 0.47s
#
# 🟠 Ridge - Stock 338/975: HXL
# ✅ Finished stock HXL | Time: 0.51s
#
# 🟠 Ridge - Stock 339/975: FELE.O
# ✅ Finished stock FELE.O | Time: 0.56s
#
# 🟠 Ridge - Stock 340/975: CNX
# ✅ Finished stock CNX | Time: 0.54s
#
# 🟠 Ridge - Stock 341/975: DY
# ✅ Finished stock DY | Time: 0.56s
#
# 🟠 Ridge - Stock 342/975: URBN.O
# ✅ Finished stock URBN.O | Time: 0.53s
#
# 🟠 Ridge - Stock 343/975: PIPR.K
# ✅ Finished stock PIPR.K | Time: 0.44s
#
# 🟠 Ridge - Stock 344/975: MOD
# ✅ Finished stock MOD | Time: 0.54s
#
# 🟠 Ridge - Stock 345/975: EEFT.O
# ✅ Finished stock EEFT.O | Time: 0.54s
#
# 🟠 Ridge - Stock 346/975: BKH
# ✅ Finished stock BKH | Time: 0.58s
#
# 🟠 Ridge - Stock 347/975: KMPR.K
# ✅ Finished stock KMPR.K | Time: 0.54s
#
# 🟠 Ridge - Stock 348/975: KBH
# ✅ Finished stock KBH | Time: 0.55s
#
# 🟠 Ridge - Stock 349/975: MSM
# ✅ Finished stock MSM | Time: 0.62s
#
# 🟠 Ridge - Stock 350/975: THO
# ✅ Finished stock THO | Time: 0.58s
#
# 🟠 Ridge - Stock 351/975: EXPO.O
# ✅ Finished stock EXPO.O | Time: 0.62s
#
# 🟠 Ridge - Stock 352/975: NNI
# ✅ Finished stock NNI | Time: 0.60s
#
# 🟠 Ridge - Stock 353/975: ESE
# ✅ Finished stock ESE | Time: 0.55s
#
# 🟠 Ridge - Stock 354/975: PBH
# ✅ Finished stock PBH | Time: 0.50s
#
# 🟠 Ridge - Stock 355/975: AVT.O
# ✅ Finished stock AVT.O | Time: 0.49s
#
# 🟠 Ridge - Stock 356/975: SANM.O
# ✅ Finished stock SANM.O | Time: 0.48s
#
# 🟠 Ridge - Stock 357/975: IPAR.O
# ✅ Finished stock IPAR.O | Time: 0.86s
#
# 🟠 Ridge - Stock 358/975: BDC
# ✅ Finished stock BDC | Time: 0.77s
#
# 🟠 Ridge - Stock 359/975: CVCO.O
# ✅ Finished stock CVCO.O | Time: 0.86s
#
# 🟠 Ridge - Stock 360/975: SLAB.O
# ✅ Finished stock SLAB.O | Time: 0.64s
#
# 🟠 Ridge - Stock 361/975: AEIS.O
# ✅ Finished stock AEIS.O | Time: 0.41s
#
# 🟠 Ridge - Stock 362/975: ANF
# ✅ Finished stock ANF | Time: 0.41s
#
# 🟠 Ridge - Stock 363/975: JWN
# ✅ Finished stock JWN | Time: 0.39s
#
# 🟠 Ridge - Stock 364/975: ITGR.K
# ✅ Finished stock ITGR.K | Time: 0.52s
#
# 🟠 Ridge - Stock 365/975: SPR
# ✅ Finished stock SPR | Time: 0.50s
#
# 🟠 Ridge - Stock 366/975: DORM.O
# ✅ Finished stock DORM.O | Time: 0.55s
#
# 🟠 Ridge - Stock 367/975: ALE
# ✅ Finished stock ALE | Time: 0.56s
#
# 🟠 Ridge - Stock 368/975: MMS
# ✅ Finished stock MMS | Time: 0.60s
#
# 🟠 Ridge - Stock 369/975: FIZZ.O
# ✅ Finished stock FIZZ.O | Time: 0.61s
#
# 🟠 Ridge - Stock 370/975: TDS
# ✅ Finished stock TDS | Time: 0.60s
#
# 🟠 Ridge - Stock 371/975: CBZ
# ✅ Finished stock CBZ | Time: 0.56s
#
# 🟠 Ridge - Stock 372/975: BCO
# ✅ Finished stock BCO | Time: 0.72s
#
# 🟠 Ridge - Stock 373/975: AVNT.K
# ✅ Finished stock AVNT.K | Time: 0.48s
#
# 🟠 Ridge - Stock 374/975: AVAV.O
# ✅ Finished stock AVAV.O | Time: 0.43s
#
# 🟠 Ridge - Stock 375/975: IESC.O
# ✅ Finished stock IESC.O | Time: 0.43s
#
# 🟠 Ridge - Stock 376/975: M
# ✅ Finished stock M | Time: 0.43s
#
# 🟠 Ridge - Stock 377/975: PRIM.K
# ✅ Finished stock PRIM.K | Time: 0.37s
#
# 🟠 Ridge - Stock 378/975: SKYW.O
# ✅ Finished stock SKYW.O | Time: 0.35s
#
# 🟠 Ridge - Stock 379/975: ICUI.O
# ✅ Finished stock ICUI.O | Time: 0.35s
#
# 🟠 Ridge - Stock 380/975: KFY
# ✅ Finished stock KFY | Time: 0.37s
#
# 🟠 Ridge - Stock 381/975: RDNT.O
# ✅ Finished stock RDNT.O | Time: 0.35s
#
# 🟠 Ridge - Stock 382/975: NWE.O
# ✅ Finished stock NWE.O | Time: 0.35s
#
# 🟠 Ridge - Stock 383/975: SM
# ✅ Finished stock SM | Time: 0.36s
#
# 🟠 Ridge - Stock 384/975: SMTC.O
# ✅ Finished stock SMTC.O | Time: 0.39s
#
# 🟠 Ridge - Stock 385/975: CCOI.O
# ✅ Finished stock CCOI.O | Time: 0.36s
#
# 🟠 Ridge - Stock 386/975: PLXS.O
# ✅ Finished stock PLXS.O | Time: 0.35s
#
# 🟠 Ridge - Stock 387/975: NSP
# ✅ Finished stock NSP | Time: 0.33s
#
# 🟠 Ridge - Stock 388/975: HAE
# ✅ Finished stock HAE | Time: 0.37s
#
# 🟠 Ridge - Stock 389/975: POWI.O
# ✅ Finished stock POWI.O | Time: 0.44s
#
# 🟠 Ridge - Stock 390/975: AVA
# ✅ Finished stock AVA | Time: 0.52s
#
# 🟠 Ridge - Stock 391/975: TNL
# ✅ Finished stock TNL | Time: 0.57s
#
# 🟠 Ridge - Stock 392/975: MHO
# ✅ Finished stock MHO | Time: 0.53s
#
# 🟠 Ridge - Stock 393/975: DXC
# ✅ Finished stock DXC | Time: 0.57s
#
# 🟠 Ridge - Stock 394/975: BLKB.O
# ✅ Finished stock BLKB.O | Time: 0.38s
#
# 🟠 Ridge - Stock 395/975: XRAY.O
# ✅ Finished stock XRAY.O | Time: 0.36s
#
# 🟠 Ridge - Stock 396/975: OSIS.O
# ✅ Finished stock OSIS.O | Time: 0.39s
#
# 🟠 Ridge - Stock 397/975: HOG
# ✅ Finished stock HOG | Time: 0.39s
#
# 🟠 Ridge - Stock 398/975: PTEN.O
# ✅ Finished stock PTEN.O | Time: 0.34s
#
# 🟠 Ridge - Stock 399/975: AMED.O
# ✅ Finished stock AMED.O | Time: 0.34s
#
# 🟠 Ridge - Stock 400/975: ASGN.K
# ✅ Finished stock ASGN.K | Time: 0.38s
#
# 🟠 Ridge - Stock 401/975: CPK
# ✅ Finished stock CPK | Time: 0.40s
#
# 🟠 Ridge - Stock 402/975: ACAD.O
# ✅ Finished stock ACAD.O | Time: 0.35s
#
# 🟠 Ridge - Stock 403/975: NOG
# ✅ Finished stock NOG | Time: 0.35s
#
# 🟠 Ridge - Stock 404/975: FUL
# ✅ Finished stock FUL | Time: 0.35s
#
# 🟠 Ridge - Stock 405/975: PATK.O
# ✅ Finished stock PATK.O | Time: 0.34s
#
# 🟠 Ridge - Stock 406/975: TGNA.K
# ✅ Finished stock TGNA.K | Time: 0.37s
#
# 🟠 Ridge - Stock 407/975: MAN
# ✅ Finished stock MAN | Time: 0.38s
#
# 🟠 Ridge - Stock 408/975: MGRC.O
# ✅ Finished stock MGRC.O | Time: 0.36s
#
# 🟠 Ridge - Stock 409/975: GNW
# ✅ Finished stock GNW | Time: 0.39s
#
# 🟠 Ridge - Stock 410/975: PDCO.O
# ✅ Finished stock PDCO.O | Time: 0.38s
#
# 🟠 Ridge - Stock 411/975: NWL.O
# ✅ Finished stock NWL.O | Time: 0.37s
#
# 🟠 Ridge - Stock 412/975: GEF
# ✅ Finished stock GEF | Time: 0.36s
#
# 🟠 Ridge - Stock 413/975: GSAT.O
# ✅ Finished stock GSAT.O | Time: 0.34s
#
# 🟠 Ridge - Stock 414/975: TEX
# ✅ Finished stock TEX | Time: 0.33s
#
# 🟠 Ridge - Stock 415/975: IPGP.O
# ✅ Finished stock IPGP.O | Time: 0.36s
#
# 🟠 Ridge - Stock 416/975: PENN.O
# ✅ Finished stock PENN.O | Time: 0.36s
#
# 🟠 Ridge - Stock 417/975: JOE
# ✅ Finished stock JOE | Time: 0.45s
#
# 🟠 Ridge - Stock 418/975: HURN.O
# ✅ Finished stock HURN.O | Time: 0.37s
#
# 🟠 Ridge - Stock 419/975: JJSF.O
# ✅ Finished stock JJSF.O | Time: 0.35s
#
# 🟠 Ridge - Stock 420/975: GT.O
# ✅ Finished stock GT.O | Time: 0.35s
#
# 🟠 Ridge - Stock 421/975: SAM
# ✅ Finished stock SAM | Time: 0.40s
#
# 🟠 Ridge - Stock 422/975: HP
# ✅ Finished stock HP | Time: 0.37s
#
# 🟠 Ridge - Stock 423/975: PSMT.O
# ✅ Finished stock PSMT.O | Time: 0.43s
#
# 🟠 Ridge - Stock 424/975: CPRX.O
# ✅ Finished stock CPRX.O | Time: 0.38s
#
# 🟠 Ridge - Stock 425/975: FORM.O
# ✅ Finished stock FORM.O | Time: 0.35s
#
# 🟠 Ridge - Stock 426/975: SYNA.O
# ✅ Finished stock SYNA.O | Time: 0.35s
#
# 🟠 Ridge - Stock 427/975: QDEL.O
# ✅ Finished stock QDEL.O | Time: 0.35s
#
# 🟠 Ridge - Stock 428/975: VIAV.O
# ✅ Finished stock VIAV.O | Time: 0.34s
#
# 🟠 Ridge - Stock 429/975: VICR.O
# ✅ Finished stock VICR.O | Time: 0.34s
#
# 🟠 Ridge - Stock 430/975: BFH
# ✅ Finished stock BFH | Time: 0.45s
#
# 🟠 Ridge - Stock 431/975: PRGS.O
# ✅ Finished stock PRGS.O | Time: 0.51s
#
# 🟠 Ridge - Stock 432/975: TRN
# ✅ Finished stock TRN | Time: 0.47s
#
# 🟠 Ridge - Stock 433/975: CAKE.O
# ✅ Finished stock CAKE.O | Time: 0.50s
#
# 🟠 Ridge - Stock 434/975: WLY
# ✅ Finished stock WLY | Time: 0.48s
#
# 🟠 Ridge - Stock 435/975: PAR
# ✅ Finished stock PAR | Time: 0.50s
#
# 🟠 Ridge - Stock 436/975: VSEC.O
# ✅ Finished stock VSEC.O | Time: 0.38s
#
# 🟠 Ridge - Stock 437/975: LCII.K
# ✅ Finished stock LCII.K | Time: 0.36s
#
# 🟠 Ridge - Stock 438/975: AIN
# ✅ Finished stock AIN | Time: 0.37s
#
# 🟠 Ridge - Stock 439/975: HUBG.O
# ✅ Finished stock HUBG.O | Time: 0.37s
#
# 🟠 Ridge - Stock 440/975: VCEL.O
# ✅ Finished stock VCEL.O | Time: 0.36s
#
# 🟠 Ridge - Stock 441/975: AAP
# ✅ Finished stock AAP | Time: 0.35s
#
# 🟠 Ridge - Stock 442/975: ALG
# ✅ Finished stock ALG | Time: 0.37s
#
# 🟠 Ridge - Stock 443/975: OII
# ✅ Finished stock OII | Time: 0.40s
#
# 🟠 Ridge - Stock 444/975: TTMI.O
# ✅ Finished stock TTMI.O | Time: 0.35s
#
# 🟠 Ridge - Stock 445/975: CXW
# ✅ Finished stock CXW | Time: 0.40s
#
# 🟠 Ridge - Stock 446/975: SSRM.O
# ✅ Finished stock SSRM.O | Time: 0.38s
#
# 🟠 Ridge - Stock 447/975: DIOD.O
# ✅ Finished stock DIOD.O | Time: 0.40s
#
# 🟠 Ridge - Stock 448/975: AEO
# ✅ Finished stock AEO | Time: 0.44s
#
# 🟠 Ridge - Stock 449/975: ARWR.O
# ✅ Finished stock ARWR.O | Time: 0.45s
#
# 🟠 Ridge - Stock 450/975: WMK
# ✅ Finished stock WMK | Time: 0.42s
#
# 🟠 Ridge - Stock 451/975: AGYS.O
# ✅ Finished stock AGYS.O | Time: 0.36s
#
# 🟠 Ridge - Stock 452/975: LGFa
# ✅ Finished stock LGFa | Time: 0.36s
#
# 🟠 Ridge - Stock 453/975: LGND.O
# ✅ Finished stock LGND.O | Time: 0.35s
#
# 🟠 Ridge - Stock 454/975: HNI
# ✅ Finished stock HNI | Time: 0.38s
#
# 🟠 Ridge - Stock 455/975: JBLU.O
# ✅ Finished stock JBLU.O | Time: 0.36s
#
# 🟠 Ridge - Stock 456/975: NEOG.O
# ✅ Finished stock NEOG.O | Time: 0.37s
#
# 🟠 Ridge - Stock 457/975: HE
# ✅ Finished stock HE | Time: 0.37s
#
# 🟠 Ridge - Stock 458/975: EXTR.O
# ✅ Finished stock EXTR.O | Time: 0.34s
#
# 🟠 Ridge - Stock 459/975: ACLS.O
# ✅ Finished stock ACLS.O | Time: 0.34s
#
# 🟠 Ridge - Stock 460/975: WERN.O
# ✅ Finished stock WERN.O | Time: 0.34s
#
# 🟠 Ridge - Stock 461/975: LMAT.O
# ✅ Finished stock LMAT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 462/975: CENX.O
# ✅ Finished stock CENX.O | Time: 0.33s
#
# 🟠 Ridge - Stock 463/975: BKE
# ✅ Finished stock BKE | Time: 0.34s
#
# 🟠 Ridge - Stock 464/975: CNMD.K
# ✅ Finished stock CNMD.K | Time: 0.35s
#
# 🟠 Ridge - Stock 465/975: OI
# ✅ Finished stock OI | Time: 0.39s
#
# 🟠 Ridge - Stock 466/975: CSGS.O
# ✅ Finished stock CSGS.O | Time: 0.34s
#
# 🟠 Ridge - Stock 467/975: RAMP.K
# ✅ Finished stock RAMP.K | Time: 0.44s
#
# 🟠 Ridge - Stock 468/975: IART.O
# ✅ Finished stock IART.O | Time: 0.42s
#
# 🟠 Ridge - Stock 469/975: ZD.O
# ✅ Finished stock ZD.O | Time: 0.44s
#
# 🟠 Ridge - Stock 470/975: PBI
# ✅ Finished stock PBI | Time: 0.39s
#
# 🟠 Ridge - Stock 471/975: GBX
# ✅ Finished stock GBX | Time: 0.55s
#
# 🟠 Ridge - Stock 472/975: DVAX.O
# ✅ Finished stock DVAX.O | Time: 0.66s
#
# 🟠 Ridge - Stock 473/975: PLUS.O
# ✅ Finished stock PLUS.O | Time: 0.51s
#
# 🟠 Ridge - Stock 474/975: AZTA.O
# ✅ Finished stock AZTA.O | Time: 0.64s
#
# 🟠 Ridge - Stock 475/975: KMT
# ✅ Finished stock KMT | Time: 0.58s
#
# 🟠 Ridge - Stock 476/975: ATRC.O
# ✅ Finished stock ATRC.O | Time: 0.55s
#
# 🟠 Ridge - Stock 477/975: UFPT.O
# ✅ Finished stock UFPT.O | Time: 0.76s
#
# 🟠 Ridge - Stock 478/975: UNFI.K
# ✅ Finished stock UNFI.K | Time: 0.51s
#
# 🟠 Ridge - Stock 479/975: BCRX.O
# ✅ Finished stock BCRX.O | Time: 0.50s
#
# 🟠 Ridge - Stock 480/975: STGW.O
# ✅ Finished stock STGW.O | Time: 0.53s
#
# 🟠 Ridge - Stock 481/975: WKC
# ✅ Finished stock WKC | Time: 0.49s
#
# 🟠 Ridge - Stock 482/975: MNKD.O
# ✅ Finished stock MNKD.O | Time: 0.39s
#
# 🟠 Ridge - Stock 483/975: MCRI.O
# ✅ Finished stock MCRI.O | Time: 0.42s
#
# 🟠 Ridge - Stock 484/975: APLD.O
# ✅ Finished stock APLD.O | Time: 0.39s
#
# 🟠 Ridge - Stock 485/975: SRCE.O
# ✅ Finished stock SRCE.O | Time: 0.42s
#
# 🟠 Ridge - Stock 486/975: OMCL.O
# ✅ Finished stock OMCL.O | Time: 0.49s
#
# 🟠 Ridge - Stock 487/975: INOD.O
# ✅ Finished stock INOD.O | Time: 0.36s
#
# 🟠 Ridge - Stock 488/975: FL
# ✅ Finished stock FL | Time: 0.40s
#
# 🟠 Ridge - Stock 489/975: NTCT.O
# ✅ Finished stock NTCT.O | Time: 0.43s
#
# 🟠 Ridge - Stock 490/975: EPC
# ✅ Finished stock EPC | Time: 0.35s
#
# 🟠 Ridge - Stock 491/975: ATSG.O
# ✅ Finished stock ATSG.O | Time: 0.35s
#
# 🟠 Ridge - Stock 492/975: ADEA.O
# ✅ Finished stock ADEA.O | Time: 0.37s
#
# 🟠 Ridge - Stock 493/975: ROG
# ✅ Finished stock ROG | Time: 0.38s
#
# 🟠 Ridge - Stock 494/975: NHC
# ✅ Finished stock NHC | Time: 0.37s
#
# 🟠 Ridge - Stock 495/975: LNN
# ✅ Finished stock LNN | Time: 0.38s
#
# 🟠 Ridge - Stock 496/975: PZZA.O
# ✅ Finished stock PZZA.O | Time: 0.42s
#
# 🟠 Ridge - Stock 497/975: BHE
# ✅ Finished stock BHE | Time: 0.41s
#
# 🟠 Ridge - Stock 498/975: UPBD.O
# ✅ Finished stock UPBD.O | Time: 0.36s
#
# 🟠 Ridge - Stock 499/975: ANIP.O
# ✅ Finished stock ANIP.O | Time: 0.37s
#
# 🟠 Ridge - Stock 500/975: CLDX.O
# ✅ Finished stock CLDX.O | Time: 0.36s
#
# 🟠 Ridge - Stock 501/975: VRNT.O
# ✅ Finished stock VRNT.O | Time: 0.34s
#
# 🟠 Ridge - Stock 502/975: PLAB.O
# ✅ Finished stock PLAB.O | Time: 0.34s
#
# 🟠 Ridge - Stock 503/975: VYX
# ✅ Finished stock VYX | Time: 0.33s
#
# 🟠 Ridge - Stock 504/975: DXPE.O
# ✅ Finished stock DXPE.O | Time: 0.40s
#
# 🟠 Ridge - Stock 505/975: ATEC.O
# ✅ Finished stock ATEC.O | Time: 0.35s
#
# 🟠 Ridge - Stock 506/975: NVAX.O
# ✅ Finished stock NVAX.O | Time: 0.35s
#
# 🟠 Ridge - Stock 507/975: CTS
# ✅ Finished stock CTS | Time: 0.33s
#
# 🟠 Ridge - Stock 508/975: VSAT.O
# ✅ Finished stock VSAT.O | Time: 0.48s
#
# 🟠 Ridge - Stock 509/975: NEO.O
# ✅ Finished stock NEO.O | Time: 0.49s
#
# 🟠 Ridge - Stock 510/975: WT
# ✅ Finished stock WT | Time: 0.49s
#
# 🟠 Ridge - Stock 511/975: SCS
# ✅ Finished stock SCS | Time: 0.50s
#
# 🟠 Ridge - Stock 512/975: VECO.O
# ✅ Finished stock VECO.O | Time: 0.43s
#
# 🟠 Ridge - Stock 513/975: INVX.K
# ✅ Finished stock INVX.K | Time: 0.39s
#
# 🟠 Ridge - Stock 514/975: DCOM.O
# ✅ Finished stock DCOM.O | Time: 0.34s
#
# 🟠 Ridge - Stock 515/975: EIG
# ✅ Finished stock EIG | Time: 0.37s
#
# 🟠 Ridge - Stock 516/975: HLIT.O
# ✅ Finished stock HLIT.O | Time: 0.37s
#
# 🟠 Ridge - Stock 517/975: HLX
# ✅ Finished stock HLX | Time: 0.35s
#
# 🟠 Ridge - Stock 518/975: IDT
# ✅ Finished stock IDT | Time: 0.33s
#
# 🟠 Ridge - Stock 519/975: BLFS.O
# ✅ Finished stock BLFS.O | Time: 0.33s
#
# 🟠 Ridge - Stock 520/975: GIII.O
# ✅ Finished stock GIII.O | Time: 0.33s
#
# 🟠 Ridge - Stock 521/975: CRAI.O
# ✅ Finished stock CRAI.O | Time: 0.32s
#
# 🟠 Ridge - Stock 522/975: IMKTA.O
# ✅ Finished stock IMKTA.O | Time: 0.34s
#
# 🟠 Ridge - Stock 523/975: OPK.O
# ✅ Finished stock OPK.O | Time: 0.36s
#
# 🟠 Ridge - Stock 524/975: SAFT.O
# ✅ Finished stock SAFT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 525/975: RES
# ✅ Finished stock RES | Time: 0.38s
#
# 🟠 Ridge - Stock 526/975: UCTT.O
# ✅ Finished stock UCTT.O | Time: 0.37s
#
# 🟠 Ridge - Stock 527/975: GYRE.O
# ✅ Finished stock GYRE.O | Time: 0.34s
#
# 🟠 Ridge - Stock 528/975: MODG.K
# ✅ Finished stock MODG.K | Time: 0.34s
#
# 🟠 Ridge - Stock 529/975: TILE.O
# ✅ Finished stock TILE.O | Time: 0.34s
#
# 🟠 Ridge - Stock 530/975: MSEX.O
# ✅ Finished stock MSEX.O | Time: 0.33s
#
# 🟠 Ridge - Stock 531/975: MRTN.O
# ✅ Finished stock MRTN.O | Time: 0.32s
#
# 🟠 Ridge - Stock 532/975: PRG
# ✅ Finished stock PRG | Time: 0.32s
#
# 🟠 Ridge - Stock 533/975: INVA.O
# ✅ Finished stock INVA.O | Time: 0.33s
#
# 🟠 Ridge - Stock 534/975: DGII.O
# ✅ Finished stock DGII.O | Time: 0.32s
#
# 🟠 Ridge - Stock 535/975: APOG.O
# ✅ Finished stock APOG.O | Time: 0.33s
#
# 🟠 Ridge - Stock 536/975: GERN.O
# ✅ Finished stock GERN.O | Time: 0.33s
#
# 🟠 Ridge - Stock 537/975: CLMT.O
# ✅ Finished stock CLMT.O | Time: 0.34s
#
# 🟠 Ridge - Stock 538/975: BBSI.O
# ✅ Finished stock BBSI.O | Time: 0.33s
#
# 🟠 Ridge - Stock 539/975: WGO
# ✅ Finished stock WGO | Time: 0.36s
#
# 🟠 Ridge - Stock 540/975: AMN
# ✅ Finished stock AMN | Time: 0.36s
#
# 🟠 Ridge - Stock 541/975: AORT.K
# ✅ Finished stock AORT.K | Time: 0.40s
#
# 🟠 Ridge - Stock 542/975: ALGT.O
# ✅ Finished stock ALGT.O | Time: 0.41s
#
# 🟠 Ridge - Stock 543/975: SBGI.O
# ✅ Finished stock SBGI.O | Time: 0.47s
#
# 🟠 Ridge - Stock 544/975: GRC
# ✅ Finished stock GRC | Time: 0.40s
#
# 🟠 Ridge - Stock 545/975: AMSF.O
# ✅ Finished stock AMSF.O | Time: 0.41s
#
# 🟠 Ridge - Stock 546/975: KFRC.K
# ✅ Finished stock KFRC.K | Time: 0.42s
#
# 🟠 Ridge - Stock 547/975: BELFA.O
# ✅ Finished stock BELFA.O | Time: 0.39s
#
# 🟠 Ridge - Stock 548/975: THRM.O
# ✅ Finished stock THRM.O | Time: 0.44s
#
# 🟠 Ridge - Stock 549/975: LQDT.O
# ✅ Finished stock LQDT.O | Time: 0.42s
#
# 🟠 Ridge - Stock 550/975: MYGN.O
# ✅ Finished stock MYGN.O | Time: 0.43s
#
# 🟠 Ridge - Stock 551/975: NSSC.O
# ✅ Finished stock NSSC.O | Time: 0.57s
#
# 🟠 Ridge - Stock 552/975: UTL
# ✅ Finished stock UTL | Time: 0.51s
#
# 🟠 Ridge - Stock 553/975: WOLF.K
# ✅ Finished stock WOLF.K | Time: 0.52s
#
# 🟠 Ridge - Stock 554/975: KSS
# ✅ Finished stock KSS | Time: 0.68s
#
# 🟠 Ridge - Stock 555/975: CBRL.O
# ✅ Finished stock CBRL.O | Time: 0.55s
#
# 🟠 Ridge - Stock 556/975: DCO
# ✅ Finished stock DCO | Time: 0.38s
#
# 🟠 Ridge - Stock 557/975: ATRO.O
# ✅ Finished stock ATRO.O | Time: 0.33s
#
# 🟠 Ridge - Stock 558/975: HSII.O
# ✅ Finished stock HSII.O | Time: 0.33s
#
# 🟠 Ridge - Stock 559/975: GIC
# ✅ Finished stock GIC | Time: 0.40s
#
# 🟠 Ridge - Stock 560/975: PDFS.O
# ✅ Finished stock PDFS.O | Time: 0.43s
#
# 🟠 Ridge - Stock 561/975: SCSC.O
# ✅ Finished stock SCSC.O | Time: 0.40s
#
# 🟠 Ridge - Stock 562/975: STAA.O
# ✅ Finished stock STAA.O | Time: 0.38s
#
# 🟠 Ridge - Stock 563/975: ASTE.O
# ✅ Finished stock ASTE.O | Time: 0.35s
#
# 🟠 Ridge - Stock 564/975: CECO.O
# ✅ Finished stock CECO.O | Time: 0.37s
#
# 🟠 Ridge - Stock 565/975: ECPG.O
# ✅ Finished stock ECPG.O | Time: 0.35s
#
# 🟠 Ridge - Stock 566/975: PRA
# ✅ Finished stock PRA | Time: 0.34s
#
# 🟠 Ridge - Stock 567/975: AVXL.O
# ✅ Finished stock AVXL.O | Time: 0.34s
#
# 🟠 Ridge - Stock 568/975: COHU.O
# ✅ Finished stock COHU.O | Time: 0.36s
#
# 🟠 Ridge - Stock 569/975: AMSC.O
# ✅ Finished stock AMSC.O | Time: 0.39s
#
# 🟠 Ridge - Stock 570/975: HCKT.O
# ✅ Finished stock HCKT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 571/975: AIOT.O
# ✅ Finished stock AIOT.O | Time: 0.40s
#
# 🟠 Ridge - Stock 572/975: PRAA.O
# ✅ Finished stock PRAA.O | Time: 0.46s
#
# 🟠 Ridge - Stock 573/975: AXGN.O
# ✅ Finished stock AXGN.O | Time: 0.42s
#
# 🟠 Ridge - Stock 574/975: OSBC.O
# ✅ Finished stock OSBC.O | Time: 0.41s
#
# 🟠 Ridge - Stock 575/975: UFCS.O
# ✅ Finished stock UFCS.O | Time: 0.36s
#
# 🟠 Ridge - Stock 576/975: BJRI.O
# ✅ Finished stock BJRI.O | Time: 0.34s
#
# 🟠 Ridge - Stock 577/975: ADTN.O
# ✅ Finished stock ADTN.O | Time: 0.35s
#
# 🟠 Ridge - Stock 578/975: XRX.O
# ✅ Finished stock XRX.O | Time: 0.34s
#
# 🟠 Ridge - Stock 579/975: OMI
# ✅ Finished stock OMI | Time: 0.43s
#
# 🟠 Ridge - Stock 580/975: PLPC.O
# ✅ Finished stock PLPC.O | Time: 0.38s
#
# 🟠 Ridge - Stock 581/975: CLB
# ✅ Finished stock CLB | Time: 0.37s
#
# 🟠 Ridge - Stock 582/975: FCBC.O
# ✅ Finished stock FCBC.O | Time: 0.38s
#
# 🟠 Ridge - Stock 583/975: SSYS.O
# ✅ Finished stock SSYS.O | Time: 0.34s
#
# 🟠 Ridge - Stock 584/975: WRLD.O
# ✅ Finished stock WRLD.O | Time: 0.34s
#
# 🟠 Ridge - Stock 585/975: RBBN.O
# ✅ Finished stock RBBN.O | Time: 0.33s
#
# 🟠 Ridge - Stock 586/975: NTGR.O
# ✅ Finished stock NTGR.O | Time: 0.35s
#
# 🟠 Ridge - Stock 587/975: MLAB.O
# ✅ Finished stock MLAB.O | Time: 0.37s
#
# 🟠 Ridge - Stock 588/975: ETD
# ✅ Finished stock ETD | Time: 0.35s
#
# 🟠 Ridge - Stock 589/975: MAGN.K
# ✅ Finished stock MAGN.K | Time: 0.34s
#
# 🟠 Ridge - Stock 590/975: SPTN.O
# ✅ Finished stock SPTN.O | Time: 0.33s
#
# 🟠 Ridge - Stock 591/975: TRNS.O
# ✅ Finished stock TRNS.O | Time: 0.38s
#
# 🟠 Ridge - Stock 592/975: SHEN.O
# ✅ Finished stock SHEN.O | Time: 0.46s
#
# 🟠 Ridge - Stock 593/975: BXC
# ✅ Finished stock BXC | Time: 0.42s
#
# 🟠 Ridge - Stock 594/975: BZH
# ✅ Finished stock BZH | Time: 0.43s
#
# 🟠 Ridge - Stock 595/975: OFIX.O
# ✅ Finished stock OFIX.O | Time: 0.49s
#
# 🟠 Ridge - Stock 596/975: HOV
# ✅ Finished stock HOV | Time: 0.47s
#
# 🟠 Ridge - Stock 597/975: OPY
# ✅ Finished stock OPY | Time: 0.34s
#
# 🟠 Ridge - Stock 598/975: REPX.K
# ✅ Finished stock REPX.K | Time: 0.35s
#
# 🟠 Ridge - Stock 599/975: CVLG.K
# ✅ Finished stock CVLG.K | Time: 0.34s
#
# 🟠 Ridge - Stock 600/975: OSPN.O
# ✅ Finished stock OSPN.O | Time: 0.34s
#
# 🟠 Ridge - Stock 601/975: FWRD.O
# ✅ Finished stock FWRD.O | Time: 0.33s
#
# 🟠 Ridge - Stock 602/975: SCVL.O
# ✅ Finished stock SCVL.O | Time: 0.32s
#
# 🟠 Ridge - Stock 603/975: JACK.O
# ✅ Finished stock JACK.O | Time: 0.33s
#
# 🟠 Ridge - Stock 604/975: SENEA.O
# ✅ Finished stock SENEA.O | Time: 0.34s
#
# 🟠 Ridge - Stock 605/975: WLDN.O
# ✅ Finished stock WLDN.O | Time: 0.33s
#
# 🟠 Ridge - Stock 606/975: CASS.O
# ✅ Finished stock CASS.O | Time: 0.33s
#
# 🟠 Ridge - Stock 607/975: SMP
# ✅ Finished stock SMP | Time: 0.32s
#
# 🟠 Ridge - Stock 608/975: CTLP.O
# ✅ Finished stock CTLP.O | Time: 0.34s
#
# 🟠 Ridge - Stock 609/975: FARO.O
# ✅ Finished stock FARO.O | Time: 0.32s
#
# 🟠 Ridge - Stock 610/975: EBF
# ✅ Finished stock EBF | Time: 0.32s
#
# 🟠 Ridge - Stock 611/975: USNA.K
# ✅ Finished stock USNA.K | Time: 0.32s
#
# 🟠 Ridge - Stock 612/975: SCHL.O
# ✅ Finished stock SCHL.O | Time: 0.32s
#
# 🟠 Ridge - Stock 613/975: DJCO.O
# ✅ Finished stock DJCO.O | Time: 0.33s
#
# 🟠 Ridge - Stock 614/975: NPKI.K
# ✅ Finished stock NPKI.K | Time: 0.32s
#
# 🟠 Ridge - Stock 615/975: AXL
# ✅ Finished stock AXL | Time: 0.33s
#
# 🟠 Ridge - Stock 616/975: CMCO.O
# ✅ Finished stock CMCO.O | Time: 0.33s
#
# 🟠 Ridge - Stock 617/975: SLP.O
# ✅ Finished stock SLP.O | Time: 0.33s
#
# 🟠 Ridge - Stock 618/975: CRDb
# ✅ Finished stock CRDb | Time: 0.33s
#
# 🟠 Ridge - Stock 619/975: TWI
# ✅ Finished stock TWI | Time: 0.33s
#
# 🟠 Ridge - Stock 620/975: HZO
# ✅ Finished stock HZO | Time: 0.33s
#
# 🟠 Ridge - Stock 621/975: CLMB.O
# ✅ Finished stock CLMB.O | Time: 0.33s
#
# 🟠 Ridge - Stock 622/975: MLR
# ✅ Finished stock MLR | Time: 0.32s
#
# 🟠 Ridge - Stock 623/975: CCRN.O
# ✅ Finished stock CCRN.O | Time: 0.32s
#
# 🟠 Ridge - Stock 624/975: YORW.O
# ✅ Finished stock YORW.O | Time: 0.33s
#
# 🟠 Ridge - Stock 625/975: BBW
# ✅ Finished stock BBW | Time: 0.33s
#
# 🟠 Ridge - Stock 626/975: VLGEA.O
# ✅ Finished stock VLGEA.O | Time: 0.32s
#
# 🟠 Ridge - Stock 627/975: LGTY.O
# ✅ Finished stock LGTY.O | Time: 0.33s
#
# 🟠 Ridge - Stock 628/975: PBT
# ✅ Finished stock PBT | Time: 0.34s
#
# 🟠 Ridge - Stock 629/975: MYE
# ✅ Finished stock MYE | Time: 0.35s
#
# 🟠 Ridge - Stock 630/975: WNC
# ✅ Finished stock WNC | Time: 0.35s
#
# 🟠 Ridge - Stock 631/975: GTN
# ✅ Finished stock GTN | Time: 0.38s
#
# 🟠 Ridge - Stock 632/975: KELYA.O
# ✅ Finished stock KELYA.O | Time: 0.38s
#
# 🟠 Ridge - Stock 633/975: ALRS.O
# ✅ Finished stock ALRS.O | Time: 0.37s
#
# 🟠 Ridge - Stock 634/975: ALT.O
# ✅ Finished stock ALT.O | Time: 0.39s
#
# 🟠 Ridge - Stock 635/975: EGY
# ✅ Finished stock EGY | Time: 0.35s
#
# 🟠 Ridge - Stock 636/975: EYPT.O
# ✅ Finished stock EYPT.O | Time: 0.35s
#
# 🟠 Ridge - Stock 637/975: SVRA.O
# ✅ Finished stock SVRA.O | Time: 0.44s
#
# 🟠 Ridge - Stock 638/975: TTI
# ✅ Finished stock TTI | Time: 0.46s
#
# 🟠 Ridge - Stock 639/975: CLFD.O
# ✅ Finished stock CLFD.O | Time: 0.48s
#
# 🟠 Ridge - Stock 640/975: NWPX.O
# ✅ Finished stock NWPX.O | Time: 0.61s
#
# 🟠 Ridge - Stock 641/975: ORKA.O
# ✅ Finished stock ORKA.O | Time: 0.56s
#
# 🟠 Ridge - Stock 642/975: DHIL.O
# ✅ Finished stock DHIL.O | Time: 0.37s
#
# 🟠 Ridge - Stock 643/975: MITK.O
# ✅ Finished stock MITK.O | Time: 0.41s
#
# 🟠 Ridge - Stock 644/975: SRDX.O
# ✅ Finished stock SRDX.O | Time: 0.42s
#
# 🟠 Ridge - Stock 645/975: FC
# ✅ Finished stock FC | Time: 0.37s
#
# 🟠 Ridge - Stock 646/975: NUS
# ✅ Finished stock NUS | Time: 0.35s
#
# 🟠 Ridge - Stock 647/975: GCBC.O
# ✅ Finished stock GCBC.O | Time: 0.40s
#
# 🟠 Ridge - Stock 648/975: TBRG.O
# ✅ Finished stock TBRG.O | Time: 0.43s
#
# 🟠 Ridge - Stock 649/975: SIGA.O
# ✅ Finished stock SIGA.O | Time: 0.43s
#
# 🟠 Ridge - Stock 650/975: ALNT.O
# ✅ Finished stock ALNT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 651/975: DIN
# ✅ Finished stock DIN | Time: 0.36s
#
# 🟠 Ridge - Stock 652/975: NATH.O
# ✅ Finished stock NATH.O | Time: 0.36s
#
# 🟠 Ridge - Stock 653/975: VALU.O
# ✅ Finished stock VALU.O | Time: 0.38s
#
# 🟠 Ridge - Stock 654/975: ZEUS.O
# ✅ Finished stock ZEUS.O | Time: 0.37s
#
# 🟠 Ridge - Stock 655/975: ANGO.O
# ✅ Finished stock ANGO.O | Time: 0.36s
#
# 🟠 Ridge - Stock 656/975: RIGL.O
# ✅ Finished stock RIGL.O | Time: 0.38s
#
# 🟠 Ridge - Stock 657/975: TRAK.K
# ✅ Finished stock TRAK.K | Time: 0.39s
#
# 🟠 Ridge - Stock 658/975: HRTX.O
# ✅ Finished stock HRTX.O | Time: 0.38s
#
# 🟠 Ridge - Stock 659/975: DDD
# ✅ Finished stock DDD | Time: 0.39s
#
# 🟠 Ridge - Stock 660/975: APPS.O
# ✅ Finished stock APPS.O | Time: 0.38s
#
# 🟠 Ridge - Stock 661/975: MSB
# ✅ Finished stock MSB | Time: 0.38s
#
# 🟠 Ridge - Stock 662/975: PNRG.O
# ✅ Finished stock PNRG.O | Time: 0.37s
#
# 🟠 Ridge - Stock 663/975: ACTG.O
# ✅ Finished stock ACTG.O | Time: 0.36s
#
# 🟠 Ridge - Stock 664/975: HVT
# ✅ Finished stock HVT | Time: 0.38s
#
# 🟠 Ridge - Stock 665/975: ATNI.O
# ✅ Finished stock ATNI.O | Time: 0.36s
#
# 🟠 Ridge - Stock 666/975: MTW
# ✅ Finished stock MTW | Time: 0.34s
#
# 🟠 Ridge - Stock 667/975: MATV.K
# ✅ Finished stock MATV.K | Time: 0.35s
#
# 🟠 Ridge - Stock 668/975: SPOK.O
# ✅ Finished stock SPOK.O | Time: 0.33s
#
# 🟠 Ridge - Stock 669/975: SHYF.O
# ✅ Finished stock SHYF.O | Time: 0.38s
#
# 🟠 Ridge - Stock 670/975: NEWT.O
# ✅ Finished stock NEWT.O | Time: 0.35s
#
# 🟠 Ridge - Stock 671/975: CYRX.O
# ✅ Finished stock CYRX.O | Time: 0.36s
#
# 🟠 Ridge - Stock 672/975: NVEC.O
# ✅ Finished stock NVEC.O | Time: 0.37s
#
# 🟠 Ridge - Stock 673/975: EBS
# ✅ Finished stock EBS | Time: 0.35s
#
# 🟠 Ridge - Stock 674/975: OIS
# ✅ Finished stock OIS | Time: 0.37s
#
# 🟠 Ridge - Stock 675/975: RLGT.K
# ✅ Finished stock RLGT.K | Time: 0.36s
#
# 🟠 Ridge - Stock 676/975: BYON.K
# ✅ Finished stock BYON.K | Time: 0.44s
#
# 🟠 Ridge - Stock 677/975: MVIS.O
# ✅ Finished stock MVIS.O | Time: 0.45s
#
# 🟠 Ridge - Stock 678/975: UIS
# ✅ Finished stock UIS | Time: 0.53s
#
# 🟠 Ridge - Stock 679/975: CDZI.O
# ✅ Finished stock CDZI.O | Time: 0.49s
#
# 🟠 Ridge - Stock 680/975: VNDA.O
# ✅ Finished stock VNDA.O | Time: 0.52s
#
# 🟠 Ridge - Stock 681/975: NGS
# ✅ Finished stock NGS | Time: 0.58s
#
# 🟠 Ridge - Stock 682/975: EGHT.O
# ✅ Finished stock EGHT.O | Time: 0.44s
#
# 🟠 Ridge - Stock 683/975: PAMT.O
# ✅ Finished stock PAMT.O | Time: 0.47s
#
# 🟠 Ridge - Stock 684/975: FNLC.O
# ✅ Finished stock FNLC.O | Time: 0.40s
#
# 🟠 Ridge - Stock 685/975: AEHR.O
# ✅ Finished stock AEHR.O | Time: 0.42s
#
# 🟠 Ridge - Stock 686/975: MOV
# ✅ Finished stock MOV | Time: 0.41s
#
# 🟠 Ridge - Stock 687/975: JAKK.O
# ✅ Finished stock JAKK.O | Time: 0.39s
#
# 🟠 Ridge - Stock 688/975: FLIC.O
# ✅ Finished stock FLIC.O | Time: 0.40s
#
# 🟠 Ridge - Stock 689/975: CERS.O
# ✅ Finished stock CERS.O | Time: 0.36s
#
# 🟠 Ridge - Stock 690/975: PKE
# ✅ Finished stock PKE | Time: 0.36s
#
# 🟠 Ridge - Stock 691/975: CRDF.O
# ✅ Finished stock CRDF.O | Time: 0.36s
#
# 🟠 Ridge - Stock 692/975: LFMD.O
# ✅ Finished stock LFMD.O | Time: 0.40s
#
# 🟠 Ridge - Stock 693/975: OSUR.O
# ✅ Finished stock OSUR.O | Time: 0.39s
#
# 🟠 Ridge - Stock 694/975: JOUT.O
# ✅ Finished stock JOUT.O | Time: 0.34s
#
# 🟠 Ridge - Stock 695/975: ASUR.O
# ✅ Finished stock ASUR.O | Time: 0.34s
#
# 🟠 Ridge - Stock 696/975: PCYO.O
# ✅ Finished stock PCYO.O | Time: 0.35s
#
# 🟠 Ridge - Stock 697/975: TCI
# ✅ Finished stock TCI | Time: 0.39s
#
# 🟠 Ridge - Stock 698/975: NC
# ✅ Finished stock NC | Time: 0.35s
#
# 🟠 Ridge - Stock 699/975: IMMR.O
# ✅ Finished stock IMMR.O | Time: 0.34s
#
# 🟠 Ridge - Stock 700/975: AVNW.O
# ✅ Finished stock AVNW.O | Time: 0.34s
#
# 🟠 Ridge - Stock 701/975: XOMA.O
# ✅ Finished stock XOMA.O | Time: 0.38s
#
# 🟠 Ridge - Stock 702/975: LFCR.O
# ✅ Finished stock LFCR.O | Time: 0.38s
#
# 🟠 Ridge - Stock 703/975: ONIT.K
# ✅ Finished stock ONIT.K | Time: 0.37s
#
# 🟠 Ridge - Stock 704/975: EHTH.O
# ✅ Finished stock EHTH.O | Time: 0.48s
#
# 🟠 Ridge - Stock 705/975: ANIK.O
# ...
# ✅ Finished stock CLAR.O | Time: 0.37s
#
# 🟠 Ridge - Stock 749/975: FEIM.O
# ✅ Finished stock FEIM.O | Time: 0.39s
#
# 🟠 Ridge - Stock 750/975: OPOF.O
# ✅ Finished stock OPOF.O | Time: 0.40s
#
# 🟠 Ridge - Stock 751/975: CCRD.K
# ✅ Finished stock CCRD.K | Time: 0.40s
#
# 🟠 Ridge - Stock 752/975: PHX
# ✅ Finished stock PHX | Time: 0.39s
#
# 🟠 Ridge - Stock 753/975: STRS.O
# ✅ Finished stock STRS.O | Time: 0.41s
#
# 🟠 Ridge - Stock 754/975: INSG.O
# ✅ Finished stock INSG.O | Time: 0.39s
#
# 🟠 Ridge - Stock 755/975: FLL.O
# ✅ Finished stock FLL.O | Time: 0.42s
#
# 🟠 Ridge - Stock 756/975: OPRX.O
# ✅ Finished stock OPRX.O | Time: 0.38s
#
# 🟠 Ridge - Stock 757/975: SRI
# ✅ Finished stock SRI | Time: 0.36s
#
# 🟠 Ridge - Stock 758/975: KEQU.O
# ✅ Finished stock KEQU.O | Time: 0.37s
#
# 🟠 Ridge - Stock 759/975: SAVA.O
# ✅ Finished stock SAVA.O | Time: 0.48s
#
# 🟠 Ridge - Stock 760/975: PESI.O
# ✅ Finished stock PESI.O | Time: 0.49s
#
# 🟠 Ridge - Stock 761/975: EGAN.O
# ✅ Finished stock EGAN.O | Time: 0.51s
#
# 🟠 Ridge - Stock 762/975: BSET.O
# ✅ Finished stock BSET.O | Time: 0.51s
#
# 🟠 Ridge - Stock 763/975: LXRX.O
# ✅ Finished stock LXRX.O | Time: 0.48s
#
# 🟠 Ridge - Stock 764/975: QVCGA.O
# ✅ Finished stock QVCGA.O | Time: 0.35s
#
# 🟠 Ridge - Stock 765/975: CSBR.O
# ✅ Finished stock CSBR.O | Time: 0.33s
#
# 🟠 Ridge - Stock 766/975: KRMD.O
# ✅ Finished stock KRMD.O | Time: 0.36s
#
# 🟠 Ridge - Stock 767/975: ACNT.O
# ✅ Finished stock ACNT.O | Time: 0.37s
#
# 🟠 Ridge - Stock 768/975: RAIL.O
# ✅ Finished stock RAIL.O | Time: 0.37s
#
# 🟠 Ridge - Stock 769/975: SNCR.O
# ✅ Finished stock SNCR.O | Time: 0.41s
#
# 🟠 Ridge - Stock 770/975: VXRT.O
# ✅ Finished stock VXRT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 771/975: RCMT.O
# ✅ Finished stock RCMT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 772/975: CMT
# ✅ Finished stock CMT | Time: 0.35s
#
# 🟠 Ridge - Stock 773/975: LCTX.K
# ✅ Finished stock LCTX.K | Time: 0.34s
#
# 🟠 Ridge - Stock 774/975: ISSC.O
# ✅ Finished stock ISSC.O | Time: 0.33s
#
# 🟠 Ridge - Stock 775/975: INFU.K
# ✅ Finished stock INFU.K | Time: 0.34s
#
# 🟠 Ridge - Stock 776/975: AXR
# ✅ Finished stock AXR | Time: 0.38s
#
# 🟠 Ridge - Stock 777/975: IVAC.O
# ✅ Finished stock IVAC.O | Time: 0.33s
#
# 🟠 Ridge - Stock 778/975: PLCE.O
# ✅ Finished stock PLCE.O | Time: 0.33s
#
# 🟠 Ridge - Stock 779/975: LTRX.O
# ✅ Finished stock LTRX.O | Time: 0.33s
#
# 🟠 Ridge - Stock 780/975: PPIH.O
# ✅ Finished stock PPIH.O | Time: 0.35s
#
# 🟠 Ridge - Stock 781/975: GNSS.O
# ✅ Finished stock GNSS.O | Time: 0.36s
#
# 🟠 Ridge - Stock 782/975: GALT.O
# ✅ Finished stock GALT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 783/975: GAIA.O
# ✅ Finished stock GAIA.O | Time: 0.35s
#
# 🟠 Ridge - Stock 784/975: KVHI.O
# ✅ Finished stock KVHI.O | Time: 0.35s
#
# 🟠 Ridge - Stock 785/975: HURC.O
# ✅ Finished stock HURC.O | Time: 0.34s
#
# 🟠 Ridge - Stock 786/975: NOTV.O
# ✅ Finished stock NOTV.O | Time: 0.40s
#
# 🟠 Ridge - Stock 787/975: DXLG.O
# ✅ Finished stock DXLG.O | Time: 0.41s
#
# 🟠 Ridge - Stock 788/975: TAYD.O
# ✅ Finished stock TAYD.O | Time: 0.40s
#
# 🟠 Ridge - Stock 789/975: PCG_pa
# ✅ Finished stock PCG_pa | Time: 0.38s
#
# 🟠 Ridge - Stock 790/975: GEOS.O
# ✅ Finished stock GEOS.O | Time: 0.43s
#
# 🟠 Ridge - Stock 791/975: SLNG.O
# ✅ Finished stock SLNG.O | Time: 0.38s
#
# 🟠 Ridge - Stock 792/975: ORMP.O
# ✅ Finished stock ORMP.O | Time: 0.38s
#
# 🟠 Ridge - Stock 793/975: INTT.K
# ✅ Finished stock INTT.K | Time: 0.34s
#
# 🟠 Ridge - Stock 794/975: ACHV.O
# ✅ Finished stock ACHV.O | Time: 0.34s
#
# 🟠 Ridge - Stock 795/975: ANIX.O
# ✅ Finished stock ANIX.O | Time: 0.35s
#
# 🟠 Ridge - Stock 796/975: ZYXI.O
# ✅ Finished stock ZYXI.O | Time: 0.39s
#
# 🟠 Ridge - Stock 797/975: QUIK.O
# ✅ Finished stock QUIK.O | Time: 0.41s
#
# 🟠 Ridge - Stock 798/975: BRID.O
# ✅ Finished stock BRID.O | Time: 0.37s
#
# 🟠 Ridge - Stock 799/975: UEIC.O
# ✅ Finished stock UEIC.O | Time: 0.37s
#
# 🟠 Ridge - Stock 800/975: QMCO.O
# ✅ Finished stock QMCO.O | Time: 0.38s
#
# 🟠 Ridge - Stock 801/975: LPSN.O
# ✅ Finished stock LPSN.O | Time: 0.52s
#
# 🟠 Ridge - Stock 802/975: FONR.O
# ✅ Finished stock FONR.O | Time: 0.40s
#
# 🟠 Ridge - Stock 803/975: MCHX.O
# ✅ Finished stock MCHX.O | Time: 0.46s
#
# 🟠 Ridge - Stock 804/975: LPTH.O
# ✅ Finished stock LPTH.O | Time: 0.44s
#
# 🟠 Ridge - Stock 805/975: HGBL.O
# ✅ Finished stock HGBL.O | Time: 0.46s
#
# 🟠 Ridge - Stock 806/975: PETS.O
# ✅ Finished stock PETS.O | Time: 0.43s
#
# 🟠 Ridge - Stock 807/975: DIT
# ✅ Finished stock DIT | Time: 0.41s
#
# 🟠 Ridge - Stock 808/975: AXTI.O
# ✅ Finished stock AXTI.O | Time: 0.41s
#
# 🟠 Ridge - Stock 809/975: FOSL.O
# ✅ Finished stock FOSL.O | Time: 0.40s
#
# 🟠 Ridge - Stock 810/975: ALOT.O
# ✅ Finished stock ALOT.O | Time: 0.39s
#
# 🟠 Ridge - Stock 811/975: HNNA.O
# ✅ Finished stock HNNA.O | Time: 0.35s
#
# 🟠 Ridge - Stock 812/975: RRGB.O
# ✅ Finished stock RRGB.O | Time: 0.37s
#
# 🟠 Ridge - Stock 813/975: UBCP.O
# ✅ Finished stock UBCP.O | Time: 0.34s
#
# 🟠 Ridge - Stock 814/975: MNOV.O
# ✅ Finished stock MNOV.O | Time: 0.34s
#
# 🟠 Ridge - Stock 815/975: INVE.O
# ✅ Finished stock INVE.O | Time: 0.36s
#
# 🟠 Ridge - Stock 816/975: SGA.O
# ✅ Finished stock SGA.O | Time: 0.34s
#
# 🟠 Ridge - Stock 817/975: ESP
# ✅ Finished stock ESP | Time: 0.37s
#
# 🟠 Ridge - Stock 818/975: OPTT.K
# ✅ Finished stock OPTT.K | Time: 0.46s
#
# 🟠 Ridge - Stock 819/975: CODA.O
# ✅ Finished stock CODA.O | Time: 0.39s
#
# 🟠 Ridge - Stock 820/975: AUBN.O
# ✅ Finished stock AUBN.O | Time: 0.41s
#
# 🟠 Ridge - Stock 821/975: INO.O
# ✅ Finished stock INO.O | Time: 0.36s
#
# 🟠 Ridge - Stock 822/975: IOR
# ✅ Finished stock IOR | Time: 0.35s
#
# 🟠 Ridge - Stock 823/975: MLSS.K
# ✅ Finished stock MLSS.K | Time: 0.40s
#
# 🟠 Ridge - Stock 824/975: AREN.K
# ✅ Finished stock AREN.K | Time: 0.48s
#
# 🟠 Ridge - Stock 825/975: VERU.O
# ✅ Finished stock VERU.O | Time: 0.41s
#
# 🟠 Ridge - Stock 826/975: ASYS.O
# ✅ Finished stock ASYS.O | Time: 0.38s
#
# 🟠 Ridge - Stock 827/975: ARMP.K
# ✅ Finished stock ARMP.K | Time: 0.40s
#
# 🟠 Ridge - Stock 828/975: ASRT.O
# ✅ Finished stock ASRT.O | Time: 0.43s
#
# 🟠 Ridge - Stock 829/975: FKWL.O
# ✅ Finished stock FKWL.O | Time: 0.36s
#
# 🟠 Ridge - Stock 830/975: DOMH.O
# ✅ Finished stock DOMH.O | Time: 0.35s
#
# 🟠 Ridge - Stock 831/975: DLHC.O
# ✅ Finished stock DLHC.O | Time: 0.37s
#
# 🟠 Ridge - Stock 832/975: PED
# ✅ Finished stock PED | Time: 0.39s
#
# 🟠 Ridge - Stock 833/975: ALTS.O
# ✅ Finished stock ALTS.O | Time: 0.40s
#
# 🟠 Ridge - Stock 834/975: CULP.K
# ✅ Finished stock CULP.K | Time: 0.42s
#
# 🟠 Ridge - Stock 835/975: SUP
# ✅ Finished stock SUP | Time: 0.42s
#
# 🟠 Ridge - Stock 836/975: CATO.K
# ✅ Finished stock CATO.K | Time: 0.40s
#
# 🟠 Ridge - Stock 837/975: CYCC.O
# ✅ Finished stock CYCC.O | Time: 0.36s
#
# 🟠 Ridge - Stock 838/975: ICAD.O
# ✅ Finished stock ICAD.O | Time: 0.40s
#
# 🟠 Ridge - Stock 839/975: WFCF.O
# ✅ Finished stock WFCF.O | Time: 0.36s
#
# 🟠 Ridge - Stock 840/975: LINK.O
# ✅ Finished stock LINK.O | Time: 0.37s
#
# 🟠 Ridge - Stock 841/975: CTSO.O
# ✅ Finished stock CTSO.O | Time: 0.55s
#
# 🟠 Ridge - Stock 842/975: CNVS.O
# ✅ Finished stock CNVS.O | Time: 0.67s
#
# 🟠 Ridge - Stock 843/975: CNTY.O
# ✅ Finished stock CNTY.O | Time: 0.46s
#
# 🟠 Ridge - Stock 844/975: MIND.O
# ✅ Finished stock MIND.O | Time: 0.43s
#
# 🟠 Ridge - Stock 845/975: SOTK.O
# ✅ Finished stock SOTK.O | Time: 0.45s
#
# 🟠 Ridge - Stock 846/975: RMTI.O
# ✅ Finished stock RMTI.O | Time: 0.38s
#
# 🟠 Ridge - Stock 847/975: CVGI.O
# ✅ Finished stock CVGI.O | Time: 0.34s
#
# 🟠 Ridge - Stock 848/975: MBOT.O
# ✅ Finished stock MBOT.O | Time: 0.34s
#
# 🟠 Ridge - Stock 849/975: LEE.O
# ✅ Finished stock LEE.O | Time: 0.33s
#
# 🟠 Ridge - Stock 850/975: CMTL.O
# ✅ Finished stock CMTL.O | Time: 0.36s
#
# 🟠 Ridge - Stock 851/975: KOSS.O
# ✅ Finished stock KOSS.O | Time: 0.38s
#
# 🟠 Ridge - Stock 852/975: BDL
# ✅ Finished stock BDL | Time: 0.39s
#
# 🟠 Ridge - Stock 853/975: UG.O
# ✅ Finished stock UG.O | Time: 0.38s
#
# 🟠 Ridge - Stock 854/975: IDN.O
# ✅ Finished stock IDN.O | Time: 0.38s
#
# 🟠 Ridge - Stock 855/975: ICCC.O
# ✅ Finished stock ICCC.O | Time: 0.37s
#
# 🟠 Ridge - Stock 856/975: CVU
# ✅ Finished stock CVU | Time: 0.38s
#
# 🟠 Ridge - Stock 857/975: AGEN.O
# ✅ Finished stock AGEN.O | Time: 0.35s
#
# 🟠 Ridge - Stock 858/975: REFR.O
# ✅ Finished stock REFR.O | Time: 0.41s
#
# 🟠 Ridge - Stock 859/975: DWSN.O
# ✅ Finished stock DWSN.O | Time: 0.36s
#
# 🟠 Ridge - Stock 860/975: AP
# ✅ Finished stock AP | Time: 0.35s
#
# 🟠 Ridge - Stock 861/975: RFIL.O
# ✅ Finished stock RFIL.O | Time: 0.38s
#
# 🟠 Ridge - Stock 862/975: USIO.O
# ✅ Finished stock USIO.O | Time: 0.37s
#
# 🟠 Ridge - Stock 863/975: CRWS.O
# ✅ Finished stock CRWS.O | Time: 0.37s
#
# 🟠 Ridge - Stock 864/975: PXLW.O
# ✅ Finished stock PXLW.O | Time: 0.41s
#
# 🟠 Ridge - Stock 865/975: APYX.O
# ✅ Finished stock APYX.O | Time: 0.38s
#
# 🟠 Ridge - Stock 866/975: TACT.O
# ✅ Finished stock TACT.O | Time: 0.38s
#
# 🟠 Ridge - Stock 867/975: SYPR.O
# ✅ Finished stock SYPR.O | Time: 0.42s
#
# 🟠 Ridge - Stock 868/975: UONEK.O
# ✅ Finished stock UONEK.O | Time: 0.39s
#
# 🟠 Ridge - Stock 869/975: ARKR.O
# ✅ Finished stock ARKR.O | Time: 0.40s
#
# 🟠 Ridge - Stock 870/975: HHS.O
# ✅ Finished stock HHS.O | Time: 0.41s
#
# 🟠 Ridge - Stock 871/975: WYY
# ✅ Finished stock WYY | Time: 0.40s
#
# 🟠 Ridge - Stock 872/975: ACCS.K
# ✅ Finished stock ACCS.K | Time: 0.44s
#
# 🟠 Ridge - Stock 873/975: AWRE.O
# ✅ Finished stock AWRE.O | Time: 0.39s
#
# 🟠 Ridge - Stock 874/975: AIFF.O
# ✅ Finished stock AIFF.O | Time: 0.45s
#
# 🟠 Ridge - Stock 875/975: SGRP.O
# ✅ Finished stock SGRP.O | Time: 0.36s
#
# 🟠 Ridge - Stock 876/975: NTIP.K
# ✅ Finished stock NTIP.K | Time: 0.39s
#
# 🟠 Ridge - Stock 877/975: VHC
# ✅ Finished stock VHC | Time: 0.44s
#
# 🟠 Ridge - Stock 878/975: FTEK.O
# ✅ Finished stock FTEK.O | Time: 0.39s
#
# 🟠 Ridge - Stock 879/975: GROW.O
# ✅ Finished stock GROW.O | Time: 0.44s
#
# 🟠 Ridge - Stock 880/975: IRD.O
# ✅ Finished stock IRD.O | Time: 0.44s
#
# 🟠 Ridge - Stock 881/975: CMS_pb
# ✅ Finished stock CMS_pb | Time: 0.53s
#
# 🟠 Ridge - Stock 882/975: KTCC.O
# ✅ Finished stock KTCC.O | Time: 0.54s
#
# 🟠 Ridge - Stock 883/975: HSON.O
# ✅ Finished stock HSON.O | Time: 0.50s
#
# 🟠 Ridge - Stock 884/975: AXDX.O
# ✅ Finished stock AXDX.O | Time: 0.72s
#
# 🟠 Ridge - Stock 885/975: HBIO.O
# ✅ Finished stock HBIO.O | Time: 0.47s
#
# 🟠 Ridge - Stock 886/975: NSYS.O
# ✅ Finished stock NSYS.O | Time: 0.43s
#
# 🟠 Ridge - Stock 887/975: OCC.O
# ✅ Finished stock OCC.O | Time: 0.45s
#
# 🟠 Ridge - Stock 888/975: NTWK.O
# ✅ Finished stock NTWK.O | Time: 0.40s
#
# 🟠 Ridge - Stock 889/975: INTG.O
# ✅ Finished stock INTG.O | Time: 0.39s
#
# 🟠 Ridge - Stock 890/975: DRRX.O
# ✅ Finished stock DRRX.O | Time: 0.34s
#
# 🟠 Ridge - Stock 891/975: IGC
# ✅ Finished stock IGC | Time: 0.40s
#
# 🟠 Ridge - Stock 892/975: TRT
# ✅ Finished stock TRT | Time: 0.35s
#
# 🟠 Ridge - Stock 893/975: ENZ
# ✅ Finished stock ENZ | Time: 0.36s
#
# 🟠 Ridge - Stock 894/975: GTIM.O
# ✅ Finished stock GTIM.O | Time: 0.34s
#
# 🟠 Ridge - Stock 895/975: TENX.O
# ✅ Finished stock TENX.O | Time: 0.37s
#
# 🟠 Ridge - Stock 896/975: CKX
# ✅ Finished stock CKX | Time: 0.36s
#
# 🟠 Ridge - Stock 897/975: CRIS.O
# ✅ Finished stock CRIS.O | Time: 0.34s
#
# 🟠 Ridge - Stock 898/975: CVM
# ✅ Finished stock CVM | Time: 0.34s
#
# 🟠 Ridge - Stock 899/975: CYTH.O
# ✅ Finished stock CYTH.O | Time: 0.36s
#
# 🟠 Ridge - Stock 900/975: DAIO.O
# ✅ Finished stock DAIO.O | Time: 0.37s
#
# 🟠 Ridge - Stock 901/975: JOB
# ✅ Finished stock JOB | Time: 0.36s
#
# 🟠 Ridge - Stock 902/975: RVP
# ✅ Finished stock RVP | Time: 0.37s
#
# 🟠 Ridge - Stock 903/975: INTZ.O
# ✅ Finished stock INTZ.O | Time: 0.38s
#
# 🟠 Ridge - Stock 904/975: NAII.O
# ✅ Finished stock NAII.O | Time: 0.36s
#
# 🟠 Ridge - Stock 905/975: CVV.O
# ✅ Finished stock CVV.O | Time: 0.34s
#
# 🟠 Ridge - Stock 906/975: LSTA.O
# ✅ Finished stock LSTA.O | Time: 0.37s
#
# 🟠 Ridge - Stock 907/975: PTN
# ✅ Finished stock PTN | Time: 0.38s
#
# 🟠 Ridge - Stock 908/975: CREX.O
# ✅ Finished stock CREX.O | Time: 0.38s
#
# 🟠 Ridge - Stock 909/975: MXC
# ✅ Finished stock MXC | Time: 0.37s
#
# 🟠 Ridge - Stock 910/975: MTEX.O
# ✅ Finished stock MTEX.O | Time: 0.38s
#
# 🟠 Ridge - Stock 911/975: NNVC.K
# ✅ Finished stock NNVC.K | Time: 0.40s
#
# 🟠 Ridge - Stock 912/975: IRIX.O
# ✅ Finished stock IRIX.O | Time: 0.39s
#
# 🟠 Ridge - Stock 913/975: AMS
# ✅ Finished stock AMS | Time: 0.39s
#
# 🟠 Ridge - Stock 914/975: SIF
# ✅ Finished stock SIF | Time: 0.35s
#
# 🟠 Ridge - Stock 915/975: BRN
# ✅ Finished stock BRN | Time: 0.43s
#
# 🟠 Ridge - Stock 916/975: NEPH.O
# ✅ Finished stock NEPH.O | Time: 0.43s
#
# 🟠 Ridge - Stock 917/975: HUSA.K
# ✅ Finished stock HUSA.K | Time: 0.38s
#
# 🟠 Ridge - Stock 918/975: CLRO.O
# ✅ Finished stock CLRO.O | Time: 0.37s
#
# 🟠 Ridge - Stock 919/975: COHN.K
# ✅ Finished stock COHN.K | Time: 0.34s
#
# 🟠 Ridge - Stock 920/975: ELSE.O
# ✅ Finished stock ELSE.O | Time: 0.37s
#
# 🟠 Ridge - Stock 921/975: MEIP.O
# ✅ Finished stock MEIP.O | Time: 0.48s
#
# 🟠 Ridge - Stock 922/975: TAIT.O
# ✅ Finished stock TAIT.O | Time: 0.53s
#
# 🟠 Ridge - Stock 923/975: JCTC.O
# ✅ Finished stock JCTC.O | Time: 0.47s
#
# 🟠 Ridge - Stock 924/975: CLRB.O
# ✅ Finished stock CLRB.O | Time: 0.49s
#
# 🟠 Ridge - Stock 925/975: GOVX.O
# ✅ Finished stock GOVX.O | Time: 0.44s
#
# 🟠 Ridge - Stock 926/975: GPUS.K
# ✅ Finished stock GPUS.K | Time: 0.38s
#
# 🟠 Ridge - Stock 927/975: ERNA.O
# ✅ Finished stock ERNA.O | Time: 0.36s
#
# 🟠 Ridge - Stock 928/975: AIRI.K
# ✅ Finished stock AIRI.K | Time: 0.36s
#
# 🟠 Ridge - Stock 929/975: SMSI.O
# ✅ Finished stock SMSI.O | Time: 0.36s
#
# 🟠 Ridge - Stock 930/975: STRM.O
# ✅ Finished stock STRM.O | Time: 0.34s
#
# 🟠 Ridge - Stock 931/975: IMNN.O
# ✅ Finished stock IMNN.O | Time: 0.36s
#
# 🟠 Ridge - Stock 932/975: AWX
# ✅ Finished stock AWX | Time: 0.34s
#
# 🟠 Ridge - Stock 933/975: BCDA.O
# ✅ Finished stock BCDA.O | Time: 0.40s
#
# 🟠 Ridge - Stock 934/975: MTR
# ✅ Finished stock MTR | Time: 0.34s
#
# 🟠 Ridge - Stock 935/975: PRPH.O
# ✅ Finished stock PRPH.O | Time: 0.33s
#
# 🟠 Ridge - Stock 936/975: SSKN.O
# ✅ Finished stock SSKN.O | Time: 0.39s
#
# 🟠 Ridge - Stock 937/975: ASTC.O
# ✅ Finished stock ASTC.O | Time: 0.34s
#
# 🟠 Ridge - Stock 938/975: PMCB.O
# ✅ Finished stock PMCB.O | Time: 0.34s
#
# 🟠 Ridge - Stock 939/975: PRPO.O
# ✅ Finished stock PRPO.O | Time: 0.36s
#
# 🟠 Ridge - Stock 940/975: BBGI.O
# ✅ Finished stock BBGI.O | Time: 0.33s
#
# 🟠 Ridge - Stock 941/975: MSN
# ✅ Finished stock MSN | Time: 0.33s
#
# 🟠 Ridge - Stock 942/975: BCLI.O
# ✅ Finished stock BCLI.O | Time: 0.34s
#
# 🟠 Ridge - Stock 943/975: NURO.O
# ✅ Finished stock NURO.O | Time: 0.33s
#
# 🟠 Ridge - Stock 944/975: SCKT.O
# ✅ Finished stock SCKT.O | Time: 0.32s
#
# 🟠 Ridge - Stock 945/975: ARTW.O
# ✅ Finished stock ARTW.O | Time: 0.34s
#
# 🟠 Ridge - Stock 946/975: AIMD.O
# ✅ Finished stock AIMD.O | Time: 0.33s
#
# 🟠 Ridge - Stock 947/975: AIM
# ✅ Finished stock AIM | Time: 0.34s
#
# 🟠 Ridge - Stock 948/975: STRR.O
# ✅ Finished stock STRR.O | Time: 0.34s
#
# 🟠 Ridge - Stock 949/975: SSY
# ✅ Finished stock SSY | Time: 0.33s
#
# 🟠 Ridge - Stock 950/975: GTBP.O
# ✅ Finished stock GTBP.O | Time: 0.34s
#
# 🟠 Ridge - Stock 951/975: SGMA.O
# ✅ Finished stock SGMA.O | Time: 0.34s
#
# 🟠 Ridge - Stock 952/975: OGEN.K
# ✅ Finished stock OGEN.K | Time: 0.33s
#
# 🟠 Ridge - Stock 953/975: RIME.O
# ✅ Finished stock RIME.O | Time: 0.34s
#
# 🟠 Ridge - Stock 954/975: SNGX.O
# ✅ Finished stock SNGX.O | Time: 0.33s
#
# 🟠 Ridge - Stock 955/975: SNOA.O
# ✅ Finished stock SNOA.O | Time: 0.33s
#
# 🟠 Ridge - Stock 956/975: AEMD.O
# ✅ Finished stock AEMD.O | Time: 0.33s
#
# 🟠 Ridge - Stock 957/975: GBR
# ✅ Finished stock GBR | Time: 0.33s
#
# 🟠 Ridge - Stock 958/975: KNW
# ✅ Finished stock KNW | Time: 0.32s
#
# 🟠 Ridge - Stock 959/975: BKYI.O
# ✅ Finished stock BKYI.O | Time: 0.32s
#
# 🟠 Ridge - Stock 960/975: UUU
# ✅ Finished stock UUU | Time: 0.34s
#
# 🟠 Ridge - Stock 961/975: PSTV.O
# ✅ Finished stock PSTV.O | Time: 0.32s
#
# 🟠 Ridge - Stock 962/975: FORD.O
# ✅ Finished stock FORD.O | Time: 0.33s
#
# 🟠 Ridge - Stock 963/975: AYRO.O
# ✅ Finished stock AYRO.O | Time: 0.34s
#
# 🟠 Ridge - Stock 964/975: TTNP.O
# ✅ Finished stock TTNP.O | Time: 0.34s
#
# 🟠 Ridge - Stock 965/975: TOVX.K
# ✅ Finished stock TOVX.K | Time: 0.37s
#
# 🟠 Ridge - Stock 966/975: PRSO.O
# ✅ Finished stock PRSO.O | Time: 0.45s
#
# 🟠 Ridge - Stock 967/975: PALI.O
# ✅ Finished stock PALI.O | Time: 0.44s
#
# 🟠 Ridge - Stock 968/975: APDN.O
# ✅ Finished stock APDN.O | Time: 0.47s
#
# 🟠 Ridge - Stock 969/975: SBET.O
# ✅ Finished stock SBET.O | Time: 0.49s
#
# 🟠 Ridge - Stock 970/975: ASTI.O
# ✅ Finished stock ASTI.O | Time: 0.47s
#
# 🟠 Ridge - Stock 971/975: AWH.O
# ✅ Finished stock AWH.O | Time: 0.40s
#
# 🟠 Ridge - Stock 972/975: SUNE.O
# ✅ Finished stock SUNE.O | Time: 0.34s
#
# 🟠 Ridge - Stock 973/975: TCRT.O
# ✅ Finished stock TCRT.O | Time: 0.34s
#
# 🟠 Ridge - Stock 974/975: WINT.O
# ✅ Finished stock WINT.O | Time: 0.33s
#
# 🟠 Ridge - Stock 975/975: DGLY.O
# ✅ Finished stock DGLY.O | Time: 0.33s
#
# 🟩 Finished all stocks | Total Time: 363.80 seconds

# %% [markdown]
# ### Hyperparameter Tuning - Lasso Regression

# %%
# Define the Fama-French factor columns
ff_3_factors = ['Date', 'Mkt-RF', 'SMB', 'HML', 'RF']

# Get list of stock columns (everything except the FF factors and 'Period')
stock_columns = [col for col in three_ff_cleaned_df.columns if col not in ff_3_factors]

# Start global timer
start_all = time.time()
# ------------------ Lasso Regression ------------------

all_lasso_results = []
best_lasso_models = {}

for idx, stock in enumerate(stock_columns):
    print(f"\n🔴 Lasso - Stock {idx + 1}/{len(stock_columns)}: {stock}")
    start_time = time.time()

    # Subset and process
    df_subset = three_ff_cleaned_df[ff_3_factors + [stock]].copy()
    df_subset['Stock_Return'] = df_subset[[stock]]
    df_subset['Excess_Mkt_Return'] = df_subset['Mkt-RF'] - df_subset['RF']
    df_subset = df_subset[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
    
    # Shift return behind by 1 to align predictors at t with return at t+1
    df_subset['Stock_Return_Shifted'] = df_subset['Stock_Return'].shift(-1)

    # Drop the first row which now has NaN in 'Stock_Return_Shifted'
    df_subset = df_subset.dropna()

    # Standardize the predictors
    scaler = StandardScaler()
    df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']] = scaler.fit_transform(df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']])

    lasso_results = []
    for alpha in alphas:
        model = Lasso(alpha=alpha, random_state=random_seed, max_iter=10000)
        val_rmse_list = []

        for i in range(train_size, train_size + val_size - 3):
            train_end = month_periods[i - 1]
            val_start = month_periods[i]
            val_end = month_periods[i + 2]

            train_mask = df_subset['Date'].dt.to_period('M') <= train_end
            val_mask = (df_subset['Date'].dt.to_period('M') >= val_start) & (df_subset['Date'].dt.to_period('M') <= val_end)

            X_train = df_subset.loc[train_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_train = df_subset.loc[train_mask, 'Stock_Return_Shifted']
            X_val = df_subset.loc[val_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_val = df_subset.loc[val_mask, 'Stock_Return_Shifted']

            model.fit(X_train, y_train)
            rmse = np.sqrt(mean_squared_error(y_val, model.predict(X_val)))
            val_rmse_list.append(rmse)

        lasso_results.append({
            'Stock': stock,
            'Alpha': alpha,
            'Avg_Validation_RMSE': np.mean(val_rmse_list),
            'Model': model
        })

    lasso_results.sort(key=lambda x: x['Avg_Validation_RMSE'])
    best_lasso_models[stock] = lasso_results[0]['Model']
    all_lasso_results.append(lasso_results[0])

    print(f"✅ Lasso done for {stock} | Best alpha: {lasso_results[0]['Alpha']}")
    
# End global timer
end_all = time.time()
print(f"\n🟩 Finished all stocks | Total Time: {end_all - start_all:.2f} seconds")
# Out:
# 🔴 Lasso - Stock 1/975: AAPL.O
# ✅ Lasso done for AAPL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 2/975: NVDA.O
# ✅ Lasso done for NVDA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 3/975: MSFT.O
# ✅ Lasso done for MSFT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 4/975: AMZN.O
# ✅ Lasso done for AMZN.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 5/975: LLY
# ✅ Lasso done for LLY | Best alpha: 1.0
#
# 🔴 Lasso - Stock 6/975: WMT
# ✅ Lasso done for WMT | Best alpha: 0.01
#
# 🔴 Lasso - Stock 7/975: XOM
# ✅ Lasso done for XOM | Best alpha: 10.0
#
# 🔴 Lasso - Stock 8/975: MA
# ✅ Lasso done for MA | Best alpha: 10.0
#
# 🔴 Lasso - Stock 9/975: UNH
# ✅ Lasso done for UNH | Best alpha: 1.0
#
# 🔴 Lasso - Stock 10/975: ORCL.K
# ✅ Lasso done for ORCL.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 11/975: COST.O
# ✅ Lasso done for COST.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 12/975: NFLX.O
# ✅ Lasso done for NFLX.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 13/975: HD
# ✅ Lasso done for HD | Best alpha: 1.0
#
# 🔴 Lasso - Stock 14/975: CVX
# ✅ Lasso done for CVX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 15/975: CRM
# ✅ Lasso done for CRM | Best alpha: 10.0
#
# 🔴 Lasso - Stock 16/975: CSCO.O
# ✅ Lasso done for CSCO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 17/975: MRK
# ✅ Lasso done for MRK | Best alpha: 1.0
#
# 🔴 Lasso - Stock 18/975: ABT
# ✅ Lasso done for ABT | Best alpha: 1.0
#
# 🔴 Lasso - Stock 19/975: MCD
# ✅ Lasso done for MCD | Best alpha: 0.1
#
# 🔴 Lasso - Stock 20/975: TMO
# ✅ Lasso done for TMO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 21/975: ISRG.O
# ✅ Lasso done for ISRG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 22/975: RTX
# ✅ Lasso done for RTX | Best alpha: 0.1
#
# 🔴 Lasso - Stock 23/975: QCOM.O
# ✅ Lasso done for QCOM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 24/975: ADBE.O
# ✅ Lasso done for ADBE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 25/975: AMGN.O
# ✅ Lasso done for AMGN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 26/975: INTU.O
# ✅ Lasso done for INTU.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 27/975: AMD.O
# ✅ Lasso done for AMD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 28/975: CAT
# ✅ Lasso done for CAT | Best alpha: 1.0
#
# 🔴 Lasso - Stock 29/975: TXN.O
# ✅ Lasso done for TXN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 30/975: NEE
# ✅ Lasso done for NEE | Best alpha: 0.01
#
# 🔴 Lasso - Stock 31/975: DHR
# ✅ Lasso done for DHR | Best alpha: 1.0
#
# 🔴 Lasso - Stock 32/975: PFE
# ✅ Lasso done for PFE | Best alpha: 0.01
#
# 🔴 Lasso - Stock 33/975: BLK
# ✅ Lasso done for BLK | Best alpha: 1.0
#
# 🔴 Lasso - Stock 34/975: UNP
# ✅ Lasso done for UNP | Best alpha: 1.0
#
# 🔴 Lasso - Stock 35/975: BSX
# ✅ Lasso done for BSX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 36/975: SYK
# ✅ Lasso done for SYK | Best alpha: 10.0
#
# 🔴 Lasso - Stock 37/975: GILD.O
# ✅ Lasso done for GILD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 38/975: HON.O
# ✅ Lasso done for HON.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 39/975: CMCSA.O
# ✅ Lasso done for CMCSA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 40/975: VRTX.O
# ✅ Lasso done for VRTX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 41/975: DE
# ✅ Lasso done for DE | Best alpha: 1.0
#
# 🔴 Lasso - Stock 42/975: TJX
# ✅ Lasso done for TJX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 43/975: COP
# ✅ Lasso done for COP | Best alpha: 10.0
#
# 🔴 Lasso - Stock 44/975: LOW
# ✅ Lasso done for LOW | Best alpha: 1.0
#
# 🔴 Lasso - Stock 45/975: BA
# ✅ Lasso done for BA | Best alpha: 10.0
#
# 🔴 Lasso - Stock 46/975: FI
# ✅ Lasso done for FI | Best alpha: 0.1
#
# 🔴 Lasso - Stock 47/975: BMY
# ✅ Lasso done for BMY | Best alpha: 0.01
#
# 🔴 Lasso - Stock 48/975: ADP.O
# ✅ Lasso done for ADP.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 49/975: MMC
# ✅ Lasso done for MMC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 50/975: MU.O
# ✅ Lasso done for MU.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 51/975: NKE
# ✅ Lasso done for NKE | Best alpha: 1.0
#
# 🔴 Lasso - Stock 52/975: INTC.O
# ✅ Lasso done for INTC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 53/975: ADI.O
# ✅ Lasso done for ADI.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 54/975: LRCX.O
# ✅ Lasso done for LRCX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 55/975: ELV
# ✅ Lasso done for ELV | Best alpha: 0.1
#
# 🔴 Lasso - Stock 56/975: KLAC.O
# ✅ Lasso done for KLAC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 57/975: DUK
# ✅ Lasso done for DUK | Best alpha: 1.0
#
# 🔴 Lasso - Stock 58/975: CI
# ✅ Lasso done for CI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 59/975: AJG
# ✅ Lasso done for AJG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 60/975: CVS
# ✅ Lasso done for CVS | Best alpha: 0.01
#
# 🔴 Lasso - Stock 61/975: MMM
# ✅ Lasso done for MMM | Best alpha: 0.01
#
# 🔴 Lasso - Stock 62/975: MCK
# ✅ Lasso done for MCK | Best alpha: 10.0
#
# 🔴 Lasso - Stock 63/975: APH
# ✅ Lasso done for APH | Best alpha: 10.0
#
# 🔴 Lasso - Stock 64/975: ORLY.O
# ✅ Lasso done for ORLY.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 65/975: REGN.O
# ✅ Lasso done for REGN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 66/975: CL
# ✅ Lasso done for CL | Best alpha: 1.0
#
# 🔴 Lasso - Stock 67/975: RSG
# ✅ Lasso done for RSG | Best alpha: 1.0
#
# 🔴 Lasso - Stock 68/975: NOC
# ✅ Lasso done for NOC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 69/975: WMB
# ✅ Lasso done for WMB | Best alpha: 10.0
#
# 🔴 Lasso - Stock 70/975: MSI
# ✅ Lasso done for MSI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 71/975: SNPS.O
# ✅ Lasso done for SNPS.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 72/975: EOG
# ✅ Lasso done for EOG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 73/975: CDNS.O
# ✅ Lasso done for CDNS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 74/975: CMG
# ✅ Lasso done for CMG | Best alpha: 0.1
#
# 🔴 Lasso - Stock 75/975: MAR.O
# ✅ Lasso done for MAR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 76/975: BDX
# ✅ Lasso done for BDX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 77/975: ROP.O
# ✅ Lasso done for ROP.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 78/975: OKE
# ✅ Lasso done for OKE | Best alpha: 10.0
#
# 🔴 Lasso - Stock 79/975: AZO
# ✅ Lasso done for AZO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 80/975: MRVL.O
# ✅ Lasso done for MRVL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 81/975: BK
# ✅ Lasso done for BK | Best alpha: 1.0
#
# 🔴 Lasso - Stock 82/975: CSX.O
# ✅ Lasso done for CSX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 83/975: SLB
# ✅ Lasso done for SLB | Best alpha: 1.0
#
# 🔴 Lasso - Stock 84/975: MET
# ✅ Lasso done for MET | Best alpha: 1.0
#
# 🔴 Lasso - Stock 85/975: ADSK.O
# ✅ Lasso done for ADSK.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 86/975: TFC
# ✅ Lasso done for TFC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 87/975: PCAR.O
# ✅ Lasso done for PCAR.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 88/975: COR
# ✅ Lasso done for COR | Best alpha: 1.0
#
# 🔴 Lasso - Stock 89/975: LNG
# ✅ Lasso done for LNG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 90/975: TGT
# ✅ Lasso done for TGT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 91/975: KR
# ✅ Lasso done for KR | Best alpha: 0.01
#
# 🔴 Lasso - Stock 92/975: D
# ✅ Lasso done for D | Best alpha: 0.01
#
# 🔴 Lasso - Stock 93/975: HES
# ✅ Lasso done for HES | Best alpha: 1.0
#
# 🔴 Lasso - Stock 94/975: FICO.K
# ✅ Lasso done for FICO.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 95/975: OXY
# ✅ Lasso done for OXY | Best alpha: 10.0
#
# 🔴 Lasso - Stock 96/975: BKR.O
# ✅ Lasso done for BKR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 97/975: ROST.O
# ✅ Lasso done for ROST.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 98/975: EW
# ✅ Lasso done for EW | Best alpha: 1.0
#
# 🔴 Lasso - Stock 99/975: VLO
# ✅ Lasso done for VLO | Best alpha: 10.0
#
# 🔴 Lasso - Stock 100/975: AME
# ✅ Lasso done for AME | Best alpha: 1.0
#
# 🔴 Lasso - Stock 101/975: GLW
# ✅ Lasso done for GLW | Best alpha: 0.1
#
# 🔴 Lasso - Stock 102/975: DHI
# ✅ Lasso done for DHI | Best alpha: 1.0
#
# 🔴 Lasso - Stock 103/975: LHX
# ✅ Lasso done for LHX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 104/975: CTSH.O
# ✅ Lasso done for CTSH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 105/975: PWR
# ✅ Lasso done for PWR | Best alpha: 1.0
#
# 🔴 Lasso - Stock 106/975: F
# ✅ Lasso done for F | Best alpha: 0.1
#
# 🔴 Lasso - Stock 107/975: EA.O
# ✅ Lasso done for EA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 108/975: TTWO.O
# ✅ Lasso done for TTWO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 109/975: A
# ✅ Lasso done for A | Best alpha: 10.0
#
# 🔴 Lasso - Stock 110/975: ODFL.O
# ✅ Lasso done for ODFL.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 111/975: BRO
# ✅ Lasso done for BRO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 112/975: IDXX.O
# ✅ Lasso done for IDXX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 113/975: CSGP.O
# ✅ Lasso done for CSGP.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 114/975: ALNY.O
# ✅ Lasso done for ALNY.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 115/975: HEI
# ✅ Lasso done for HEI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 116/975: LVS
# ✅ Lasso done for LVS | Best alpha: 10.0
#
# 🔴 Lasso - Stock 117/975: CAH
# ✅ Lasso done for CAH | Best alpha: 1.0
#
# 🔴 Lasso - Stock 118/975: WAB
# ✅ Lasso done for WAB | Best alpha: 1.0
#
# 🔴 Lasso - Stock 119/975: HUM
# ✅ Lasso done for HUM | Best alpha: 1.0
#
# 🔴 Lasso - Stock 120/975: NUE
# ✅ Lasso done for NUE | Best alpha: 10.0
#
# 🔴 Lasso - Stock 121/975: EBAY.O
# ✅ Lasso done for EBAY.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 122/975: TPL
# ✅ Lasso done for TPL | Best alpha: 0.01
#
# 🔴 Lasso - Stock 123/975: EQT
# ✅ Lasso done for EQT | Best alpha: 1.0
#
# 🔴 Lasso - Stock 124/975: ROK
# ✅ Lasso done for ROK | Best alpha: 1.0
#
# 🔴 Lasso - Stock 125/975: MPWR.O
# ✅ Lasso done for MPWR.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 126/975: MCHP.O
# ✅ Lasso done for MCHP.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 127/975: ANSS.O
# ✅ Lasso done for ANSS.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 128/975: DTE
# ✅ Lasso done for DTE | Best alpha: 0.01
#
# 🔴 Lasso - Stock 129/975: DXCM.O
# ✅ Lasso done for DXCM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 130/975: IP
# ✅ Lasso done for IP | Best alpha: 10.0
#
# 🔴 Lasso - Stock 131/975: AEE
# ✅ Lasso done for AEE | Best alpha: 0.01
#
# 🔴 Lasso - Stock 132/975: PPG
# ✅ Lasso done for PPG | Best alpha: 1.0
#
# 🔴 Lasso - Stock 133/975: PPL
# ✅ Lasso done for PPL | Best alpha: 1.0
#
# 🔴 Lasso - Stock 134/975: MTD
# ✅ Lasso done for MTD | Best alpha: 1.0
#
# 🔴 Lasso - Stock 135/975: WBD.O
# ✅ Lasso done for WBD.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 136/975: TYL
# ✅ Lasso done for TYL | Best alpha: 0.1
#
# 🔴 Lasso - Stock 137/975: EL
# ✅ Lasso done for EL | Best alpha: 0.01
#
# 🔴 Lasso - Stock 138/975: ATO
# ✅ Lasso done for ATO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 139/975: GPN
# ✅ Lasso done for GPN | Best alpha: 1.0
#
# 🔴 Lasso - Stock 140/975: TDY
# ✅ Lasso done for TDY | Best alpha: 1.0
#
# 🔴 Lasso - Stock 141/975: VRSN.O
# ✅ Lasso done for VRSN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 142/975: DVN
# ✅ Lasso done for DVN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 143/975: WAT
# ✅ Lasso done for WAT | Best alpha: 1.0
#
# 🔴 Lasso - Stock 144/975: ERIE.O
# ✅ Lasso done for ERIE.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 145/975: ZBH
# ✅ Lasso done for ZBH | Best alpha: 1.0
#
# 🔴 Lasso - Stock 146/975: DRI
# ✅ Lasso done for DRI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 147/975: HAL
# ✅ Lasso done for HAL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 148/975: NVR
# ✅ Lasso done for NVR | Best alpha: 1.0
#
# 🔴 Lasso - Stock 149/975: TSN
# ✅ Lasso done for TSN | Best alpha: 0.1
#
# 🔴 Lasso - Stock 150/975: CTRA.K
# ✅ Lasso done for CTRA.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 151/975: PHM
# ✅ Lasso done for PHM | Best alpha: 10.0
#
# 🔴 Lasso - Stock 152/975: TROW.O
# ✅ Lasso done for TROW.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 153/975: LII
# ✅ Lasso done for LII | Best alpha: 1.0
#
# 🔴 Lasso - Stock 154/975: BIIB.O
# ✅ Lasso done for BIIB.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 155/975: LH
# ✅ Lasso done for LH | Best alpha: 1.0
#
# 🔴 Lasso - Stock 156/975: STLD.O
# ✅ Lasso done for STLD.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 157/975: NRG
# ✅ Lasso done for NRG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 158/975: DGX
# ✅ Lasso done for DGX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 159/975: LUV
# ✅ Lasso done for LUV | Best alpha: 0.1
#
# 🔴 Lasso - Stock 160/975: PTC.O
# ✅ Lasso done for PTC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 161/975: NTAP.O
# ✅ Lasso done for NTAP.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 162/975: ON.O
# ✅ Lasso done for ON.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 163/975: CLX
# ✅ Lasso done for CLX | Best alpha: 0.1
#
# 🔴 Lasso - Stock 164/975: DECK.K
# ✅ Lasso done for DECK.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 165/975: FNF
# ✅ Lasso done for FNF | Best alpha: 10.0
#
# 🔴 Lasso - Stock 166/975: BAX
# ✅ Lasso done for BAX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 167/975: EME
# ✅ Lasso done for EME | Best alpha: 1.0
#
# 🔴 Lasso - Stock 168/975: TRMB.O
# ✅ Lasso done for TRMB.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 169/975: GPC
# ✅ Lasso done for GPC | Best alpha: 0.1
#
# 🔴 Lasso - Stock 170/975: GEN.O
# ✅ Lasso done for GEN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 171/975: WST
# ✅ Lasso done for WST | Best alpha: 1.0
#
# 🔴 Lasso - Stock 172/975: HRL
# ✅ Lasso done for HRL | Best alpha: 0.01
#
# 🔴 Lasso - Stock 173/975: COO.O
# ✅ Lasso done for COO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 174/975: EXPD.K
# ✅ Lasso done for EXPD.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 175/975: WDC.O
# ✅ Lasso done for WDC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 176/975: BBY
# ✅ Lasso done for BBY | Best alpha: 10.0
#
# 🔴 Lasso - Stock 177/975: FFIV.O
# ✅ Lasso done for FFIV.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 178/975: RS
# ✅ Lasso done for RS | Best alpha: 10.0
#
# 🔴 Lasso - Stock 179/975: RPM
# ✅ Lasso done for RPM | Best alpha: 1.0
#
# 🔴 Lasso - Stock 180/975: JBL
# ✅ Lasso done for JBL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 181/975: ENTG.O
# ✅ Lasso done for ENTG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 182/975: BALL.K
# ✅ Lasso done for BALL.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 183/975: BLDR.K
# ✅ Lasso done for BLDR.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 184/975: FSLR.O
# ✅ Lasso done for FSLR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 185/975: GGG
# ✅ Lasso done for GGG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 186/975: TER.O
# ✅ Lasso done for TER.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 187/975: UNM
# ✅ Lasso done for UNM | Best alpha: 1.0
#
# 🔴 Lasso - Stock 188/975: DLTR.O
# ✅ Lasso done for DLTR.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 189/975: INSM.O
# ✅ Lasso done for INSM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 190/975: UTHR.O
# ✅ Lasso done for UTHR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 191/975: HOLX.O
# ✅ Lasso done for HOLX.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 192/975: ILMN.O
# ✅ Lasso done for ILMN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 193/975: RVTY.K
# ✅ Lasso done for RVTY.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 194/975: BMRN.O
# ✅ Lasso done for BMRN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 195/975: FLEX.O
# ✅ Lasso done for FLEX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 196/975: INCY.O
# ✅ Lasso done for INCY.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 197/975: JKHY.O
# ✅ Lasso done for JKHY.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 198/975: MORN.O
# ✅ Lasso done for MORN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 199/975: ALGN.O
# ✅ Lasso done for ALGN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 200/975: EWBC.O
# ✅ Lasso done for EWBC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 201/975: AKAM.O
# ✅ Lasso done for AKAM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 202/975: FIX
# ✅ Lasso done for FIX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 203/975: JNPR.K
# ✅ Lasso done for JNPR.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 204/975: SJM
# ✅ Lasso done for SJM | Best alpha: 1.0
#
# 🔴 Lasso - Stock 205/975: JLL
# ✅ Lasso done for JLL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 206/975: NDSN.O
# ✅ Lasso done for NDSN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 207/975: CHRW.O
# ✅ Lasso done for CHRW.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 208/975: THC
# ✅ Lasso done for THC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 209/975: JEF
# ✅ Lasso done for JEF | Best alpha: 10.0
#
# 🔴 Lasso - Stock 210/975: COKE.O
# ✅ Lasso done for COKE.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 211/975: TXRH.O
# ✅ Lasso done for TXRH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 212/975: SWKS.O
# ✅ Lasso done for SWKS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 213/975: NBIX.O
# ✅ Lasso done for NBIX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 214/975: ITT
# ✅ Lasso done for ITT | Best alpha: 1.0
#
# 🔴 Lasso - Stock 215/975: VTRS.O
# ✅ Lasso done for VTRS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 216/975: SNX
# ✅ Lasso done for SNX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 217/975: AIZ
# ✅ Lasso done for AIZ | Best alpha: 10.0
#
# 🔴 Lasso - Stock 218/975: RBC
# ✅ Lasso done for RBC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 219/975: OVV
# ✅ Lasso done for OVV | Best alpha: 10.0
#
# 🔴 Lasso - Stock 220/975: MANH.O
# ✅ Lasso done for MANH.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 221/975: EMN
# ✅ Lasso done for EMN | Best alpha: 1.0
#
# 🔴 Lasso - Stock 222/975: CCK
# ✅ Lasso done for CCK | Best alpha: 1.0
#
# 🔴 Lasso - Stock 223/975: TOL
# ✅ Lasso done for TOL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 224/975: CLH
# ✅ Lasso done for CLH | Best alpha: 1.0
#
# 🔴 Lasso - Stock 225/975: GME
# ✅ Lasso done for GME | Best alpha: 0.01
#
# 🔴 Lasso - Stock 226/975: EXEL.O
# ✅ Lasso done for EXEL.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 227/975: RGLD.O
# ✅ Lasso done for RGLD.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 228/975: COHR.K
# ✅ Lasso done for COHR.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 229/975: DOX.O
# ✅ Lasso done for DOX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 230/975: IPG
# ✅ Lasso done for IPG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 231/975: TECH.O
# ✅ Lasso done for TECH.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 232/975: ATR
# ✅ Lasso done for ATR | Best alpha: 1.0
#
# 🔴 Lasso - Stock 233/975: WBA.O
# ✅ Lasso done for WBA.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 234/975: MTZ
# ✅ Lasso done for MTZ | Best alpha: 1.0
#
# 🔴 Lasso - Stock 235/975: SRPT.O
# ✅ Lasso done for SRPT.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 236/975: SAIA.O
# ✅ Lasso done for SAIA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 237/975: SEIC.O
# ✅ Lasso done for SEIC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 238/975: RRC
# ✅ Lasso done for RRC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 239/975: WYNN.O
# ✅ Lasso done for WYNN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 240/975: CRS
# ✅ Lasso done for CRS | Best alpha: 1.0
#
# 🔴 Lasso - Stock 241/975: CIEN.K
# ✅ Lasso done for CIEN.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 242/975: ALB
# ✅ Lasso done for ALB | Best alpha: 0.01
#
# 🔴 Lasso - Stock 243/975: X
# ✅ Lasso done for X | Best alpha: 10.0
#
# 🔴 Lasso - Stock 244/975: HSIC.O
# ✅ Lasso done for HSIC.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 245/975: LNW.O
# ✅ Lasso done for LNW.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 246/975: CHE
# ✅ Lasso done for CHE | Best alpha: 1.0
#
# 🔴 Lasso - Stock 247/975: CRL
# ✅ Lasso done for CRL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 248/975: DRS.O
# ✅ Lasso done for DRS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 249/975: RGEN.O
# ✅ Lasso done for RGEN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 250/975: LSCC.O
# ✅ Lasso done for LSCC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 251/975: EXAS.O
# ✅ Lasso done for EXAS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 252/975: HAS.O
# ✅ Lasso done for HAS.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 253/975: PARA.O
# ✅ Lasso done for PARA.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 254/975: DCI
# ✅ Lasso done for DCI | Best alpha: 1.0
#
# 🔴 Lasso - Stock 255/975: CHDN.O
# ✅ Lasso done for CHDN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 256/975: MKTX.O
# ✅ Lasso done for MKTX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 257/975: NYT
# ✅ Lasso done for NYT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 258/975: WCC
# ✅ Lasso done for WCC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 259/975: DLB
# ✅ Lasso done for DLB | Best alpha: 10.0
#
# 🔴 Lasso - Stock 260/975: EVR
# ✅ Lasso done for EVR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 261/975: TTEK.O
# ✅ Lasso done for TTEK.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 262/975: RRX
# ✅ Lasso done for RRX | Best alpha: 0.1
#
# 🔴 Lasso - Stock 263/975: SIRI.O
# ✅ Lasso done for SIRI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 264/975: HALO.O
# ✅ Lasso done for HALO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 265/975: GAP
# ✅ Lasso done for GAP | Best alpha: 10.0
#
# 🔴 Lasso - Stock 266/975: EXLS.O
# ✅ Lasso done for EXLS.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 267/975: ATI
# ✅ Lasso done for ATI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 268/975: TTC
# ✅ Lasso done for TTC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 269/975: ZION.O
# ✅ Lasso done for ZION.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 270/975: BIO
# ✅ Lasso done for BIO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 271/975: MHK
# ✅ Lasso done for MHK | Best alpha: 10.0
#
# 🔴 Lasso - Stock 272/975: APA.O
# ✅ Lasso done for APA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 273/975: CVLT.O
# ✅ Lasso done for CVLT.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 274/975: AGCO.K
# ✅ Lasso done for AGCO.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 275/975: BRKR.O
# ✅ Lasso done for BRKR.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 276/975: RLI
# ✅ Lasso done for RLI | Best alpha: 1.0
#
# 🔴 Lasso - Stock 277/975: IVZ
# ✅ Lasso done for IVZ | Best alpha: 0.01
#
# 🔴 Lasso - Stock 278/975: ONTO.K
# ✅ Lasso done for ONTO.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 279/975: CWST.O
# ✅ Lasso done for CWST.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 280/975: QRVO.O
# ✅ Lasso done for QRVO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 281/975: AAON.O
# ✅ Lasso done for AAON.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 282/975: ALK
# ✅ Lasso done for ALK | Best alpha: 10.0
#
# 🔴 Lasso - Stock 283/975: UFPI.O
# ✅ Lasso done for UFPI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 284/975: FLS
# ✅ Lasso done for FLS | Best alpha: 1.0
#
# 🔴 Lasso - Stock 285/975: SNV
# ✅ Lasso done for SNV | Best alpha: 1.0
#
# 🔴 Lasso - Stock 286/975: TGTX.O
# ✅ Lasso done for TGTX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 287/975: TFX
# ✅ Lasso done for TFX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 288/975: CELH.O
# ✅ Lasso done for CELH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 289/975: EAT
# ✅ Lasso done for EAT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 290/975: PEGA.O
# ✅ Lasso done for PEGA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 291/975: OSK
# ✅ Lasso done for OSK | Best alpha: 10.0
#
# 🔴 Lasso - Stock 292/975: LNC
# ✅ Lasso done for LNC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 293/975: AWI
# ✅ Lasso done for AWI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 294/975: CHH
# ✅ Lasso done for CHH | Best alpha: 10.0
#
# 🔴 Lasso - Stock 295/975: WEX
# ✅ Lasso done for WEX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 296/975: CORT.O
# ✅ Lasso done for CORT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 297/975: MSA
# ✅ Lasso done for MSA | Best alpha: 1.0
#
# 🔴 Lasso - Stock 298/975: RMBS.O
# ✅ Lasso done for RMBS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 299/975: FCN
# ✅ Lasso done for FCN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 300/975: BMI
# ✅ Lasso done for BMI | Best alpha: 0.01
#
# 🔴 Lasso - Stock 301/975: MMSI.O
# ✅ Lasso done for MMSI.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 302/975: MKSI.O
# ✅ Lasso done for MKSI.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 303/975: CACC.O
# ✅ Lasso done for CACC.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 304/975: BYD
# ✅ Lasso done for BYD | Best alpha: 10.0
#
# 🔴 Lasso - Stock 305/975: DDS
# ✅ Lasso done for DDS | Best alpha: 10.0
#
# 🔴 Lasso - Stock 306/975: IDCC.O
# ✅ Lasso done for IDCC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 307/975: ACIW.O
# ✅ Lasso done for ACIW.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 308/975: USM
# ✅ Lasso done for USM | Best alpha: 1.0
#
# 🔴 Lasso - Stock 309/975: CROX.O
# ✅ Lasso done for CROX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 310/975: GNTX.O
# ✅ Lasso done for GNTX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 311/975: CRVL.O
# ✅ Lasso done for CRVL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 312/975: ARW
# ✅ Lasso done for ARW | Best alpha: 1.0
#
# 🔴 Lasso - Stock 313/975: NOV
# ✅ Lasso done for NOV | Best alpha: 1.0
#
# 🔴 Lasso - Stock 314/975: RHI
# ✅ Lasso done for RHI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 315/975: SKY
# ✅ Lasso done for SKY | Best alpha: 0.1
#
# 🔴 Lasso - Stock 316/975: CRK
# ✅ Lasso done for CRK | Best alpha: 1.0
#
# 🔴 Lasso - Stock 317/975: OPCH.O
# ✅ Lasso done for OPCH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 318/975: CGNX.O
# ✅ Lasso done for CGNX.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 319/975: LSTR.O
# ✅ Lasso done for LSTR.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 320/975: CRUS.O
# ✅ Lasso done for CRUS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 321/975: CMC
# ✅ Lasso done for CMC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 322/975: CYTK.O
# ✅ Lasso done for CYTK.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 323/975: QXO
# ✅ Lasso done for QXO | Best alpha: 10.0
#
# 🔴 Lasso - Stock 324/975: IONS.O
# ✅ Lasso done for IONS.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 325/975: TKR
# ✅ Lasso done for TKR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 326/975: LFUS.O
# ✅ Lasso done for LFUS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 327/975: NXST.O
# ✅ Lasso done for NXST.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 328/975: LAZ
# ✅ Lasso done for LAZ | Best alpha: 0.1
#
# 🔴 Lasso - Stock 329/975: MTH
# ✅ Lasso done for MTH | Best alpha: 10.0
#
# 🔴 Lasso - Stock 330/975: TXNM.K
# ✅ Lasso done for TXNM.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 331/975: LUMN.K
# ✅ Lasso done for LUMN.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 332/975: POR
# ✅ Lasso done for POR | Best alpha: 1.0
#
# 🔴 Lasso - Stock 333/975: AMKR.O
# ✅ Lasso done for AMKR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 334/975: NSIT.O
# ✅ Lasso done for NSIT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 335/975: AMG
# ✅ Lasso done for AMG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 336/975: ITRI.O
# ✅ Lasso done for ITRI.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 337/975: FSS
# ✅ Lasso done for FSS | Best alpha: 1.0
#
# 🔴 Lasso - Stock 338/975: HXL
# ✅ Lasso done for HXL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 339/975: FELE.O
# ✅ Lasso done for FELE.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 340/975: CNX
# ✅ Lasso done for CNX | Best alpha: 1.0
#
# 🔴 Lasso - Stock 341/975: DY
# ✅ Lasso done for DY | Best alpha: 10.0
#
# 🔴 Lasso - Stock 342/975: URBN.O
# ✅ Lasso done for URBN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 343/975: PIPR.K
# ✅ Lasso done for PIPR.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 344/975: MOD
# ✅ Lasso done for MOD | Best alpha: 10.0
#
# 🔴 Lasso - Stock 345/975: EEFT.O
# ✅ Lasso done for EEFT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 346/975: BKH
# ✅ Lasso done for BKH | Best alpha: 10.0
#
# 🔴 Lasso - Stock 347/975: KMPR.K
# ✅ Lasso done for KMPR.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 348/975: KBH
# ✅ Lasso done for KBH | Best alpha: 10.0
#
# 🔴 Lasso - Stock 349/975: MSM
# ✅ Lasso done for MSM | Best alpha: 1.0
#
# 🔴 Lasso - Stock 350/975: THO
# ✅ Lasso done for THO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 351/975: EXPO.O
# ✅ Lasso done for EXPO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 352/975: NNI
# ✅ Lasso done for NNI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 353/975: ESE
# ✅ Lasso done for ESE | Best alpha: 1.0
#
# 🔴 Lasso - Stock 354/975: PBH
# ✅ Lasso done for PBH | Best alpha: 1.0
#
# 🔴 Lasso - Stock 355/975: AVT.O
# ✅ Lasso done for AVT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 356/975: SANM.O
# ✅ Lasso done for SANM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 357/975: IPAR.O
# ✅ Lasso done for IPAR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 358/975: BDC
# ✅ Lasso done for BDC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 359/975: CVCO.O
# ✅ Lasso done for CVCO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 360/975: SLAB.O
# ✅ Lasso done for SLAB.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 361/975: AEIS.O
# ✅ Lasso done for AEIS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 362/975: ANF
# ✅ Lasso done for ANF | Best alpha: 10.0
#
# 🔴 Lasso - Stock 363/975: JWN
# ✅ Lasso done for JWN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 364/975: ITGR.K
# ✅ Lasso done for ITGR.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 365/975: SPR
# ✅ Lasso done for SPR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 366/975: DORM.O
# ✅ Lasso done for DORM.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 367/975: ALE
# ✅ Lasso done for ALE | Best alpha: 0.01
#
# 🔴 Lasso - Stock 368/975: MMS
# ✅ Lasso done for MMS | Best alpha: 10.0
#
# 🔴 Lasso - Stock 369/975: FIZZ.O
# ✅ Lasso done for FIZZ.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 370/975: TDS
# ✅ Lasso done for TDS | Best alpha: 1.0
#
# 🔴 Lasso - Stock 371/975: CBZ
# ✅ Lasso done for CBZ | Best alpha: 1.0
#
# 🔴 Lasso - Stock 372/975: BCO
# ✅ Lasso done for BCO | Best alpha: 10.0
#
# 🔴 Lasso - Stock 373/975: AVNT.K
# ✅ Lasso done for AVNT.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 374/975: AVAV.O
# ✅ Lasso done for AVAV.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 375/975: IESC.O
# ✅ Lasso done for IESC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 376/975: M
# ✅ Lasso done for M | Best alpha: 10.0
#
# 🔴 Lasso - Stock 377/975: PRIM.K
# ✅ Lasso done for PRIM.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 378/975: SKYW.O
# ✅ Lasso done for SKYW.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 379/975: ICUI.O
# ✅ Lasso done for ICUI.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 380/975: KFY
# ✅ Lasso done for KFY | Best alpha: 10.0
#
# 🔴 Lasso - Stock 381/975: RDNT.O
# ✅ Lasso done for RDNT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 382/975: NWE.O
# ✅ Lasso done for NWE.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 383/975: SM
# ✅ Lasso done for SM | Best alpha: 10.0
#
# 🔴 Lasso - Stock 384/975: SMTC.O
# ✅ Lasso done for SMTC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 385/975: CCOI.O
# ✅ Lasso done for CCOI.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 386/975: PLXS.O
# ✅ Lasso done for PLXS.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 387/975: NSP
# ✅ Lasso done for NSP | Best alpha: 0.1
#
# 🔴 Lasso - Stock 388/975: HAE
# ✅ Lasso done for HAE | Best alpha: 1.0
#
# 🔴 Lasso - Stock 389/975: POWI.O
# ✅ Lasso done for POWI.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 390/975: AVA
# ✅ Lasso done for AVA | Best alpha: 1.0
#
# 🔴 Lasso - Stock 391/975: TNL
# ✅ Lasso done for TNL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 392/975: MHO
# ✅ Lasso done for MHO | Best alpha: 10.0
#
# 🔴 Lasso - Stock 393/975: DXC
# ✅ Lasso done for DXC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 394/975: BLKB.O
# ✅ Lasso done for BLKB.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 395/975: XRAY.O
# ✅ Lasso done for XRAY.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 396/975: OSIS.O
# ✅ Lasso done for OSIS.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 397/975: HOG
# ✅ Lasso done for HOG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 398/975: PTEN.O
# ✅ Lasso done for PTEN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 399/975: AMED.O
# ✅ Lasso done for AMED.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 400/975: ASGN.K
# ✅ Lasso done for ASGN.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 401/975: CPK
# ✅ Lasso done for CPK | Best alpha: 0.01
#
# 🔴 Lasso - Stock 402/975: ACAD.O
# ✅ Lasso done for ACAD.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 403/975: NOG
# ✅ Lasso done for NOG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 404/975: FUL
# ✅ Lasso done for FUL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 405/975: PATK.O
# ✅ Lasso done for PATK.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 406/975: TGNA.K
# ✅ Lasso done for TGNA.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 407/975: MAN
# ✅ Lasso done for MAN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 408/975: MGRC.O
# ✅ Lasso done for MGRC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 409/975: GNW
# ✅ Lasso done for GNW | Best alpha: 10.0
#
# 🔴 Lasso - Stock 410/975: PDCO.O
# ✅ Lasso done for PDCO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 411/975: NWL.O
# ✅ Lasso done for NWL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 412/975: GEF
# ✅ Lasso done for GEF | Best alpha: 10.0
#
# 🔴 Lasso - Stock 413/975: GSAT.O
# ✅ Lasso done for GSAT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 414/975: TEX
# ✅ Lasso done for TEX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 415/975: IPGP.O
# ✅ Lasso done for IPGP.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 416/975: PENN.O
# ✅ Lasso done for PENN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 417/975: JOE
# ✅ Lasso done for JOE | Best alpha: 10.0
#
# 🔴 Lasso - Stock 418/975: HURN.O
# ✅ Lasso done for HURN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 419/975: JJSF.O
# ✅ Lasso done for JJSF.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 420/975: GT.O
# ✅ Lasso done for GT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 421/975: SAM
# ✅ Lasso done for SAM | Best alpha: 10.0
#
# 🔴 Lasso - Stock 422/975: HP
# ✅ Lasso done for HP | Best alpha: 10.0
#
# 🔴 Lasso - Stock 423/975: PSMT.O
# ✅ Lasso done for PSMT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 424/975: CPRX.O
# ✅ Lasso done for CPRX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 425/975: FORM.O
# ✅ Lasso done for FORM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 426/975: SYNA.O
# ✅ Lasso done for SYNA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 427/975: QDEL.O
# ✅ Lasso done for QDEL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 428/975: VIAV.O
# ✅ Lasso done for VIAV.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 429/975: VICR.O
# ✅ Lasso done for VICR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 430/975: BFH
# ✅ Lasso done for BFH | Best alpha: 10.0
#
# 🔴 Lasso - Stock 431/975: PRGS.O
# ✅ Lasso done for PRGS.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 432/975: TRN
# ✅ Lasso done for TRN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 433/975: CAKE.O
# ✅ Lasso done for CAKE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 434/975: WLY
# ✅ Lasso done for WLY | Best alpha: 0.01
#
# 🔴 Lasso - Stock 435/975: PAR
# ✅ Lasso done for PAR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 436/975: VSEC.O
# ✅ Lasso done for VSEC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 437/975: LCII.K
# ✅ Lasso done for LCII.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 438/975: AIN
# ✅ Lasso done for AIN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 439/975: HUBG.O
# ✅ Lasso done for HUBG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 440/975: VCEL.O
# ✅ Lasso done for VCEL.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 441/975: AAP
# ✅ Lasso done for AAP | Best alpha: 0.01
#
# 🔴 Lasso - Stock 442/975: ALG
# ✅ Lasso done for ALG | Best alpha: 1.0
#
# 🔴 Lasso - Stock 443/975: OII
# ✅ Lasso done for OII | Best alpha: 1.0
#
# 🔴 Lasso - Stock 444/975: TTMI.O
# ✅ Lasso done for TTMI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 445/975: CXW
# ✅ Lasso done for CXW | Best alpha: 0.1
#
# 🔴 Lasso - Stock 446/975: SSRM.O
# ✅ Lasso done for SSRM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 447/975: DIOD.O
# ✅ Lasso done for DIOD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 448/975: AEO
# ✅ Lasso done for AEO | Best alpha: 10.0
#
# 🔴 Lasso - Stock 449/975: ARWR.O
# ✅ Lasso done for ARWR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 450/975: WMK
# ✅ Lasso done for WMK | Best alpha: 0.01
#
# 🔴 Lasso - Stock 451/975: AGYS.O
# ✅ Lasso done for AGYS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 452/975: LGFa
# ✅ Lasso done for LGFa | Best alpha: 10.0
#
# 🔴 Lasso - Stock 453/975: LGND.O
# ✅ Lasso done for LGND.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 454/975: HNI
# ✅ Lasso done for HNI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 455/975: JBLU.O
# ✅ Lasso done for JBLU.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 456/975: NEOG.O
# ✅ Lasso done for NEOG.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 457/975: HE
# ✅ Lasso done for HE | Best alpha: 10.0
#
# 🔴 Lasso - Stock 458/975: EXTR.O
# ✅ Lasso done for EXTR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 459/975: ACLS.O
# ✅ Lasso done for ACLS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 460/975: WERN.O
# ✅ Lasso done for WERN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 461/975: LMAT.O
# ✅ Lasso done for LMAT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 462/975: CENX.O
# ✅ Lasso done for CENX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 463/975: BKE
# ✅ Lasso done for BKE | Best alpha: 1.0
#
# 🔴 Lasso - Stock 464/975: CNMD.K
# ✅ Lasso done for CNMD.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 465/975: OI
# ✅ Lasso done for OI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 466/975: CSGS.O
# ✅ Lasso done for CSGS.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 467/975: RAMP.K
# ✅ Lasso done for RAMP.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 468/975: IART.O
# ✅ Lasso done for IART.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 469/975: ZD.O
# ✅ Lasso done for ZD.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 470/975: PBI
# ✅ Lasso done for PBI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 471/975: GBX
# ✅ Lasso done for GBX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 472/975: DVAX.O
# ✅ Lasso done for DVAX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 473/975: PLUS.O
# ✅ Lasso done for PLUS.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 474/975: AZTA.O
# ✅ Lasso done for AZTA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 475/975: KMT
# ✅ Lasso done for KMT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 476/975: ATRC.O
# ✅ Lasso done for ATRC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 477/975: UFPT.O
# ✅ Lasso done for UFPT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 478/975: UNFI.K
# ✅ Lasso done for UNFI.K | Best alpha: 0.1
#
# 🔴 Lasso - Stock 479/975: BCRX.O
# ✅ Lasso done for BCRX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 480/975: STGW.O
# ✅ Lasso done for STGW.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 481/975: WKC
# ✅ Lasso done for WKC | Best alpha: 0.1
#
# 🔴 Lasso - Stock 482/975: MNKD.O
# ✅ Lasso done for MNKD.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 483/975: MCRI.O
# ✅ Lasso done for MCRI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 484/975: APLD.O
# ✅ Lasso done for APLD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 485/975: SRCE.O
# ✅ Lasso done for SRCE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 486/975: OMCL.O
# ✅ Lasso done for OMCL.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 487/975: INOD.O
# ✅ Lasso done for INOD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 488/975: FL
# ✅ Lasso done for FL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 489/975: NTCT.O
# ✅ Lasso done for NTCT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 490/975: EPC
# ✅ Lasso done for EPC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 491/975: ATSG.O
# ✅ Lasso done for ATSG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 492/975: ADEA.O
# ✅ Lasso done for ADEA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 493/975: ROG
# ✅ Lasso done for ROG | Best alpha: 10.0
#
# 🔴 Lasso - Stock 494/975: NHC
# ✅ Lasso done for NHC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 495/975: LNN
# ✅ Lasso done for LNN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 496/975: PZZA.O
# ✅ Lasso done for PZZA.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 497/975: BHE
# ✅ Lasso done for BHE | Best alpha: 10.0
#
# 🔴 Lasso - Stock 498/975: UPBD.O
# ✅ Lasso done for UPBD.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 499/975: ANIP.O
# ✅ Lasso done for ANIP.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 500/975: CLDX.O
# ✅ Lasso done for CLDX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 501/975: VRNT.O
# ✅ Lasso done for VRNT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 502/975: PLAB.O
# ✅ Lasso done for PLAB.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 503/975: VYX
# ✅ Lasso done for VYX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 504/975: DXPE.O
# ✅ Lasso done for DXPE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 505/975: ATEC.O
# ✅ Lasso done for ATEC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 506/975: NVAX.O
# ✅ Lasso done for NVAX.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 507/975: CTS
# ✅ Lasso done for CTS | Best alpha: 10.0
#
# 🔴 Lasso - Stock 508/975: VSAT.O
# ✅ Lasso done for VSAT.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 509/975: NEO.O
# ✅ Lasso done for NEO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 510/975: WT
# ✅ Lasso done for WT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 511/975: SCS
# ✅ Lasso done for SCS | Best alpha: 10.0
#
# 🔴 Lasso - Stock 512/975: VECO.O
# ✅ Lasso done for VECO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 513/975: INVX.K
# ✅ Lasso done for INVX.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 514/975: DCOM.O
# ✅ Lasso done for DCOM.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 515/975: EIG
# ✅ Lasso done for EIG | Best alpha: 1.0
#
# 🔴 Lasso - Stock 516/975: HLIT.O
# ✅ Lasso done for HLIT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 517/975: HLX
# ✅ Lasso done for HLX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 518/975: IDT
# ✅ Lasso done for IDT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 519/975: BLFS.O
# ✅ Lasso done for BLFS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 520/975: GIII.O
# ✅ Lasso done for GIII.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 521/975: CRAI.O
# ✅ Lasso done for CRAI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 522/975: IMKTA.O
# ✅ Lasso done for IMKTA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 523/975: OPK.O
# ✅ Lasso done for OPK.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 524/975: SAFT.O
# ✅ Lasso done for SAFT.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 525/975: RES
# ✅ Lasso done for RES | Best alpha: 10.0
#
# 🔴 Lasso - Stock 526/975: UCTT.O
# ✅ Lasso done for UCTT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 527/975: GYRE.O
# ✅ Lasso done for GYRE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 528/975: MODG.K
# ✅ Lasso done for MODG.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 529/975: TILE.O
# ✅ Lasso done for TILE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 530/975: MSEX.O
# ✅ Lasso done for MSEX.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 531/975: MRTN.O
# ✅ Lasso done for MRTN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 532/975: PRG
# ✅ Lasso done for PRG | Best alpha: 0.1
#
# 🔴 Lasso - Stock 533/975: INVA.O
# ✅ Lasso done for INVA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 534/975: DGII.O
# ✅ Lasso done for DGII.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 535/975: APOG.O
# ✅ Lasso done for APOG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 536/975: GERN.O
# ✅ Lasso done for GERN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 537/975: CLMT.O
# ✅ Lasso done for CLMT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 538/975: BBSI.O
# ✅ Lasso done for BBSI.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 539/975: WGO
# ✅ Lasso done for WGO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 540/975: AMN
# ✅ Lasso done for AMN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 541/975: AORT.K
# ✅ Lasso done for AORT.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 542/975: ALGT.O
# ✅ Lasso done for ALGT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 543/975: SBGI.O
# ✅ Lasso done for SBGI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 544/975: GRC
# ✅ Lasso done for GRC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 545/975: AMSF.O
# ✅ Lasso done for AMSF.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 546/975: KFRC.K
# ✅ Lasso done for KFRC.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 547/975: BELFA.O
# ✅ Lasso done for BELFA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 548/975: THRM.O
# ✅ Lasso done for THRM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 549/975: LQDT.O
# ✅ Lasso done for LQDT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 550/975: MYGN.O
# ✅ Lasso done for MYGN.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 551/975: NSSC.O
# ✅ Lasso done for NSSC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 552/975: UTL
# ✅ Lasso done for UTL | Best alpha: 0.1
#
# 🔴 Lasso - Stock 553/975: WOLF.K
# ✅ Lasso done for WOLF.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 554/975: KSS
# ✅ Lasso done for KSS | Best alpha: 10.0
#
# 🔴 Lasso - Stock 555/975: CBRL.O
# ✅ Lasso done for CBRL.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 556/975: DCO
# ✅ Lasso done for DCO | Best alpha: 10.0
#
# 🔴 Lasso - Stock 557/975: ATRO.O
# ✅ Lasso done for ATRO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 558/975: HSII.O
# ✅ Lasso done for HSII.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 559/975: GIC
# ✅ Lasso done for GIC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 560/975: PDFS.O
# ✅ Lasso done for PDFS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 561/975: SCSC.O
# ✅ Lasso done for SCSC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 562/975: STAA.O
# ✅ Lasso done for STAA.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 563/975: ASTE.O
# ✅ Lasso done for ASTE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 564/975: CECO.O
# ✅ Lasso done for CECO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 565/975: ECPG.O
# ✅ Lasso done for ECPG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 566/975: PRA
# ✅ Lasso done for PRA | Best alpha: 1.0
#
# 🔴 Lasso - Stock 567/975: AVXL.O
# ✅ Lasso done for AVXL.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 568/975: COHU.O
# ✅ Lasso done for COHU.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 569/975: AMSC.O
# ✅ Lasso done for AMSC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 570/975: HCKT.O
# ✅ Lasso done for HCKT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 571/975: AIOT.O
# ✅ Lasso done for AIOT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 572/975: PRAA.O
# ✅ Lasso done for PRAA.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 573/975: AXGN.O
# ✅ Lasso done for AXGN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 574/975: OSBC.O
# ✅ Lasso done for OSBC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 575/975: UFCS.O
# ✅ Lasso done for UFCS.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 576/975: BJRI.O
# ✅ Lasso done for BJRI.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 577/975: ADTN.O
# ✅ Lasso done for ADTN.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 578/975: XRX.O
# ✅ Lasso done for XRX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 579/975: OMI
# ✅ Lasso done for OMI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 580/975: PLPC.O
# ✅ Lasso done for PLPC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 581/975: CLB
# ✅ Lasso done for CLB | Best alpha: 1.0
#
# 🔴 Lasso - Stock 582/975: FCBC.O
# ✅ Lasso done for FCBC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 583/975: SSYS.O
# ✅ Lasso done for SSYS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 584/975: WRLD.O
# ✅ Lasso done for WRLD.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 585/975: RBBN.O
# ✅ Lasso done for RBBN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 586/975: NTGR.O
# ✅ Lasso done for NTGR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 587/975: MLAB.O
# ✅ Lasso done for MLAB.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 588/975: ETD
# ✅ Lasso done for ETD | Best alpha: 1.0
#
# 🔴 Lasso - Stock 589/975: MAGN.K
# ✅ Lasso done for MAGN.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 590/975: SPTN.O
# ✅ Lasso done for SPTN.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 591/975: TRNS.O
# ✅ Lasso done for TRNS.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 592/975: SHEN.O
# ✅ Lasso done for SHEN.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 593/975: BXC
# ✅ Lasso done for BXC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 594/975: BZH
# ✅ Lasso done for BZH | Best alpha: 10.0
#
# 🔴 Lasso - Stock 595/975: OFIX.O
# ✅ Lasso done for OFIX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 596/975: HOV
# ✅ Lasso done for HOV | Best alpha: 10.0
#
# 🔴 Lasso - Stock 597/975: OPY
# ✅ Lasso done for OPY | Best alpha: 10.0
#
# 🔴 Lasso - Stock 598/975: REPX.K
# ✅ Lasso done for REPX.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 599/975: CVLG.K
# ✅ Lasso done for CVLG.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 600/975: OSPN.O
# ✅ Lasso done for OSPN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 601/975: FWRD.O
# ✅ Lasso done for FWRD.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 602/975: SCVL.O
# ✅ Lasso done for SCVL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 603/975: JACK.O
# ✅ Lasso done for JACK.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 604/975: SENEA.O
# ✅ Lasso done for SENEA.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 605/975: WLDN.O
# ✅ Lasso done for WLDN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 606/975: CASS.O
# ✅ Lasso done for CASS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 607/975: SMP
# ✅ Lasso done for SMP | Best alpha: 10.0
#
# 🔴 Lasso - Stock 608/975: CTLP.O
# ✅ Lasso done for CTLP.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 609/975: FARO.O
# ✅ Lasso done for FARO.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 610/975: EBF
# ✅ Lasso done for EBF | Best alpha: 10.0
#
# 🔴 Lasso - Stock 611/975: USNA.K
# ✅ Lasso done for USNA.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 612/975: SCHL.O
# ✅ Lasso done for SCHL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 613/975: DJCO.O
# ✅ Lasso done for DJCO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 614/975: NPKI.K
# ✅ Lasso done for NPKI.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 615/975: AXL
# ✅ Lasso done for AXL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 616/975: CMCO.O
# ✅ Lasso done for CMCO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 617/975: SLP.O
# ✅ Lasso done for SLP.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 618/975: CRDb
# ✅ Lasso done for CRDb | Best alpha: 0.01
#
# 🔴 Lasso - Stock 619/975: TWI
# ✅ Lasso done for TWI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 620/975: HZO
# ✅ Lasso done for HZO | Best alpha: 1.0
#
# 🔴 Lasso - Stock 621/975: CLMB.O
# ✅ Lasso done for CLMB.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 622/975: MLR
# ✅ Lasso done for MLR | Best alpha: 1.0
#
# 🔴 Lasso - Stock 623/975: CCRN.O
# ✅ Lasso done for CCRN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 624/975: YORW.O
# ✅ Lasso done for YORW.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 625/975: BBW
# ✅ Lasso done for BBW | Best alpha: 10.0
#
# 🔴 Lasso - Stock 626/975: VLGEA.O
# ✅ Lasso done for VLGEA.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 627/975: LGTY.O
# ✅ Lasso done for LGTY.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 628/975: PBT
# ✅ Lasso done for PBT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 629/975: MYE
# ✅ Lasso done for MYE | Best alpha: 1.0
#
# 🔴 Lasso - Stock 630/975: WNC
# ✅ Lasso done for WNC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 631/975: GTN
# ✅ Lasso done for GTN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 632/975: KELYA.O
# ✅ Lasso done for KELYA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 633/975: ALRS.O
# ✅ Lasso done for ALRS.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 634/975: ALT.O
# ✅ Lasso done for ALT.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 635/975: EGY
# ✅ Lasso done for EGY | Best alpha: 1.0
#
# 🔴 Lasso - Stock 636/975: EYPT.O
# ✅ Lasso done for EYPT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 637/975: SVRA.O
# ✅ Lasso done for SVRA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 638/975: TTI
# ✅ Lasso done for TTI | Best alpha: 10.0
#
# 🔴 Lasso - Stock 639/975: CLFD.O
# ✅ Lasso done for CLFD.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 640/975: NWPX.O
# ✅ Lasso done for NWPX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 641/975: ORKA.O
# ✅ Lasso done for ORKA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 642/975: DHIL.O
# ✅ Lasso done for DHIL.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 643/975: MITK.O
# ✅ Lasso done for MITK.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 644/975: SRDX.O
# ✅ Lasso done for SRDX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 645/975: FC
# ✅ Lasso done for FC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 646/975: NUS
# ✅ Lasso done for NUS | Best alpha: 0.01
#
# 🔴 Lasso - Stock 647/975: GCBC.O
# ✅ Lasso done for GCBC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 648/975: TBRG.O
# ✅ Lasso done for TBRG.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 649/975: SIGA.O
# ✅ Lasso done for SIGA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 650/975: ALNT.O
# ✅ Lasso done for ALNT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 651/975: DIN
# ✅ Lasso done for DIN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 652/975: NATH.O
# ✅ Lasso done for NATH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 653/975: VALU.O
# ✅ Lasso done for VALU.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 654/975: ZEUS.O
# ✅ Lasso done for ZEUS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 655/975: ANGO.O
# ✅ Lasso done for ANGO.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 656/975: RIGL.O
# ✅ Lasso done for RIGL.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 657/975: TRAK.K
# ✅ Lasso done for TRAK.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 658/975: HRTX.O
# ✅ Lasso done for HRTX.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 659/975: DDD
# ✅ Lasso done for DDD | Best alpha: 0.01
#
# 🔴 Lasso - Stock 660/975: APPS.O
# ✅ Lasso done for APPS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 661/975: MSB
# ✅ Lasso done for MSB | Best alpha: 10.0
#
# ...
#
# 🔴 Lasso - Stock 763/975: LXRX.O
# ✅ Lasso done for LXRX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 764/975: QVCGA.O
# ✅ Lasso done for QVCGA.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 765/975: CSBR.O
# ✅ Lasso done for CSBR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 766/975: KRMD.O
# ✅ Lasso done for KRMD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 767/975: ACNT.O
# ✅ Lasso done for ACNT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 768/975: RAIL.O
# ✅ Lasso done for RAIL.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 769/975: SNCR.O
# ✅ Lasso done for SNCR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 770/975: VXRT.O
# ✅ Lasso done for VXRT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 771/975: RCMT.O
# ✅ Lasso done for RCMT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 772/975: CMT
# ✅ Lasso done for CMT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 773/975: LCTX.K
# ✅ Lasso done for LCTX.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 774/975: ISSC.O
# ✅ Lasso done for ISSC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 775/975: INFU.K
# ✅ Lasso done for INFU.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 776/975: AXR
# ✅ Lasso done for AXR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 777/975: IVAC.O
# ✅ Lasso done for IVAC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 778/975: PLCE.O
# ✅ Lasso done for PLCE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 779/975: LTRX.O
# ✅ Lasso done for LTRX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 780/975: PPIH.O
# ✅ Lasso done for PPIH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 781/975: GNSS.O
# ✅ Lasso done for GNSS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 782/975: GALT.O
# ✅ Lasso done for GALT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 783/975: GAIA.O
# ✅ Lasso done for GAIA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 784/975: KVHI.O
# ✅ Lasso done for KVHI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 785/975: HURC.O
# ✅ Lasso done for HURC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 786/975: NOTV.O
# ✅ Lasso done for NOTV.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 787/975: DXLG.O
# ✅ Lasso done for DXLG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 788/975: TAYD.O
# ✅ Lasso done for TAYD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 789/975: PCG_pa
# ✅ Lasso done for PCG_pa | Best alpha: 1.0
#
# 🔴 Lasso - Stock 790/975: GEOS.O
# ✅ Lasso done for GEOS.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 791/975: SLNG.O
# ✅ Lasso done for SLNG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 792/975: ORMP.O
# ✅ Lasso done for ORMP.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 793/975: INTT.K
# ✅ Lasso done for INTT.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 794/975: ACHV.O
# ✅ Lasso done for ACHV.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 795/975: ANIX.O
# ✅ Lasso done for ANIX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 796/975: ZYXI.O
# ✅ Lasso done for ZYXI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 797/975: QUIK.O
# ✅ Lasso done for QUIK.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 798/975: BRID.O
# ✅ Lasso done for BRID.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 799/975: UEIC.O
# ✅ Lasso done for UEIC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 800/975: QMCO.O
# ✅ Lasso done for QMCO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 801/975: LPSN.O
# ✅ Lasso done for LPSN.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 802/975: FONR.O
# ✅ Lasso done for FONR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 803/975: MCHX.O
# ✅ Lasso done for MCHX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 804/975: LPTH.O
# ✅ Lasso done for LPTH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 805/975: HGBL.O
# ✅ Lasso done for HGBL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 806/975: PETS.O
# ✅ Lasso done for PETS.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 807/975: DIT
# ✅ Lasso done for DIT | Best alpha: 1.0
#
# 🔴 Lasso - Stock 808/975: AXTI.O
# ✅ Lasso done for AXTI.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 809/975: FOSL.O
# ✅ Lasso done for FOSL.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 810/975: ALOT.O
# ✅ Lasso done for ALOT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 811/975: HNNA.O
# ✅ Lasso done for HNNA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 812/975: RRGB.O
# ✅ Lasso done for RRGB.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 813/975: UBCP.O
# ✅ Lasso done for UBCP.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 814/975: MNOV.O
# ✅ Lasso done for MNOV.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 815/975: INVE.O
# ✅ Lasso done for INVE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 816/975: SGA.O
# ✅ Lasso done for SGA.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 817/975: ESP
# ✅ Lasso done for ESP | Best alpha: 1.0
#
# 🔴 Lasso - Stock 818/975: OPTT.K
# ✅ Lasso done for OPTT.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 819/975: CODA.O
# ✅ Lasso done for CODA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 820/975: AUBN.O
# ✅ Lasso done for AUBN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 821/975: INO.O
# ✅ Lasso done for INO.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 822/975: IOR
# ✅ Lasso done for IOR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 823/975: MLSS.K
# ✅ Lasso done for MLSS.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 824/975: AREN.K
# ✅ Lasso done for AREN.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 825/975: VERU.O
# ✅ Lasso done for VERU.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 826/975: ASYS.O
# ✅ Lasso done for ASYS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 827/975: ARMP.K
# ✅ Lasso done for ARMP.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 828/975: ASRT.O
# ✅ Lasso done for ASRT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 829/975: FKWL.O
# ✅ Lasso done for FKWL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 830/975: DOMH.O
# ✅ Lasso done for DOMH.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 831/975: DLHC.O
# ✅ Lasso done for DLHC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 832/975: PED
# ✅ Lasso done for PED | Best alpha: 1.0
#
# 🔴 Lasso - Stock 833/975: ALTS.O
# ✅ Lasso done for ALTS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 834/975: CULP.K
# ✅ Lasso done for CULP.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 835/975: SUP
# ✅ Lasso done for SUP | Best alpha: 0.1
#
# 🔴 Lasso - Stock 836/975: CATO.K
# ✅ Lasso done for CATO.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 837/975: CYCC.O
# ✅ Lasso done for CYCC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 838/975: ICAD.O
# ✅ Lasso done for ICAD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 839/975: WFCF.O
# ✅ Lasso done for WFCF.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 840/975: LINK.O
# ✅ Lasso done for LINK.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 841/975: CTSO.O
# ✅ Lasso done for CTSO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 842/975: CNVS.O
# ✅ Lasso done for CNVS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 843/975: CNTY.O
# ✅ Lasso done for CNTY.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 844/975: MIND.O
# ✅ Lasso done for MIND.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 845/975: SOTK.O
# ✅ Lasso done for SOTK.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 846/975: RMTI.O
# ✅ Lasso done for RMTI.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 847/975: CVGI.O
# ✅ Lasso done for CVGI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 848/975: MBOT.O
# ✅ Lasso done for MBOT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 849/975: LEE.O
# ✅ Lasso done for LEE.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 850/975: CMTL.O
# ✅ Lasso done for CMTL.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 851/975: KOSS.O
# ✅ Lasso done for KOSS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 852/975: BDL
# ✅ Lasso done for BDL | Best alpha: 10.0
#
# 🔴 Lasso - Stock 853/975: UG.O
# ✅ Lasso done for UG.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 854/975: IDN.O
# ✅ Lasso done for IDN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 855/975: ICCC.O
# ✅ Lasso done for ICCC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 856/975: CVU
# ✅ Lasso done for CVU | Best alpha: 1.0
#
# 🔴 Lasso - Stock 857/975: AGEN.O
# ✅ Lasso done for AGEN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 858/975: REFR.O
# ✅ Lasso done for REFR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 859/975: DWSN.O
# ✅ Lasso done for DWSN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 860/975: AP
# ✅ Lasso done for AP | Best alpha: 10.0
#
# 🔴 Lasso - Stock 861/975: RFIL.O
# ✅ Lasso done for RFIL.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 862/975: USIO.O
# ✅ Lasso done for USIO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 863/975: CRWS.O
# ✅ Lasso done for CRWS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 864/975: PXLW.O
# ✅ Lasso done for PXLW.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 865/975: APYX.O
# ✅ Lasso done for APYX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 866/975: TACT.O
# ✅ Lasso done for TACT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 867/975: SYPR.O
# ✅ Lasso done for SYPR.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 868/975: UONEK.O
# ✅ Lasso done for UONEK.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 869/975: ARKR.O
# ✅ Lasso done for ARKR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 870/975: HHS.O
# ✅ Lasso done for HHS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 871/975: WYY
# ✅ Lasso done for WYY | Best alpha: 10.0
#
# 🔴 Lasso - Stock 872/975: ACCS.K
# ✅ Lasso done for ACCS.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 873/975: AWRE.O
# ✅ Lasso done for AWRE.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 874/975: AIFF.O
# ✅ Lasso done for AIFF.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 875/975: SGRP.O
# ✅ Lasso done for SGRP.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 876/975: NTIP.K
# ✅ Lasso done for NTIP.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 877/975: VHC
# ✅ Lasso done for VHC | Best alpha: 1.0
#
# 🔴 Lasso - Stock 878/975: FTEK.O
# ✅ Lasso done for FTEK.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 879/975: GROW.O
# ✅ Lasso done for GROW.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 880/975: IRD.O
# ✅ Lasso done for IRD.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 881/975: CMS_pb
# ✅ Lasso done for CMS_pb | Best alpha: 1.0
#
# 🔴 Lasso - Stock 882/975: KTCC.O
# ✅ Lasso done for KTCC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 883/975: HSON.O
# ✅ Lasso done for HSON.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 884/975: AXDX.O
# ✅ Lasso done for AXDX.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 885/975: HBIO.O
# ✅ Lasso done for HBIO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 886/975: NSYS.O
# ✅ Lasso done for NSYS.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 887/975: OCC.O
# ✅ Lasso done for OCC.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 888/975: NTWK.O
# ✅ Lasso done for NTWK.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 889/975: INTG.O
# ✅ Lasso done for INTG.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 890/975: DRRX.O
# ✅ Lasso done for DRRX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 891/975: IGC
# ✅ Lasso done for IGC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 892/975: TRT
# ✅ Lasso done for TRT | Best alpha: 10.0
#
# 🔴 Lasso - Stock 893/975: ENZ
# ✅ Lasso done for ENZ | Best alpha: 0.01
#
# 🔴 Lasso - Stock 894/975: GTIM.O
# ✅ Lasso done for GTIM.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 895/975: TENX.O
# ✅ Lasso done for TENX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 896/975: CKX
# ✅ Lasso done for CKX | Best alpha: 0.1
#
# 🔴 Lasso - Stock 897/975: CRIS.O
# ✅ Lasso done for CRIS.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 898/975: CVM
# ✅ Lasso done for CVM | Best alpha: 10.0
#
# 🔴 Lasso - Stock 899/975: CYTH.O
# ✅ Lasso done for CYTH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 900/975: DAIO.O
# ✅ Lasso done for DAIO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 901/975: JOB
# ✅ Lasso done for JOB | Best alpha: 10.0
#
# 🔴 Lasso - Stock 902/975: RVP
# ✅ Lasso done for RVP | Best alpha: 0.01
#
# 🔴 Lasso - Stock 903/975: INTZ.O
# ✅ Lasso done for INTZ.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 904/975: NAII.O
# ✅ Lasso done for NAII.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 905/975: CVV.O
# ✅ Lasso done for CVV.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 906/975: LSTA.O
# ✅ Lasso done for LSTA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 907/975: PTN
# ✅ Lasso done for PTN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 908/975: CREX.O
# ✅ Lasso done for CREX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 909/975: MXC
# ✅ Lasso done for MXC | Best alpha: 10.0
#
# 🔴 Lasso - Stock 910/975: MTEX.O
# ✅ Lasso done for MTEX.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 911/975: NNVC.K
# ✅ Lasso done for NNVC.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 912/975: IRIX.O
# ✅ Lasso done for IRIX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 913/975: AMS
# ✅ Lasso done for AMS | Best alpha: 1.0
#
# 🔴 Lasso - Stock 914/975: SIF
# ✅ Lasso done for SIF | Best alpha: 10.0
#
# 🔴 Lasso - Stock 915/975: BRN
# ✅ Lasso done for BRN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 916/975: NEPH.O
# ✅ Lasso done for NEPH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 917/975: HUSA.K
# ✅ Lasso done for HUSA.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 918/975: CLRO.O
# ✅ Lasso done for CLRO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 919/975: COHN.K
# ✅ Lasso done for COHN.K | Best alpha: 1.0
#
# 🔴 Lasso - Stock 920/975: ELSE.O
# ✅ Lasso done for ELSE.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 921/975: MEIP.O
# ✅ Lasso done for MEIP.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 922/975: TAIT.O
# ✅ Lasso done for TAIT.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 923/975: JCTC.O
# ✅ Lasso done for JCTC.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 924/975: CLRB.O
# ✅ Lasso done for CLRB.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 925/975: GOVX.O
# ✅ Lasso done for GOVX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 926/975: GPUS.K
# ✅ Lasso done for GPUS.K | Best alpha: 0.01
#
# 🔴 Lasso - Stock 927/975: ERNA.O
# ✅ Lasso done for ERNA.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 928/975: AIRI.K
# ✅ Lasso done for AIRI.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 929/975: SMSI.O
# ✅ Lasso done for SMSI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 930/975: STRM.O
# ✅ Lasso done for STRM.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 931/975: IMNN.O
# ✅ Lasso done for IMNN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 932/975: AWX
# ✅ Lasso done for AWX | Best alpha: 10.0
#
# 🔴 Lasso - Stock 933/975: BCDA.O
# ✅ Lasso done for BCDA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 934/975: MTR
# ✅ Lasso done for MTR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 935/975: PRPH.O
# ✅ Lasso done for PRPH.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 936/975: SSKN.O
# ✅ Lasso done for SSKN.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 937/975: ASTC.O
# ✅ Lasso done for ASTC.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 938/975: PMCB.O
# ✅ Lasso done for PMCB.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 939/975: PRPO.O
# ✅ Lasso done for PRPO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 940/975: BBGI.O
# ✅ Lasso done for BBGI.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 941/975: MSN
# ✅ Lasso done for MSN | Best alpha: 10.0
#
# 🔴 Lasso - Stock 942/975: BCLI.O
# ✅ Lasso done for BCLI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 943/975: NURO.O
# ✅ Lasso done for NURO.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 944/975: SCKT.O
# ✅ Lasso done for SCKT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 945/975: ARTW.O
# ✅ Lasso done for ARTW.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 946/975: AIMD.O
# ✅ Lasso done for AIMD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 947/975: AIM
# ✅ Lasso done for AIM | Best alpha: 10.0
#
# 🔴 Lasso - Stock 948/975: STRR.O
# ✅ Lasso done for STRR.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 949/975: SSY
# ✅ Lasso done for SSY | Best alpha: 0.01
#
# 🔴 Lasso - Stock 950/975: GTBP.O
# ✅ Lasso done for GTBP.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 951/975: SGMA.O
# ✅ Lasso done for SGMA.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 952/975: OGEN.K
# ✅ Lasso done for OGEN.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 953/975: RIME.O
# ✅ Lasso done for RIME.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 954/975: SNGX.O
# ✅ Lasso done for SNGX.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 955/975: SNOA.O
# ✅ Lasso done for SNOA.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 956/975: AEMD.O
# ✅ Lasso done for AEMD.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 957/975: GBR
# ✅ Lasso done for GBR | Best alpha: 10.0
#
# 🔴 Lasso - Stock 958/975: KNW
# ✅ Lasso done for KNW | Best alpha: 0.01
#
# 🔴 Lasso - Stock 959/975: BKYI.O
# ✅ Lasso done for BKYI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 960/975: UUU
# ✅ Lasso done for UUU | Best alpha: 10.0
#
# 🔴 Lasso - Stock 961/975: PSTV.O
# ✅ Lasso done for PSTV.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 962/975: FORD.O
# ✅ Lasso done for FORD.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 963/975: AYRO.O
# ✅ Lasso done for AYRO.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 964/975: TTNP.O
# ✅ Lasso done for TTNP.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 965/975: TOVX.K
# ✅ Lasso done for TOVX.K | Best alpha: 10.0
#
# 🔴 Lasso - Stock 966/975: PRSO.O
# ✅ Lasso done for PRSO.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 967/975: PALI.O
# ✅ Lasso done for PALI.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 968/975: APDN.O
# ✅ Lasso done for APDN.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 969/975: SBET.O
# ✅ Lasso done for SBET.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 970/975: ASTI.O
# ✅ Lasso done for ASTI.O | Best alpha: 0.1
#
# 🔴 Lasso - Stock 971/975: AWH.O
# ✅ Lasso done for AWH.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 972/975: SUNE.O
# ✅ Lasso done for SUNE.O | Best alpha: 1.0
#
# 🔴 Lasso - Stock 973/975: TCRT.O
# ✅ Lasso done for TCRT.O | Best alpha: 0.01
#
# 🔴 Lasso - Stock 974/975: WINT.O
# ✅ Lasso done for WINT.O | Best alpha: 10.0
#
# 🔴 Lasso - Stock 975/975: DGLY.O
# ✅ Lasso done for DGLY.O | Best alpha: 10.0
#
# 🟩 Finished all stocks | Total Time: 443.40 seconds

# %% [markdown]
# ### Hyperparameter Tuning - ElasticNet

# %%
# Define the Fama-French factor columns
ff_3_factors = ['Date', 'Mkt-RF', 'SMB', 'HML', 'RF']

# Get list of stock columns (everything except the FF factors and 'Period')
stock_columns = [col for col in three_ff_cleaned_df.columns if col not in ff_3_factors]

# Start global timer
start_all = time.time()

# ------------------ ElasticNet Regression ------------------

all_elastic_results = []
best_elastic_models = {}

for idx, stock in enumerate(stock_columns):
    print(f"\n🟠 ElasticNet - Stock {idx + 1}/{len(stock_columns)}: {stock}")
    start_time = time.time()

    # Subset and process
    df_subset = three_ff_cleaned_df[ff_3_factors + [stock]].copy()
    df_subset['Stock_Return'] = df_subset[[stock]]
    df_subset['Excess_Mkt_Return'] = df_subset['Mkt-RF'] - df_subset['RF']
    df_subset = df_subset[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
    
    # Shift return behind by 1 to align predictors at t with return at t+1
    df_subset['Stock_Return_Shifted'] = df_subset['Stock_Return'].shift(-1)

    # Drop the first row which now has NaN in 'Stock_Return_Shifted'
    df_subset = df_subset.dropna()

    # Standardize the predictors
    scaler = StandardScaler()
    df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']] = scaler.fit_transform(df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']])

    elastic_results = []
    for alpha in alphas:
        for l1_ratio in l1_ratios:
            model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=random_seed, max_iter=10000)
            val_rmse_list = []

            for i in range(train_size, train_size + val_size - 3):
                train_end = month_periods[i - 1]
                val_start = month_periods[i]
                val_end = month_periods[i + 2]

                train_mask = df_subset['Date'].dt.to_period('M') <= train_end
                val_mask = (df_subset['Date'].dt.to_period('M') >= val_start) & (df_subset['Date'].dt.to_period('M') <= val_end)

                X_train = df_subset.loc[train_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
                y_train = df_subset.loc[train_mask, 'Stock_Return_Shifted']
                X_val = df_subset.loc[val_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
                y_val = df_subset.loc[val_mask, 'Stock_Return_Shifted']

                model.fit(X_train, y_train)
                rmse = np.sqrt(mean_squared_error(y_val, model.predict(X_val)))
                val_rmse_list.append(rmse)

            elastic_results.append({
                'Stock': stock,
                'Alpha': alpha,
                'L1_Ratio': l1_ratio,
                'Avg_Validation_RMSE': np.mean(val_rmse_list),
                'Model': model
            })

    elastic_results.sort(key=lambda x: x['Avg_Validation_RMSE'])
    best_elastic_models[stock] = elastic_results[0]['Model']
    all_elastic_results.append(elastic_results[0])
    print(f"✅ ElasticNet done for {stock} | Best α: {elastic_results[0]['Alpha']} | L1: {elastic_results[0]['L1_Ratio']}")
    
# End global timer
end_all = time.time()
print(f"\n🟩 Finished all stocks | Total Time: {end_all - start_all:.2f} seconds")
# Out:
# 🟠 ElasticNet - Stock 1/975: AAPL.O
# ✅ ElasticNet done for AAPL.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 2/975: NVDA.O
# ✅ ElasticNet done for NVDA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 3/975: MSFT.O
# ✅ ElasticNet done for MSFT.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 4/975: AMZN.O
# ✅ ElasticNet done for AMZN.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 5/975: LLY
# ✅ ElasticNet done for LLY | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 6/975: WMT
# ✅ ElasticNet done for WMT | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 7/975: XOM
# ✅ ElasticNet done for XOM | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 8/975: MA
# ✅ ElasticNet done for MA | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 9/975: UNH
# ✅ ElasticNet done for UNH | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 10/975: ORCL.K
# ✅ ElasticNet done for ORCL.K | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 11/975: COST.O
# ✅ ElasticNet done for COST.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 12/975: NFLX.O
# ✅ ElasticNet done for NFLX.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 13/975: HD
# ✅ ElasticNet done for HD | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 14/975: CVX
# ✅ ElasticNet done for CVX | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 15/975: CRM
# ✅ ElasticNet done for CRM | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 16/975: CSCO.O
# ✅ ElasticNet done for CSCO.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 17/975: MRK
# ✅ ElasticNet done for MRK | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 18/975: ABT
# ✅ ElasticNet done for ABT | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 19/975: MCD
# ✅ ElasticNet done for MCD | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 20/975: TMO
# ✅ ElasticNet done for TMO | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 21/975: ISRG.O
# ✅ ElasticNet done for ISRG.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 22/975: RTX
# ✅ ElasticNet done for RTX | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 23/975: QCOM.O
# ✅ ElasticNet done for QCOM.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 24/975: ADBE.O
# ✅ ElasticNet done for ADBE.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 25/975: AMGN.O
# ✅ ElasticNet done for AMGN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 26/975: INTU.O
# ✅ ElasticNet done for INTU.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 27/975: AMD.O
# ✅ ElasticNet done for AMD.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 28/975: CAT
# ✅ ElasticNet done for CAT | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 29/975: TXN.O
# ✅ ElasticNet done for TXN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 30/975: NEE
# ✅ ElasticNet done for NEE | Best α: 0.01 | L1: 0.5
#
# 🟠 ElasticNet - Stock 31/975: DHR
# ✅ ElasticNet done for DHR | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 32/975: PFE
# ✅ ElasticNet done for PFE | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 33/975: BLK
# ✅ ElasticNet done for BLK | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 34/975: UNP
# ✅ ElasticNet done for UNP | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 35/975: BSX
# ✅ ElasticNet done for BSX | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 36/975: SYK
# ✅ ElasticNet done for SYK | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 37/975: GILD.O
# ✅ ElasticNet done for GILD.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 38/975: HON.O
# ✅ ElasticNet done for HON.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 39/975: CMCSA.O
# ✅ ElasticNet done for CMCSA.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 40/975: VRTX.O
# ✅ ElasticNet done for VRTX.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 41/975: DE
# ✅ ElasticNet done for DE | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 42/975: TJX
# ✅ ElasticNet done for TJX | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 43/975: COP
# ✅ ElasticNet done for COP | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 44/975: LOW
# ✅ ElasticNet done for LOW | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 45/975: BA
# ✅ ElasticNet done for BA | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 46/975: FI
# ✅ ElasticNet done for FI | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 47/975: BMY
# ✅ ElasticNet done for BMY | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 48/975: ADP.O
# ✅ ElasticNet done for ADP.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 49/975: MMC
# ✅ ElasticNet done for MMC | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 50/975: MU.O
# ✅ ElasticNet done for MU.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 51/975: NKE
# ✅ ElasticNet done for NKE | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 52/975: INTC.O
# ✅ ElasticNet done for INTC.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 53/975: ADI.O
# ✅ ElasticNet done for ADI.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 54/975: LRCX.O
# ✅ ElasticNet done for LRCX.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 55/975: ELV
# ✅ ElasticNet done for ELV | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 56/975: KLAC.O
# ✅ ElasticNet done for KLAC.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 57/975: DUK
# ✅ ElasticNet done for DUK | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 58/975: CI
# ✅ ElasticNet done for CI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 59/975: AJG
# ✅ ElasticNet done for AJG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 60/975: CVS
# ✅ ElasticNet done for CVS | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 61/975: MMM
# ✅ ElasticNet done for MMM | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 62/975: MCK
# ✅ ElasticNet done for MCK | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 63/975: APH
# ✅ ElasticNet done for APH | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 64/975: ORLY.O
# ✅ ElasticNet done for ORLY.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 65/975: REGN.O
# ✅ ElasticNet done for REGN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 66/975: CL
# ✅ ElasticNet done for CL | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 67/975: RSG
# ✅ ElasticNet done for RSG | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 68/975: NOC
# ✅ ElasticNet done for NOC | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 69/975: WMB
# ✅ ElasticNet done for WMB | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 70/975: MSI
# ✅ ElasticNet done for MSI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 71/975: SNPS.O
# ✅ ElasticNet done for SNPS.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 72/975: EOG
# ✅ ElasticNet done for EOG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 73/975: CDNS.O
# ✅ ElasticNet done for CDNS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 74/975: CMG
# ✅ ElasticNet done for CMG | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 75/975: MAR.O
# ✅ ElasticNet done for MAR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 76/975: BDX
# ✅ ElasticNet done for BDX | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 77/975: ROP.O
# ✅ ElasticNet done for ROP.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 78/975: OKE
# ✅ ElasticNet done for OKE | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 79/975: AZO
# ✅ ElasticNet done for AZO | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 80/975: MRVL.O
# ✅ ElasticNet done for MRVL.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 81/975: BK
# ✅ ElasticNet done for BK | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 82/975: CSX.O
# ✅ ElasticNet done for CSX.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 83/975: SLB
# ✅ ElasticNet done for SLB | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 84/975: MET
# ✅ ElasticNet done for MET | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 85/975: ADSK.O
# ✅ ElasticNet done for ADSK.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 86/975: TFC
# ✅ ElasticNet done for TFC | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 87/975: PCAR.O
# ✅ ElasticNet done for PCAR.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 88/975: COR
# ✅ ElasticNet done for COR | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 89/975: LNG
# ✅ ElasticNet done for LNG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 90/975: TGT
# ✅ ElasticNet done for TGT | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 91/975: KR
# ✅ ElasticNet done for KR | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 92/975: D
# ✅ ElasticNet done for D | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 93/975: HES
# ✅ ElasticNet done for HES | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 94/975: FICO.K
# ✅ ElasticNet done for FICO.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 95/975: OXY
# ✅ ElasticNet done for OXY | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 96/975: BKR.O
# ✅ ElasticNet done for BKR.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 97/975: ROST.O
# ✅ ElasticNet done for ROST.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 98/975: EW
# ✅ ElasticNet done for EW | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 99/975: VLO
# ✅ ElasticNet done for VLO | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 100/975: AME
# ✅ ElasticNet done for AME | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 101/975: GLW
# ✅ ElasticNet done for GLW | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 102/975: DHI
# ✅ ElasticNet done for DHI | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 103/975: LHX
# ✅ ElasticNet done for LHX | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 104/975: CTSH.O
# ✅ ElasticNet done for CTSH.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 105/975: PWR
# ✅ ElasticNet done for PWR | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 106/975: F
# ✅ ElasticNet done for F | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 107/975: EA.O
# ✅ ElasticNet done for EA.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 108/975: TTWO.O
# ✅ ElasticNet done for TTWO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 109/975: A
# ✅ ElasticNet done for A | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 110/975: ODFL.O
# ✅ ElasticNet done for ODFL.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 111/975: BRO
# ✅ ElasticNet done for BRO | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 112/975: IDXX.O
# ✅ ElasticNet done for IDXX.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 113/975: CSGP.O
# ✅ ElasticNet done for CSGP.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 114/975: ALNY.O
# ✅ ElasticNet done for ALNY.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 115/975: HEI
# ✅ ElasticNet done for HEI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 116/975: LVS
# ✅ ElasticNet done for LVS | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 117/975: CAH
# ✅ ElasticNet done for CAH | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 118/975: WAB
# ✅ ElasticNet done for WAB | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 119/975: HUM
# ✅ ElasticNet done for HUM | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 120/975: NUE
# ✅ ElasticNet done for NUE | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 121/975: EBAY.O
# ✅ ElasticNet done for EBAY.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 122/975: TPL
# ✅ ElasticNet done for TPL | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 123/975: EQT
# ✅ ElasticNet done for EQT | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 124/975: ROK
# ✅ ElasticNet done for ROK | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 125/975: MPWR.O
# ✅ ElasticNet done for MPWR.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 126/975: MCHP.O
# ✅ ElasticNet done for MCHP.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 127/975: ANSS.O
# ✅ ElasticNet done for ANSS.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 128/975: DTE
# ✅ ElasticNet done for DTE | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 129/975: DXCM.O
# ✅ ElasticNet done for DXCM.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 130/975: IP
# ✅ ElasticNet done for IP | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 131/975: AEE
# ✅ ElasticNet done for AEE | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 132/975: PPG
# ✅ ElasticNet done for PPG | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 133/975: PPL
# ✅ ElasticNet done for PPL | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 134/975: MTD
# ✅ ElasticNet done for MTD | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 135/975: WBD.O
# ✅ ElasticNet done for WBD.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 136/975: TYL
# ✅ ElasticNet done for TYL | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 137/975: EL
# ✅ ElasticNet done for EL | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 138/975: ATO
# ✅ ElasticNet done for ATO | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 139/975: GPN
# ✅ ElasticNet done for GPN | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 140/975: TDY
# ✅ ElasticNet done for TDY | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 141/975: VRSN.O
# ✅ ElasticNet done for VRSN.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 142/975: DVN
# ✅ ElasticNet done for DVN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 143/975: WAT
# ✅ ElasticNet done for WAT | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 144/975: ERIE.O
# ✅ ElasticNet done for ERIE.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 145/975: ZBH
# ✅ ElasticNet done for ZBH | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 146/975: DRI
# ✅ ElasticNet done for DRI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 147/975: HAL
# ✅ ElasticNet done for HAL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 148/975: NVR
# ✅ ElasticNet done for NVR | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 149/975: TSN
# ✅ ElasticNet done for TSN | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 150/975: CTRA.K
# ✅ ElasticNet done for CTRA.K | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 151/975: PHM
# ✅ ElasticNet done for PHM | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 152/975: TROW.O
# ✅ ElasticNet done for TROW.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 153/975: LII
# ✅ ElasticNet done for LII | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 154/975: BIIB.O
# ✅ ElasticNet done for BIIB.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 155/975: LH
# ✅ ElasticNet done for LH | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 156/975: STLD.O
# ✅ ElasticNet done for STLD.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 157/975: NRG
# ✅ ElasticNet done for NRG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 158/975: DGX
# ✅ ElasticNet done for DGX | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 159/975: LUV
# ✅ ElasticNet done for LUV | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 160/975: PTC.O
# ✅ ElasticNet done for PTC.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 161/975: NTAP.O
# ✅ ElasticNet done for NTAP.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 162/975: ON.O
# ✅ ElasticNet done for ON.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 163/975: CLX
# ✅ ElasticNet done for CLX | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 164/975: DECK.K
# ✅ ElasticNet done for DECK.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 165/975: FNF
# ✅ ElasticNet done for FNF | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 166/975: BAX
# ✅ ElasticNet done for BAX | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 167/975: EME
# ✅ ElasticNet done for EME | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 168/975: TRMB.O
# ✅ ElasticNet done for TRMB.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 169/975: GPC
# ✅ ElasticNet done for GPC | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 170/975: GEN.O
# ✅ ElasticNet done for GEN.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 171/975: WST
# ✅ ElasticNet done for WST | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 172/975: HRL
# ✅ ElasticNet done for HRL | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 173/975: COO.O
# ✅ ElasticNet done for COO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 174/975: EXPD.K
# ✅ ElasticNet done for EXPD.K | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 175/975: WDC.O
# ✅ ElasticNet done for WDC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 176/975: BBY
# ✅ ElasticNet done for BBY | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 177/975: FFIV.O
# ✅ ElasticNet done for FFIV.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 178/975: RS
# ✅ ElasticNet done for RS | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 179/975: RPM
# ✅ ElasticNet done for RPM | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 180/975: JBL
# ✅ ElasticNet done for JBL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 181/975: ENTG.O
# ✅ ElasticNet done for ENTG.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 182/975: BALL.K
# ✅ ElasticNet done for BALL.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 183/975: BLDR.K
# ✅ ElasticNet done for BLDR.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 184/975: FSLR.O
# ✅ ElasticNet done for FSLR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 185/975: GGG
# ✅ ElasticNet done for GGG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 186/975: TER.O
# ✅ ElasticNet done for TER.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 187/975: UNM
# ✅ ElasticNet done for UNM | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 188/975: DLTR.O
# ✅ ElasticNet done for DLTR.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 189/975: INSM.O
# ✅ ElasticNet done for INSM.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 190/975: UTHR.O
# ✅ ElasticNet done for UTHR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 191/975: HOLX.O
# ✅ ElasticNet done for HOLX.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 192/975: ILMN.O
# ✅ ElasticNet done for ILMN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 193/975: RVTY.K
# ✅ ElasticNet done for RVTY.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 194/975: BMRN.O
# ✅ ElasticNet done for BMRN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 195/975: FLEX.O
# ✅ ElasticNet done for FLEX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 196/975: INCY.O
# ✅ ElasticNet done for INCY.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 197/975: JKHY.O
# ✅ ElasticNet done for JKHY.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 198/975: MORN.O
# ✅ ElasticNet done for MORN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 199/975: ALGN.O
# ✅ ElasticNet done for ALGN.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 200/975: EWBC.O
# ✅ ElasticNet done for EWBC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 201/975: AKAM.O
# ✅ ElasticNet done for AKAM.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 202/975: FIX
# ✅ ElasticNet done for FIX | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 203/975: JNPR.K
# ✅ ElasticNet done for JNPR.K | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 204/975: SJM
# ✅ ElasticNet done for SJM | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 205/975: JLL
# ✅ ElasticNet done for JLL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 206/975: NDSN.O
# ✅ ElasticNet done for NDSN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 207/975: CHRW.O
# ✅ ElasticNet done for CHRW.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 208/975: THC
# ✅ ElasticNet done for THC | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 209/975: JEF
# ✅ ElasticNet done for JEF | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 210/975: COKE.O
# ✅ ElasticNet done for COKE.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 211/975: TXRH.O
# ✅ ElasticNet done for TXRH.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 212/975: SWKS.O
# ✅ ElasticNet done for SWKS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 213/975: NBIX.O
# ✅ ElasticNet done for NBIX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 214/975: ITT
# ✅ ElasticNet done for ITT | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 215/975: VTRS.O
# ✅ ElasticNet done for VTRS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 216/975: SNX
# ✅ ElasticNet done for SNX | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 217/975: AIZ
# ✅ ElasticNet done for AIZ | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 218/975: RBC
# ✅ ElasticNet done for RBC | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 219/975: OVV
# ✅ ElasticNet done for OVV | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 220/975: MANH.O
# ✅ ElasticNet done for MANH.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 221/975: EMN
# ✅ ElasticNet done for EMN | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 222/975: CCK
# ✅ ElasticNet done for CCK | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 223/975: TOL
# ✅ ElasticNet done for TOL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 224/975: CLH
# ✅ ElasticNet done for CLH | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 225/975: GME
# ✅ ElasticNet done for GME | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 226/975: EXEL.O
# ✅ ElasticNet done for EXEL.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 227/975: RGLD.O
# ✅ ElasticNet done for RGLD.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 228/975: COHR.K
# ✅ ElasticNet done for COHR.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 229/975: DOX.O
# ✅ ElasticNet done for DOX.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 230/975: IPG
# ✅ ElasticNet done for IPG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 231/975: TECH.O
# ✅ ElasticNet done for TECH.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 232/975: ATR
# ✅ ElasticNet done for ATR | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 233/975: WBA.O
# ✅ ElasticNet done for WBA.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 234/975: MTZ
# ✅ ElasticNet done for MTZ | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 235/975: SRPT.O
# ✅ ElasticNet done for SRPT.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 236/975: SAIA.O
# ✅ ElasticNet done for SAIA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 237/975: SEIC.O
# ✅ ElasticNet done for SEIC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 238/975: RRC
# ✅ ElasticNet done for RRC | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 239/975: WYNN.O
# ✅ ElasticNet done for WYNN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 240/975: CRS
# ✅ ElasticNet done for CRS | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 241/975: CIEN.K
# ✅ ElasticNet done for CIEN.K | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 242/975: ALB
# ✅ ElasticNet done for ALB | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 243/975: X
# ✅ ElasticNet done for X | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 244/975: HSIC.O
# ✅ ElasticNet done for HSIC.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 245/975: LNW.O
# ✅ ElasticNet done for LNW.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 246/975: CHE
# ✅ ElasticNet done for CHE | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 247/975: CRL
# ✅ ElasticNet done for CRL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 248/975: DRS.O
# ✅ ElasticNet done for DRS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 249/975: RGEN.O
# ✅ ElasticNet done for RGEN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 250/975: LSCC.O
# ✅ ElasticNet done for LSCC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 251/975: EXAS.O
# ✅ ElasticNet done for EXAS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 252/975: HAS.O
# ✅ ElasticNet done for HAS.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 253/975: PARA.O
# ✅ ElasticNet done for PARA.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 254/975: DCI
# ✅ ElasticNet done for DCI | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 255/975: CHDN.O
# ✅ ElasticNet done for CHDN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 256/975: MKTX.O
# ✅ ElasticNet done for MKTX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 257/975: NYT
# ✅ ElasticNet done for NYT | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 258/975: WCC
# ✅ ElasticNet done for WCC | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 259/975: DLB
# ✅ ElasticNet done for DLB | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 260/975: EVR
# ✅ ElasticNet done for EVR | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 261/975: TTEK.O
# ✅ ElasticNet done for TTEK.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 262/975: RRX
# ✅ ElasticNet done for RRX | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 263/975: SIRI.O
# ✅ ElasticNet done for SIRI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 264/975: HALO.O
# ✅ ElasticNet done for HALO.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 265/975: GAP
# ✅ ElasticNet done for GAP | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 266/975: EXLS.O
# ✅ ElasticNet done for EXLS.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 267/975: ATI
# ✅ ElasticNet done for ATI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 268/975: TTC
# ✅ ElasticNet done for TTC | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 269/975: ZION.O
# ✅ ElasticNet done for ZION.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 270/975: BIO
# ✅ ElasticNet done for BIO | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 271/975: MHK
# ✅ ElasticNet done for MHK | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 272/975: APA.O
# ✅ ElasticNet done for APA.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 273/975: CVLT.O
# ✅ ElasticNet done for CVLT.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 274/975: AGCO.K
# ✅ ElasticNet done for AGCO.K | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 275/975: BRKR.O
# ✅ ElasticNet done for BRKR.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 276/975: RLI
# ✅ ElasticNet done for RLI | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 277/975: IVZ
# ✅ ElasticNet done for IVZ | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 278/975: ONTO.K
# ✅ ElasticNet done for ONTO.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 279/975: CWST.O
# ✅ ElasticNet done for CWST.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 280/975: QRVO.O
# ✅ ElasticNet done for QRVO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 281/975: AAON.O
# ✅ ElasticNet done for AAON.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 282/975: ALK
# ✅ ElasticNet done for ALK | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 283/975: UFPI.O
# ✅ ElasticNet done for UFPI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 284/975: FLS
# ✅ ElasticNet done for FLS | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 285/975: SNV
# ✅ ElasticNet done for SNV | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 286/975: TGTX.O
# ✅ ElasticNet done for TGTX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 287/975: TFX
# ✅ ElasticNet done for TFX | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 288/975: CELH.O
# ✅ ElasticNet done for CELH.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 289/975: EAT
# ✅ ElasticNet done for EAT | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 290/975: PEGA.O
# ✅ ElasticNet done for PEGA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 291/975: OSK
# ✅ ElasticNet done for OSK | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 292/975: LNC
# ✅ ElasticNet done for LNC | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 293/975: AWI
# ✅ ElasticNet done for AWI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 294/975: CHH
# ✅ ElasticNet done for CHH | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 295/975: WEX
# ✅ ElasticNet done for WEX | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 296/975: CORT.O
# ✅ ElasticNet done for CORT.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 297/975: MSA
# ✅ ElasticNet done for MSA | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 298/975: RMBS.O
# ✅ ElasticNet done for RMBS.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 299/975: FCN
# ✅ ElasticNet done for FCN | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 300/975: BMI
# ✅ ElasticNet done for BMI | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 301/975: MMSI.O
# ✅ ElasticNet done for MMSI.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 302/975: MKSI.O
# ✅ ElasticNet done for MKSI.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 303/975: CACC.O
# ✅ ElasticNet done for CACC.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 304/975: BYD
# ✅ ElasticNet done for BYD | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 305/975: DDS
# ✅ ElasticNet done for DDS | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 306/975: IDCC.O
# ✅ ElasticNet done for IDCC.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 307/975: ACIW.O
# ✅ ElasticNet done for ACIW.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 308/975: USM
# ✅ ElasticNet done for USM | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 309/975: CROX.O
# ✅ ElasticNet done for CROX.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 310/975: GNTX.O
# ✅ ElasticNet done for GNTX.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 311/975: CRVL.O
# ✅ ElasticNet done for CRVL.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 312/975: ARW
# ✅ ElasticNet done for ARW | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 313/975: NOV
# ✅ ElasticNet done for NOV | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 314/975: RHI
# ✅ ElasticNet done for RHI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 315/975: SKY
# ✅ ElasticNet done for SKY | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 316/975: CRK
# ✅ ElasticNet done for CRK | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 317/975: OPCH.O
# ✅ ElasticNet done for OPCH.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 318/975: CGNX.O
# ✅ ElasticNet done for CGNX.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 319/975: LSTR.O
# ✅ ElasticNet done for LSTR.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 320/975: CRUS.O
# ✅ ElasticNet done for CRUS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 321/975: CMC
# ✅ ElasticNet done for CMC | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 322/975: CYTK.O
# ✅ ElasticNet done for CYTK.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 323/975: QXO
# ✅ ElasticNet done for QXO | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 324/975: IONS.O
# ✅ ElasticNet done for IONS.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 325/975: TKR
# ✅ ElasticNet done for TKR | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 326/975: LFUS.O
# ✅ ElasticNet done for LFUS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 327/975: NXST.O
# ✅ ElasticNet done for NXST.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 328/975: LAZ
# ✅ ElasticNet done for LAZ | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 329/975: MTH
# ✅ ElasticNet done for MTH | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 330/975: TXNM.K
# ✅ ElasticNet done for TXNM.K | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 331/975: LUMN.K
# ✅ ElasticNet done for LUMN.K | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 332/975: POR
# ✅ ElasticNet done for POR | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 333/975: AMKR.O
# ✅ ElasticNet done for AMKR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 334/975: NSIT.O
# ✅ ElasticNet done for NSIT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 335/975: AMG
# ✅ ElasticNet done for AMG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 336/975: ITRI.O
# ✅ ElasticNet done for ITRI.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 337/975: FSS
# ✅ ElasticNet done for FSS | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 338/975: HXL
# ✅ ElasticNet done for HXL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 339/975: FELE.O
# ✅ ElasticNet done for FELE.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 340/975: CNX
# ✅ ElasticNet done for CNX | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 341/975: DY
# ✅ ElasticNet done for DY | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 342/975: URBN.O
# ✅ ElasticNet done for URBN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 343/975: PIPR.K
# ✅ ElasticNet done for PIPR.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 344/975: MOD
# ✅ ElasticNet done for MOD | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 345/975: EEFT.O
# ✅ ElasticNet done for EEFT.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 346/975: BKH
# ✅ ElasticNet done for BKH | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 347/975: KMPR.K
# ✅ ElasticNet done for KMPR.K | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 348/975: KBH
# ✅ ElasticNet done for KBH | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 349/975: MSM
# ✅ ElasticNet done for MSM | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 350/975: THO
# ✅ ElasticNet done for THO | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 351/975: EXPO.O
# ✅ ElasticNet done for EXPO.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 352/975: NNI
# ✅ ElasticNet done for NNI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 353/975: ESE
# ✅ ElasticNet done for ESE | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 354/975: PBH
# ✅ ElasticNet done for PBH | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 355/975: AVT.O
# ✅ ElasticNet done for AVT.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 356/975: SANM.O
# ✅ ElasticNet done for SANM.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 357/975: IPAR.O
# ✅ ElasticNet done for IPAR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 358/975: BDC
# ✅ ElasticNet done for BDC | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 359/975: CVCO.O
# ✅ ElasticNet done for CVCO.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 360/975: SLAB.O
# ✅ ElasticNet done for SLAB.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 361/975: AEIS.O
# ✅ ElasticNet done for AEIS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 362/975: ANF
# ✅ ElasticNet done for ANF | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 363/975: JWN
# ✅ ElasticNet done for JWN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 364/975: ITGR.K
# ✅ ElasticNet done for ITGR.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 365/975: SPR
# ✅ ElasticNet done for SPR | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 366/975: DORM.O
# ✅ ElasticNet done for DORM.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 367/975: ALE
# ✅ ElasticNet done for ALE | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 368/975: MMS
# ✅ ElasticNet done for MMS | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 369/975: FIZZ.O
# ✅ ElasticNet done for FIZZ.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 370/975: TDS
# ✅ ElasticNet done for TDS | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 371/975: CBZ
# ✅ ElasticNet done for CBZ | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 372/975: BCO
# ✅ ElasticNet done for BCO | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 373/975: AVNT.K
# ✅ ElasticNet done for AVNT.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 374/975: AVAV.O
# ✅ ElasticNet done for AVAV.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 375/975: IESC.O
# ✅ ElasticNet done for IESC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 376/975: M
# ✅ ElasticNet done for M | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 377/975: PRIM.K
# ✅ ElasticNet done for PRIM.K | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 378/975: SKYW.O
# ✅ ElasticNet done for SKYW.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 379/975: ICUI.O
# ✅ ElasticNet done for ICUI.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 380/975: KFY
# ✅ ElasticNet done for KFY | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 381/975: RDNT.O
# ✅ ElasticNet done for RDNT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 382/975: NWE.O
# ✅ ElasticNet done for NWE.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 383/975: SM
# ✅ ElasticNet done for SM | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 384/975: SMTC.O
# ✅ ElasticNet done for SMTC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 385/975: CCOI.O
# ✅ ElasticNet done for CCOI.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 386/975: PLXS.O
# ✅ ElasticNet done for PLXS.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 387/975: NSP
# ✅ ElasticNet done for NSP | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 388/975: HAE
# ✅ ElasticNet done for HAE | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 389/975: POWI.O
# ✅ ElasticNet done for POWI.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 390/975: AVA
# ✅ ElasticNet done for AVA | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 391/975: TNL
# ✅ ElasticNet done for TNL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 392/975: MHO
# ✅ ElasticNet done for MHO | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 393/975: DXC
# ✅ ElasticNet done for DXC | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 394/975: BLKB.O
# ✅ ElasticNet done for BLKB.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 395/975: XRAY.O
# ✅ ElasticNet done for XRAY.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 396/975: OSIS.O
# ✅ ElasticNet done for OSIS.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 397/975: HOG
# ✅ ElasticNet done for HOG | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 398/975: PTEN.O
# ✅ ElasticNet done for PTEN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 399/975: AMED.O
# ✅ ElasticNet done for AMED.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 400/975: ASGN.K
# ✅ ElasticNet done for ASGN.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 401/975: CPK
# ✅ ElasticNet done for CPK | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 402/975: ACAD.O
# ✅ ElasticNet done for ACAD.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 403/975: NOG
# ✅ ElasticNet done for NOG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 404/975: FUL
# ✅ ElasticNet done for FUL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 405/975: PATK.O
# ✅ ElasticNet done for PATK.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 406/975: TGNA.K
# ✅ ElasticNet done for TGNA.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 407/975: MAN
# ✅ ElasticNet done for MAN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 408/975: MGRC.O
# ✅ ElasticNet done for MGRC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 409/975: GNW
# ✅ ElasticNet done for GNW | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 410/975: PDCO.O
# ✅ ElasticNet done for PDCO.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 411/975: NWL.O
# ✅ ElasticNet done for NWL.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 412/975: GEF
# ✅ ElasticNet done for GEF | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 413/975: GSAT.O
# ✅ ElasticNet done for GSAT.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 414/975: TEX
# ✅ ElasticNet done for TEX | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 415/975: IPGP.O
# ✅ ElasticNet done for IPGP.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 416/975: PENN.O
# ✅ ElasticNet done for PENN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 417/975: JOE
# ✅ ElasticNet done for JOE | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 418/975: HURN.O
# ✅ ElasticNet done for HURN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 419/975: JJSF.O
# ✅ ElasticNet done for JJSF.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 420/975: GT.O
# ✅ ElasticNet done for GT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 421/975: SAM
# ✅ ElasticNet done for SAM | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 422/975: HP
# ✅ ElasticNet done for HP | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 423/975: PSMT.O
# ✅ ElasticNet done for PSMT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 424/975: CPRX.O
# ✅ ElasticNet done for CPRX.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 425/975: FORM.O
# ✅ ElasticNet done for FORM.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 426/975: SYNA.O
# ✅ ElasticNet done for SYNA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 427/975: QDEL.O
# ✅ ElasticNet done for QDEL.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 428/975: VIAV.O
# ✅ ElasticNet done for VIAV.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 429/975: VICR.O
# ✅ ElasticNet done for VICR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 430/975: BFH
# ✅ ElasticNet done for BFH | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 431/975: PRGS.O
# ✅ ElasticNet done for PRGS.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 432/975: TRN
# ✅ ElasticNet done for TRN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 433/975: CAKE.O
# ✅ ElasticNet done for CAKE.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 434/975: WLY
# ✅ ElasticNet done for WLY | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 435/975: PAR
# ✅ ElasticNet done for PAR | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 436/975: VSEC.O
# ✅ ElasticNet done for VSEC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 437/975: LCII.K
# ✅ ElasticNet done for LCII.K | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 438/975: AIN
# ✅ ElasticNet done for AIN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 439/975: HUBG.O
# ✅ ElasticNet done for HUBG.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 440/975: VCEL.O
# ✅ ElasticNet done for VCEL.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 441/975: AAP
# ✅ ElasticNet done for AAP | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 442/975: ALG
# ✅ ElasticNet done for ALG | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 443/975: OII
# ✅ ElasticNet done for OII | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 444/975: TTMI.O
# ✅ ElasticNet done for TTMI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 445/975: CXW
# ✅ ElasticNet done for CXW | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 446/975: SSRM.O
# ✅ ElasticNet done for SSRM.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 447/975: DIOD.O
# ✅ ElasticNet done for DIOD.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 448/975: AEO
# ✅ ElasticNet done for AEO | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 449/975: ARWR.O
# ✅ ElasticNet done for ARWR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 450/975: WMK
# ✅ ElasticNet done for WMK | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 451/975: AGYS.O
# ✅ ElasticNet done for AGYS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 452/975: LGFa
# ✅ ElasticNet done for LGFa | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 453/975: LGND.O
# ✅ ElasticNet done for LGND.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 454/975: HNI
# ✅ ElasticNet done for HNI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 455/975: JBLU.O
# ✅ ElasticNet done for JBLU.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 456/975: NEOG.O
# ✅ ElasticNet done for NEOG.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 457/975: HE
# ✅ ElasticNet done for HE | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 458/975: EXTR.O
# ✅ ElasticNet done for EXTR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 459/975: ACLS.O
# ✅ ElasticNet done for ACLS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 460/975: WERN.O
# ✅ ElasticNet done for WERN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 461/975: LMAT.O
# ✅ ElasticNet done for LMAT.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 462/975: CENX.O
# ✅ ElasticNet done for CENX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 463/975: BKE
# ✅ ElasticNet done for BKE | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 464/975: CNMD.K
# ✅ ElasticNet done for CNMD.K | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 465/975: OI
# ✅ ElasticNet done for OI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 466/975: CSGS.O
# ✅ ElasticNet done for CSGS.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 467/975: RAMP.K
# ✅ ElasticNet done for RAMP.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 468/975: IART.O
# ✅ ElasticNet done for IART.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 469/975: ZD.O
# ✅ ElasticNet done for ZD.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 470/975: PBI
# ✅ ElasticNet done for PBI | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 471/975: GBX
# ✅ ElasticNet done for GBX | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 472/975: DVAX.O
# ✅ ElasticNet done for DVAX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 473/975: PLUS.O
# ✅ ElasticNet done for PLUS.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 474/975: AZTA.O
# ✅ ElasticNet done for AZTA.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 475/975: KMT
# ✅ ElasticNet done for KMT | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 476/975: ATRC.O
# ✅ ElasticNet done for ATRC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 477/975: UFPT.O
# ✅ ElasticNet done for UFPT.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 478/975: UNFI.K
# ✅ ElasticNet done for UNFI.K | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 479/975: BCRX.O
# ✅ ElasticNet done for BCRX.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 480/975: STGW.O
# ✅ ElasticNet done for STGW.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 481/975: WKC
# ✅ ElasticNet done for WKC | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 482/975: MNKD.O
# ✅ ElasticNet done for MNKD.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 483/975: MCRI.O
# ✅ ElasticNet done for MCRI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 484/975: APLD.O
# ✅ ElasticNet done for APLD.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 485/975: SRCE.O
# ✅ ElasticNet done for SRCE.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 486/975: OMCL.O
# ✅ ElasticNet done for OMCL.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 487/975: INOD.O
# ✅ ElasticNet done for INOD.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 488/975: FL
# ✅ ElasticNet done for FL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 489/975: NTCT.O
# ✅ ElasticNet done for NTCT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 490/975: EPC
# ✅ ElasticNet done for EPC | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 491/975: ATSG.O
# ✅ ElasticNet done for ATSG.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 492/975: ADEA.O
# ✅ ElasticNet done for ADEA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 493/975: ROG
# ✅ ElasticNet done for ROG | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 494/975: NHC
# ✅ ElasticNet done for NHC | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 495/975: LNN
# ✅ ElasticNet done for LNN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 496/975: PZZA.O
# ✅ ElasticNet done for PZZA.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 497/975: BHE
# ✅ ElasticNet done for BHE | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 498/975: UPBD.O
# ✅ ElasticNet done for UPBD.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 499/975: ANIP.O
# ✅ ElasticNet done for ANIP.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 500/975: CLDX.O
# ✅ ElasticNet done for CLDX.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 501/975: VRNT.O
# ✅ ElasticNet done for VRNT.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 502/975: PLAB.O
# ✅ ElasticNet done for PLAB.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 503/975: VYX
# ✅ ElasticNet done for VYX | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 504/975: DXPE.O
# ✅ ElasticNet done for DXPE.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 505/975: ATEC.O
# ✅ ElasticNet done for ATEC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 506/975: NVAX.O
# ✅ ElasticNet done for NVAX.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 507/975: CTS
# ✅ ElasticNet done for CTS | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 508/975: VSAT.O
# ✅ ElasticNet done for VSAT.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 509/975: NEO.O
# ✅ ElasticNet done for NEO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 510/975: WT
# ✅ ElasticNet done for WT | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 511/975: SCS
# ✅ ElasticNet done for SCS | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 512/975: VECO.O
# ✅ ElasticNet done for VECO.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 513/975: INVX.K
# ✅ ElasticNet done for INVX.K | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 514/975: DCOM.O
# ✅ ElasticNet done for DCOM.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 515/975: EIG
# ✅ ElasticNet done for EIG | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 516/975: HLIT.O
# ✅ ElasticNet done for HLIT.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 517/975: HLX
# ✅ ElasticNet done for HLX | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 518/975: IDT
# ✅ ElasticNet done for IDT | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 519/975: BLFS.O
# ✅ ElasticNet done for BLFS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 520/975: GIII.O
# ✅ ElasticNet done for GIII.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 521/975: CRAI.O
# ✅ ElasticNet done for CRAI.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 522/975: IMKTA.O
# ✅ ElasticNet done for IMKTA.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 523/975: OPK.O
# ✅ ElasticNet done for OPK.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 524/975: SAFT.O
# ✅ ElasticNet done for SAFT.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 525/975: RES
# ✅ ElasticNet done for RES | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 526/975: UCTT.O
# ✅ ElasticNet done for UCTT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 527/975: GYRE.O
# ✅ ElasticNet done for GYRE.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 528/975: MODG.K
# ✅ ElasticNet done for MODG.K | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 529/975: TILE.O
# ✅ ElasticNet done for TILE.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 530/975: MSEX.O
# ✅ ElasticNet done for MSEX.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 531/975: MRTN.O
# ✅ ElasticNet done for MRTN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 532/975: PRG
# ✅ ElasticNet done for PRG | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 533/975: INVA.O
# ✅ ElasticNet done for INVA.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 534/975: DGII.O
# ✅ ElasticNet done for DGII.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 535/975: APOG.O
# ✅ ElasticNet done for APOG.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 536/975: GERN.O
# ✅ ElasticNet done for GERN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 537/975: CLMT.O
# ✅ ElasticNet done for CLMT.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 538/975: BBSI.O
# ✅ ElasticNet done for BBSI.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 539/975: WGO
# ✅ ElasticNet done for WGO | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 540/975: AMN
# ✅ ElasticNet done for AMN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 541/975: AORT.K
# ✅ ElasticNet done for AORT.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 542/975: ALGT.O
# ✅ ElasticNet done for ALGT.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 543/975: SBGI.O
# ✅ ElasticNet done for SBGI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 544/975: GRC
# ...
#
# 🟠 ElasticNet - Stock 800/975: QMCO.O
# ✅ ElasticNet done for QMCO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 801/975: LPSN.O
# ✅ ElasticNet done for LPSN.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 802/975: FONR.O
# ✅ ElasticNet done for FONR.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 803/975: MCHX.O
# ✅ ElasticNet done for MCHX.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 804/975: LPTH.O
# ✅ ElasticNet done for LPTH.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 805/975: HGBL.O
# ✅ ElasticNet done for HGBL.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 806/975: PETS.O
# ✅ ElasticNet done for PETS.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 807/975: DIT
# ✅ ElasticNet done for DIT | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 808/975: AXTI.O
# ✅ ElasticNet done for AXTI.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 809/975: FOSL.O
# ✅ ElasticNet done for FOSL.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 810/975: ALOT.O
# ✅ ElasticNet done for ALOT.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 811/975: HNNA.O
# ✅ ElasticNet done for HNNA.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 812/975: RRGB.O
# ✅ ElasticNet done for RRGB.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 813/975: UBCP.O
# ✅ ElasticNet done for UBCP.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 814/975: MNOV.O
# ✅ ElasticNet done for MNOV.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 815/975: INVE.O
# ✅ ElasticNet done for INVE.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 816/975: SGA.O
# ✅ ElasticNet done for SGA.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 817/975: ESP
# ✅ ElasticNet done for ESP | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 818/975: OPTT.K
# ✅ ElasticNet done for OPTT.K | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 819/975: CODA.O
# ✅ ElasticNet done for CODA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 820/975: AUBN.O
# ✅ ElasticNet done for AUBN.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 821/975: INO.O
# ✅ ElasticNet done for INO.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 822/975: IOR
# ✅ ElasticNet done for IOR | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 823/975: MLSS.K
# ✅ ElasticNet done for MLSS.K | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 824/975: AREN.K
# ✅ ElasticNet done for AREN.K | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 825/975: VERU.O
# ✅ ElasticNet done for VERU.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 826/975: ASYS.O
# ✅ ElasticNet done for ASYS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 827/975: ARMP.K
# ✅ ElasticNet done for ARMP.K | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 828/975: ASRT.O
# ✅ ElasticNet done for ASRT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 829/975: FKWL.O
# ✅ ElasticNet done for FKWL.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 830/975: DOMH.O
# ✅ ElasticNet done for DOMH.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 831/975: DLHC.O
# ✅ ElasticNet done for DLHC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 832/975: PED
# ✅ ElasticNet done for PED | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 833/975: ALTS.O
# ✅ ElasticNet done for ALTS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 834/975: CULP.K
# ✅ ElasticNet done for CULP.K | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 835/975: SUP
# ✅ ElasticNet done for SUP | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 836/975: CATO.K
# ✅ ElasticNet done for CATO.K | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 837/975: CYCC.O
# ✅ ElasticNet done for CYCC.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 838/975: ICAD.O
# ✅ ElasticNet done for ICAD.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 839/975: WFCF.O
# ✅ ElasticNet done for WFCF.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 840/975: LINK.O
# ✅ ElasticNet done for LINK.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 841/975: CTSO.O
# ✅ ElasticNet done for CTSO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 842/975: CNVS.O
# ✅ ElasticNet done for CNVS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 843/975: CNTY.O
# ✅ ElasticNet done for CNTY.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 844/975: MIND.O
# ✅ ElasticNet done for MIND.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 845/975: SOTK.O
# ✅ ElasticNet done for SOTK.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 846/975: RMTI.O
# ✅ ElasticNet done for RMTI.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 847/975: CVGI.O
# ✅ ElasticNet done for CVGI.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 848/975: MBOT.O
# ✅ ElasticNet done for MBOT.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 849/975: LEE.O
# ✅ ElasticNet done for LEE.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 850/975: CMTL.O
# ✅ ElasticNet done for CMTL.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 851/975: KOSS.O
# ✅ ElasticNet done for KOSS.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 852/975: BDL
# ✅ ElasticNet done for BDL | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 853/975: UG.O
# ✅ ElasticNet done for UG.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 854/975: IDN.O
# ✅ ElasticNet done for IDN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 855/975: ICCC.O
# ✅ ElasticNet done for ICCC.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 856/975: CVU
# ✅ ElasticNet done for CVU | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 857/975: AGEN.O
# ✅ ElasticNet done for AGEN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 858/975: REFR.O
# ✅ ElasticNet done for REFR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 859/975: DWSN.O
# ✅ ElasticNet done for DWSN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 860/975: AP
# ✅ ElasticNet done for AP | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 861/975: RFIL.O
# ✅ ElasticNet done for RFIL.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 862/975: USIO.O
# ✅ ElasticNet done for USIO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 863/975: CRWS.O
# ✅ ElasticNet done for CRWS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 864/975: PXLW.O
# ✅ ElasticNet done for PXLW.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 865/975: APYX.O
# ✅ ElasticNet done for APYX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 866/975: TACT.O
# ✅ ElasticNet done for TACT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 867/975: SYPR.O
# ✅ ElasticNet done for SYPR.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 868/975: UONEK.O
# ✅ ElasticNet done for UONEK.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 869/975: ARKR.O
# ✅ ElasticNet done for ARKR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 870/975: HHS.O
# ✅ ElasticNet done for HHS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 871/975: WYY
# ✅ ElasticNet done for WYY | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 872/975: ACCS.K
# ✅ ElasticNet done for ACCS.K | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 873/975: AWRE.O
# ✅ ElasticNet done for AWRE.O | Best α: 0.1 | L1: 0.5
#
# 🟠 ElasticNet - Stock 874/975: AIFF.O
# ✅ ElasticNet done for AIFF.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 875/975: SGRP.O
# ✅ ElasticNet done for SGRP.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 876/975: NTIP.K
# ✅ ElasticNet done for NTIP.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 877/975: VHC
# ✅ ElasticNet done for VHC | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 878/975: FTEK.O
# ✅ ElasticNet done for FTEK.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 879/975: GROW.O
# ✅ ElasticNet done for GROW.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 880/975: IRD.O
# ✅ ElasticNet done for IRD.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 881/975: CMS_pb
# ✅ ElasticNet done for CMS_pb | Best α: 0.1 | L1: 0.5
#
# 🟠 ElasticNet - Stock 882/975: KTCC.O
# ✅ ElasticNet done for KTCC.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 883/975: HSON.O
# ✅ ElasticNet done for HSON.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 884/975: AXDX.O
# ✅ ElasticNet done for AXDX.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 885/975: HBIO.O
# ✅ ElasticNet done for HBIO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 886/975: NSYS.O
# ✅ ElasticNet done for NSYS.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 887/975: OCC.O
# ✅ ElasticNet done for OCC.O | Best α: 0.1 | L1: 0.9
#
# 🟠 ElasticNet - Stock 888/975: NTWK.O
# ✅ ElasticNet done for NTWK.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 889/975: INTG.O
# ✅ ElasticNet done for INTG.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 890/975: DRRX.O
# ✅ ElasticNet done for DRRX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 891/975: IGC
# ✅ ElasticNet done for IGC | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 892/975: TRT
# ✅ ElasticNet done for TRT | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 893/975: ENZ
# ✅ ElasticNet done for ENZ | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 894/975: GTIM.O
# ✅ ElasticNet done for GTIM.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 895/975: TENX.O
# ✅ ElasticNet done for TENX.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 896/975: CKX
# ✅ ElasticNet done for CKX | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 897/975: CRIS.O
# ✅ ElasticNet done for CRIS.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 898/975: CVM
# ✅ ElasticNet done for CVM | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 899/975: CYTH.O
# ✅ ElasticNet done for CYTH.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 900/975: DAIO.O
# ✅ ElasticNet done for DAIO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 901/975: JOB
# ✅ ElasticNet done for JOB | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 902/975: RVP
# ✅ ElasticNet done for RVP | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 903/975: INTZ.O
# ✅ ElasticNet done for INTZ.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 904/975: NAII.O
# ✅ ElasticNet done for NAII.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 905/975: CVV.O
# ✅ ElasticNet done for CVV.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 906/975: LSTA.O
# ✅ ElasticNet done for LSTA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 907/975: PTN
# ✅ ElasticNet done for PTN | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 908/975: CREX.O
# ✅ ElasticNet done for CREX.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 909/975: MXC
# ✅ ElasticNet done for MXC | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 910/975: MTEX.O
# ✅ ElasticNet done for MTEX.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 911/975: NNVC.K
# ✅ ElasticNet done for NNVC.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 912/975: IRIX.O
# ✅ ElasticNet done for IRIX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 913/975: AMS
# ✅ ElasticNet done for AMS | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 914/975: SIF
# ✅ ElasticNet done for SIF | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 915/975: BRN
# ✅ ElasticNet done for BRN | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 916/975: NEPH.O
# ✅ ElasticNet done for NEPH.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 917/975: HUSA.K
# ✅ ElasticNet done for HUSA.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 918/975: CLRO.O
# ✅ ElasticNet done for CLRO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 919/975: COHN.K
# ✅ ElasticNet done for COHN.K | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 920/975: ELSE.O
# ✅ ElasticNet done for ELSE.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 921/975: MEIP.O
# ✅ ElasticNet done for MEIP.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 922/975: TAIT.O
# ✅ ElasticNet done for TAIT.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 923/975: JCTC.O
# ✅ ElasticNet done for JCTC.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 924/975: CLRB.O
# ✅ ElasticNet done for CLRB.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 925/975: GOVX.O
# ✅ ElasticNet done for GOVX.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 926/975: GPUS.K
# ✅ ElasticNet done for GPUS.K | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 927/975: ERNA.O
# ✅ ElasticNet done for ERNA.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 928/975: AIRI.K
# ✅ ElasticNet done for AIRI.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 929/975: SMSI.O
# ✅ ElasticNet done for SMSI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 930/975: STRM.O
# ✅ ElasticNet done for STRM.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 931/975: IMNN.O
# ✅ ElasticNet done for IMNN.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 932/975: AWX
# ✅ ElasticNet done for AWX | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 933/975: BCDA.O
# ✅ ElasticNet done for BCDA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 934/975: MTR
# ✅ ElasticNet done for MTR | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 935/975: PRPH.O
# ✅ ElasticNet done for PRPH.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 936/975: SSKN.O
# ✅ ElasticNet done for SSKN.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 937/975: ASTC.O
# ✅ ElasticNet done for ASTC.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 938/975: PMCB.O
# ✅ ElasticNet done for PMCB.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 939/975: PRPO.O
# ✅ ElasticNet done for PRPO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 940/975: BBGI.O
# ✅ ElasticNet done for BBGI.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 941/975: MSN
# ✅ ElasticNet done for MSN | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 942/975: BCLI.O
# ✅ ElasticNet done for BCLI.O | Best α: 10.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 943/975: NURO.O
# ✅ ElasticNet done for NURO.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 944/975: SCKT.O
# ✅ ElasticNet done for SCKT.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 945/975: ARTW.O
# ✅ ElasticNet done for ARTW.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 946/975: AIMD.O
# ✅ ElasticNet done for AIMD.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 947/975: AIM
# ✅ ElasticNet done for AIM | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 948/975: STRR.O
# ✅ ElasticNet done for STRR.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 949/975: SSY
# ✅ ElasticNet done for SSY | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 950/975: GTBP.O
# ✅ ElasticNet done for GTBP.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 951/975: SGMA.O
# ✅ ElasticNet done for SGMA.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 952/975: OGEN.K
# ✅ ElasticNet done for OGEN.K | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 953/975: RIME.O
# ✅ ElasticNet done for RIME.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 954/975: SNGX.O
# ✅ ElasticNet done for SNGX.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 955/975: SNOA.O
# ✅ ElasticNet done for SNOA.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 956/975: AEMD.O
# ✅ ElasticNet done for AEMD.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 957/975: GBR
# ✅ ElasticNet done for GBR | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 958/975: KNW
# ✅ ElasticNet done for KNW | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 959/975: BKYI.O
# ✅ ElasticNet done for BKYI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 960/975: UUU
# ✅ ElasticNet done for UUU | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 961/975: PSTV.O
# ✅ ElasticNet done for PSTV.O | Best α: 1.0 | L1: 0.1
#
# 🟠 ElasticNet - Stock 962/975: FORD.O
# ✅ ElasticNet done for FORD.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 963/975: AYRO.O
# ✅ ElasticNet done for AYRO.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 964/975: TTNP.O
# ✅ ElasticNet done for TTNP.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 965/975: TOVX.K
# ✅ ElasticNet done for TOVX.K | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 966/975: PRSO.O
# ✅ ElasticNet done for PRSO.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 967/975: PALI.O
# ✅ ElasticNet done for PALI.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 968/975: APDN.O
# ✅ ElasticNet done for APDN.O | Best α: 0.1 | L1: 0.1
#
# 🟠 ElasticNet - Stock 969/975: SBET.O
# ✅ ElasticNet done for SBET.O | Best α: 0.01 | L1: 0.9
#
# 🟠 ElasticNet - Stock 970/975: ASTI.O
# ✅ ElasticNet done for ASTI.O | Best α: 1.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 971/975: AWH.O
# ✅ ElasticNet done for AWH.O | Best α: 10.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 972/975: SUNE.O
# ✅ ElasticNet done for SUNE.O | Best α: 1.0 | L1: 0.9
#
# 🟠 ElasticNet - Stock 973/975: TCRT.O
# ✅ ElasticNet done for TCRT.O | Best α: 0.01 | L1: 0.1
#
# 🟠 ElasticNet - Stock 974/975: WINT.O
# ✅ ElasticNet done for WINT.O | Best α: 10.0 | L1: 0.5
#
# 🟠 ElasticNet - Stock 975/975: DGLY.O
# ✅ ElasticNet done for DGLY.O | Best α: 10.0 | L1: 0.5
#
# 🟩 Finished all stocks | Total Time: 1152.43 seconds

# %% [markdown]
# ### Hyperparameter Tuning - SVR

# %%
# Define the Fama-French factor columns
ff_3_factors = ['Date', 'Mkt-RF', 'SMB', 'HML', 'RF']

# Get list of stock columns (everything except the FF factors and 'Period')
stock_columns = [col for col in three_ff_cleaned_df.columns if col not in ff_3_factors]

# Start global timer
start_all = time.time()

# ------------------ SVR ------------------

all_svr_results = []
best_svr_models = {}

for idx, stock in enumerate(stock_columns):
    print(f"\n🟣 SVR - Stock {idx + 1}/{len(stock_columns)}: {stock}")

    # Subset and process
    df_subset = three_ff_cleaned_df[ff_3_factors + [stock]].copy()
    df_subset['Stock_Return'] = df_subset[[stock]]
    df_subset['Excess_Mkt_Return'] = df_subset['Mkt-RF'] - df_subset['RF']
    df_subset = df_subset[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
    
    # Shift return behind by 1 to align predictors at t with return at t+1
    df_subset['Stock_Return_Shifted'] = df_subset['Stock_Return'].shift(-1)

    # Drop the first row which now has NaN in 'Stock_Return_Shifted'
    df_subset = df_subset.dropna()

    # Standardize the predictors
    scaler = StandardScaler()
    df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']] = scaler.fit_transform(df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']])

    svr_results = []

    for C in svr_C_values:
        for epsilon in svr_epsilons:
            model = SVR(C=C, epsilon=epsilon)
            val_rmse_list = []

            for i in range(train_size, train_size + val_size - 3):
                train_end = month_periods[i - 1]
                val_start = month_periods[i]
                val_end = month_periods[i + 2]

                train_mask = df_subset['Date'].dt.to_period('M') <= train_end
                val_mask = (df_subset['Date'].dt.to_period('M') >= val_start) & (df_subset['Date'].dt.to_period('M') <= val_end)

                X_train = df_subset.loc[train_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
                y_train = df_subset.loc[train_mask, 'Stock_Return_Shifted']
                X_val = df_subset.loc[val_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
                y_val = df_subset.loc[val_mask, 'Stock_Return_Shifted']

                model.fit(X_train, y_train)
                rmse = np.sqrt(mean_squared_error(y_val, model.predict(X_val)))
                val_rmse_list.append(rmse)

            svr_results.append({
                'Stock': stock,
                'C': C,
                'Epsilon': epsilon,
                'Avg_Validation_RMSE': np.mean(val_rmse_list),
                'Model': model
            })

    svr_results.sort(key=lambda x: x['Avg_Validation_RMSE'])
    best_svr_models[stock] = svr_results[0]['Model']
    all_svr_results.append(svr_results[0])
    print(f"✅ SVR done for {stock} | Best C: {svr_results[0]['C']} | Epsilon: {svr_results[0]['Epsilon']}")
    
# End global timer
end_all = time.time()
print(f"\n🟩 Finished all stocks | Total Time: {end_all - start_all:.2f} seconds")
# Out:
# 🟣 SVR - Stock 1/975: AAPL.O
# ✅ SVR done for AAPL.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 2/975: NVDA.O
# ✅ SVR done for NVDA.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 3/975: MSFT.O
# ✅ SVR done for MSFT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 4/975: AMZN.O
# ✅ SVR done for AMZN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 5/975: LLY
# ✅ SVR done for LLY | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 6/975: WMT
# ✅ SVR done for WMT | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 7/975: XOM
# ✅ SVR done for XOM | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 8/975: MA
# ✅ SVR done for MA | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 9/975: UNH
# ✅ SVR done for UNH | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 10/975: ORCL.K
# ✅ SVR done for ORCL.K | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 11/975: COST.O
# ✅ SVR done for COST.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 12/975: NFLX.O
# ✅ SVR done for NFLX.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 13/975: HD
# ✅ SVR done for HD | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 14/975: CVX
# ✅ SVR done for CVX | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 15/975: CRM
# ✅ SVR done for CRM | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 16/975: CSCO.O
# ✅ SVR done for CSCO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 17/975: MRK
# ✅ SVR done for MRK | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 18/975: ABT
# ✅ SVR done for ABT | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 19/975: MCD
# ✅ SVR done for MCD | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 20/975: TMO
# ✅ SVR done for TMO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 21/975: ISRG.O
# ✅ SVR done for ISRG.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 22/975: RTX
# ✅ SVR done for RTX | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 23/975: QCOM.O
# ✅ SVR done for QCOM.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 24/975: ADBE.O
# ✅ SVR done for ADBE.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 25/975: AMGN.O
# ✅ SVR done for AMGN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 26/975: INTU.O
# ✅ SVR done for INTU.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 27/975: AMD.O
# ✅ SVR done for AMD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 28/975: CAT
# ✅ SVR done for CAT | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 29/975: TXN.O
# ✅ SVR done for TXN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 30/975: NEE
# ✅ SVR done for NEE | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 31/975: DHR
# ✅ SVR done for DHR | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 32/975: PFE
# ✅ SVR done for PFE | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 33/975: BLK
# ✅ SVR done for BLK | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 34/975: UNP
# ✅ SVR done for UNP | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 35/975: BSX
# ✅ SVR done for BSX | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 36/975: SYK
# ✅ SVR done for SYK | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 37/975: GILD.O
# ✅ SVR done for GILD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 38/975: HON.O
# ✅ SVR done for HON.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 39/975: CMCSA.O
# ✅ SVR done for CMCSA.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 40/975: VRTX.O
# ✅ SVR done for VRTX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 41/975: DE
# ✅ SVR done for DE | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 42/975: TJX
# ✅ SVR done for TJX | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 43/975: COP
# ✅ SVR done for COP | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 44/975: LOW
# ✅ SVR done for LOW | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 45/975: BA
# ✅ SVR done for BA | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 46/975: FI
# ✅ SVR done for FI | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 47/975: BMY
# ✅ SVR done for BMY | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 48/975: ADP.O
# ✅ SVR done for ADP.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 49/975: MMC
# ✅ SVR done for MMC | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 50/975: MU.O
# ✅ SVR done for MU.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 51/975: NKE
# ✅ SVR done for NKE | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 52/975: INTC.O
# ✅ SVR done for INTC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 53/975: ADI.O
# ✅ SVR done for ADI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 54/975: LRCX.O
# ✅ SVR done for LRCX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 55/975: ELV
# ✅ SVR done for ELV | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 56/975: KLAC.O
# ✅ SVR done for KLAC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 57/975: DUK
# ✅ SVR done for DUK | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 58/975: CI
# ✅ SVR done for CI | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 59/975: AJG
# ✅ SVR done for AJG | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 60/975: CVS
# ✅ SVR done for CVS | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 61/975: MMM
# ✅ SVR done for MMM | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 62/975: MCK
# ✅ SVR done for MCK | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 63/975: APH
# ✅ SVR done for APH | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 64/975: ORLY.O
# ✅ SVR done for ORLY.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 65/975: REGN.O
# ✅ SVR done for REGN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 66/975: CL
# ✅ SVR done for CL | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 67/975: RSG
# ✅ SVR done for RSG | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 68/975: NOC
# ✅ SVR done for NOC | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 69/975: WMB
# ✅ SVR done for WMB | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 70/975: MSI
# ✅ SVR done for MSI | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 71/975: SNPS.O
# ✅ SVR done for SNPS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 72/975: EOG
# ✅ SVR done for EOG | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 73/975: CDNS.O
# ✅ SVR done for CDNS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 74/975: CMG
# ✅ SVR done for CMG | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 75/975: MAR.O
# ✅ SVR done for MAR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 76/975: BDX
# ✅ SVR done for BDX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 77/975: ROP.O
# ✅ SVR done for ROP.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 78/975: OKE
# ✅ SVR done for OKE | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 79/975: AZO
# ✅ SVR done for AZO | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 80/975: MRVL.O
# ✅ SVR done for MRVL.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 81/975: BK
# ✅ SVR done for BK | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 82/975: CSX.O
# ✅ SVR done for CSX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 83/975: SLB
# ✅ SVR done for SLB | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 84/975: MET
# ✅ SVR done for MET | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 85/975: ADSK.O
# ✅ SVR done for ADSK.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 86/975: TFC
# ✅ SVR done for TFC | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 87/975: PCAR.O
# ✅ SVR done for PCAR.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 88/975: COR
# ✅ SVR done for COR | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 89/975: LNG
# ✅ SVR done for LNG | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 90/975: TGT
# ✅ SVR done for TGT | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 91/975: KR
# ✅ SVR done for KR | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 92/975: D
# ✅ SVR done for D | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 93/975: HES
# ✅ SVR done for HES | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 94/975: FICO.K
# ✅ SVR done for FICO.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 95/975: OXY
# ✅ SVR done for OXY | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 96/975: BKR.O
# ✅ SVR done for BKR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 97/975: ROST.O
# ✅ SVR done for ROST.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 98/975: EW
# ✅ SVR done for EW | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 99/975: VLO
# ✅ SVR done for VLO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 100/975: AME
# ✅ SVR done for AME | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 101/975: GLW
# ✅ SVR done for GLW | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 102/975: DHI
# ✅ SVR done for DHI | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 103/975: LHX
# ✅ SVR done for LHX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 104/975: CTSH.O
# ✅ SVR done for CTSH.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 105/975: PWR
# ✅ SVR done for PWR | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 106/975: F
# ✅ SVR done for F | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 107/975: EA.O
# ✅ SVR done for EA.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 108/975: TTWO.O
# ✅ SVR done for TTWO.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 109/975: A
# ✅ SVR done for A | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 110/975: ODFL.O
# ✅ SVR done for ODFL.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 111/975: BRO
# ✅ SVR done for BRO | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 112/975: IDXX.O
# ✅ SVR done for IDXX.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 113/975: CSGP.O
# ✅ SVR done for CSGP.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 114/975: ALNY.O
# ✅ SVR done for ALNY.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 115/975: HEI
# ✅ SVR done for HEI | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 116/975: LVS
# ✅ SVR done for LVS | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 117/975: CAH
# ✅ SVR done for CAH | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 118/975: WAB
# ✅ SVR done for WAB | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 119/975: HUM
# ✅ SVR done for HUM | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 120/975: NUE
# ✅ SVR done for NUE | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 121/975: EBAY.O
# ✅ SVR done for EBAY.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 122/975: TPL
# ✅ SVR done for TPL | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 123/975: EQT
# ✅ SVR done for EQT | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 124/975: ROK
# ✅ SVR done for ROK | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 125/975: MPWR.O
# ✅ SVR done for MPWR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 126/975: MCHP.O
# ✅ SVR done for MCHP.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 127/975: ANSS.O
# ✅ SVR done for ANSS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 128/975: DTE
# ✅ SVR done for DTE | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 129/975: DXCM.O
# ✅ SVR done for DXCM.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 130/975: IP
# ✅ SVR done for IP | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 131/975: AEE
# ✅ SVR done for AEE | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 132/975: PPG
# ✅ SVR done for PPG | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 133/975: PPL
# ✅ SVR done for PPL | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 134/975: MTD
# ✅ SVR done for MTD | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 135/975: WBD.O
# ✅ SVR done for WBD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 136/975: TYL
# ✅ SVR done for TYL | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 137/975: EL
# ✅ SVR done for EL | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 138/975: ATO
# ✅ SVR done for ATO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 139/975: GPN
# ✅ SVR done for GPN | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 140/975: TDY
# ✅ SVR done for TDY | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 141/975: VRSN.O
# ✅ SVR done for VRSN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 142/975: DVN
# ✅ SVR done for DVN | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 143/975: WAT
# ✅ SVR done for WAT | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 144/975: ERIE.O
# ✅ SVR done for ERIE.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 145/975: ZBH
# ✅ SVR done for ZBH | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 146/975: DRI
# ✅ SVR done for DRI | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 147/975: HAL
# ✅ SVR done for HAL | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 148/975: NVR
# ✅ SVR done for NVR | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 149/975: TSN
# ✅ SVR done for TSN | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 150/975: CTRA.K
# ✅ SVR done for CTRA.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 151/975: PHM
# ✅ SVR done for PHM | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 152/975: TROW.O
# ✅ SVR done for TROW.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 153/975: LII
# ✅ SVR done for LII | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 154/975: BIIB.O
# ✅ SVR done for BIIB.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 155/975: LH
# ✅ SVR done for LH | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 156/975: STLD.O
# ✅ SVR done for STLD.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 157/975: NRG
# ✅ SVR done for NRG | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 158/975: DGX
# ✅ SVR done for DGX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 159/975: LUV
# ✅ SVR done for LUV | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 160/975: PTC.O
# ✅ SVR done for PTC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 161/975: NTAP.O
# ✅ SVR done for NTAP.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 162/975: ON.O
# ✅ SVR done for ON.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 163/975: CLX
# ✅ SVR done for CLX | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 164/975: DECK.K
# ✅ SVR done for DECK.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 165/975: FNF
# ✅ SVR done for FNF | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 166/975: BAX
# ✅ SVR done for BAX | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 167/975: EME
# ✅ SVR done for EME | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 168/975: TRMB.O
# ✅ SVR done for TRMB.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 169/975: GPC
# ✅ SVR done for GPC | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 170/975: GEN.O
# ✅ SVR done for GEN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 171/975: WST
# ✅ SVR done for WST | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 172/975: HRL
# ✅ SVR done for HRL | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 173/975: COO.O
# ✅ SVR done for COO.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 174/975: EXPD.K
# ✅ SVR done for EXPD.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 175/975: WDC.O
# ✅ SVR done for WDC.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 176/975: BBY
# ✅ SVR done for BBY | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 177/975: FFIV.O
# ✅ SVR done for FFIV.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 178/975: RS
# ✅ SVR done for RS | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 179/975: RPM
# ✅ SVR done for RPM | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 180/975: JBL
# ✅ SVR done for JBL | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 181/975: ENTG.O
# ✅ SVR done for ENTG.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 182/975: BALL.K
# ✅ SVR done for BALL.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 183/975: BLDR.K
# ✅ SVR done for BLDR.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 184/975: FSLR.O
# ✅ SVR done for FSLR.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 185/975: GGG
# ✅ SVR done for GGG | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 186/975: TER.O
# ✅ SVR done for TER.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 187/975: UNM
# ✅ SVR done for UNM | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 188/975: DLTR.O
# ✅ SVR done for DLTR.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 189/975: INSM.O
# ✅ SVR done for INSM.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 190/975: UTHR.O
# ✅ SVR done for UTHR.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 191/975: HOLX.O
# ✅ SVR done for HOLX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 192/975: ILMN.O
# ✅ SVR done for ILMN.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 193/975: RVTY.K
# ✅ SVR done for RVTY.K | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 194/975: BMRN.O
# ✅ SVR done for BMRN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 195/975: FLEX.O
# ✅ SVR done for FLEX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 196/975: INCY.O
# ✅ SVR done for INCY.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 197/975: JKHY.O
# ✅ SVR done for JKHY.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 198/975: MORN.O
# ✅ SVR done for MORN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 199/975: ALGN.O
# ✅ SVR done for ALGN.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 200/975: EWBC.O
# ✅ SVR done for EWBC.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 201/975: AKAM.O
# ✅ SVR done for AKAM.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 202/975: FIX
# ✅ SVR done for FIX | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 203/975: JNPR.K
# ✅ SVR done for JNPR.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 204/975: SJM
# ✅ SVR done for SJM | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 205/975: JLL
# ✅ SVR done for JLL | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 206/975: NDSN.O
# ✅ SVR done for NDSN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 207/975: CHRW.O
# ✅ SVR done for CHRW.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 208/975: THC
# ✅ SVR done for THC | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 209/975: JEF
# ✅ SVR done for JEF | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 210/975: COKE.O
# ✅ SVR done for COKE.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 211/975: TXRH.O
# ✅ SVR done for TXRH.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 212/975: SWKS.O
# ✅ SVR done for SWKS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 213/975: NBIX.O
# ✅ SVR done for NBIX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 214/975: ITT
# ✅ SVR done for ITT | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 215/975: VTRS.O
# ✅ SVR done for VTRS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 216/975: SNX
# ✅ SVR done for SNX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 217/975: AIZ
# ✅ SVR done for AIZ | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 218/975: RBC
# ✅ SVR done for RBC | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 219/975: OVV
# ✅ SVR done for OVV | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 220/975: MANH.O
# ✅ SVR done for MANH.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 221/975: EMN
# ✅ SVR done for EMN | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 222/975: CCK
# ✅ SVR done for CCK | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 223/975: TOL
# ✅ SVR done for TOL | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 224/975: CLH
# ✅ SVR done for CLH | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 225/975: GME
# ✅ SVR done for GME | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 226/975: EXEL.O
# ✅ SVR done for EXEL.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 227/975: RGLD.O
# ✅ SVR done for RGLD.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 228/975: COHR.K
# ✅ SVR done for COHR.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 229/975: DOX.O
# ✅ SVR done for DOX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 230/975: IPG
# ✅ SVR done for IPG | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 231/975: TECH.O
# ✅ SVR done for TECH.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 232/975: ATR
# ✅ SVR done for ATR | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 233/975: WBA.O
# ✅ SVR done for WBA.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 234/975: MTZ
# ✅ SVR done for MTZ | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 235/975: SRPT.O
# ✅ SVR done for SRPT.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 236/975: SAIA.O
# ✅ SVR done for SAIA.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 237/975: SEIC.O
# ✅ SVR done for SEIC.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 238/975: RRC
# ✅ SVR done for RRC | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 239/975: WYNN.O
# ✅ SVR done for WYNN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 240/975: CRS
# ✅ SVR done for CRS | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 241/975: CIEN.K
# ✅ SVR done for CIEN.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 242/975: ALB
# ✅ SVR done for ALB | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 243/975: X
# ✅ SVR done for X | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 244/975: HSIC.O
# ✅ SVR done for HSIC.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 245/975: LNW.O
# ✅ SVR done for LNW.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 246/975: CHE
# ✅ SVR done for CHE | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 247/975: CRL
# ✅ SVR done for CRL | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 248/975: DRS.O
# ✅ SVR done for DRS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 249/975: RGEN.O
# ✅ SVR done for RGEN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 250/975: LSCC.O
# ✅ SVR done for LSCC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 251/975: EXAS.O
# ✅ SVR done for EXAS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 252/975: HAS.O
# ✅ SVR done for HAS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 253/975: PARA.O
# ✅ SVR done for PARA.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 254/975: DCI
# ✅ SVR done for DCI | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 255/975: CHDN.O
# ✅ SVR done for CHDN.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 256/975: MKTX.O
# ✅ SVR done for MKTX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 257/975: NYT
# ✅ SVR done for NYT | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 258/975: WCC
# ✅ SVR done for WCC | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 259/975: DLB
# ✅ SVR done for DLB | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 260/975: EVR
# ✅ SVR done for EVR | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 261/975: TTEK.O
# ✅ SVR done for TTEK.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 262/975: RRX
# ✅ SVR done for RRX | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 263/975: SIRI.O
# ✅ SVR done for SIRI.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 264/975: HALO.O
# ✅ SVR done for HALO.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 265/975: GAP
# ✅ SVR done for GAP | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 266/975: EXLS.O
# ✅ SVR done for EXLS.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 267/975: ATI
# ✅ SVR done for ATI | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 268/975: TTC
# ✅ SVR done for TTC | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 269/975: ZION.O
# ✅ SVR done for ZION.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 270/975: BIO
# ✅ SVR done for BIO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 271/975: MHK
# ✅ SVR done for MHK | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 272/975: APA.O
# ✅ SVR done for APA.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 273/975: CVLT.O
# ✅ SVR done for CVLT.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 274/975: AGCO.K
# ✅ SVR done for AGCO.K | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 275/975: BRKR.O
# ✅ SVR done for BRKR.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 276/975: RLI
# ✅ SVR done for RLI | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 277/975: IVZ
# ✅ SVR done for IVZ | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 278/975: ONTO.K
# ✅ SVR done for ONTO.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 279/975: CWST.O
# ✅ SVR done for CWST.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 280/975: QRVO.O
# ✅ SVR done for QRVO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 281/975: AAON.O
# ✅ SVR done for AAON.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 282/975: ALK
# ✅ SVR done for ALK | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 283/975: UFPI.O
# ✅ SVR done for UFPI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 284/975: FLS
# ✅ SVR done for FLS | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 285/975: SNV
# ✅ SVR done for SNV | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 286/975: TGTX.O
# ✅ SVR done for TGTX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 287/975: TFX
# ✅ SVR done for TFX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 288/975: CELH.O
# ✅ SVR done for CELH.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 289/975: EAT
# ✅ SVR done for EAT | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 290/975: PEGA.O
# ✅ SVR done for PEGA.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 291/975: OSK
# ✅ SVR done for OSK | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 292/975: LNC
# ✅ SVR done for LNC | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 293/975: AWI
# ✅ SVR done for AWI | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 294/975: CHH
# ✅ SVR done for CHH | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 295/975: WEX
# ✅ SVR done for WEX | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 296/975: CORT.O
# ✅ SVR done for CORT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 297/975: MSA
# ✅ SVR done for MSA | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 298/975: RMBS.O
# ✅ SVR done for RMBS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 299/975: FCN
# ✅ SVR done for FCN | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 300/975: BMI
# ✅ SVR done for BMI | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 301/975: MMSI.O
# ✅ SVR done for MMSI.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 302/975: MKSI.O
# ✅ SVR done for MKSI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 303/975: CACC.O
# ✅ SVR done for CACC.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 304/975: BYD
# ✅ SVR done for BYD | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 305/975: DDS
# ✅ SVR done for DDS | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 306/975: IDCC.O
# ✅ SVR done for IDCC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 307/975: ACIW.O
# ✅ SVR done for ACIW.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 308/975: USM
# ✅ SVR done for USM | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 309/975: CROX.O
# ✅ SVR done for CROX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 310/975: GNTX.O
# ✅ SVR done for GNTX.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 311/975: CRVL.O
# ✅ SVR done for CRVL.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 312/975: ARW
# ✅ SVR done for ARW | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 313/975: NOV
# ✅ SVR done for NOV | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 314/975: RHI
# ✅ SVR done for RHI | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 315/975: SKY
# ✅ SVR done for SKY | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 316/975: CRK
# ✅ SVR done for CRK | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 317/975: OPCH.O
# ✅ SVR done for OPCH.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 318/975: CGNX.O
# ✅ SVR done for CGNX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 319/975: LSTR.O
# ✅ SVR done for LSTR.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 320/975: CRUS.O
# ✅ SVR done for CRUS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 321/975: CMC
# ✅ SVR done for CMC | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 322/975: CYTK.O
# ✅ SVR done for CYTK.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 323/975: QXO
# ✅ SVR done for QXO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 324/975: IONS.O
# ✅ SVR done for IONS.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 325/975: TKR
# ✅ SVR done for TKR | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 326/975: LFUS.O
# ✅ SVR done for LFUS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 327/975: NXST.O
# ✅ SVR done for NXST.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 328/975: LAZ
# ✅ SVR done for LAZ | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 329/975: MTH
# ✅ SVR done for MTH | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 330/975: TXNM.K
# ✅ SVR done for TXNM.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 331/975: LUMN.K
# ✅ SVR done for LUMN.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 332/975: POR
# ✅ SVR done for POR | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 333/975: AMKR.O
# ✅ SVR done for AMKR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 334/975: NSIT.O
# ✅ SVR done for NSIT.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 335/975: AMG
# ✅ SVR done for AMG | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 336/975: ITRI.O
# ✅ SVR done for ITRI.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 337/975: FSS
# ✅ SVR done for FSS | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 338/975: HXL
# ✅ SVR done for HXL | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 339/975: FELE.O
# ✅ SVR done for FELE.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 340/975: CNX
# ✅ SVR done for CNX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 341/975: DY
# ✅ SVR done for DY | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 342/975: URBN.O
# ✅ SVR done for URBN.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 343/975: PIPR.K
# ✅ SVR done for PIPR.K | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 344/975: MOD
# ✅ SVR done for MOD | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 345/975: EEFT.O
# ✅ SVR done for EEFT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 346/975: BKH
# ✅ SVR done for BKH | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 347/975: KMPR.K
# ✅ SVR done for KMPR.K | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 348/975: KBH
# ✅ SVR done for KBH | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 349/975: MSM
# ✅ SVR done for MSM | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 350/975: THO
# ✅ SVR done for THO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 351/975: EXPO.O
# ✅ SVR done for EXPO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 352/975: NNI
# ✅ SVR done for NNI | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 353/975: ESE
# ✅ SVR done for ESE | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 354/975: PBH
# ✅ SVR done for PBH | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 355/975: AVT.O
# ✅ SVR done for AVT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 356/975: SANM.O
# ✅ SVR done for SANM.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 357/975: IPAR.O
# ✅ SVR done for IPAR.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 358/975: BDC
# ✅ SVR done for BDC | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 359/975: CVCO.O
# ✅ SVR done for CVCO.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 360/975: SLAB.O
# ✅ SVR done for SLAB.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 361/975: AEIS.O
# ✅ SVR done for AEIS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 362/975: ANF
# ✅ SVR done for ANF | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 363/975: JWN
# ✅ SVR done for JWN | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 364/975: ITGR.K
# ✅ SVR done for ITGR.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 365/975: SPR
# ✅ SVR done for SPR | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 366/975: DORM.O
# ✅ SVR done for DORM.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 367/975: ALE
# ✅ SVR done for ALE | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 368/975: MMS
# ✅ SVR done for MMS | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 369/975: FIZZ.O
# ✅ SVR done for FIZZ.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 370/975: TDS
# ✅ SVR done for TDS | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 371/975: CBZ
# ✅ SVR done for CBZ | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 372/975: BCO
# ✅ SVR done for BCO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 373/975: AVNT.K
# ✅ SVR done for AVNT.K | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 374/975: AVAV.O
# ✅ SVR done for AVAV.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 375/975: IESC.O
# ✅ SVR done for IESC.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 376/975: M
# ✅ SVR done for M | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 377/975: PRIM.K
# ✅ SVR done for PRIM.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 378/975: SKYW.O
# ✅ SVR done for SKYW.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 379/975: ICUI.O
# ✅ SVR done for ICUI.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 380/975: KFY
# ✅ SVR done for KFY | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 381/975: RDNT.O
# ✅ SVR done for RDNT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 382/975: NWE.O
# ✅ SVR done for NWE.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 383/975: SM
# ✅ SVR done for SM | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 384/975: SMTC.O
# ✅ SVR done for SMTC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 385/975: CCOI.O
# ✅ SVR done for CCOI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 386/975: PLXS.O
# ✅ SVR done for PLXS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 387/975: NSP
# ✅ SVR done for NSP | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 388/975: HAE
# ✅ SVR done for HAE | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 389/975: POWI.O
# ✅ SVR done for POWI.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 390/975: AVA
# ✅ SVR done for AVA | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 391/975: TNL
# ✅ SVR done for TNL | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 392/975: MHO
# ✅ SVR done for MHO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 393/975: DXC
# ✅ SVR done for DXC | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 394/975: BLKB.O
# ✅ SVR done for BLKB.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 395/975: XRAY.O
# ✅ SVR done for XRAY.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 396/975: OSIS.O
# ✅ SVR done for OSIS.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 397/975: HOG
# ✅ SVR done for HOG | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 398/975: PTEN.O
# ✅ SVR done for PTEN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 399/975: AMED.O
# ✅ SVR done for AMED.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 400/975: ASGN.K
# ✅ SVR done for ASGN.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 401/975: CPK
# ✅ SVR done for CPK | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 402/975: ACAD.O
# ✅ SVR done for ACAD.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 403/975: NOG
# ✅ SVR done for NOG | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 404/975: FUL
# ✅ SVR done for FUL | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 405/975: PATK.O
# ✅ SVR done for PATK.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 406/975: TGNA.K
# ✅ SVR done for TGNA.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 407/975: MAN
# ✅ SVR done for MAN | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 408/975: MGRC.O
# ✅ SVR done for MGRC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 409/975: GNW
# ✅ SVR done for GNW | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 410/975: PDCO.O
# ✅ SVR done for PDCO.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 411/975: NWL.O
# ✅ SVR done for NWL.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 412/975: GEF
# ✅ SVR done for GEF | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 413/975: GSAT.O
# ✅ SVR done for GSAT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 414/975: TEX
# ✅ SVR done for TEX | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 415/975: IPGP.O
# ✅ SVR done for IPGP.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 416/975: PENN.O
# ✅ SVR done for PENN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 417/975: JOE
# ✅ SVR done for JOE | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 418/975: HURN.O
# ✅ SVR done for HURN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 419/975: JJSF.O
# ✅ SVR done for JJSF.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 420/975: GT.O
# ✅ SVR done for GT.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 421/975: SAM
# ✅ SVR done for SAM | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 422/975: HP
# ✅ SVR done for HP | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 423/975: PSMT.O
# ✅ SVR done for PSMT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 424/975: CPRX.O
# ✅ SVR done for CPRX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 425/975: FORM.O
# ✅ SVR done for FORM.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 426/975: SYNA.O
# ✅ SVR done for SYNA.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 427/975: QDEL.O
# ✅ SVR done for QDEL.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 428/975: VIAV.O
# ✅ SVR done for VIAV.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 429/975: VICR.O
# ✅ SVR done for VICR.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 430/975: BFH
# ✅ SVR done for BFH | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 431/975: PRGS.O
# ✅ SVR done for PRGS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 432/975: TRN
# ✅ SVR done for TRN | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 433/975: CAKE.O
# ✅ SVR done for CAKE.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 434/975: WLY
# ✅ SVR done for WLY | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 435/975: PAR
# ✅ SVR done for PAR | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 436/975: VSEC.O
# ✅ SVR done for VSEC.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 437/975: LCII.K
# ✅ SVR done for LCII.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 438/975: AIN
# ✅ SVR done for AIN | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 439/975: HUBG.O
# ✅ SVR done for HUBG.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 440/975: VCEL.O
# ✅ SVR done for VCEL.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 441/975: AAP
# ✅ SVR done for AAP | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 442/975: ALG
# ✅ SVR done for ALG | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 443/975: OII
# ✅ SVR done for OII | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 444/975: TTMI.O
# ✅ SVR done for TTMI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 445/975: CXW
# ✅ SVR done for CXW | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 446/975: SSRM.O
# ✅ SVR done for SSRM.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 447/975: DIOD.O
# ✅ SVR done for DIOD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 448/975: AEO
# ✅ SVR done for AEO | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 449/975: ARWR.O
# ✅ SVR done for ARWR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 450/975: WMK
# ✅ SVR done for WMK | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 451/975: AGYS.O
# ✅ SVR done for AGYS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 452/975: LGFa
# ✅ SVR done for LGFa | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 453/975: LGND.O
# ✅ SVR done for LGND.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 454/975: HNI
# ✅ SVR done for HNI | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 455/975: JBLU.O
# ✅ SVR done for JBLU.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 456/975: NEOG.O
# ✅ SVR done for NEOG.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 457/975: HE
# ✅ SVR done for HE | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 458/975: EXTR.O
# ✅ SVR done for EXTR.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 459/975: ACLS.O
# ✅ SVR done for ACLS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 460/975: WERN.O
# ✅ SVR done for WERN.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 461/975: LMAT.O
# ✅ SVR done for LMAT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 462/975: CENX.O
# ✅ SVR done for CENX.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 463/975: BKE
# ✅ SVR done for BKE | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 464/975: CNMD.K
# ✅ SVR done for CNMD.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 465/975: OI
# ✅ SVR done for OI | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 466/975: CSGS.O
# ✅ SVR done for CSGS.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 467/975: RAMP.K
# ✅ SVR done for RAMP.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 468/975: IART.O
# ✅ SVR done for IART.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 469/975: ZD.O
# ✅ SVR done for ZD.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 470/975: PBI
# ✅ SVR done for PBI | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 471/975: GBX
# ✅ SVR done for GBX | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 472/975: DVAX.O
# ✅ SVR done for DVAX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 473/975: PLUS.O
# ✅ SVR done for PLUS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 474/975: AZTA.O
# ✅ SVR done for AZTA.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 475/975: KMT
# ✅ SVR done for KMT | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 476/975: ATRC.O
# ✅ SVR done for ATRC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 477/975: UFPT.O
# ✅ SVR done for UFPT.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 478/975: UNFI.K
# ✅ SVR done for UNFI.K | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 479/975: BCRX.O
# ✅ SVR done for BCRX.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 480/975: STGW.O
# ✅ SVR done for STGW.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 481/975: WKC
# ✅ SVR done for WKC | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 482/975: MNKD.O
# ✅ SVR done for MNKD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 483/975: MCRI.O
# ✅ SVR done for MCRI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 484/975: APLD.O
# ✅ SVR done for APLD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 485/975: SRCE.O
# ✅ SVR done for SRCE.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 486/975: OMCL.O
# ✅ SVR done for OMCL.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 487/975: INOD.O
# ✅ SVR done for INOD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 488/975: FL
# ✅ SVR done for FL | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 489/975: NTCT.O
# ✅ SVR done for NTCT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 490/975: EPC
# ✅ SVR done for EPC | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 491/975: ATSG.O
# ✅ SVR done for ATSG.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 492/975: ADEA.O
# ✅ SVR done for ADEA.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 493/975: ROG
# ✅ SVR done for ROG | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 494/975: NHC
# ✅ SVR done for NHC | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 495/975: LNN
# ✅ SVR done for LNN | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 496/975: PZZA.O
# ✅ SVR done for PZZA.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 497/975: BHE
# ✅ SVR done for BHE | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 498/975: UPBD.O
# ✅ SVR done for UPBD.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 499/975: ANIP.O
# ✅ SVR done for ANIP.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 500/975: CLDX.O
# ✅ SVR done for CLDX.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 501/975: VRNT.O
# ✅ SVR done for VRNT.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 502/975: PLAB.O
# ✅ SVR done for PLAB.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 503/975: VYX
# ✅ SVR done for VYX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 504/975: DXPE.O
# ✅ SVR done for DXPE.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 505/975: ATEC.O
# ✅ SVR done for ATEC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 506/975: NVAX.O
# ✅ SVR done for NVAX.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 507/975: CTS
# ✅ SVR done for CTS | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 508/975: VSAT.O
# ✅ SVR done for VSAT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 509/975: NEO.O
# ✅ SVR done for NEO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 510/975: WT
# ✅ SVR done for WT | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 511/975: SCS
# ✅ SVR done for SCS | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 512/975: VECO.O
# ✅ SVR done for VECO.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 513/975: INVX.K
# ✅ SVR done for INVX.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 514/975: DCOM.O
# ✅ SVR done for DCOM.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 515/975: EIG
# ✅ SVR done for EIG | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 516/975: HLIT.O
# ✅ SVR done for HLIT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 517/975: HLX
# ✅ SVR done for HLX | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 518/975: IDT
# ✅ SVR done for IDT | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 519/975: BLFS.O
# ✅ SVR done for BLFS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 520/975: GIII.O
# ✅ SVR done for GIII.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 521/975: CRAI.O
# ✅ SVR done for CRAI.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 522/975: IMKTA.O
# ✅ SVR done for IMKTA.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 523/975: OPK.O
# ✅ SVR done for OPK.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 524/975: SAFT.O
# ✅ SVR done for SAFT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 525/975: RES
# ✅ SVR done for RES | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 526/975: UCTT.O
# ✅ SVR done for UCTT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 527/975: GYRE.O
# ✅ SVR done for GYRE.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 528/975: MODG.K
# ✅ SVR done for MODG.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 529/975: TILE.O
# ✅ SVR done for TILE.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 530/975: MSEX.O
# ✅ SVR done for MSEX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 531/975: MRTN.O
# ✅ SVR done for MRTN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 532/975: PRG
# ✅ SVR done for PRG | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 533/975: INVA.O
# ✅ SVR done for INVA.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 534/975: DGII.O
# ✅ SVR done for DGII.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 535/975: APOG.O
# ✅ SVR done for APOG.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 536/975: GERN.O
# ✅ SVR done for GERN.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 537/975: CLMT.O
# ✅ SVR done for CLMT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 538/975: BBSI.O
# ✅ SVR done for BBSI.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 539/975: WGO
# ✅ SVR done for WGO | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 540/975: AMN
# ✅ SVR done for AMN | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 541/975: AORT.K
# ✅ SVR done for AORT.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 542/975: ALGT.O
# ✅ SVR done for ALGT.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 543/975: SBGI.O
# ✅ SVR done for SBGI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 544/975: GRC
# ✅ SVR done for GRC | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 545/975: AMSF.O
# ✅ SVR done for AMSF.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 546/975: KFRC.K
# ✅ SVR done for KFRC.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 547/975: BELFA.O
# ✅ SVR done for BELFA.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 548/975: THRM.O
# ✅ SVR done for THRM.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 549/975: LQDT.O
# ✅ SVR done for LQDT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 550/975: MYGN.O
# ✅ SVR done for MYGN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 551/975: NSSC.O
# ✅ SVR done for NSSC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 552/975: UTL
# ✅ SVR done for UTL | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 553/975: WOLF.K
# ✅ SVR done for WOLF.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 554/975: KSS
# ✅ SVR done for KSS | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 555/975: CBRL.O
# ✅ SVR done for CBRL.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 556/975: DCO
# ✅ SVR done for DCO | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 557/975: ATRO.O
# ✅ SVR done for ATRO.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 558/975: HSII.O
# ✅ SVR done for HSII.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 559/975: GIC
# ✅ SVR done for GIC | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 560/975: PDFS.O
# ✅ SVR done for PDFS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 561/975: SCSC.O
# ✅ SVR done for SCSC.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 562/975: STAA.O
# ✅ SVR done for STAA.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 563/975: ASTE.O
# ✅ SVR done for ASTE.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 564/975: CECO.O
# ✅ SVR done for CECO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 565/975: ECPG.O
# ✅ SVR done for ECPG.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 566/975: PRA
# ✅ SVR done for PRA | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 567/975: AVXL.O
# ✅ SVR done for AVXL.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 568/975: COHU.O
# ✅ SVR done for COHU.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 569/975: AMSC.O
# ✅ SVR done for AMSC.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 570/975: HCKT.O
# ✅ SVR done for HCKT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 571/975: AIOT.O
# ✅ SVR done for AIOT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 572/975: PRAA.O
# ✅ SVR done for PRAA.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 573/975: AXGN.O
# ✅ SVR done for AXGN.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 574/975: OSBC.O
# ✅ SVR done for OSBC.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 575/975: UFCS.O
# ✅ SVR done for UFCS.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 576/975: BJRI.O
# ✅ SVR done for BJRI.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 577/975: ADTN.O
# ✅ SVR done for ADTN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 578/975: XRX.O
# ✅ SVR done for XRX.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 579/975: OMI
# ✅ SVR done for OMI | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 580/975: PLPC.O
# ✅ SVR done for PLPC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 581/975: CLB
# ✅ SVR done for CLB | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 582/975: FCBC.O
# ✅ SVR done for FCBC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 583/975: SSYS.O
# ✅ SVR done for SSYS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 584/975: WRLD.O
# ✅ SVR done for WRLD.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 585/975: RBBN.O
# ✅ SVR done for RBBN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 586/975: NTGR.O
# ✅ SVR done for NTGR.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 587/975: MLAB.O
# ✅ SVR done for MLAB.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 588/975: ETD
# ✅ SVR done for ETD | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 589/975: MAGN.K
# ✅ SVR done for MAGN.K | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 590/975: SPTN.O
# ✅ SVR done for SPTN.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 591/975: TRNS.O
# ✅ SVR done for TRNS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 592/975: SHEN.O
# ✅ SVR done for SHEN.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 593/975: BXC
# ✅ SVR done for BXC | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 594/975: BZH
# ✅ SVR done for BZH | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 595/975: OFIX.O
# ✅ SVR done for OFIX.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 596/975: HOV
# ✅ SVR done for HOV | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 597/975: OPY
# ✅ SVR done for OPY | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 598/975: REPX.K
# ✅ SVR done for REPX.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 599/975: CVLG.K
# ✅ SVR done for CVLG.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 600/975: OSPN.O
# ✅ SVR done for OSPN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 601/975: FWRD.O
# ✅ SVR done for FWRD.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 602/975: SCVL.O
# ✅ SVR done for SCVL.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 603/975: JACK.O
# ✅ SVR done for JACK.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 604/975: SENEA.O
# ✅ SVR done for SENEA.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 605/975: WLDN.O
# ✅ SVR done for WLDN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 606/975: CASS.O
# ✅ SVR done for CASS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 607/975: SMP
# ✅ SVR done for SMP | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 608/975: CTLP.O
# ✅ SVR done for CTLP.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 609/975: FARO.O
# ✅ SVR done for FARO.O | Best C: 0.1 | Epsilon: 0.1
#
# ...
#
# 🟣 SVR - Stock 779/975: LTRX.O
# ✅ SVR done for LTRX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 780/975: PPIH.O
# ✅ SVR done for PPIH.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 781/975: GNSS.O
# ✅ SVR done for GNSS.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 782/975: GALT.O
# ✅ SVR done for GALT.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 783/975: GAIA.O
# ✅ SVR done for GAIA.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 784/975: KVHI.O
# ✅ SVR done for KVHI.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 785/975: HURC.O
# ✅ SVR done for HURC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 786/975: NOTV.O
# ✅ SVR done for NOTV.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 787/975: DXLG.O
# ✅ SVR done for DXLG.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 788/975: TAYD.O
# ✅ SVR done for TAYD.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 789/975: PCG_pa
# ✅ SVR done for PCG_pa | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 790/975: GEOS.O
# ✅ SVR done for GEOS.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 791/975: SLNG.O
# ✅ SVR done for SLNG.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 792/975: ORMP.O
# ✅ SVR done for ORMP.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 793/975: INTT.K
# ✅ SVR done for INTT.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 794/975: ACHV.O
# ✅ SVR done for ACHV.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 795/975: ANIX.O
# ✅ SVR done for ANIX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 796/975: ZYXI.O
# ✅ SVR done for ZYXI.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 797/975: QUIK.O
# ✅ SVR done for QUIK.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 798/975: BRID.O
# ✅ SVR done for BRID.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 799/975: UEIC.O
# ✅ SVR done for UEIC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 800/975: QMCO.O
# ✅ SVR done for QMCO.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 801/975: LPSN.O
# ✅ SVR done for LPSN.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 802/975: FONR.O
# ✅ SVR done for FONR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 803/975: MCHX.O
# ✅ SVR done for MCHX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 804/975: LPTH.O
# ✅ SVR done for LPTH.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 805/975: HGBL.O
# ✅ SVR done for HGBL.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 806/975: PETS.O
# ✅ SVR done for PETS.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 807/975: DIT
# ✅ SVR done for DIT | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 808/975: AXTI.O
# ✅ SVR done for AXTI.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 809/975: FOSL.O
# ✅ SVR done for FOSL.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 810/975: ALOT.O
# ✅ SVR done for ALOT.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 811/975: HNNA.O
# ✅ SVR done for HNNA.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 812/975: RRGB.O
# ✅ SVR done for RRGB.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 813/975: UBCP.O
# ✅ SVR done for UBCP.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 814/975: MNOV.O
# ✅ SVR done for MNOV.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 815/975: INVE.O
# ✅ SVR done for INVE.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 816/975: SGA.O
# ✅ SVR done for SGA.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 817/975: ESP
# ✅ SVR done for ESP | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 818/975: OPTT.K
# ✅ SVR done for OPTT.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 819/975: CODA.O
# ✅ SVR done for CODA.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 820/975: AUBN.O
# ✅ SVR done for AUBN.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 821/975: INO.O
# ✅ SVR done for INO.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 822/975: IOR
# ✅ SVR done for IOR | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 823/975: MLSS.K
# ✅ SVR done for MLSS.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 824/975: AREN.K
# ✅ SVR done for AREN.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 825/975: VERU.O
# ✅ SVR done for VERU.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 826/975: ASYS.O
# ✅ SVR done for ASYS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 827/975: ARMP.K
# ✅ SVR done for ARMP.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 828/975: ASRT.O
# ✅ SVR done for ASRT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 829/975: FKWL.O
# ✅ SVR done for FKWL.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 830/975: DOMH.O
# ✅ SVR done for DOMH.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 831/975: DLHC.O
# ✅ SVR done for DLHC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 832/975: PED
# ✅ SVR done for PED | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 833/975: ALTS.O
# ✅ SVR done for ALTS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 834/975: CULP.K
# ✅ SVR done for CULP.K | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 835/975: SUP
# ✅ SVR done for SUP | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 836/975: CATO.K
# ✅ SVR done for CATO.K | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 837/975: CYCC.O
# ✅ SVR done for CYCC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 838/975: ICAD.O
# ✅ SVR done for ICAD.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 839/975: WFCF.O
# ✅ SVR done for WFCF.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 840/975: LINK.O
# ✅ SVR done for LINK.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 841/975: CTSO.O
# ✅ SVR done for CTSO.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 842/975: CNVS.O
# ✅ SVR done for CNVS.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 843/975: CNTY.O
# ✅ SVR done for CNTY.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 844/975: MIND.O
# ✅ SVR done for MIND.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 845/975: SOTK.O
# ✅ SVR done for SOTK.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 846/975: RMTI.O
# ✅ SVR done for RMTI.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 847/975: CVGI.O
# ✅ SVR done for CVGI.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 848/975: MBOT.O
# ✅ SVR done for MBOT.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 849/975: LEE.O
# ✅ SVR done for LEE.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 850/975: CMTL.O
# ✅ SVR done for CMTL.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 851/975: KOSS.O
# ✅ SVR done for KOSS.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 852/975: BDL
# ✅ SVR done for BDL | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 853/975: UG.O
# ✅ SVR done for UG.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 854/975: IDN.O
# ✅ SVR done for IDN.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 855/975: ICCC.O
# ✅ SVR done for ICCC.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 856/975: CVU
# ✅ SVR done for CVU | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 857/975: AGEN.O
# ✅ SVR done for AGEN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 858/975: REFR.O
# ✅ SVR done for REFR.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 859/975: DWSN.O
# ✅ SVR done for DWSN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 860/975: AP
# ✅ SVR done for AP | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 861/975: RFIL.O
# ✅ SVR done for RFIL.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 862/975: USIO.O
# ✅ SVR done for USIO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 863/975: CRWS.O
# ✅ SVR done for CRWS.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 864/975: PXLW.O
# ✅ SVR done for PXLW.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 865/975: APYX.O
# ✅ SVR done for APYX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 866/975: TACT.O
# ✅ SVR done for TACT.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 867/975: SYPR.O
# ✅ SVR done for SYPR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 868/975: UONEK.O
# ✅ SVR done for UONEK.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 869/975: ARKR.O
# ✅ SVR done for ARKR.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 870/975: HHS.O
# ✅ SVR done for HHS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 871/975: WYY
# ✅ SVR done for WYY | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 872/975: ACCS.K
# ✅ SVR done for ACCS.K | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 873/975: AWRE.O
# ✅ SVR done for AWRE.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 874/975: AIFF.O
# ✅ SVR done for AIFF.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 875/975: SGRP.O
# ✅ SVR done for SGRP.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 876/975: NTIP.K
# ✅ SVR done for NTIP.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 877/975: VHC
# ✅ SVR done for VHC | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 878/975: FTEK.O
# ✅ SVR done for FTEK.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 879/975: GROW.O
# ✅ SVR done for GROW.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 880/975: IRD.O
# ✅ SVR done for IRD.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 881/975: CMS_pb
# ✅ SVR done for CMS_pb | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 882/975: KTCC.O
# ✅ SVR done for KTCC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 883/975: HSON.O
# ✅ SVR done for HSON.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 884/975: AXDX.O
# ✅ SVR done for AXDX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 885/975: HBIO.O
# ✅ SVR done for HBIO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 886/975: NSYS.O
# ✅ SVR done for NSYS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 887/975: OCC.O
# ✅ SVR done for OCC.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 888/975: NTWK.O
# ✅ SVR done for NTWK.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 889/975: INTG.O
# ✅ SVR done for INTG.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 890/975: DRRX.O
# ✅ SVR done for DRRX.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 891/975: IGC
# ✅ SVR done for IGC | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 892/975: TRT
# ✅ SVR done for TRT | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 893/975: ENZ
# ✅ SVR done for ENZ | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 894/975: GTIM.O
# ✅ SVR done for GTIM.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 895/975: TENX.O
# ✅ SVR done for TENX.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 896/975: CKX
# ✅ SVR done for CKX | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 897/975: CRIS.O
# ✅ SVR done for CRIS.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 898/975: CVM
# ✅ SVR done for CVM | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 899/975: CYTH.O
# ✅ SVR done for CYTH.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 900/975: DAIO.O
# ✅ SVR done for DAIO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 901/975: JOB
# ✅ SVR done for JOB | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 902/975: RVP
# ✅ SVR done for RVP | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 903/975: INTZ.O
# ✅ SVR done for INTZ.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 904/975: NAII.O
# ✅ SVR done for NAII.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 905/975: CVV.O
# ✅ SVR done for CVV.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 906/975: LSTA.O
# ✅ SVR done for LSTA.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 907/975: PTN
# ✅ SVR done for PTN | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 908/975: CREX.O
# ✅ SVR done for CREX.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 909/975: MXC
# ✅ SVR done for MXC | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 910/975: MTEX.O
# ✅ SVR done for MTEX.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 911/975: NNVC.K
# ✅ SVR done for NNVC.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 912/975: IRIX.O
# ✅ SVR done for IRIX.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 913/975: AMS
# ✅ SVR done for AMS | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 914/975: SIF
# ✅ SVR done for SIF | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 915/975: BRN
# ✅ SVR done for BRN | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 916/975: NEPH.O
# ✅ SVR done for NEPH.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 917/975: HUSA.K
# ✅ SVR done for HUSA.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 918/975: CLRO.O
# ✅ SVR done for CLRO.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 919/975: COHN.K
# ✅ SVR done for COHN.K | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 920/975: ELSE.O
# ✅ SVR done for ELSE.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 921/975: MEIP.O
# ✅ SVR done for MEIP.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 922/975: TAIT.O
# ✅ SVR done for TAIT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 923/975: JCTC.O
# ✅ SVR done for JCTC.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 924/975: CLRB.O
# ✅ SVR done for CLRB.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 925/975: GOVX.O
# ✅ SVR done for GOVX.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 926/975: GPUS.K
# ✅ SVR done for GPUS.K | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 927/975: ERNA.O
# ✅ SVR done for ERNA.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 928/975: AIRI.K
# ✅ SVR done for AIRI.K | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 929/975: SMSI.O
# ✅ SVR done for SMSI.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 930/975: STRM.O
# ✅ SVR done for STRM.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 931/975: IMNN.O
# ✅ SVR done for IMNN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 932/975: AWX
# ✅ SVR done for AWX | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 933/975: BCDA.O
# ✅ SVR done for BCDA.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 934/975: MTR
# ✅ SVR done for MTR | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 935/975: PRPH.O
# ✅ SVR done for PRPH.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 936/975: SSKN.O
# ✅ SVR done for SSKN.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 937/975: ASTC.O
# ✅ SVR done for ASTC.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 938/975: PMCB.O
# ✅ SVR done for PMCB.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 939/975: PRPO.O
# ✅ SVR done for PRPO.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 940/975: BBGI.O
# ✅ SVR done for BBGI.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 941/975: MSN
# ✅ SVR done for MSN | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 942/975: BCLI.O
# ✅ SVR done for BCLI.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 943/975: NURO.O
# ✅ SVR done for NURO.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 944/975: SCKT.O
# ✅ SVR done for SCKT.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 945/975: ARTW.O
# ✅ SVR done for ARTW.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 946/975: AIMD.O
# ✅ SVR done for AIMD.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 947/975: AIM
# ✅ SVR done for AIM | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 948/975: STRR.O
# ✅ SVR done for STRR.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 949/975: SSY
# ✅ SVR done for SSY | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 950/975: GTBP.O
# ✅ SVR done for GTBP.O | Best C: 10 | Epsilon: 0.1
#
# 🟣 SVR - Stock 951/975: SGMA.O
# ✅ SVR done for SGMA.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 952/975: OGEN.K
# ✅ SVR done for OGEN.K | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 953/975: RIME.O
# ✅ SVR done for RIME.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 954/975: SNGX.O
# ✅ SVR done for SNGX.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 955/975: SNOA.O
# ✅ SVR done for SNOA.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 956/975: AEMD.O
# ✅ SVR done for AEMD.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 957/975: GBR
# ✅ SVR done for GBR | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 958/975: KNW
# ✅ SVR done for KNW | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 959/975: BKYI.O
# ✅ SVR done for BKYI.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 960/975: UUU
# ✅ SVR done for UUU | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 961/975: PSTV.O
# ✅ SVR done for PSTV.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 962/975: FORD.O
# ✅ SVR done for FORD.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 963/975: AYRO.O
# ✅ SVR done for AYRO.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 964/975: TTNP.O
# ✅ SVR done for TTNP.O | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 965/975: TOVX.K
# ✅ SVR done for TOVX.K | Best C: 10 | Epsilon: 0.01
#
# 🟣 SVR - Stock 966/975: PRSO.O
# ✅ SVR done for PRSO.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 967/975: PALI.O
# ✅ SVR done for PALI.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 968/975: APDN.O
# ✅ SVR done for APDN.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 969/975: SBET.O
# ✅ SVR done for SBET.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 970/975: ASTI.O
# ✅ SVR done for ASTI.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 971/975: AWH.O
# ✅ SVR done for AWH.O | Best C: 0.1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 972/975: SUNE.O
# ✅ SVR done for SUNE.O | Best C: 1 | Epsilon: 0.1
#
# 🟣 SVR - Stock 973/975: TCRT.O
# ✅ SVR done for TCRT.O | Best C: 1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 974/975: WINT.O
# ✅ SVR done for WINT.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟣 SVR - Stock 975/975: DGLY.O
# ✅ SVR done for DGLY.O | Best C: 0.1 | Epsilon: 0.01
#
# 🟩 Finished all stocks | Total Time: 634.38 seconds

# %% [markdown]
# ### Hyperparameter Tuning - DecisionTreeRegressor

# %%
# Define the Fama-French factor columns
ff_3_factors = ['Date', 'Mkt-RF', 'SMB', 'HML', 'RF']

# Get list of stock columns (everything except the FF factors and 'Period')
stock_columns = [col for col in three_ff_cleaned_df.columns if col not in ff_3_factors]

# Start global timer
start_all = time.time()

# ------------------ Decision Tree Regression ------------------

all_dt_results = []
best_dt_models = {}

# Start global timer
start_all = time.time()

for idx, stock in enumerate(stock_columns):
    print(f"\n🌲 Decision Tree - Stock {idx + 1}/{len(stock_columns)}: {stock}")
    start_time = time.time()

    # Subset and process
    df_subset = three_ff_cleaned_df[ff_3_factors + [stock]].copy()
    df_subset['Stock_Return'] = df_subset[[stock]]
    df_subset['Excess_Mkt_Return'] = df_subset['Mkt-RF'] - df_subset['RF']
    df_subset = df_subset[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
    
    # Shift return behind by 1 to align predictors at t with return at t+1
    df_subset['Stock_Return_Shifted'] = df_subset['Stock_Return'].shift(-1)

    # Drop the first row which now has NaN in 'Stock_Return_Shifted'
    df_subset = df_subset.dropna()

    # Standardize the predictors
    scaler = StandardScaler()
    df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']] = scaler.fit_transform(df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']])

    dt_results = []

    for max_depth in tree_depths:
        model = DecisionTreeRegressor(max_depth=max_depth, random_state=random_seed)
        val_rmse_list = []

        for i in range(train_size, train_size + val_size - 3):
            train_end = month_periods[i - 1]
            val_start = month_periods[i]
            val_end = month_periods[i + 2]

            train_mask = df_subset['Date'].dt.to_period('M') <= train_end
            val_mask = (df_subset['Date'].dt.to_period('M') >= val_start) & \
                       (df_subset['Date'].dt.to_period('M') <= val_end)

            X_train = df_subset.loc[train_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_train = df_subset.loc[train_mask, 'Stock_Return_Shifted']
            X_val = df_subset.loc[val_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_val = df_subset.loc[val_mask, 'Stock_Return_Shifted']

            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)
            rmse = np.sqrt(mean_squared_error(y_val, y_pred))
            val_rmse_list.append(rmse)

        dt_results.append({
            'Stock': stock,
            'Max_Depth': max_depth,
            'Avg_Validation_RMSE': np.mean(val_rmse_list),
            'Model': model
        })

    dt_results.sort(key=lambda x: x['Avg_Validation_RMSE'])
    best_dt_models[stock] = dt_results[0]['Model']
    all_dt_results.append(dt_results[0])
    print(f"✅ Decision Tree done for {stock} | Best max_depth: {dt_results[0]['Max_Depth']}")
    
# End global timer
end_all = time.time()
print(f"\n🟩 Finished all stocks | Total Time: {end_all - start_all:.2f} seconds")
# Out:
# 🌲 Decision Tree - Stock 1/975: AAPL.O
# ✅ Decision Tree done for AAPL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 2/975: NVDA.O
# ✅ Decision Tree done for NVDA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 3/975: MSFT.O
# ✅ Decision Tree done for MSFT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 4/975: AMZN.O
# ✅ Decision Tree done for AMZN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 5/975: LLY
# ✅ Decision Tree done for LLY | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 6/975: WMT
# ✅ Decision Tree done for WMT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 7/975: XOM
# ✅ Decision Tree done for XOM | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 8/975: MA
# ✅ Decision Tree done for MA | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 9/975: UNH
# ✅ Decision Tree done for UNH | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 10/975: ORCL.K
# ✅ Decision Tree done for ORCL.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 11/975: COST.O
# ✅ Decision Tree done for COST.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 12/975: NFLX.O
# ✅ Decision Tree done for NFLX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 13/975: HD
# ✅ Decision Tree done for HD | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 14/975: CVX
# ✅ Decision Tree done for CVX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 15/975: CRM
# ✅ Decision Tree done for CRM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 16/975: CSCO.O
# ✅ Decision Tree done for CSCO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 17/975: MRK
# ✅ Decision Tree done for MRK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 18/975: ABT
# ✅ Decision Tree done for ABT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 19/975: MCD
# ✅ Decision Tree done for MCD | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 20/975: TMO
# ✅ Decision Tree done for TMO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 21/975: ISRG.O
# ✅ Decision Tree done for ISRG.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 22/975: RTX
# ✅ Decision Tree done for RTX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 23/975: QCOM.O
# ✅ Decision Tree done for QCOM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 24/975: ADBE.O
# ✅ Decision Tree done for ADBE.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 25/975: AMGN.O
# ✅ Decision Tree done for AMGN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 26/975: INTU.O
# ✅ Decision Tree done for INTU.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 27/975: AMD.O
# ✅ Decision Tree done for AMD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 28/975: CAT
# ✅ Decision Tree done for CAT | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 29/975: TXN.O
# ✅ Decision Tree done for TXN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 30/975: NEE
# ✅ Decision Tree done for NEE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 31/975: DHR
# ✅ Decision Tree done for DHR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 32/975: PFE
# ✅ Decision Tree done for PFE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 33/975: BLK
# ✅ Decision Tree done for BLK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 34/975: UNP
# ✅ Decision Tree done for UNP | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 35/975: BSX
# ✅ Decision Tree done for BSX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 36/975: SYK
# ✅ Decision Tree done for SYK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 37/975: GILD.O
# ✅ Decision Tree done for GILD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 38/975: HON.O
# ✅ Decision Tree done for HON.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 39/975: CMCSA.O
# ✅ Decision Tree done for CMCSA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 40/975: VRTX.O
# ✅ Decision Tree done for VRTX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 41/975: DE
# ✅ Decision Tree done for DE | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 42/975: TJX
# ✅ Decision Tree done for TJX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 43/975: COP
# ✅ Decision Tree done for COP | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 44/975: LOW
# ✅ Decision Tree done for LOW | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 45/975: BA
# ✅ Decision Tree done for BA | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 46/975: FI
# ✅ Decision Tree done for FI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 47/975: BMY
# ✅ Decision Tree done for BMY | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 48/975: ADP.O
# ✅ Decision Tree done for ADP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 49/975: MMC
# ✅ Decision Tree done for MMC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 50/975: MU.O
# ✅ Decision Tree done for MU.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 51/975: NKE
# ✅ Decision Tree done for NKE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 52/975: INTC.O
# ✅ Decision Tree done for INTC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 53/975: ADI.O
# ✅ Decision Tree done for ADI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 54/975: LRCX.O
# ✅ Decision Tree done for LRCX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 55/975: ELV
# ✅ Decision Tree done for ELV | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 56/975: KLAC.O
# ✅ Decision Tree done for KLAC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 57/975: DUK
# ✅ Decision Tree done for DUK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 58/975: CI
# ✅ Decision Tree done for CI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 59/975: AJG
# ✅ Decision Tree done for AJG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 60/975: CVS
# ✅ Decision Tree done for CVS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 61/975: MMM
# ✅ Decision Tree done for MMM | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 62/975: MCK
# ✅ Decision Tree done for MCK | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 63/975: APH
# ✅ Decision Tree done for APH | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 64/975: ORLY.O
# ✅ Decision Tree done for ORLY.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 65/975: REGN.O
# ✅ Decision Tree done for REGN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 66/975: CL
# ✅ Decision Tree done for CL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 67/975: RSG
# ✅ Decision Tree done for RSG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 68/975: NOC
# ✅ Decision Tree done for NOC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 69/975: WMB
# ✅ Decision Tree done for WMB | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 70/975: MSI
# ✅ Decision Tree done for MSI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 71/975: SNPS.O
# ✅ Decision Tree done for SNPS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 72/975: EOG
# ✅ Decision Tree done for EOG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 73/975: CDNS.O
# ✅ Decision Tree done for CDNS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 74/975: CMG
# ✅ Decision Tree done for CMG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 75/975: MAR.O
# ✅ Decision Tree done for MAR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 76/975: BDX
# ✅ Decision Tree done for BDX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 77/975: ROP.O
# ✅ Decision Tree done for ROP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 78/975: OKE
# ✅ Decision Tree done for OKE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 79/975: AZO
# ✅ Decision Tree done for AZO | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 80/975: MRVL.O
# ✅ Decision Tree done for MRVL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 81/975: BK
# ✅ Decision Tree done for BK | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 82/975: CSX.O
# ✅ Decision Tree done for CSX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 83/975: SLB
# ✅ Decision Tree done for SLB | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 84/975: MET
# ✅ Decision Tree done for MET | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 85/975: ADSK.O
# ✅ Decision Tree done for ADSK.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 86/975: TFC
# ✅ Decision Tree done for TFC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 87/975: PCAR.O
# ✅ Decision Tree done for PCAR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 88/975: COR
# ✅ Decision Tree done for COR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 89/975: LNG
# ✅ Decision Tree done for LNG | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 90/975: TGT
# ✅ Decision Tree done for TGT | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 91/975: KR
# ✅ Decision Tree done for KR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 92/975: D
# ✅ Decision Tree done for D | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 93/975: HES
# ✅ Decision Tree done for HES | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 94/975: FICO.K
# ✅ Decision Tree done for FICO.K | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 95/975: OXY
# ✅ Decision Tree done for OXY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 96/975: BKR.O
# ✅ Decision Tree done for BKR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 97/975: ROST.O
# ✅ Decision Tree done for ROST.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 98/975: EW
# ✅ Decision Tree done for EW | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 99/975: VLO
# ✅ Decision Tree done for VLO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 100/975: AME
# ✅ Decision Tree done for AME | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 101/975: GLW
# ✅ Decision Tree done for GLW | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 102/975: DHI
# ✅ Decision Tree done for DHI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 103/975: LHX
# ✅ Decision Tree done for LHX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 104/975: CTSH.O
# ✅ Decision Tree done for CTSH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 105/975: PWR
# ✅ Decision Tree done for PWR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 106/975: F
# ✅ Decision Tree done for F | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 107/975: EA.O
# ✅ Decision Tree done for EA.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 108/975: TTWO.O
# ✅ Decision Tree done for TTWO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 109/975: A
# ✅ Decision Tree done for A | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 110/975: ODFL.O
# ✅ Decision Tree done for ODFL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 111/975: BRO
# ✅ Decision Tree done for BRO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 112/975: IDXX.O
# ✅ Decision Tree done for IDXX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 113/975: CSGP.O
# ✅ Decision Tree done for CSGP.O | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 114/975: ALNY.O
# ✅ Decision Tree done for ALNY.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 115/975: HEI
# ✅ Decision Tree done for HEI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 116/975: LVS
# ✅ Decision Tree done for LVS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 117/975: CAH
# ✅ Decision Tree done for CAH | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 118/975: WAB
# ✅ Decision Tree done for WAB | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 119/975: HUM
# ✅ Decision Tree done for HUM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 120/975: NUE
# ✅ Decision Tree done for NUE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 121/975: EBAY.O
# ✅ Decision Tree done for EBAY.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 122/975: TPL
# ✅ Decision Tree done for TPL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 123/975: EQT
# ✅ Decision Tree done for EQT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 124/975: ROK
# ✅ Decision Tree done for ROK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 125/975: MPWR.O
# ✅ Decision Tree done for MPWR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 126/975: MCHP.O
# ✅ Decision Tree done for MCHP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 127/975: ANSS.O
# ✅ Decision Tree done for ANSS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 128/975: DTE
# ✅ Decision Tree done for DTE | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 129/975: DXCM.O
# ✅ Decision Tree done for DXCM.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 130/975: IP
# ✅ Decision Tree done for IP | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 131/975: AEE
# ✅ Decision Tree done for AEE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 132/975: PPG
# ✅ Decision Tree done for PPG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 133/975: PPL
# ✅ Decision Tree done for PPL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 134/975: MTD
# ✅ Decision Tree done for MTD | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 135/975: WBD.O
# ✅ Decision Tree done for WBD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 136/975: TYL
# ✅ Decision Tree done for TYL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 137/975: EL
# ✅ Decision Tree done for EL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 138/975: ATO
# ✅ Decision Tree done for ATO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 139/975: GPN
# ✅ Decision Tree done for GPN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 140/975: TDY
# ✅ Decision Tree done for TDY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 141/975: VRSN.O
# ✅ Decision Tree done for VRSN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 142/975: DVN
# ✅ Decision Tree done for DVN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 143/975: WAT
# ✅ Decision Tree done for WAT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 144/975: ERIE.O
# ✅ Decision Tree done for ERIE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 145/975: ZBH
# ✅ Decision Tree done for ZBH | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 146/975: DRI
# ✅ Decision Tree done for DRI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 147/975: HAL
# ✅ Decision Tree done for HAL | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 148/975: NVR
# ✅ Decision Tree done for NVR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 149/975: TSN
# ✅ Decision Tree done for TSN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 150/975: CTRA.K
# ✅ Decision Tree done for CTRA.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 151/975: PHM
# ✅ Decision Tree done for PHM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 152/975: TROW.O
# ✅ Decision Tree done for TROW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 153/975: LII
# ✅ Decision Tree done for LII | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 154/975: BIIB.O
# ✅ Decision Tree done for BIIB.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 155/975: LH
# ✅ Decision Tree done for LH | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 156/975: STLD.O
# ✅ Decision Tree done for STLD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 157/975: NRG
# ✅ Decision Tree done for NRG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 158/975: DGX
# ✅ Decision Tree done for DGX | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 159/975: LUV
# ✅ Decision Tree done for LUV | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 160/975: PTC.O
# ✅ Decision Tree done for PTC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 161/975: NTAP.O
# ✅ Decision Tree done for NTAP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 162/975: ON.O
# ✅ Decision Tree done for ON.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 163/975: CLX
# ✅ Decision Tree done for CLX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 164/975: DECK.K
# ✅ Decision Tree done for DECK.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 165/975: FNF
# ✅ Decision Tree done for FNF | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 166/975: BAX
# ✅ Decision Tree done for BAX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 167/975: EME
# ✅ Decision Tree done for EME | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 168/975: TRMB.O
# ✅ Decision Tree done for TRMB.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 169/975: GPC
# ✅ Decision Tree done for GPC | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 170/975: GEN.O
# ✅ Decision Tree done for GEN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 171/975: WST
# ✅ Decision Tree done for WST | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 172/975: HRL
# ✅ Decision Tree done for HRL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 173/975: COO.O
# ✅ Decision Tree done for COO.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 174/975: EXPD.K
# ✅ Decision Tree done for EXPD.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 175/975: WDC.O
# ✅ Decision Tree done for WDC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 176/975: BBY
# ✅ Decision Tree done for BBY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 177/975: FFIV.O
# ✅ Decision Tree done for FFIV.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 178/975: RS
# ✅ Decision Tree done for RS | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 179/975: RPM
# ✅ Decision Tree done for RPM | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 180/975: JBL
# ✅ Decision Tree done for JBL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 181/975: ENTG.O
# ✅ Decision Tree done for ENTG.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 182/975: BALL.K
# ✅ Decision Tree done for BALL.K | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 183/975: BLDR.K
# ✅ Decision Tree done for BLDR.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 184/975: FSLR.O
# ✅ Decision Tree done for FSLR.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 185/975: GGG
# ✅ Decision Tree done for GGG | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 186/975: TER.O
# ✅ Decision Tree done for TER.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 187/975: UNM
# ✅ Decision Tree done for UNM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 188/975: DLTR.O
# ✅ Decision Tree done for DLTR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 189/975: INSM.O
# ✅ Decision Tree done for INSM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 190/975: UTHR.O
# ✅ Decision Tree done for UTHR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 191/975: HOLX.O
# ✅ Decision Tree done for HOLX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 192/975: ILMN.O
# ✅ Decision Tree done for ILMN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 193/975: RVTY.K
# ✅ Decision Tree done for RVTY.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 194/975: BMRN.O
# ✅ Decision Tree done for BMRN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 195/975: FLEX.O
# ✅ Decision Tree done for FLEX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 196/975: INCY.O
# ✅ Decision Tree done for INCY.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 197/975: JKHY.O
# ✅ Decision Tree done for JKHY.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 198/975: MORN.O
# ✅ Decision Tree done for MORN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 199/975: ALGN.O
# ✅ Decision Tree done for ALGN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 200/975: EWBC.O
# ✅ Decision Tree done for EWBC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 201/975: AKAM.O
# ✅ Decision Tree done for AKAM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 202/975: FIX
# ✅ Decision Tree done for FIX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 203/975: JNPR.K
# ✅ Decision Tree done for JNPR.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 204/975: SJM
# ✅ Decision Tree done for SJM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 205/975: JLL
# ✅ Decision Tree done for JLL | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 206/975: NDSN.O
# ✅ Decision Tree done for NDSN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 207/975: CHRW.O
# ✅ Decision Tree done for CHRW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 208/975: THC
# ✅ Decision Tree done for THC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 209/975: JEF
# ✅ Decision Tree done for JEF | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 210/975: COKE.O
# ✅ Decision Tree done for COKE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 211/975: TXRH.O
# ✅ Decision Tree done for TXRH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 212/975: SWKS.O
# ✅ Decision Tree done for SWKS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 213/975: NBIX.O
# ✅ Decision Tree done for NBIX.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 214/975: ITT
# ✅ Decision Tree done for ITT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 215/975: VTRS.O
# ✅ Decision Tree done for VTRS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 216/975: SNX
# ✅ Decision Tree done for SNX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 217/975: AIZ
# ✅ Decision Tree done for AIZ | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 218/975: RBC
# ✅ Decision Tree done for RBC | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 219/975: OVV
# ✅ Decision Tree done for OVV | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 220/975: MANH.O
# ✅ Decision Tree done for MANH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 221/975: EMN
# ✅ Decision Tree done for EMN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 222/975: CCK
# ✅ Decision Tree done for CCK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 223/975: TOL
# ✅ Decision Tree done for TOL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 224/975: CLH
# ✅ Decision Tree done for CLH | Best max_depth: 10
#
# 🌲 Decision Tree - Stock 225/975: GME
# ✅ Decision Tree done for GME | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 226/975: EXEL.O
# ✅ Decision Tree done for EXEL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 227/975: RGLD.O
# ✅ Decision Tree done for RGLD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 228/975: COHR.K
# ✅ Decision Tree done for COHR.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 229/975: DOX.O
# ✅ Decision Tree done for DOX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 230/975: IPG
# ✅ Decision Tree done for IPG | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 231/975: TECH.O
# ✅ Decision Tree done for TECH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 232/975: ATR
# ✅ Decision Tree done for ATR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 233/975: WBA.O
# ✅ Decision Tree done for WBA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 234/975: MTZ
# ✅ Decision Tree done for MTZ | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 235/975: SRPT.O
# ✅ Decision Tree done for SRPT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 236/975: SAIA.O
# ✅ Decision Tree done for SAIA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 237/975: SEIC.O
# ✅ Decision Tree done for SEIC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 238/975: RRC
# ✅ Decision Tree done for RRC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 239/975: WYNN.O
# ✅ Decision Tree done for WYNN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 240/975: CRS
# ✅ Decision Tree done for CRS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 241/975: CIEN.K
# ✅ Decision Tree done for CIEN.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 242/975: ALB
# ✅ Decision Tree done for ALB | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 243/975: X
# ✅ Decision Tree done for X | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 244/975: HSIC.O
# ✅ Decision Tree done for HSIC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 245/975: LNW.O
# ✅ Decision Tree done for LNW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 246/975: CHE
# ✅ Decision Tree done for CHE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 247/975: CRL
# ✅ Decision Tree done for CRL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 248/975: DRS.O
# ✅ Decision Tree done for DRS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 249/975: RGEN.O
# ✅ Decision Tree done for RGEN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 250/975: LSCC.O
# ✅ Decision Tree done for LSCC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 251/975: EXAS.O
# ✅ Decision Tree done for EXAS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 252/975: HAS.O
# ✅ Decision Tree done for HAS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 253/975: PARA.O
# ✅ Decision Tree done for PARA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 254/975: DCI
# ✅ Decision Tree done for DCI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 255/975: CHDN.O
# ✅ Decision Tree done for CHDN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 256/975: MKTX.O
# ✅ Decision Tree done for MKTX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 257/975: NYT
# ✅ Decision Tree done for NYT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 258/975: WCC
# ✅ Decision Tree done for WCC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 259/975: DLB
# ✅ Decision Tree done for DLB | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 260/975: EVR
# ✅ Decision Tree done for EVR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 261/975: TTEK.O
# ✅ Decision Tree done for TTEK.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 262/975: RRX
# ✅ Decision Tree done for RRX | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 263/975: SIRI.O
# ✅ Decision Tree done for SIRI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 264/975: HALO.O
# ✅ Decision Tree done for HALO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 265/975: GAP
# ✅ Decision Tree done for GAP | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 266/975: EXLS.O
# ✅ Decision Tree done for EXLS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 267/975: ATI
# ✅ Decision Tree done for ATI | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 268/975: TTC
# ✅ Decision Tree done for TTC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 269/975: ZION.O
# ✅ Decision Tree done for ZION.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 270/975: BIO
# ✅ Decision Tree done for BIO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 271/975: MHK
# ✅ Decision Tree done for MHK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 272/975: APA.O
# ✅ Decision Tree done for APA.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 273/975: CVLT.O
# ✅ Decision Tree done for CVLT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 274/975: AGCO.K
# ✅ Decision Tree done for AGCO.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 275/975: BRKR.O
# ✅ Decision Tree done for BRKR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 276/975: RLI
# ✅ Decision Tree done for RLI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 277/975: IVZ
# ✅ Decision Tree done for IVZ | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 278/975: ONTO.K
# ✅ Decision Tree done for ONTO.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 279/975: CWST.O
# ✅ Decision Tree done for CWST.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 280/975: QRVO.O
# ✅ Decision Tree done for QRVO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 281/975: AAON.O
# ✅ Decision Tree done for AAON.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 282/975: ALK
# ✅ Decision Tree done for ALK | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 283/975: UFPI.O
# ✅ Decision Tree done for UFPI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 284/975: FLS
# ✅ Decision Tree done for FLS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 285/975: SNV
# ✅ Decision Tree done for SNV | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 286/975: TGTX.O
# ✅ Decision Tree done for TGTX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 287/975: TFX
# ✅ Decision Tree done for TFX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 288/975: CELH.O
# ✅ Decision Tree done for CELH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 289/975: EAT
# ✅ Decision Tree done for EAT | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 290/975: PEGA.O
# ✅ Decision Tree done for PEGA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 291/975: OSK
# ✅ Decision Tree done for OSK | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 292/975: LNC
# ✅ Decision Tree done for LNC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 293/975: AWI
# ✅ Decision Tree done for AWI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 294/975: CHH
# ✅ Decision Tree done for CHH | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 295/975: WEX
# ✅ Decision Tree done for WEX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 296/975: CORT.O
# ✅ Decision Tree done for CORT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 297/975: MSA
# ✅ Decision Tree done for MSA | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 298/975: RMBS.O
# ✅ Decision Tree done for RMBS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 299/975: FCN
# ✅ Decision Tree done for FCN | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 300/975: BMI
# ✅ Decision Tree done for BMI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 301/975: MMSI.O
# ✅ Decision Tree done for MMSI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 302/975: MKSI.O
# ✅ Decision Tree done for MKSI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 303/975: CACC.O
# ✅ Decision Tree done for CACC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 304/975: BYD
# ✅ Decision Tree done for BYD | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 305/975: DDS
# ✅ Decision Tree done for DDS | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 306/975: IDCC.O
# ✅ Decision Tree done for IDCC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 307/975: ACIW.O
# ✅ Decision Tree done for ACIW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 308/975: USM
# ✅ Decision Tree done for USM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 309/975: CROX.O
# ✅ Decision Tree done for CROX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 310/975: GNTX.O
# ✅ Decision Tree done for GNTX.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 311/975: CRVL.O
# ✅ Decision Tree done for CRVL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 312/975: ARW
# ✅ Decision Tree done for ARW | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 313/975: NOV
# ✅ Decision Tree done for NOV | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 314/975: RHI
# ✅ Decision Tree done for RHI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 315/975: SKY
# ✅ Decision Tree done for SKY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 316/975: CRK
# ✅ Decision Tree done for CRK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 317/975: OPCH.O
# ✅ Decision Tree done for OPCH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 318/975: CGNX.O
# ✅ Decision Tree done for CGNX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 319/975: LSTR.O
# ✅ Decision Tree done for LSTR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 320/975: CRUS.O
# ✅ Decision Tree done for CRUS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 321/975: CMC
# ✅ Decision Tree done for CMC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 322/975: CYTK.O
# ✅ Decision Tree done for CYTK.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 323/975: QXO
# ✅ Decision Tree done for QXO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 324/975: IONS.O
# ✅ Decision Tree done for IONS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 325/975: TKR
# ✅ Decision Tree done for TKR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 326/975: LFUS.O
# ✅ Decision Tree done for LFUS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 327/975: NXST.O
# ✅ Decision Tree done for NXST.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 328/975: LAZ
# ✅ Decision Tree done for LAZ | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 329/975: MTH
# ✅ Decision Tree done for MTH | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 330/975: TXNM.K
# ✅ Decision Tree done for TXNM.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 331/975: LUMN.K
# ✅ Decision Tree done for LUMN.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 332/975: POR
# ✅ Decision Tree done for POR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 333/975: AMKR.O
# ✅ Decision Tree done for AMKR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 334/975: NSIT.O
# ✅ Decision Tree done for NSIT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 335/975: AMG
# ✅ Decision Tree done for AMG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 336/975: ITRI.O
# ✅ Decision Tree done for ITRI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 337/975: FSS
# ✅ Decision Tree done for FSS | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 338/975: HXL
# ✅ Decision Tree done for HXL | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 339/975: FELE.O
# ✅ Decision Tree done for FELE.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 340/975: CNX
# ✅ Decision Tree done for CNX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 341/975: DY
# ✅ Decision Tree done for DY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 342/975: URBN.O
# ✅ Decision Tree done for URBN.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 343/975: PIPR.K
# ✅ Decision Tree done for PIPR.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 344/975: MOD
# ✅ Decision Tree done for MOD | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 345/975: EEFT.O
# ✅ Decision Tree done for EEFT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 346/975: BKH
# ✅ Decision Tree done for BKH | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 347/975: KMPR.K
# ✅ Decision Tree done for KMPR.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 348/975: KBH
# ✅ Decision Tree done for KBH | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 349/975: MSM
# ✅ Decision Tree done for MSM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 350/975: THO
# ✅ Decision Tree done for THO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 351/975: EXPO.O
# ✅ Decision Tree done for EXPO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 352/975: NNI
# ✅ Decision Tree done for NNI | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 353/975: ESE
# ✅ Decision Tree done for ESE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 354/975: PBH
# ✅ Decision Tree done for PBH | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 355/975: AVT.O
# ✅ Decision Tree done for AVT.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 356/975: SANM.O
# ✅ Decision Tree done for SANM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 357/975: IPAR.O
# ✅ Decision Tree done for IPAR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 358/975: BDC
# ✅ Decision Tree done for BDC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 359/975: CVCO.O
# ✅ Decision Tree done for CVCO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 360/975: SLAB.O
# ✅ Decision Tree done for SLAB.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 361/975: AEIS.O
# ✅ Decision Tree done for AEIS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 362/975: ANF
# ✅ Decision Tree done for ANF | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 363/975: JWN
# ✅ Decision Tree done for JWN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 364/975: ITGR.K
# ✅ Decision Tree done for ITGR.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 365/975: SPR
# ✅ Decision Tree done for SPR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 366/975: DORM.O
# ✅ Decision Tree done for DORM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 367/975: ALE
# ✅ Decision Tree done for ALE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 368/975: MMS
# ✅ Decision Tree done for MMS | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 369/975: FIZZ.O
# ✅ Decision Tree done for FIZZ.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 370/975: TDS
# ✅ Decision Tree done for TDS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 371/975: CBZ
# ✅ Decision Tree done for CBZ | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 372/975: BCO
# ✅ Decision Tree done for BCO | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 373/975: AVNT.K
# ✅ Decision Tree done for AVNT.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 374/975: AVAV.O
# ✅ Decision Tree done for AVAV.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 375/975: IESC.O
# ✅ Decision Tree done for IESC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 376/975: M
# ✅ Decision Tree done for M | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 377/975: PRIM.K
# ✅ Decision Tree done for PRIM.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 378/975: SKYW.O
# ✅ Decision Tree done for SKYW.O | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 379/975: ICUI.O
# ✅ Decision Tree done for ICUI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 380/975: KFY
# ✅ Decision Tree done for KFY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 381/975: RDNT.O
# ✅ Decision Tree done for RDNT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 382/975: NWE.O
# ✅ Decision Tree done for NWE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 383/975: SM
# ✅ Decision Tree done for SM | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 384/975: SMTC.O
# ✅ Decision Tree done for SMTC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 385/975: CCOI.O
# ✅ Decision Tree done for CCOI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 386/975: PLXS.O
# ✅ Decision Tree done for PLXS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 387/975: NSP
# ✅ Decision Tree done for NSP | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 388/975: HAE
# ✅ Decision Tree done for HAE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 389/975: POWI.O
# ✅ Decision Tree done for POWI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 390/975: AVA
# ✅ Decision Tree done for AVA | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 391/975: TNL
# ✅ Decision Tree done for TNL | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 392/975: MHO
# ✅ Decision Tree done for MHO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 393/975: DXC
# ✅ Decision Tree done for DXC | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 394/975: BLKB.O
# ✅ Decision Tree done for BLKB.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 395/975: XRAY.O
# ✅ Decision Tree done for XRAY.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 396/975: OSIS.O
# ✅ Decision Tree done for OSIS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 397/975: HOG
# ✅ Decision Tree done for HOG | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 398/975: PTEN.O
# ✅ Decision Tree done for PTEN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 399/975: AMED.O
# ✅ Decision Tree done for AMED.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 400/975: ASGN.K
# ✅ Decision Tree done for ASGN.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 401/975: CPK
# ✅ Decision Tree done for CPK | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 402/975: ACAD.O
# ✅ Decision Tree done for ACAD.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 403/975: NOG
# ✅ Decision Tree done for NOG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 404/975: FUL
# ✅ Decision Tree done for FUL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 405/975: PATK.O
# ✅ Decision Tree done for PATK.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 406/975: TGNA.K
# ✅ Decision Tree done for TGNA.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 407/975: MAN
# ✅ Decision Tree done for MAN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 408/975: MGRC.O
# ✅ Decision Tree done for MGRC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 409/975: GNW
# ✅ Decision Tree done for GNW | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 410/975: PDCO.O
# ✅ Decision Tree done for PDCO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 411/975: NWL.O
# ✅ Decision Tree done for NWL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 412/975: GEF
# ✅ Decision Tree done for GEF | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 413/975: GSAT.O
# ✅ Decision Tree done for GSAT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 414/975: TEX
# ✅ Decision Tree done for TEX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 415/975: IPGP.O
# ✅ Decision Tree done for IPGP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 416/975: PENN.O
# ✅ Decision Tree done for PENN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 417/975: JOE
# ✅ Decision Tree done for JOE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 418/975: HURN.O
# ✅ Decision Tree done for HURN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 419/975: JJSF.O
# ✅ Decision Tree done for JJSF.O | Best max_depth: 10
#
# 🌲 Decision Tree - Stock 420/975: GT.O
# ✅ Decision Tree done for GT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 421/975: SAM
# ✅ Decision Tree done for SAM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 422/975: HP
# ✅ Decision Tree done for HP | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 423/975: PSMT.O
# ✅ Decision Tree done for PSMT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 424/975: CPRX.O
# ✅ Decision Tree done for CPRX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 425/975: FORM.O
# ✅ Decision Tree done for FORM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 426/975: SYNA.O
# ✅ Decision Tree done for SYNA.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 427/975: QDEL.O
# ✅ Decision Tree done for QDEL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 428/975: VIAV.O
# ✅ Decision Tree done for VIAV.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 429/975: VICR.O
# ✅ Decision Tree done for VICR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 430/975: BFH
# ✅ Decision Tree done for BFH | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 431/975: PRGS.O
# ✅ Decision Tree done for PRGS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 432/975: TRN
# ✅ Decision Tree done for TRN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 433/975: CAKE.O
# ✅ Decision Tree done for CAKE.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 434/975: WLY
# ✅ Decision Tree done for WLY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 435/975: PAR
# ✅ Decision Tree done for PAR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 436/975: VSEC.O
# ✅ Decision Tree done for VSEC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 437/975: LCII.K
# ✅ Decision Tree done for LCII.K | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 438/975: AIN
# ✅ Decision Tree done for AIN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 439/975: HUBG.O
# ✅ Decision Tree done for HUBG.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 440/975: VCEL.O
# ✅ Decision Tree done for VCEL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 441/975: AAP
# ✅ Decision Tree done for AAP | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 442/975: ALG
# ✅ Decision Tree done for ALG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 443/975: OII
# ✅ Decision Tree done for OII | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 444/975: TTMI.O
# ✅ Decision Tree done for TTMI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 445/975: CXW
# ✅ Decision Tree done for CXW | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 446/975: SSRM.O
# ✅ Decision Tree done for SSRM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 447/975: DIOD.O
# ✅ Decision Tree done for DIOD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 448/975: AEO
# ✅ Decision Tree done for AEO | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 449/975: ARWR.O
# ✅ Decision Tree done for ARWR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 450/975: WMK
# ✅ Decision Tree done for WMK | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 451/975: AGYS.O
# ✅ Decision Tree done for AGYS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 452/975: LGFa
# ✅ Decision Tree done for LGFa | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 453/975: LGND.O
# ✅ Decision Tree done for LGND.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 454/975: HNI
# ✅ Decision Tree done for HNI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 455/975: JBLU.O
# ✅ Decision Tree done for JBLU.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 456/975: NEOG.O
# ✅ Decision Tree done for NEOG.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 457/975: HE
# ✅ Decision Tree done for HE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 458/975: EXTR.O
# ✅ Decision Tree done for EXTR.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 459/975: ACLS.O
# ✅ Decision Tree done for ACLS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 460/975: WERN.O
# ✅ Decision Tree done for WERN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 461/975: LMAT.O
# ✅ Decision Tree done for LMAT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 462/975: CENX.O
# ✅ Decision Tree done for CENX.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 463/975: BKE
# ✅ Decision Tree done for BKE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 464/975: CNMD.K
# ✅ Decision Tree done for CNMD.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 465/975: OI
# ✅ Decision Tree done for OI | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 466/975: CSGS.O
# ✅ Decision Tree done for CSGS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 467/975: RAMP.K
# ✅ Decision Tree done for RAMP.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 468/975: IART.O
# ✅ Decision Tree done for IART.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 469/975: ZD.O
# ✅ Decision Tree done for ZD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 470/975: PBI
# ✅ Decision Tree done for PBI | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 471/975: GBX
# ✅ Decision Tree done for GBX | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 472/975: DVAX.O
# ✅ Decision Tree done for DVAX.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 473/975: PLUS.O
# ✅ Decision Tree done for PLUS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 474/975: AZTA.O
# ✅ Decision Tree done for AZTA.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 475/975: KMT
# ✅ Decision Tree done for KMT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 476/975: ATRC.O
# ✅ Decision Tree done for ATRC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 477/975: UFPT.O
# ✅ Decision Tree done for UFPT.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 478/975: UNFI.K
# ✅ Decision Tree done for UNFI.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 479/975: BCRX.O
# ✅ Decision Tree done for BCRX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 480/975: STGW.O
# ✅ Decision Tree done for STGW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 481/975: WKC
# ✅ Decision Tree done for WKC | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 482/975: MNKD.O
# ✅ Decision Tree done for MNKD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 483/975: MCRI.O
# ✅ Decision Tree done for MCRI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 484/975: APLD.O
# ✅ Decision Tree done for APLD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 485/975: SRCE.O
# ✅ Decision Tree done for SRCE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 486/975: OMCL.O
# ✅ Decision Tree done for OMCL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 487/975: INOD.O
# ✅ Decision Tree done for INOD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 488/975: FL
# ✅ Decision Tree done for FL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 489/975: NTCT.O
# ✅ Decision Tree done for NTCT.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 490/975: EPC
# ✅ Decision Tree done for EPC | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 491/975: ATSG.O
# ✅ Decision Tree done for ATSG.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 492/975: ADEA.O
# ✅ Decision Tree done for ADEA.O | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 493/975: ROG
# ✅ Decision Tree done for ROG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 494/975: NHC
# ✅ Decision Tree done for NHC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 495/975: LNN
# ✅ Decision Tree done for LNN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 496/975: PZZA.O
# ✅ Decision Tree done for PZZA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 497/975: BHE
# ✅ Decision Tree done for BHE | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 498/975: UPBD.O
# ✅ Decision Tree done for UPBD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 499/975: ANIP.O
# ✅ Decision Tree done for ANIP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 500/975: CLDX.O
# ✅ Decision Tree done for CLDX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 501/975: VRNT.O
# ✅ Decision Tree done for VRNT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 502/975: PLAB.O
# ✅ Decision Tree done for PLAB.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 503/975: VYX
# ✅ Decision Tree done for VYX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 504/975: DXPE.O
# ✅ Decision Tree done for DXPE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 505/975: ATEC.O
# ✅ Decision Tree done for ATEC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 506/975: NVAX.O
# ✅ Decision Tree done for NVAX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 507/975: CTS
# ✅ Decision Tree done for CTS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 508/975: VSAT.O
# ✅ Decision Tree done for VSAT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 509/975: NEO.O
# ✅ Decision Tree done for NEO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 510/975: WT
# ✅ Decision Tree done for WT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 511/975: SCS
# ✅ Decision Tree done for SCS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 512/975: VECO.O
# ✅ Decision Tree done for VECO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 513/975: INVX.K
# ✅ Decision Tree done for INVX.K | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 514/975: DCOM.O
# ✅ Decision Tree done for DCOM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 515/975: EIG
# ✅ Decision Tree done for EIG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 516/975: HLIT.O
# ✅ Decision Tree done for HLIT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 517/975: HLX
# ✅ Decision Tree done for HLX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 518/975: IDT
# ✅ Decision Tree done for IDT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 519/975: BLFS.O
# ✅ Decision Tree done for BLFS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 520/975: GIII.O
# ✅ Decision Tree done for GIII.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 521/975: CRAI.O
# ✅ Decision Tree done for CRAI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 522/975: IMKTA.O
# ✅ Decision Tree done for IMKTA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 523/975: OPK.O
# ✅ Decision Tree done for OPK.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 524/975: SAFT.O
# ✅ Decision Tree done for SAFT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 525/975: RES
# ✅ Decision Tree done for RES | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 526/975: UCTT.O
# ✅ Decision Tree done for UCTT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 527/975: GYRE.O
# ✅ Decision Tree done for GYRE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 528/975: MODG.K
# ✅ Decision Tree done for MODG.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 529/975: TILE.O
# ✅ Decision Tree done for TILE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 530/975: MSEX.O
# ✅ Decision Tree done for MSEX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 531/975: MRTN.O
# ✅ Decision Tree done for MRTN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 532/975: PRG
# ✅ Decision Tree done for PRG | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 533/975: INVA.O
# ✅ Decision Tree done for INVA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 534/975: DGII.O
# ✅ Decision Tree done for DGII.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 535/975: APOG.O
# ✅ Decision Tree done for APOG.O | Best max_depth: 4
#
# ...
# ✅ Decision Tree done for FONR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 803/975: MCHX.O
# ✅ Decision Tree done for MCHX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 804/975: LPTH.O
# ✅ Decision Tree done for LPTH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 805/975: HGBL.O
# ✅ Decision Tree done for HGBL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 806/975: PETS.O
# ✅ Decision Tree done for PETS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 807/975: DIT
# ✅ Decision Tree done for DIT | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 808/975: AXTI.O
# ✅ Decision Tree done for AXTI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 809/975: FOSL.O
# ✅ Decision Tree done for FOSL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 810/975: ALOT.O
# ✅ Decision Tree done for ALOT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 811/975: HNNA.O
# ✅ Decision Tree done for HNNA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 812/975: RRGB.O
# ✅ Decision Tree done for RRGB.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 813/975: UBCP.O
# ✅ Decision Tree done for UBCP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 814/975: MNOV.O
# ✅ Decision Tree done for MNOV.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 815/975: INVE.O
# ✅ Decision Tree done for INVE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 816/975: SGA.O
# ✅ Decision Tree done for SGA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 817/975: ESP
# ✅ Decision Tree done for ESP | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 818/975: OPTT.K
# ✅ Decision Tree done for OPTT.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 819/975: CODA.O
# ✅ Decision Tree done for CODA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 820/975: AUBN.O
# ✅ Decision Tree done for AUBN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 821/975: INO.O
# ✅ Decision Tree done for INO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 822/975: IOR
# ✅ Decision Tree done for IOR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 823/975: MLSS.K
# ✅ Decision Tree done for MLSS.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 824/975: AREN.K
# ✅ Decision Tree done for AREN.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 825/975: VERU.O
# ✅ Decision Tree done for VERU.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 826/975: ASYS.O
# ✅ Decision Tree done for ASYS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 827/975: ARMP.K
# ✅ Decision Tree done for ARMP.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 828/975: ASRT.O
# ✅ Decision Tree done for ASRT.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 829/975: FKWL.O
# ✅ Decision Tree done for FKWL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 830/975: DOMH.O
# ✅ Decision Tree done for DOMH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 831/975: DLHC.O
# ✅ Decision Tree done for DLHC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 832/975: PED
# ✅ Decision Tree done for PED | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 833/975: ALTS.O
# ✅ Decision Tree done for ALTS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 834/975: CULP.K
# ✅ Decision Tree done for CULP.K | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 835/975: SUP
# ✅ Decision Tree done for SUP | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 836/975: CATO.K
# ✅ Decision Tree done for CATO.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 837/975: CYCC.O
# ✅ Decision Tree done for CYCC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 838/975: ICAD.O
# ✅ Decision Tree done for ICAD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 839/975: WFCF.O
# ✅ Decision Tree done for WFCF.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 840/975: LINK.O
# ✅ Decision Tree done for LINK.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 841/975: CTSO.O
# ✅ Decision Tree done for CTSO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 842/975: CNVS.O
# ✅ Decision Tree done for CNVS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 843/975: CNTY.O
# ✅ Decision Tree done for CNTY.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 844/975: MIND.O
# ✅ Decision Tree done for MIND.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 845/975: SOTK.O
# ✅ Decision Tree done for SOTK.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 846/975: RMTI.O
# ✅ Decision Tree done for RMTI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 847/975: CVGI.O
# ✅ Decision Tree done for CVGI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 848/975: MBOT.O
# ✅ Decision Tree done for MBOT.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 849/975: LEE.O
# ✅ Decision Tree done for LEE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 850/975: CMTL.O
# ✅ Decision Tree done for CMTL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 851/975: KOSS.O
# ✅ Decision Tree done for KOSS.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 852/975: BDL
# ✅ Decision Tree done for BDL | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 853/975: UG.O
# ✅ Decision Tree done for UG.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 854/975: IDN.O
# ✅ Decision Tree done for IDN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 855/975: ICCC.O
# ✅ Decision Tree done for ICCC.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 856/975: CVU
# ✅ Decision Tree done for CVU | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 857/975: AGEN.O
# ✅ Decision Tree done for AGEN.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 858/975: REFR.O
# ✅ Decision Tree done for REFR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 859/975: DWSN.O
# ✅ Decision Tree done for DWSN.O | Best max_depth: 10
#
# 🌲 Decision Tree - Stock 860/975: AP
# ✅ Decision Tree done for AP | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 861/975: RFIL.O
# ✅ Decision Tree done for RFIL.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 862/975: USIO.O
# ✅ Decision Tree done for USIO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 863/975: CRWS.O
# ✅ Decision Tree done for CRWS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 864/975: PXLW.O
# ✅ Decision Tree done for PXLW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 865/975: APYX.O
# ✅ Decision Tree done for APYX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 866/975: TACT.O
# ✅ Decision Tree done for TACT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 867/975: SYPR.O
# ✅ Decision Tree done for SYPR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 868/975: UONEK.O
# ✅ Decision Tree done for UONEK.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 869/975: ARKR.O
# ✅ Decision Tree done for ARKR.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 870/975: HHS.O
# ✅ Decision Tree done for HHS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 871/975: WYY
# ✅ Decision Tree done for WYY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 872/975: ACCS.K
# ✅ Decision Tree done for ACCS.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 873/975: AWRE.O
# ✅ Decision Tree done for AWRE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 874/975: AIFF.O
# ✅ Decision Tree done for AIFF.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 875/975: SGRP.O
# ✅ Decision Tree done for SGRP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 876/975: NTIP.K
# ✅ Decision Tree done for NTIP.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 877/975: VHC
# ✅ Decision Tree done for VHC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 878/975: FTEK.O
# ✅ Decision Tree done for FTEK.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 879/975: GROW.O
# ✅ Decision Tree done for GROW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 880/975: IRD.O
# ✅ Decision Tree done for IRD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 881/975: CMS_pb
# ✅ Decision Tree done for CMS_pb | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 882/975: KTCC.O
# ✅ Decision Tree done for KTCC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 883/975: HSON.O
# ✅ Decision Tree done for HSON.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 884/975: AXDX.O
# ✅ Decision Tree done for AXDX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 885/975: HBIO.O
# ✅ Decision Tree done for HBIO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 886/975: NSYS.O
# ✅ Decision Tree done for NSYS.O | Best max_depth: 6
#
# 🌲 Decision Tree - Stock 887/975: OCC.O
# ✅ Decision Tree done for OCC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 888/975: NTWK.O
# ✅ Decision Tree done for NTWK.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 889/975: INTG.O
# ✅ Decision Tree done for INTG.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 890/975: DRRX.O
# ✅ Decision Tree done for DRRX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 891/975: IGC
# ✅ Decision Tree done for IGC | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 892/975: TRT
# ✅ Decision Tree done for TRT | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 893/975: ENZ
# ✅ Decision Tree done for ENZ | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 894/975: GTIM.O
# ✅ Decision Tree done for GTIM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 895/975: TENX.O
# ✅ Decision Tree done for TENX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 896/975: CKX
# ✅ Decision Tree done for CKX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 897/975: CRIS.O
# ✅ Decision Tree done for CRIS.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 898/975: CVM
# ✅ Decision Tree done for CVM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 899/975: CYTH.O
# ✅ Decision Tree done for CYTH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 900/975: DAIO.O
# ✅ Decision Tree done for DAIO.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 901/975: JOB
# ✅ Decision Tree done for JOB | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 902/975: RVP
# ✅ Decision Tree done for RVP | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 903/975: INTZ.O
# ✅ Decision Tree done for INTZ.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 904/975: NAII.O
# ✅ Decision Tree done for NAII.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 905/975: CVV.O
# ✅ Decision Tree done for CVV.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 906/975: LSTA.O
# ✅ Decision Tree done for LSTA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 907/975: PTN
# ✅ Decision Tree done for PTN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 908/975: CREX.O
# ✅ Decision Tree done for CREX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 909/975: MXC
# ✅ Decision Tree done for MXC | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 910/975: MTEX.O
# ✅ Decision Tree done for MTEX.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 911/975: NNVC.K
# ✅ Decision Tree done for NNVC.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 912/975: IRIX.O
# ✅ Decision Tree done for IRIX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 913/975: AMS
# ✅ Decision Tree done for AMS | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 914/975: SIF
# ✅ Decision Tree done for SIF | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 915/975: BRN
# ✅ Decision Tree done for BRN | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 916/975: NEPH.O
# ✅ Decision Tree done for NEPH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 917/975: HUSA.K
# ✅ Decision Tree done for HUSA.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 918/975: CLRO.O
# ✅ Decision Tree done for CLRO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 919/975: COHN.K
# ✅ Decision Tree done for COHN.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 920/975: ELSE.O
# ✅ Decision Tree done for ELSE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 921/975: MEIP.O
# ✅ Decision Tree done for MEIP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 922/975: TAIT.O
# ✅ Decision Tree done for TAIT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 923/975: JCTC.O
# ✅ Decision Tree done for JCTC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 924/975: CLRB.O
# ✅ Decision Tree done for CLRB.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 925/975: GOVX.O
# ✅ Decision Tree done for GOVX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 926/975: GPUS.K
# ✅ Decision Tree done for GPUS.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 927/975: ERNA.O
# ✅ Decision Tree done for ERNA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 928/975: AIRI.K
# ✅ Decision Tree done for AIRI.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 929/975: SMSI.O
# ✅ Decision Tree done for SMSI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 930/975: STRM.O
# ✅ Decision Tree done for STRM.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 931/975: IMNN.O
# ✅ Decision Tree done for IMNN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 932/975: AWX
# ✅ Decision Tree done for AWX | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 933/975: BCDA.O
# ✅ Decision Tree done for BCDA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 934/975: MTR
# ✅ Decision Tree done for MTR | Best max_depth: 10
#
# 🌲 Decision Tree - Stock 935/975: PRPH.O
# ✅ Decision Tree done for PRPH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 936/975: SSKN.O
# ✅ Decision Tree done for SSKN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 937/975: ASTC.O
# ✅ Decision Tree done for ASTC.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 938/975: PMCB.O
# ✅ Decision Tree done for PMCB.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 939/975: PRPO.O
# ✅ Decision Tree done for PRPO.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 940/975: BBGI.O
# ✅ Decision Tree done for BBGI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 941/975: MSN
# ✅ Decision Tree done for MSN | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 942/975: BCLI.O
# ✅ Decision Tree done for BCLI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 943/975: NURO.O
# ✅ Decision Tree done for NURO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 944/975: SCKT.O
# ✅ Decision Tree done for SCKT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 945/975: ARTW.O
# ✅ Decision Tree done for ARTW.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 946/975: AIMD.O
# ✅ Decision Tree done for AIMD.O | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 947/975: AIM
# ✅ Decision Tree done for AIM | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 948/975: STRR.O
# ✅ Decision Tree done for STRR.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 949/975: SSY
# ✅ Decision Tree done for SSY | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 950/975: GTBP.O
# ✅ Decision Tree done for GTBP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 951/975: SGMA.O
# ✅ Decision Tree done for SGMA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 952/975: OGEN.K
# ✅ Decision Tree done for OGEN.K | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 953/975: RIME.O
# ✅ Decision Tree done for RIME.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 954/975: SNGX.O
# ✅ Decision Tree done for SNGX.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 955/975: SNOA.O
# ✅ Decision Tree done for SNOA.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 956/975: AEMD.O
# ✅ Decision Tree done for AEMD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 957/975: GBR
# ✅ Decision Tree done for GBR | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 958/975: KNW
# ✅ Decision Tree done for KNW | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 959/975: BKYI.O
# ✅ Decision Tree done for BKYI.O | Best max_depth: 4
#
# 🌲 Decision Tree - Stock 960/975: UUU
# ✅ Decision Tree done for UUU | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 961/975: PSTV.O
# ✅ Decision Tree done for PSTV.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 962/975: FORD.O
# ✅ Decision Tree done for FORD.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 963/975: AYRO.O
# ✅ Decision Tree done for AYRO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 964/975: TTNP.O
# ✅ Decision Tree done for TTNP.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 965/975: TOVX.K
# ✅ Decision Tree done for TOVX.K | Best max_depth: 8
#
# 🌲 Decision Tree - Stock 966/975: PRSO.O
# ✅ Decision Tree done for PRSO.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 967/975: PALI.O
# ✅ Decision Tree done for PALI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 968/975: APDN.O
# ✅ Decision Tree done for APDN.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 969/975: SBET.O
# ✅ Decision Tree done for SBET.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 970/975: ASTI.O
# ✅ Decision Tree done for ASTI.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 971/975: AWH.O
# ✅ Decision Tree done for AWH.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 972/975: SUNE.O
# ✅ Decision Tree done for SUNE.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 973/975: TCRT.O
# ✅ Decision Tree done for TCRT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 974/975: WINT.O
# ✅ Decision Tree done for WINT.O | Best max_depth: 2
#
# 🌲 Decision Tree - Stock 975/975: DGLY.O
# ✅ Decision Tree done for DGLY.O | Best max_depth: 2
#
# 🟩 Finished all stocks | Total Time: 385.06 seconds

# %% [markdown]
# ### Hyperparameter Tuning - XGBoost

# %%
# Define the Fama-French factor columns
ff_3_factors = ['Date', 'Mkt-RF', 'SMB', 'HML', 'RF']

# Get list of stock columns (everything except the FF factors and 'Period')
stock_columns = [col for col in three_ff_cleaned_df.columns if col not in ff_3_factors]

# ------------------ XGBoost ------------------

all_xgb_results = []
best_xgb_models = {}

for idx, stock in enumerate(stock_columns):
    print(f"\n🟢 XGBoost - Stock {idx + 1}/{len(stock_columns)}: {stock}")

    # Subset and process
    df_subset = three_ff_cleaned_df[ff_3_factors + [stock]].copy()
    df_subset['Stock_Return'] = df_subset[[stock]]
    df_subset['Excess_Mkt_Return'] = df_subset['Mkt-RF'] - df_subset['RF']
    df_subset = df_subset[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
    
    # Shift return behind by 1 to align predictors at t with return at t+1
    df_subset['Stock_Return_Shifted'] = df_subset['Stock_Return'].shift(-1)

    # Drop the first row which now has NaN in 'Stock_Return_Shifted'
    df_subset = df_subset.dropna()

    # Standardize the predictors
    scaler = StandardScaler()
    df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']] = scaler.fit_transform(df_subset[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']])

    xgb_results = []

    for n_estimators, lr in xgb_params:
        model = XGBRegressor(n_estimators=n_estimators, learning_rate=lr, random_state=random_seed)
        val_rmse_list = []

        for i in range(train_size, train_size + val_size - 3):
            train_end = month_periods[i - 1]
            val_start = month_periods[i]
            val_end = month_periods[i + 2]

            train_mask = df_subset['Date'].dt.to_period('M') <= train_end
            val_mask = (df_subset['Date'].dt.to_period('M') >= val_start) & (df_subset['Date'].dt.to_period('M') <= val_end)

            X_train = df_subset.loc[train_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_train = df_subset.loc[train_mask, 'Stock_Return_Shifted']
            X_val = df_subset.loc[val_mask, ['Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
            y_val = df_subset.loc[val_mask, 'Stock_Return_Shifted']

            model.fit(X_train, y_train)
            rmse = np.sqrt(mean_squared_error(y_val, model.predict(X_val)))
            val_rmse_list.append(rmse)

        xgb_results.append({
            'Stock': stock,
            'n_estimators': n_estimators,
            'learning_rate': lr,
            'Avg_Validation_RMSE': np.mean(val_rmse_list),
            'Model': model
        })

    xgb_results.sort(key=lambda x: x['Avg_Validation_RMSE'])
    best_xgb_models[stock] = xgb_results[0]['Model']
    all_xgb_results.append(xgb_results[0])
    print(f"✅ XGBoost done for {stock} | Estimators: {xgb_results[0]['n_estimators']} | LR: {xgb_results[0]['learning_rate']}")

# End global timer
end_all = time.time()
print(f"\n🟩 Finished all stocks | Total Time: {end_all - start_all:.2f} seconds")
# Out:
# 🟢 XGBoost - Stock 1/975: AAPL.O
# ✅ XGBoost done for AAPL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 2/975: NVDA.O
# ✅ XGBoost done for NVDA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 3/975: MSFT.O
# ✅ XGBoost done for MSFT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 4/975: AMZN.O
# ✅ XGBoost done for AMZN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 5/975: LLY
# ✅ XGBoost done for LLY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 6/975: WMT
# ✅ XGBoost done for WMT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 7/975: XOM
# ✅ XGBoost done for XOM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 8/975: MA
# ✅ XGBoost done for MA | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 9/975: UNH
# ✅ XGBoost done for UNH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 10/975: ORCL.K
# ✅ XGBoost done for ORCL.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 11/975: COST.O
# ✅ XGBoost done for COST.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 12/975: NFLX.O
# ✅ XGBoost done for NFLX.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 13/975: HD
# ✅ XGBoost done for HD | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 14/975: CVX
# ✅ XGBoost done for CVX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 15/975: CRM
# ✅ XGBoost done for CRM | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 16/975: CSCO.O
# ✅ XGBoost done for CSCO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 17/975: MRK
# ✅ XGBoost done for MRK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 18/975: ABT
# ✅ XGBoost done for ABT | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 19/975: MCD
# ✅ XGBoost done for MCD | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 20/975: TMO
# ✅ XGBoost done for TMO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 21/975: ISRG.O
# ✅ XGBoost done for ISRG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 22/975: RTX
# ✅ XGBoost done for RTX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 23/975: QCOM.O
# ✅ XGBoost done for QCOM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 24/975: ADBE.O
# ✅ XGBoost done for ADBE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 25/975: AMGN.O
# ✅ XGBoost done for AMGN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 26/975: INTU.O
# ✅ XGBoost done for INTU.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 27/975: AMD.O
# ✅ XGBoost done for AMD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 28/975: CAT
# ✅ XGBoost done for CAT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 29/975: TXN.O
# ✅ XGBoost done for TXN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 30/975: NEE
# ✅ XGBoost done for NEE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 31/975: DHR
# ✅ XGBoost done for DHR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 32/975: PFE
# ✅ XGBoost done for PFE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 33/975: BLK
# ✅ XGBoost done for BLK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 34/975: UNP
# ✅ XGBoost done for UNP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 35/975: BSX
# ✅ XGBoost done for BSX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 36/975: SYK
# ✅ XGBoost done for SYK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 37/975: GILD.O
# ✅ XGBoost done for GILD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 38/975: HON.O
# ✅ XGBoost done for HON.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 39/975: CMCSA.O
# ✅ XGBoost done for CMCSA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 40/975: VRTX.O
# ✅ XGBoost done for VRTX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 41/975: DE
# ✅ XGBoost done for DE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 42/975: TJX
# ✅ XGBoost done for TJX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 43/975: COP
# ✅ XGBoost done for COP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 44/975: LOW
# ✅ XGBoost done for LOW | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 45/975: BA
# ✅ XGBoost done for BA | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 46/975: FI
# ✅ XGBoost done for FI | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 47/975: BMY
# ✅ XGBoost done for BMY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 48/975: ADP.O
# ✅ XGBoost done for ADP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 49/975: MMC
# ✅ XGBoost done for MMC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 50/975: MU.O
# ✅ XGBoost done for MU.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 51/975: NKE
# ✅ XGBoost done for NKE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 52/975: INTC.O
# ✅ XGBoost done for INTC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 53/975: ADI.O
# ✅ XGBoost done for ADI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 54/975: LRCX.O
# ✅ XGBoost done for LRCX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 55/975: ELV
# ✅ XGBoost done for ELV | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 56/975: KLAC.O
# ✅ XGBoost done for KLAC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 57/975: DUK
# ✅ XGBoost done for DUK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 58/975: CI
# ✅ XGBoost done for CI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 59/975: AJG
# ✅ XGBoost done for AJG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 60/975: CVS
# ✅ XGBoost done for CVS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 61/975: MMM
# ✅ XGBoost done for MMM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 62/975: MCK
# ✅ XGBoost done for MCK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 63/975: APH
# ✅ XGBoost done for APH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 64/975: ORLY.O
# ✅ XGBoost done for ORLY.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 65/975: REGN.O
# ✅ XGBoost done for REGN.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 66/975: CL
# ✅ XGBoost done for CL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 67/975: RSG
# ✅ XGBoost done for RSG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 68/975: NOC
# ✅ XGBoost done for NOC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 69/975: WMB
# ✅ XGBoost done for WMB | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 70/975: MSI
# ✅ XGBoost done for MSI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 71/975: SNPS.O
# ✅ XGBoost done for SNPS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 72/975: EOG
# ✅ XGBoost done for EOG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 73/975: CDNS.O
# ✅ XGBoost done for CDNS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 74/975: CMG
# ✅ XGBoost done for CMG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 75/975: MAR.O
# ✅ XGBoost done for MAR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 76/975: BDX
# ✅ XGBoost done for BDX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 77/975: ROP.O
# ✅ XGBoost done for ROP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 78/975: OKE
# ✅ XGBoost done for OKE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 79/975: AZO
# ✅ XGBoost done for AZO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 80/975: MRVL.O
# ✅ XGBoost done for MRVL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 81/975: BK
# ✅ XGBoost done for BK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 82/975: CSX.O
# ✅ XGBoost done for CSX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 83/975: SLB
# ✅ XGBoost done for SLB | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 84/975: MET
# ✅ XGBoost done for MET | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 85/975: ADSK.O
# ✅ XGBoost done for ADSK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 86/975: TFC
# ✅ XGBoost done for TFC | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 87/975: PCAR.O
# ✅ XGBoost done for PCAR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 88/975: COR
# ✅ XGBoost done for COR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 89/975: LNG
# ✅ XGBoost done for LNG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 90/975: TGT
# ✅ XGBoost done for TGT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 91/975: KR
# ✅ XGBoost done for KR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 92/975: D
# ✅ XGBoost done for D | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 93/975: HES
# ✅ XGBoost done for HES | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 94/975: FICO.K
# ✅ XGBoost done for FICO.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 95/975: OXY
# ✅ XGBoost done for OXY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 96/975: BKR.O
# ✅ XGBoost done for BKR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 97/975: ROST.O
# ✅ XGBoost done for ROST.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 98/975: EW
# ✅ XGBoost done for EW | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 99/975: VLO
# ✅ XGBoost done for VLO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 100/975: AME
# ✅ XGBoost done for AME | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 101/975: GLW
# ✅ XGBoost done for GLW | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 102/975: DHI
# ✅ XGBoost done for DHI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 103/975: LHX
# ✅ XGBoost done for LHX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 104/975: CTSH.O
# ✅ XGBoost done for CTSH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 105/975: PWR
# ✅ XGBoost done for PWR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 106/975: F
# ✅ XGBoost done for F | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 107/975: EA.O
# ✅ XGBoost done for EA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 108/975: TTWO.O
# ✅ XGBoost done for TTWO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 109/975: A
# ✅ XGBoost done for A | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 110/975: ODFL.O
# ✅ XGBoost done for ODFL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 111/975: BRO
# ✅ XGBoost done for BRO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 112/975: IDXX.O
# ✅ XGBoost done for IDXX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 113/975: CSGP.O
# ✅ XGBoost done for CSGP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 114/975: ALNY.O
# ✅ XGBoost done for ALNY.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 115/975: HEI
# ✅ XGBoost done for HEI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 116/975: LVS
# ✅ XGBoost done for LVS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 117/975: CAH
# ✅ XGBoost done for CAH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 118/975: WAB
# ✅ XGBoost done for WAB | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 119/975: HUM
# ✅ XGBoost done for HUM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 120/975: NUE
# ✅ XGBoost done for NUE | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 121/975: EBAY.O
# ✅ XGBoost done for EBAY.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 122/975: TPL
# ✅ XGBoost done for TPL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 123/975: EQT
# ✅ XGBoost done for EQT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 124/975: ROK
# ✅ XGBoost done for ROK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 125/975: MPWR.O
# ✅ XGBoost done for MPWR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 126/975: MCHP.O
# ✅ XGBoost done for MCHP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 127/975: ANSS.O
# ✅ XGBoost done for ANSS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 128/975: DTE
# ✅ XGBoost done for DTE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 129/975: DXCM.O
# ✅ XGBoost done for DXCM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 130/975: IP
# ✅ XGBoost done for IP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 131/975: AEE
# ✅ XGBoost done for AEE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 132/975: PPG
# ✅ XGBoost done for PPG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 133/975: PPL
# ✅ XGBoost done for PPL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 134/975: MTD
# ✅ XGBoost done for MTD | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 135/975: WBD.O
# ✅ XGBoost done for WBD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 136/975: TYL
# ✅ XGBoost done for TYL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 137/975: EL
# ✅ XGBoost done for EL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 138/975: ATO
# ✅ XGBoost done for ATO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 139/975: GPN
# ✅ XGBoost done for GPN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 140/975: TDY
# ✅ XGBoost done for TDY | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 141/975: VRSN.O
# ✅ XGBoost done for VRSN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 142/975: DVN
# ✅ XGBoost done for DVN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 143/975: WAT
# ✅ XGBoost done for WAT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 144/975: ERIE.O
# ✅ XGBoost done for ERIE.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 145/975: ZBH
# ✅ XGBoost done for ZBH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 146/975: DRI
# ✅ XGBoost done for DRI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 147/975: HAL
# ✅ XGBoost done for HAL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 148/975: NVR
# ✅ XGBoost done for NVR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 149/975: TSN
# ✅ XGBoost done for TSN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 150/975: CTRA.K
# ✅ XGBoost done for CTRA.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 151/975: PHM
# ✅ XGBoost done for PHM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 152/975: TROW.O
# ✅ XGBoost done for TROW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 153/975: LII
# ✅ XGBoost done for LII | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 154/975: BIIB.O
# ✅ XGBoost done for BIIB.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 155/975: LH
# ✅ XGBoost done for LH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 156/975: STLD.O
# ✅ XGBoost done for STLD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 157/975: NRG
# ✅ XGBoost done for NRG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 158/975: DGX
# ✅ XGBoost done for DGX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 159/975: LUV
# ✅ XGBoost done for LUV | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 160/975: PTC.O
# ✅ XGBoost done for PTC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 161/975: NTAP.O
# ✅ XGBoost done for NTAP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 162/975: ON.O
# ✅ XGBoost done for ON.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 163/975: CLX
# ✅ XGBoost done for CLX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 164/975: DECK.K
# ✅ XGBoost done for DECK.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 165/975: FNF
# ✅ XGBoost done for FNF | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 166/975: BAX
# ✅ XGBoost done for BAX | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 167/975: EME
# ✅ XGBoost done for EME | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 168/975: TRMB.O
# ✅ XGBoost done for TRMB.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 169/975: GPC
# ✅ XGBoost done for GPC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 170/975: GEN.O
# ✅ XGBoost done for GEN.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 171/975: WST
# ✅ XGBoost done for WST | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 172/975: HRL
# ✅ XGBoost done for HRL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 173/975: COO.O
# ✅ XGBoost done for COO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 174/975: EXPD.K
# ✅ XGBoost done for EXPD.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 175/975: WDC.O
# ✅ XGBoost done for WDC.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 176/975: BBY
# ✅ XGBoost done for BBY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 177/975: FFIV.O
# ✅ XGBoost done for FFIV.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 178/975: RS
# ✅ XGBoost done for RS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 179/975: RPM
# ✅ XGBoost done for RPM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 180/975: JBL
# ✅ XGBoost done for JBL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 181/975: ENTG.O
# ✅ XGBoost done for ENTG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 182/975: BALL.K
# ✅ XGBoost done for BALL.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 183/975: BLDR.K
# ✅ XGBoost done for BLDR.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 184/975: FSLR.O
# ✅ XGBoost done for FSLR.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 185/975: GGG
# ✅ XGBoost done for GGG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 186/975: TER.O
# ✅ XGBoost done for TER.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 187/975: UNM
# ✅ XGBoost done for UNM | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 188/975: DLTR.O
# ✅ XGBoost done for DLTR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 189/975: INSM.O
# ✅ XGBoost done for INSM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 190/975: UTHR.O
# ✅ XGBoost done for UTHR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 191/975: HOLX.O
# ✅ XGBoost done for HOLX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 192/975: ILMN.O
# ✅ XGBoost done for ILMN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 193/975: RVTY.K
# ✅ XGBoost done for RVTY.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 194/975: BMRN.O
# ✅ XGBoost done for BMRN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 195/975: FLEX.O
# ✅ XGBoost done for FLEX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 196/975: INCY.O
# ✅ XGBoost done for INCY.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 197/975: JKHY.O
# ✅ XGBoost done for JKHY.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 198/975: MORN.O
# ✅ XGBoost done for MORN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 199/975: ALGN.O
# ✅ XGBoost done for ALGN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 200/975: EWBC.O
# ✅ XGBoost done for EWBC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 201/975: AKAM.O
# ✅ XGBoost done for AKAM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 202/975: FIX
# ✅ XGBoost done for FIX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 203/975: JNPR.K
# ✅ XGBoost done for JNPR.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 204/975: SJM
# ✅ XGBoost done for SJM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 205/975: JLL
# ✅ XGBoost done for JLL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 206/975: NDSN.O
# ✅ XGBoost done for NDSN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 207/975: CHRW.O
# ✅ XGBoost done for CHRW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 208/975: THC
# ✅ XGBoost done for THC | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 209/975: JEF
# ✅ XGBoost done for JEF | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 210/975: COKE.O
# ✅ XGBoost done for COKE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 211/975: TXRH.O
# ✅ XGBoost done for TXRH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 212/975: SWKS.O
# ✅ XGBoost done for SWKS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 213/975: NBIX.O
# ✅ XGBoost done for NBIX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 214/975: ITT
# ✅ XGBoost done for ITT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 215/975: VTRS.O
# ✅ XGBoost done for VTRS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 216/975: SNX
# ✅ XGBoost done for SNX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 217/975: AIZ
# ✅ XGBoost done for AIZ | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 218/975: RBC
# ✅ XGBoost done for RBC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 219/975: OVV
# ✅ XGBoost done for OVV | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 220/975: MANH.O
# ✅ XGBoost done for MANH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 221/975: EMN
# ✅ XGBoost done for EMN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 222/975: CCK
# ✅ XGBoost done for CCK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 223/975: TOL
# ✅ XGBoost done for TOL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 224/975: CLH
# ✅ XGBoost done for CLH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 225/975: GME
# ✅ XGBoost done for GME | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 226/975: EXEL.O
# ✅ XGBoost done for EXEL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 227/975: RGLD.O
# ✅ XGBoost done for RGLD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 228/975: COHR.K
# ✅ XGBoost done for COHR.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 229/975: DOX.O
# ✅ XGBoost done for DOX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 230/975: IPG
# ✅ XGBoost done for IPG | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 231/975: TECH.O
# ✅ XGBoost done for TECH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 232/975: ATR
# ✅ XGBoost done for ATR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 233/975: WBA.O
# ✅ XGBoost done for WBA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 234/975: MTZ
# ✅ XGBoost done for MTZ | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 235/975: SRPT.O
# ✅ XGBoost done for SRPT.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 236/975: SAIA.O
# ✅ XGBoost done for SAIA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 237/975: SEIC.O
# ✅ XGBoost done for SEIC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 238/975: RRC
# ✅ XGBoost done for RRC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 239/975: WYNN.O
# ✅ XGBoost done for WYNN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 240/975: CRS
# ✅ XGBoost done for CRS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 241/975: CIEN.K
# ✅ XGBoost done for CIEN.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 242/975: ALB
# ✅ XGBoost done for ALB | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 243/975: X
# ✅ XGBoost done for X | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 244/975: HSIC.O
# ✅ XGBoost done for HSIC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 245/975: LNW.O
# ✅ XGBoost done for LNW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 246/975: CHE
# ✅ XGBoost done for CHE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 247/975: CRL
# ✅ XGBoost done for CRL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 248/975: DRS.O
# ✅ XGBoost done for DRS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 249/975: RGEN.O
# ✅ XGBoost done for RGEN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 250/975: LSCC.O
# ✅ XGBoost done for LSCC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 251/975: EXAS.O
# ✅ XGBoost done for EXAS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 252/975: HAS.O
# ✅ XGBoost done for HAS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 253/975: PARA.O
# ✅ XGBoost done for PARA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 254/975: DCI
# ✅ XGBoost done for DCI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 255/975: CHDN.O
# ✅ XGBoost done for CHDN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 256/975: MKTX.O
# ✅ XGBoost done for MKTX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 257/975: NYT
# ✅ XGBoost done for NYT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 258/975: WCC
# ✅ XGBoost done for WCC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 259/975: DLB
# ✅ XGBoost done for DLB | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 260/975: EVR
# ✅ XGBoost done for EVR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 261/975: TTEK.O
# ✅ XGBoost done for TTEK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 262/975: RRX
# ✅ XGBoost done for RRX | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 263/975: SIRI.O
# ✅ XGBoost done for SIRI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 264/975: HALO.O
# ✅ XGBoost done for HALO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 265/975: GAP
# ✅ XGBoost done for GAP | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 266/975: EXLS.O
# ✅ XGBoost done for EXLS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 267/975: ATI
# ✅ XGBoost done for ATI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 268/975: TTC
# ✅ XGBoost done for TTC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 269/975: ZION.O
# ✅ XGBoost done for ZION.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 270/975: BIO
# ✅ XGBoost done for BIO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 271/975: MHK
# ✅ XGBoost done for MHK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 272/975: APA.O
# ✅ XGBoost done for APA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 273/975: CVLT.O
# ✅ XGBoost done for CVLT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 274/975: AGCO.K
# ✅ XGBoost done for AGCO.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 275/975: BRKR.O
# ✅ XGBoost done for BRKR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 276/975: RLI
# ✅ XGBoost done for RLI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 277/975: IVZ
# ✅ XGBoost done for IVZ | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 278/975: ONTO.K
# ✅ XGBoost done for ONTO.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 279/975: CWST.O
# ✅ XGBoost done for CWST.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 280/975: QRVO.O
# ✅ XGBoost done for QRVO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 281/975: AAON.O
# ✅ XGBoost done for AAON.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 282/975: ALK
# ✅ XGBoost done for ALK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 283/975: UFPI.O
# ✅ XGBoost done for UFPI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 284/975: FLS
# ✅ XGBoost done for FLS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 285/975: SNV
# ✅ XGBoost done for SNV | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 286/975: TGTX.O
# ✅ XGBoost done for TGTX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 287/975: TFX
# ✅ XGBoost done for TFX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 288/975: CELH.O
# ✅ XGBoost done for CELH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 289/975: EAT
# ✅ XGBoost done for EAT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 290/975: PEGA.O
# ✅ XGBoost done for PEGA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 291/975: OSK
# ✅ XGBoost done for OSK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 292/975: LNC
# ✅ XGBoost done for LNC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 293/975: AWI
# ✅ XGBoost done for AWI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 294/975: CHH
# ✅ XGBoost done for CHH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 295/975: WEX
# ✅ XGBoost done for WEX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 296/975: CORT.O
# ✅ XGBoost done for CORT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 297/975: MSA
# ✅ XGBoost done for MSA | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 298/975: RMBS.O
# ✅ XGBoost done for RMBS.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 299/975: FCN
# ✅ XGBoost done for FCN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 300/975: BMI
# ✅ XGBoost done for BMI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 301/975: MMSI.O
# ✅ XGBoost done for MMSI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 302/975: MKSI.O
# ✅ XGBoost done for MKSI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 303/975: CACC.O
# ✅ XGBoost done for CACC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 304/975: BYD
# ✅ XGBoost done for BYD | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 305/975: DDS
# ✅ XGBoost done for DDS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 306/975: IDCC.O
# ✅ XGBoost done for IDCC.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 307/975: ACIW.O
# ✅ XGBoost done for ACIW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 308/975: USM
# ✅ XGBoost done for USM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 309/975: CROX.O
# ✅ XGBoost done for CROX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 310/975: GNTX.O
# ✅ XGBoost done for GNTX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 311/975: CRVL.O
# ✅ XGBoost done for CRVL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 312/975: ARW
# ✅ XGBoost done for ARW | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 313/975: NOV
# ✅ XGBoost done for NOV | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 314/975: RHI
# ✅ XGBoost done for RHI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 315/975: SKY
# ✅ XGBoost done for SKY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 316/975: CRK
# ✅ XGBoost done for CRK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 317/975: OPCH.O
# ✅ XGBoost done for OPCH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 318/975: CGNX.O
# ✅ XGBoost done for CGNX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 319/975: LSTR.O
# ✅ XGBoost done for LSTR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 320/975: CRUS.O
# ✅ XGBoost done for CRUS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 321/975: CMC
# ✅ XGBoost done for CMC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 322/975: CYTK.O
# ✅ XGBoost done for CYTK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 323/975: QXO
# ✅ XGBoost done for QXO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 324/975: IONS.O
# ✅ XGBoost done for IONS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 325/975: TKR
# ✅ XGBoost done for TKR | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 326/975: LFUS.O
# ✅ XGBoost done for LFUS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 327/975: NXST.O
# ✅ XGBoost done for NXST.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 328/975: LAZ
# ✅ XGBoost done for LAZ | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 329/975: MTH
# ✅ XGBoost done for MTH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 330/975: TXNM.K
# ✅ XGBoost done for TXNM.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 331/975: LUMN.K
# ✅ XGBoost done for LUMN.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 332/975: POR
# ✅ XGBoost done for POR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 333/975: AMKR.O
# ✅ XGBoost done for AMKR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 334/975: NSIT.O
# ✅ XGBoost done for NSIT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 335/975: AMG
# ✅ XGBoost done for AMG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 336/975: ITRI.O
# ✅ XGBoost done for ITRI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 337/975: FSS
# ✅ XGBoost done for FSS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 338/975: HXL
# ✅ XGBoost done for HXL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 339/975: FELE.O
# ✅ XGBoost done for FELE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 340/975: CNX
# ✅ XGBoost done for CNX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 341/975: DY
# ✅ XGBoost done for DY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 342/975: URBN.O
# ✅ XGBoost done for URBN.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 343/975: PIPR.K
# ✅ XGBoost done for PIPR.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 344/975: MOD
# ✅ XGBoost done for MOD | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 345/975: EEFT.O
# ✅ XGBoost done for EEFT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 346/975: BKH
# ✅ XGBoost done for BKH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 347/975: KMPR.K
# ✅ XGBoost done for KMPR.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 348/975: KBH
# ✅ XGBoost done for KBH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 349/975: MSM
# ✅ XGBoost done for MSM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 350/975: THO
# ✅ XGBoost done for THO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 351/975: EXPO.O
# ✅ XGBoost done for EXPO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 352/975: NNI
# ✅ XGBoost done for NNI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 353/975: ESE
# ✅ XGBoost done for ESE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 354/975: PBH
# ✅ XGBoost done for PBH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 355/975: AVT.O
# ✅ XGBoost done for AVT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 356/975: SANM.O
# ✅ XGBoost done for SANM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 357/975: IPAR.O
# ✅ XGBoost done for IPAR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 358/975: BDC
# ✅ XGBoost done for BDC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 359/975: CVCO.O
# ✅ XGBoost done for CVCO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 360/975: SLAB.O
# ✅ XGBoost done for SLAB.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 361/975: AEIS.O
# ✅ XGBoost done for AEIS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 362/975: ANF
# ✅ XGBoost done for ANF | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 363/975: JWN
# ✅ XGBoost done for JWN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 364/975: ITGR.K
# ✅ XGBoost done for ITGR.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 365/975: SPR
# ✅ XGBoost done for SPR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 366/975: DORM.O
# ✅ XGBoost done for DORM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 367/975: ALE
# ✅ XGBoost done for ALE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 368/975: MMS
# ✅ XGBoost done for MMS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 369/975: FIZZ.O
# ✅ XGBoost done for FIZZ.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 370/975: TDS
# ✅ XGBoost done for TDS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 371/975: CBZ
# ✅ XGBoost done for CBZ | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 372/975: BCO
# ✅ XGBoost done for BCO | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 373/975: AVNT.K
# ✅ XGBoost done for AVNT.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 374/975: AVAV.O
# ✅ XGBoost done for AVAV.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 375/975: IESC.O
# ✅ XGBoost done for IESC.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 376/975: M
# ✅ XGBoost done for M | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 377/975: PRIM.K
# ✅ XGBoost done for PRIM.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 378/975: SKYW.O
# ✅ XGBoost done for SKYW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 379/975: ICUI.O
# ✅ XGBoost done for ICUI.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 380/975: KFY
# ✅ XGBoost done for KFY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 381/975: RDNT.O
# ✅ XGBoost done for RDNT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 382/975: NWE.O
# ✅ XGBoost done for NWE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 383/975: SM
# ✅ XGBoost done for SM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 384/975: SMTC.O
# ✅ XGBoost done for SMTC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 385/975: CCOI.O
# ✅ XGBoost done for CCOI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 386/975: PLXS.O
# ✅ XGBoost done for PLXS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 387/975: NSP
# ✅ XGBoost done for NSP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 388/975: HAE
# ✅ XGBoost done for HAE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 389/975: POWI.O
# ✅ XGBoost done for POWI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 390/975: AVA
# ✅ XGBoost done for AVA | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 391/975: TNL
# ✅ XGBoost done for TNL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 392/975: MHO
# ✅ XGBoost done for MHO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 393/975: DXC
# ✅ XGBoost done for DXC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 394/975: BLKB.O
# ✅ XGBoost done for BLKB.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 395/975: XRAY.O
# ✅ XGBoost done for XRAY.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 396/975: OSIS.O
# ✅ XGBoost done for OSIS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 397/975: HOG
# ✅ XGBoost done for HOG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 398/975: PTEN.O
# ✅ XGBoost done for PTEN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 399/975: AMED.O
# ✅ XGBoost done for AMED.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 400/975: ASGN.K
# ✅ XGBoost done for ASGN.K | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 401/975: CPK
# ✅ XGBoost done for CPK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 402/975: ACAD.O
# ✅ XGBoost done for ACAD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 403/975: NOG
# ✅ XGBoost done for NOG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 404/975: FUL
# ✅ XGBoost done for FUL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 405/975: PATK.O
# ✅ XGBoost done for PATK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 406/975: TGNA.K
# ✅ XGBoost done for TGNA.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 407/975: MAN
# ✅ XGBoost done for MAN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 408/975: MGRC.O
# ✅ XGBoost done for MGRC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 409/975: GNW
# ✅ XGBoost done for GNW | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 410/975: PDCO.O
# ✅ XGBoost done for PDCO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 411/975: NWL.O
# ✅ XGBoost done for NWL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 412/975: GEF
# ✅ XGBoost done for GEF | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 413/975: GSAT.O
# ✅ XGBoost done for GSAT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 414/975: TEX
# ✅ XGBoost done for TEX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 415/975: IPGP.O
# ✅ XGBoost done for IPGP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 416/975: PENN.O
# ✅ XGBoost done for PENN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 417/975: JOE
# ✅ XGBoost done for JOE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 418/975: HURN.O
# ✅ XGBoost done for HURN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 419/975: JJSF.O
# ✅ XGBoost done for JJSF.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 420/975: GT.O
# ✅ XGBoost done for GT.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 421/975: SAM
# ✅ XGBoost done for SAM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 422/975: HP
# ✅ XGBoost done for HP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 423/975: PSMT.O
# ✅ XGBoost done for PSMT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 424/975: CPRX.O
# ✅ XGBoost done for CPRX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 425/975: FORM.O
# ✅ XGBoost done for FORM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 426/975: SYNA.O
# ✅ XGBoost done for SYNA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 427/975: QDEL.O
# ✅ XGBoost done for QDEL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 428/975: VIAV.O
# ✅ XGBoost done for VIAV.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 429/975: VICR.O
# ✅ XGBoost done for VICR.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 430/975: BFH
# ✅ XGBoost done for BFH | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 431/975: PRGS.O
# ✅ XGBoost done for PRGS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 432/975: TRN
# ✅ XGBoost done for TRN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 433/975: CAKE.O
# ✅ XGBoost done for CAKE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 434/975: WLY
# ✅ XGBoost done for WLY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 435/975: PAR
# ✅ XGBoost done for PAR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 436/975: VSEC.O
# ✅ XGBoost done for VSEC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 437/975: LCII.K
# ✅ XGBoost done for LCII.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 438/975: AIN
# ✅ XGBoost done for AIN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 439/975: HUBG.O
# ✅ XGBoost done for HUBG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 440/975: VCEL.O
# ✅ XGBoost done for VCEL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 441/975: AAP
# ✅ XGBoost done for AAP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 442/975: ALG
# ✅ XGBoost done for ALG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 443/975: OII
# ✅ XGBoost done for OII | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 444/975: TTMI.O
# ✅ XGBoost done for TTMI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 445/975: CXW
# ✅ XGBoost done for CXW | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 446/975: SSRM.O
# ✅ XGBoost done for SSRM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 447/975: DIOD.O
# ✅ XGBoost done for DIOD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 448/975: AEO
# ✅ XGBoost done for AEO | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 449/975: ARWR.O
# ✅ XGBoost done for ARWR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 450/975: WMK
# ✅ XGBoost done for WMK | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 451/975: AGYS.O
# ✅ XGBoost done for AGYS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 452/975: LGFa
# ✅ XGBoost done for LGFa | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 453/975: LGND.O
# ✅ XGBoost done for LGND.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 454/975: HNI
# ✅ XGBoost done for HNI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 455/975: JBLU.O
# ✅ XGBoost done for JBLU.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 456/975: NEOG.O
# ✅ XGBoost done for NEOG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 457/975: HE
# ✅ XGBoost done for HE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 458/975: EXTR.O
# ✅ XGBoost done for EXTR.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 459/975: ACLS.O
# ✅ XGBoost done for ACLS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 460/975: WERN.O
# ✅ XGBoost done for WERN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 461/975: LMAT.O
# ✅ XGBoost done for LMAT.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 462/975: CENX.O
# ✅ XGBoost done for CENX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 463/975: BKE
# ✅ XGBoost done for BKE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 464/975: CNMD.K
# ✅ XGBoost done for CNMD.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 465/975: OI
# ✅ XGBoost done for OI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 466/975: CSGS.O
# ✅ XGBoost done for CSGS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 467/975: RAMP.K
# ✅ XGBoost done for RAMP.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 468/975: IART.O
# ✅ XGBoost done for IART.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 469/975: ZD.O
# ✅ XGBoost done for ZD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 470/975: PBI
# ✅ XGBoost done for PBI | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 471/975: GBX
# ✅ XGBoost done for GBX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 472/975: DVAX.O
# ✅ XGBoost done for DVAX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 473/975: PLUS.O
# ✅ XGBoost done for PLUS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 474/975: AZTA.O
# ✅ XGBoost done for AZTA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 475/975: KMT
# ✅ XGBoost done for KMT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 476/975: ATRC.O
# ✅ XGBoost done for ATRC.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 477/975: UFPT.O
# ✅ XGBoost done for UFPT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 478/975: UNFI.K
# ✅ XGBoost done for UNFI.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 479/975: BCRX.O
# ✅ XGBoost done for BCRX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 480/975: STGW.O
# ✅ XGBoost done for STGW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 481/975: WKC
# ✅ XGBoost done for WKC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 482/975: MNKD.O
# ✅ XGBoost done for MNKD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 483/975: MCRI.O
# ✅ XGBoost done for MCRI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 484/975: APLD.O
# ✅ XGBoost done for APLD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 485/975: SRCE.O
# ✅ XGBoost done for SRCE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 486/975: OMCL.O
# ✅ XGBoost done for OMCL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 487/975: INOD.O
# ✅ XGBoost done for INOD.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 488/975: FL
# ✅ XGBoost done for FL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 489/975: NTCT.O
# ✅ XGBoost done for NTCT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 490/975: EPC
# ✅ XGBoost done for EPC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 491/975: ATSG.O
# ✅ XGBoost done for ATSG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 492/975: ADEA.O
# ✅ XGBoost done for ADEA.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 493/975: ROG
# ✅ XGBoost done for ROG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 494/975: NHC
# ✅ XGBoost done for NHC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 495/975: LNN
# ✅ XGBoost done for LNN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 496/975: PZZA.O
# ✅ XGBoost done for PZZA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 497/975: BHE
# ✅ XGBoost done for BHE | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 498/975: UPBD.O
# ✅ XGBoost done for UPBD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 499/975: ANIP.O
# ✅ XGBoost done for ANIP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 500/975: CLDX.O
# ✅ XGBoost done for CLDX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 501/975: VRNT.O
# ✅ XGBoost done for VRNT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 502/975: PLAB.O
# ✅ XGBoost done for PLAB.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 503/975: VYX
# ✅ XGBoost done for VYX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 504/975: DXPE.O
# ✅ XGBoost done for DXPE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 505/975: ATEC.O
# ✅ XGBoost done for ATEC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 506/975: NVAX.O
# ✅ XGBoost done for NVAX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 507/975: CTS
# ✅ XGBoost done for CTS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 508/975: VSAT.O
# ✅ XGBoost done for VSAT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 509/975: NEO.O
# ✅ XGBoost done for NEO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 510/975: WT
# ✅ XGBoost done for WT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 511/975: SCS
# ✅ XGBoost done for SCS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 512/975: VECO.O
# ✅ XGBoost done for VECO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 513/975: INVX.K
# ✅ XGBoost done for INVX.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 514/975: DCOM.O
# ✅ XGBoost done for DCOM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 515/975: EIG
# ✅ XGBoost done for EIG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 516/975: HLIT.O
# ✅ XGBoost done for HLIT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 517/975: HLX
# ✅ XGBoost done for HLX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 518/975: IDT
# ✅ XGBoost done for IDT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 519/975: BLFS.O
# ✅ XGBoost done for BLFS.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 520/975: GIII.O
# ✅ XGBoost done for GIII.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 521/975: CRAI.O
# ✅ XGBoost done for CRAI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 522/975: IMKTA.O
# ✅ XGBoost done for IMKTA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 523/975: OPK.O
# ✅ XGBoost done for OPK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 524/975: SAFT.O
# ✅ XGBoost done for SAFT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 525/975: RES
# ✅ XGBoost done for RES | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 526/975: UCTT.O
# ✅ XGBoost done for UCTT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 527/975: GYRE.O
# ✅ XGBoost done for GYRE.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 528/975: MODG.K
# ✅ XGBoost done for MODG.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 529/975: TILE.O
# ✅ XGBoost done for TILE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 530/975: MSEX.O
# ✅ XGBoost done for MSEX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 531/975: MRTN.O
# ✅ XGBoost done for MRTN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 532/975: PRG
# ✅ XGBoost done for PRG | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 533/975: INVA.O
# ✅ XGBoost done for INVA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 534/975: DGII.O
# ✅ XGBoost done for DGII.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 535/975: APOG.O
# ✅ XGBoost done for APOG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 536/975: GERN.O
# ✅ XGBoost done for GERN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 537/975: CLMT.O
# ✅ XGBoost done for CLMT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 538/975: BBSI.O
# ✅ XGBoost done for BBSI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 539/975: WGO
# ✅ XGBoost done for WGO | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 540/975: AMN
# ✅ XGBoost done for AMN | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 541/975: AORT.K
# ✅ XGBoost done for AORT.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 542/975: ALGT.O
# ✅ XGBoost done for ALGT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 543/975: SBGI.O
# ✅ XGBoost done for SBGI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 544/975: GRC
# ✅ XGBoost done for GRC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 545/975: AMSF.O
# ✅ XGBoost done for AMSF.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 546/975: KFRC.K
# ✅ XGBoost done for KFRC.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 547/975: BELFA.O
# ✅ XGBoost done for BELFA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 548/975: THRM.O
# ✅ XGBoost done for THRM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 549/975: LQDT.O
# ✅ XGBoost done for LQDT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 550/975: MYGN.O
# ✅ XGBoost done for MYGN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 551/975: NSSC.O
# ✅ XGBoost done for NSSC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 552/975: UTL
# ✅ XGBoost done for UTL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 553/975: WOLF.K
# ✅ XGBoost done for WOLF.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 554/975: KSS
# ...
# ✅ XGBoost done for ZYXI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 797/975: QUIK.O
# ✅ XGBoost done for QUIK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 798/975: BRID.O
# ✅ XGBoost done for BRID.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 799/975: UEIC.O
# ✅ XGBoost done for UEIC.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 800/975: QMCO.O
# ✅ XGBoost done for QMCO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 801/975: LPSN.O
# ✅ XGBoost done for LPSN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 802/975: FONR.O
# ✅ XGBoost done for FONR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 803/975: MCHX.O
# ✅ XGBoost done for MCHX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 804/975: LPTH.O
# ✅ XGBoost done for LPTH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 805/975: HGBL.O
# ✅ XGBoost done for HGBL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 806/975: PETS.O
# ✅ XGBoost done for PETS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 807/975: DIT
# ✅ XGBoost done for DIT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 808/975: AXTI.O
# ✅ XGBoost done for AXTI.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 809/975: FOSL.O
# ✅ XGBoost done for FOSL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 810/975: ALOT.O
# ✅ XGBoost done for ALOT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 811/975: HNNA.O
# ✅ XGBoost done for HNNA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 812/975: RRGB.O
# ✅ XGBoost done for RRGB.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 813/975: UBCP.O
# ✅ XGBoost done for UBCP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 814/975: MNOV.O
# ✅ XGBoost done for MNOV.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 815/975: INVE.O
# ✅ XGBoost done for INVE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 816/975: SGA.O
# ✅ XGBoost done for SGA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 817/975: ESP
# ✅ XGBoost done for ESP | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 818/975: OPTT.K
# ✅ XGBoost done for OPTT.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 819/975: CODA.O
# ✅ XGBoost done for CODA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 820/975: AUBN.O
# ✅ XGBoost done for AUBN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 821/975: INO.O
# ✅ XGBoost done for INO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 822/975: IOR
# ✅ XGBoost done for IOR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 823/975: MLSS.K
# ✅ XGBoost done for MLSS.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 824/975: AREN.K
# ✅ XGBoost done for AREN.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 825/975: VERU.O
# ✅ XGBoost done for VERU.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 826/975: ASYS.O
# ✅ XGBoost done for ASYS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 827/975: ARMP.K
# ✅ XGBoost done for ARMP.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 828/975: ASRT.O
# ✅ XGBoost done for ASRT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 829/975: FKWL.O
# ✅ XGBoost done for FKWL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 830/975: DOMH.O
# ✅ XGBoost done for DOMH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 831/975: DLHC.O
# ✅ XGBoost done for DLHC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 832/975: PED
# ✅ XGBoost done for PED | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 833/975: ALTS.O
# ✅ XGBoost done for ALTS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 834/975: CULP.K
# ✅ XGBoost done for CULP.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 835/975: SUP
# ✅ XGBoost done for SUP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 836/975: CATO.K
# ✅ XGBoost done for CATO.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 837/975: CYCC.O
# ✅ XGBoost done for CYCC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 838/975: ICAD.O
# ✅ XGBoost done for ICAD.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 839/975: WFCF.O
# ✅ XGBoost done for WFCF.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 840/975: LINK.O
# ✅ XGBoost done for LINK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 841/975: CTSO.O
# ✅ XGBoost done for CTSO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 842/975: CNVS.O
# ✅ XGBoost done for CNVS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 843/975: CNTY.O
# ✅ XGBoost done for CNTY.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 844/975: MIND.O
# ✅ XGBoost done for MIND.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 845/975: SOTK.O
# ✅ XGBoost done for SOTK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 846/975: RMTI.O
# ✅ XGBoost done for RMTI.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 847/975: CVGI.O
# ✅ XGBoost done for CVGI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 848/975: MBOT.O
# ✅ XGBoost done for MBOT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 849/975: LEE.O
# ✅ XGBoost done for LEE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 850/975: CMTL.O
# ✅ XGBoost done for CMTL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 851/975: KOSS.O
# ✅ XGBoost done for KOSS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 852/975: BDL
# ✅ XGBoost done for BDL | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 853/975: UG.O
# ✅ XGBoost done for UG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 854/975: IDN.O
# ✅ XGBoost done for IDN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 855/975: ICCC.O
# ✅ XGBoost done for ICCC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 856/975: CVU
# ✅ XGBoost done for CVU | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 857/975: AGEN.O
# ✅ XGBoost done for AGEN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 858/975: REFR.O
# ✅ XGBoost done for REFR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 859/975: DWSN.O
# ✅ XGBoost done for DWSN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 860/975: AP
# ✅ XGBoost done for AP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 861/975: RFIL.O
# ✅ XGBoost done for RFIL.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 862/975: USIO.O
# ✅ XGBoost done for USIO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 863/975: CRWS.O
# ✅ XGBoost done for CRWS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 864/975: PXLW.O
# ✅ XGBoost done for PXLW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 865/975: APYX.O
# ✅ XGBoost done for APYX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 866/975: TACT.O
# ✅ XGBoost done for TACT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 867/975: SYPR.O
# ✅ XGBoost done for SYPR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 868/975: UONEK.O
# ✅ XGBoost done for UONEK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 869/975: ARKR.O
# ✅ XGBoost done for ARKR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 870/975: HHS.O
# ✅ XGBoost done for HHS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 871/975: WYY
# ✅ XGBoost done for WYY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 872/975: ACCS.K
# ✅ XGBoost done for ACCS.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 873/975: AWRE.O
# ✅ XGBoost done for AWRE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 874/975: AIFF.O
# ✅ XGBoost done for AIFF.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 875/975: SGRP.O
# ✅ XGBoost done for SGRP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 876/975: NTIP.K
# ✅ XGBoost done for NTIP.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 877/975: VHC
# ✅ XGBoost done for VHC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 878/975: FTEK.O
# ✅ XGBoost done for FTEK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 879/975: GROW.O
# ✅ XGBoost done for GROW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 880/975: IRD.O
# ✅ XGBoost done for IRD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 881/975: CMS_pb
# ✅ XGBoost done for CMS_pb | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 882/975: KTCC.O
# ✅ XGBoost done for KTCC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 883/975: HSON.O
# ✅ XGBoost done for HSON.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 884/975: AXDX.O
# ✅ XGBoost done for AXDX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 885/975: HBIO.O
# ✅ XGBoost done for HBIO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 886/975: NSYS.O
# ✅ XGBoost done for NSYS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 887/975: OCC.O
# ✅ XGBoost done for OCC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 888/975: NTWK.O
# ✅ XGBoost done for NTWK.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 889/975: INTG.O
# ✅ XGBoost done for INTG.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 890/975: DRRX.O
# ✅ XGBoost done for DRRX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 891/975: IGC
# ✅ XGBoost done for IGC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 892/975: TRT
# ✅ XGBoost done for TRT | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 893/975: ENZ
# ✅ XGBoost done for ENZ | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 894/975: GTIM.O
# ✅ XGBoost done for GTIM.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 895/975: TENX.O
# ✅ XGBoost done for TENX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 896/975: CKX
# ✅ XGBoost done for CKX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 897/975: CRIS.O
# ✅ XGBoost done for CRIS.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 898/975: CVM
# ✅ XGBoost done for CVM | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 899/975: CYTH.O
# ✅ XGBoost done for CYTH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 900/975: DAIO.O
# ✅ XGBoost done for DAIO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 901/975: JOB
# ✅ XGBoost done for JOB | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 902/975: RVP
# ✅ XGBoost done for RVP | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 903/975: INTZ.O
# ✅ XGBoost done for INTZ.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 904/975: NAII.O
# ✅ XGBoost done for NAII.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 905/975: CVV.O
# ✅ XGBoost done for CVV.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 906/975: LSTA.O
# ✅ XGBoost done for LSTA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 907/975: PTN
# ✅ XGBoost done for PTN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 908/975: CREX.O
# ✅ XGBoost done for CREX.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 909/975: MXC
# ✅ XGBoost done for MXC | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 910/975: MTEX.O
# ✅ XGBoost done for MTEX.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 911/975: NNVC.K
# ✅ XGBoost done for NNVC.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 912/975: IRIX.O
# ✅ XGBoost done for IRIX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 913/975: AMS
# ✅ XGBoost done for AMS | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 914/975: SIF
# ✅ XGBoost done for SIF | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 915/975: BRN
# ✅ XGBoost done for BRN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 916/975: NEPH.O
# ✅ XGBoost done for NEPH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 917/975: HUSA.K
# ✅ XGBoost done for HUSA.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 918/975: CLRO.O
# ✅ XGBoost done for CLRO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 919/975: COHN.K
# ✅ XGBoost done for COHN.K | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 920/975: ELSE.O
# ✅ XGBoost done for ELSE.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 921/975: MEIP.O
# ✅ XGBoost done for MEIP.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 922/975: TAIT.O
# ✅ XGBoost done for TAIT.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 923/975: JCTC.O
# ✅ XGBoost done for JCTC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 924/975: CLRB.O
# ✅ XGBoost done for CLRB.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 925/975: GOVX.O
# ✅ XGBoost done for GOVX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 926/975: GPUS.K
# ✅ XGBoost done for GPUS.K | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 927/975: ERNA.O
# ✅ XGBoost done for ERNA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 928/975: AIRI.K
# ✅ XGBoost done for AIRI.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 929/975: SMSI.O
# ✅ XGBoost done for SMSI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 930/975: STRM.O
# ✅ XGBoost done for STRM.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 931/975: IMNN.O
# ✅ XGBoost done for IMNN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 932/975: AWX
# ✅ XGBoost done for AWX | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 933/975: BCDA.O
# ✅ XGBoost done for BCDA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 934/975: MTR
# ✅ XGBoost done for MTR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 935/975: PRPH.O
# ✅ XGBoost done for PRPH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 936/975: SSKN.O
# ✅ XGBoost done for SSKN.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 937/975: ASTC.O
# ✅ XGBoost done for ASTC.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 938/975: PMCB.O
# ✅ XGBoost done for PMCB.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 939/975: PRPO.O
# ✅ XGBoost done for PRPO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 940/975: BBGI.O
# ✅ XGBoost done for BBGI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 941/975: MSN
# ✅ XGBoost done for MSN | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 942/975: BCLI.O
# ✅ XGBoost done for BCLI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 943/975: NURO.O
# ✅ XGBoost done for NURO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 944/975: SCKT.O
# ✅ XGBoost done for SCKT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 945/975: ARTW.O
# ✅ XGBoost done for ARTW.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 946/975: AIMD.O
# ✅ XGBoost done for AIMD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 947/975: AIM
# ✅ XGBoost done for AIM | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 948/975: STRR.O
# ✅ XGBoost done for STRR.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 949/975: SSY
# ✅ XGBoost done for SSY | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 950/975: GTBP.O
# ✅ XGBoost done for GTBP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 951/975: SGMA.O
# ✅ XGBoost done for SGMA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 952/975: OGEN.K
# ✅ XGBoost done for OGEN.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 953/975: RIME.O
# ✅ XGBoost done for RIME.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 954/975: SNGX.O
# ✅ XGBoost done for SNGX.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 955/975: SNOA.O
# ✅ XGBoost done for SNOA.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 956/975: AEMD.O
# ✅ XGBoost done for AEMD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 957/975: GBR
# ✅ XGBoost done for GBR | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 958/975: KNW
# ✅ XGBoost done for KNW | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 959/975: BKYI.O
# ✅ XGBoost done for BKYI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 960/975: UUU
# ✅ XGBoost done for UUU | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 961/975: PSTV.O
# ✅ XGBoost done for PSTV.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 962/975: FORD.O
# ✅ XGBoost done for FORD.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 963/975: AYRO.O
# ✅ XGBoost done for AYRO.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 964/975: TTNP.O
# ✅ XGBoost done for TTNP.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 965/975: TOVX.K
# ✅ XGBoost done for TOVX.K | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 966/975: PRSO.O
# ✅ XGBoost done for PRSO.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 967/975: PALI.O
# ✅ XGBoost done for PALI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 968/975: APDN.O
# ✅ XGBoost done for APDN.O | Estimators: 100 | LR: 0.05
#
# 🟢 XGBoost - Stock 969/975: SBET.O
# ✅ XGBoost done for SBET.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 970/975: ASTI.O
# ✅ XGBoost done for ASTI.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 971/975: AWH.O
# ✅ XGBoost done for AWH.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 972/975: SUNE.O
# ✅ XGBoost done for SUNE.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 973/975: TCRT.O
# ✅ XGBoost done for TCRT.O | Estimators: 200 | LR: 0.01
#
# 🟢 XGBoost - Stock 974/975: WINT.O
# ✅ XGBoost done for WINT.O | Estimators: 50 | LR: 0.1
#
# 🟢 XGBoost - Stock 975/975: DGLY.O
# ✅ XGBoost done for DGLY.O | Estimators: 200 | LR: 0.01
#
# 🟩 Finished all stocks | Total Time: 10977.67 seconds

# %% [markdown]
# ### Output the best tuned config for each model for each stock

# %%
# Step 1: Build rows from each model's best result list
rows = []

for stock in stock_columns:
    row = {'Stock': stock}

    # Ridge
    ridge = next((r for r in all_ridge_results if r['Stock'] == stock), None)
    if ridge:
        row['Ridge'] = f"α={ridge['Alpha']}"

    # Lasso
    lasso = next((r for r in all_lasso_results if r['Stock'] == stock), None)
    if lasso:
        row['Lasso'] = f"α={lasso['Alpha']}"

    # ElasticNet
    elastic = next((r for r in all_elastic_results if r['Stock'] == stock), None)
    if elastic:
        row['ElasticNet'] = f"α={elastic['Alpha']}, l1={elastic['L1_Ratio']}"

    # SVR
    svr = next((r for r in all_svr_results if r['Stock'] == stock), None)
    if svr:
        row['SVR'] = f"C={svr['C']}, ε={svr['Epsilon']}"

    # Decision Tree
    dt = next((r for r in all_dt_results if r['Stock'] == stock), None)
    if dt:
        row['DecisionTree'] = f"depth={dt['Max_Depth']}"
        
    # XGBoost
    xgb = next((r for r in all_xgb_results if r['Stock'] == stock), None)
    if xgb:
        row['XGBoost'] = f"est={xgb['n_estimators']}, lr={xgb['learning_rate']}"

    rows.append(row)

# Step 2: Create DataFrame
model_summary_df = pd.DataFrame(rows)
# Define output path
excel_path = 'output/models/3ff_tuned_para.xlsx'

# Export to Excel
model_summary_df.to_excel(excel_path, index=False)
