# %%
# %%capture
# %run Data_Cleaning.ipynb

# %%
random_seed = 42
training_size = 0.85
validation_size = 0.1

# Get unique month periods
month_periods = sorted(three_ff_cleaned_df['Date'].dt.to_period('M').unique())
# Split size calculation
total_periods = three_ff_cleaned_df['Date'].dt.to_period('M').nunique()
train_size = int(total_periods * training_size)
val_size = int(total_periods * validation_size)
test_size = total_periods - train_size - val_size

# print(month_periods)
print("train_size is :", train_size, "months")
print("val_size is :", val_size, "months")
print("test_size is :", test_size, "months")

# Define training and testing date boundaries
train_cutoff = pd.to_datetime("2023-12-31")
test_start_date = pd.to_datetime("2024-01-01")
test_end_date = pd.to_datetime("2024-12-31")
# Out:
# train_size is : 182 months
# val_size is : 21 months
# test_size is : 12 months

# %%
# Preview the 3ff result
three_ff_cleaned_df = three_ff_cleaned_df.sort_values('Date').reset_index(drop=True)
three_ff_cleaned_df.head(4)
# Out:
#         Date     AAPL.O     NVDA.O    MSFT.O     AMZN.O       LLY       WMT  \
# 0 2007-02-28  -1.315037   1.135388 -9.120327   3.828094 -2.867782  1.291682
# 1 2007-03-31   9.357873  -7.430645 -1.070674   1.647066  2.107322 -2.855538
# 2 2007-04-30   7.153685  13.348787  7.164454  43.265350  9.613921  2.044975
# 3 2007-05-31  19.419975   5.181152  2.474475  11.986431 -0.866247 -0.670016
#
#         XOM         MA       UNH  ...     ASTI.O      AWH.O     SUNE.O  \
# 0 -3.320376  -3.996326 -0.153198  ...  36.080434 -27.996003   4.710145
# 1  5.125842  -0.880898  1.502644  ...  66.263841   7.410797  -1.991531
# 2  5.077626   4.993695  0.169763  ...  12.778380   2.817088   7.561204
# 3  4.664026  29.199315  3.171925  ... -26.859959 -20.763936 -13.074411
#
#      TCRT.O     WINT.O     DGLY.O  Mkt-RF   SMB   HML    RF
# 0 -0.564442 -13.182539 -16.907633   -1.96  1.19 -0.14  0.38
# 1 -3.650742   7.443259  14.090545    0.68  0.16 -0.97  0.43
# 2  4.776457  22.567200  31.585295    3.49 -2.16 -1.45  0.44
# 3 -1.125715  13.226797  -0.417537    3.24  0.24 -0.65  0.41
#
# [4 rows x 980 columns]

# %% [markdown]
# ### Read tuned model files for 3ff

# %%
# Read the Excel file
tuned_3ff_df = pd.read_excel(r"Output\models\3ff_tuned_para.xlsx")
tuned_3ff_df.head(3)
# Out:
#     Stock    Ridge   Lasso      ElasticNet            SVR DecisionTree  \
# 0  AAPL.O  α=100.0  α=10.0  α=10.0, l1=0.5   C=0.1, ε=0.1      depth=2
# 1  NVDA.O  α=100.0  α=10.0  α=10.0, l1=0.5    C=1, ε=0.01      depth=2
# 2  MSFT.O  α=100.0   α=1.0   α=1.0, l1=0.9  C=0.1, ε=0.01      depth=2
#
#             XGBoost
# 0  est=200, lr=0.01
# 1  est=200, lr=0.01
# 2  est=200, lr=0.01

# %% [markdown]
# ### 3ff model prediction

# %%
# --------------------
# Start global timer
# --------------------
start_time = time.time()

# Inputs
returns_df = three_ff_cleaned_df.copy()
params_df = tuned_3ff_df.copy()

# FF factors
ff_factors = ['Mkt-RF', 'SMB', 'HML', 'RF']
returns_df['Date'] = pd.to_datetime(returns_df['Date'])

# Outputs
rmse_results = []
all_predictions = []

# Get stock list
stock_columns = [col for col in returns_df.columns if col not in ['Date'] + ff_factors]

for idx, stock in enumerate(stock_columns, start=1):
    print(f"\n🔁 Processing stock: {stock}")
    
    stock_data = returns_df[['Date'] + ff_factors + [stock]].copy()
    stock_data['Stock_Return'] = stock_data[stock]
    stock_data['Excess_Mkt_Return'] = stock_data['Mkt-RF'] - stock_data['RF']

    stock_data = stock_data[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RF']]
    stock_data['Stock_Return_Shifted'] = stock_data['Stock_Return'].shift(-1)
    stock_data = stock_data.dropna().reset_index(drop=True)
    print(len(stock_data))

    X_full = stock_data[['Excess_Mkt_Return', 'SMB', 'HML', 'RF']].values
    y_full = stock_data['Stock_Return_Shifted'].values
    dates = stock_data['Date'].values

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_full)

    row = params_df[params_df['Stock'] == stock]
    if row.empty:
        continue

    try:
        models = {}

        # Tuned models
        models['Ridge'] = Ridge(alpha=float(re.findall(r"α=(\d+\.?\d*)", row['Ridge'].values[0])[0]))
        models['Lasso'] = Lasso(alpha=float(re.findall(r"α=(\d+\.?\d*)", row['Lasso'].values[0])[0]))
        
        en_alpha, en_l1 = re.findall(r"α=(\d+\.?\d*), l1=(\d+\.?\d*)", row['ElasticNet'].values[0])[0]
        models['ElasticNet'] = ElasticNet(alpha=float(en_alpha), l1_ratio=float(en_l1))
        
        svr_C, svr_eps = re.findall(r"C=(\d+\.?\d*), ε=([\d\.-]+)", row['SVR'].values[0])[0]
        models['SVR'] = SVR(C=float(svr_C), epsilon=float(svr_eps))
        
        dt_depth = int(re.findall(r"depth=(\d+)", row['DecisionTree'].values[0])[0])
        models['DecisionTree'] = DecisionTreeRegressor(max_depth=dt_depth)
        
        xgb_est, xgb_lr = re.findall(r"est=(\d+), lr=([\d\.]+)", row['XGBoost'].values[0])[0]
        models['XGBoost'] = XGBRegressor(n_estimators=int(xgb_est), learning_rate=float(xgb_lr), verbosity=0)

        # Benchmark model
        models['OLS'] = LinearRegression()

    except Exception as e:
        print(f"⚠️ Error parsing hyperparameters for {stock}: {e}")
        continue

    preds_by_model = {m: [] for m in models}
    actuals = []

    for i in range(len(stock_data)):
        current_date = stock_data.loc[i, 'Date']
        if test_start_date <= current_date <= test_end_date:
            train_mask = stock_data['Date'] < current_date
            test_mask = stock_data['Date'] == current_date

            X_train = X_scaled[train_mask]
            y_train = y_full[train_mask]
            X_test = X_scaled[test_mask]
            y_test = y_full[test_mask]

            if len(X_train) == 0 or X_test.shape[0] == 0:
                continue

            actual = y_test[0]

            for name, model in models.items():
                try:
                    model.fit(X_train, y_train)
                    pred = model.predict(X_test)[0]
                    preds_by_model[name].append(pred)
                    all_predictions.append({
                        'Stock': stock,
                        'Date': current_date,
                        'Model': name,
                        'Actual': actual,
                        'Predicted': pred
                    })
                except Exception as e:
                    print(f"⚠️ Prediction error for {stock} - {name}: {e}")
                    continue

            actuals.append(actual)

    for name in preds_by_model:
        pred_arr = np.array(preds_by_model[name])
        if len(pred_arr) == len(actuals) and len(actuals) > 0:
            rmse = mean_squared_error(actuals, pred_arr, squared=False)
            rmse_results.append({
                'Stock': stock,
                'Model': name,
                'RMSE': rmse
            })

# Convert results
rmse_df = pd.DataFrame(rmse_results)
predictions_df = pd.DataFrame(all_predictions)

# --------------------
# End global timer
# --------------------
end_time = time.time()
print(f"\n✅ Total Time: {(end_time - start_time)/60:.2f} minutes")
# Out:
# 🔁 Processing stock: AAPL.O
# 214
#
# 🔁 Processing stock: NVDA.O
# 214
#
# 🔁 Processing stock: MSFT.O
# 214
#
# 🔁 Processing stock: AMZN.O
# 214
#
# 🔁 Processing stock: LLY
# 214
#
# 🔁 Processing stock: WMT
# 214
#
# 🔁 Processing stock: XOM
# 214
#
# 🔁 Processing stock: MA
# 214
#
# 🔁 Processing stock: UNH
# 214
#
# 🔁 Processing stock: ORCL.K
# 214
#
# 🔁 Processing stock: COST.O
# 214
#
# 🔁 Processing stock: NFLX.O
# 214
#
# 🔁 Processing stock: HD
# 214
#
# 🔁 Processing stock: CVX
# 214
#
# 🔁 Processing stock: CRM
# 214
#
# 🔁 Processing stock: CSCO.O
# 214
#
# 🔁 Processing stock: MRK
# 214
#
# 🔁 Processing stock: ABT
# 214
#
# 🔁 Processing stock: MCD
# 214
#
# 🔁 Processing stock: TMO
# 214
#
# 🔁 Processing stock: ISRG.O
# 214
#
# 🔁 Processing stock: RTX
# 214
#
# 🔁 Processing stock: QCOM.O
# 214
#
# 🔁 Processing stock: ADBE.O
# 214
#
# 🔁 Processing stock: AMGN.O
# 214
#
# 🔁 Processing stock: INTU.O
# 214
#
# 🔁 Processing stock: AMD.O
# 214
#
# 🔁 Processing stock: CAT
# 214
#
# 🔁 Processing stock: TXN.O
# 214
#
# 🔁 Processing stock: NEE
# 214
#
# 🔁 Processing stock: DHR
# 214
#
# 🔁 Processing stock: PFE
# 214
#
# 🔁 Processing stock: BLK
# 214
#
# 🔁 Processing stock: UNP
# 214
#
# 🔁 Processing stock: BSX
# 214
#
# 🔁 Processing stock: SYK
# 214
#
# 🔁 Processing stock: GILD.O
# 214
#
# 🔁 Processing stock: HON.O
# 214
#
# 🔁 Processing stock: CMCSA.O
# 214
#
# 🔁 Processing stock: VRTX.O
# 214
#
# 🔁 Processing stock: DE
# 214
#
# 🔁 Processing stock: TJX
# 214
#
# 🔁 Processing stock: COP
# 214
#
# 🔁 Processing stock: LOW
# 214
#
# 🔁 Processing stock: BA
# 214
#
# 🔁 Processing stock: FI
# 214
#
# 🔁 Processing stock: BMY
# 214
#
# 🔁 Processing stock: ADP.O
# 214
#
# 🔁 Processing stock: MMC
# 214
#
# 🔁 Processing stock: MU.O
# 214
#
# 🔁 Processing stock: NKE
# 214
#
# 🔁 Processing stock: INTC.O
# 214
#
# 🔁 Processing stock: ADI.O
# 214
#
# 🔁 Processing stock: LRCX.O
# 214
#
# 🔁 Processing stock: ELV
# 214
#
# 🔁 Processing stock: KLAC.O
# 214
#
# 🔁 Processing stock: DUK
# 214
#
# 🔁 Processing stock: CI
# 214
#
# 🔁 Processing stock: AJG
# 214
#
# 🔁 Processing stock: CVS
# 214
#
# 🔁 Processing stock: MMM
# 214
#
# 🔁 Processing stock: MCK
# 214
#
# 🔁 Processing stock: APH
# 214
#
# 🔁 Processing stock: ORLY.O
# 214
#
# 🔁 Processing stock: REGN.O
# 214
#
# 🔁 Processing stock: CL
# 214
#
# 🔁 Processing stock: RSG
# 214
#
# 🔁 Processing stock: NOC
# 214
#
# 🔁 Processing stock: WMB
# 214
#
# 🔁 Processing stock: MSI
# 214
#
# 🔁 Processing stock: SNPS.O
# 214
#
# 🔁 Processing stock: EOG
# 214
#
# 🔁 Processing stock: CDNS.O
# 214
#
# 🔁 Processing stock: CMG
# 214
#
# 🔁 Processing stock: MAR.O
# 214
#
# 🔁 Processing stock: BDX
# 214
#
# 🔁 Processing stock: ROP.O
# 214
#
# 🔁 Processing stock: OKE
# 214
#
# 🔁 Processing stock: AZO
# 214
#
# 🔁 Processing stock: MRVL.O
# 214
#
# 🔁 Processing stock: BK
# 214
#
# 🔁 Processing stock: CSX.O
# 214
#
# 🔁 Processing stock: SLB
# 214
#
# 🔁 Processing stock: MET
# 214
#
# 🔁 Processing stock: ADSK.O
# 214
#
# 🔁 Processing stock: TFC
# 214
#
# 🔁 Processing stock: PCAR.O
# 214
#
# 🔁 Processing stock: COR
# 214
#
# 🔁 Processing stock: LNG
# 214
#
# 🔁 Processing stock: TGT
# 214
#
# 🔁 Processing stock: KR
# 214
#
# 🔁 Processing stock: D
# 214
#
# 🔁 Processing stock: HES
# 214
#
# 🔁 Processing stock: FICO.K
# 214
#
# 🔁 Processing stock: OXY
# 214
#
# 🔁 Processing stock: BKR.O
# 214
#
# 🔁 Processing stock: ROST.O
# 214
#
# 🔁 Processing stock: EW
# 214
#
# 🔁 Processing stock: VLO
# 214
#
# 🔁 Processing stock: AME
# 214
#
# 🔁 Processing stock: GLW
# 214
#
# 🔁 Processing stock: DHI
# 214
#
# 🔁 Processing stock: LHX
# 214
#
# 🔁 Processing stock: CTSH.O
# 214
#
# 🔁 Processing stock: PWR
# 214
#
# 🔁 Processing stock: F
# 214
#
# 🔁 Processing stock: EA.O
# 214
#
# 🔁 Processing stock: TTWO.O
# 214
#
# 🔁 Processing stock: A
# 214
#
# 🔁 Processing stock: ODFL.O
# 214
#
# 🔁 Processing stock: BRO
# 214
#
# 🔁 Processing stock: IDXX.O
# 214
#
# 🔁 Processing stock: CSGP.O
# 214
#
# 🔁 Processing stock: ALNY.O
# 214
#
# 🔁 Processing stock: HEI
# 214
#
# 🔁 Processing stock: LVS
# 214
#
# 🔁 Processing stock: CAH
# 214
#
# 🔁 Processing stock: WAB
# 214
#
# 🔁 Processing stock: HUM
# 214
#
# 🔁 Processing stock: NUE
# 214
#
# 🔁 Processing stock: EBAY.O
# 214
#
# 🔁 Processing stock: TPL
# 214
#
# 🔁 Processing stock: EQT
# 214
#
# 🔁 Processing stock: ROK
# 214
#
# 🔁 Processing stock: MPWR.O
# 214
#
# 🔁 Processing stock: MCHP.O
# 214
#
# 🔁 Processing stock: ANSS.O
# 214
#
# 🔁 Processing stock: DTE
# 214
#
# 🔁 Processing stock: DXCM.O
# 214
#
# 🔁 Processing stock: IP
# 214
#
# 🔁 Processing stock: AEE
# 214
#
# 🔁 Processing stock: PPG
# 214
#
# 🔁 Processing stock: PPL
# 214
#
# 🔁 Processing stock: MTD
# 214
#
# 🔁 Processing stock: WBD.O
# 214
#
# 🔁 Processing stock: TYL
# 214
#
# 🔁 Processing stock: EL
# 214
#
# 🔁 Processing stock: ATO
# 214
#
# 🔁 Processing stock: GPN
# 214
#
# 🔁 Processing stock: TDY
# 214
#
# 🔁 Processing stock: VRSN.O
# 214
#
# 🔁 Processing stock: DVN
# 214
#
# 🔁 Processing stock: WAT
# 214
#
# 🔁 Processing stock: ERIE.O
# 214
#
# 🔁 Processing stock: ZBH
# 214
#
# 🔁 Processing stock: DRI
# 214
#
# 🔁 Processing stock: HAL
# 214
#
# 🔁 Processing stock: NVR
# 214
#
# 🔁 Processing stock: TSN
# 214
#
# 🔁 Processing stock: CTRA.K
# 214
#
# 🔁 Processing stock: PHM
# 214
#
# 🔁 Processing stock: TROW.O
# 214
#
# 🔁 Processing stock: LII
# 214
#
# 🔁 Processing stock: BIIB.O
# 214
#
# 🔁 Processing stock: LH
# 214
#
# 🔁 Processing stock: STLD.O
# 214
#
# 🔁 Processing stock: NRG
# 214
#
# 🔁 Processing stock: DGX
# 214
#
# 🔁 Processing stock: LUV
# 214
#
# 🔁 Processing stock: PTC.O
# 214
#
# 🔁 Processing stock: NTAP.O
# 214
#
# 🔁 Processing stock: ON.O
# 214
#
# 🔁 Processing stock: CLX
# 214
#
# 🔁 Processing stock: DECK.K
# 214
#
# 🔁 Processing stock: FNF
# 214
#
# 🔁 Processing stock: BAX
# 214
#
# 🔁 Processing stock: EME
# 214
#
# 🔁 Processing stock: TRMB.O
# 214
#
# 🔁 Processing stock: GPC
# 214
#
# 🔁 Processing stock: GEN.O
# 214
#
# 🔁 Processing stock: WST
# 214
#
# 🔁 Processing stock: HRL
# 214
#
# 🔁 Processing stock: COO.O
# 214
#
# 🔁 Processing stock: EXPD.K
# 214
#
# 🔁 Processing stock: WDC.O
# 214
#
# 🔁 Processing stock: BBY
# 214
#
# 🔁 Processing stock: FFIV.O
# 214
#
# 🔁 Processing stock: RS
# 214
#
# 🔁 Processing stock: RPM
# 214
#
# 🔁 Processing stock: JBL
# 214
#
# 🔁 Processing stock: ENTG.O
# 214
#
# 🔁 Processing stock: BALL.K
# 214
#
# 🔁 Processing stock: BLDR.K
# 214
#
# 🔁 Processing stock: FSLR.O
# 214
#
# 🔁 Processing stock: GGG
# 214
#
# 🔁 Processing stock: TER.O
# 214
#
# 🔁 Processing stock: UNM
# 214
#
# 🔁 Processing stock: DLTR.O
# 214
#
# 🔁 Processing stock: INSM.O
# 214
#
# 🔁 Processing stock: UTHR.O
# 214
#
# 🔁 Processing stock: HOLX.O
# 214
#
# 🔁 Processing stock: ILMN.O
# 214
#
# 🔁 Processing stock: RVTY.K
# 214
#
# 🔁 Processing stock: BMRN.O
# 214
#
# 🔁 Processing stock: FLEX.O
# 214
#
# 🔁 Processing stock: INCY.O
# 214
#
# 🔁 Processing stock: JKHY.O
# 214
#
# 🔁 Processing stock: MORN.O
# 214
#
# 🔁 Processing stock: ALGN.O
# 214
#
# 🔁 Processing stock: EWBC.O
# 214
#
# 🔁 Processing stock: AKAM.O
# 214
#
# 🔁 Processing stock: FIX
# 214
#
# 🔁 Processing stock: JNPR.K
# 214
#
# 🔁 Processing stock: SJM
# 214
#
# 🔁 Processing stock: JLL
# 214
#
# 🔁 Processing stock: NDSN.O
# 214
#
# 🔁 Processing stock: CHRW.O
# 214
#
# 🔁 Processing stock: THC
# 214
#
# 🔁 Processing stock: JEF
# 214
#
# 🔁 Processing stock: COKE.O
# 214
#
# 🔁 Processing stock: TXRH.O
# 214
#
# 🔁 Processing stock: SWKS.O
# 214
#
# 🔁 Processing stock: NBIX.O
# 214
#
# 🔁 Processing stock: ITT
# 214
#
# 🔁 Processing stock: VTRS.O
# 214
#
# 🔁 Processing stock: SNX
# 214
#
# 🔁 Processing stock: AIZ
# 214
#
# 🔁 Processing stock: RBC
# 214
#
# 🔁 Processing stock: OVV
# 214
#
# 🔁 Processing stock: MANH.O
# 214
#
# 🔁 Processing stock: EMN
# 214
#
# 🔁 Processing stock: CCK
# 214
#
# 🔁 Processing stock: TOL
# 214
#
# 🔁 Processing stock: CLH
# 214
#
# 🔁 Processing stock: GME
# 214
#
# 🔁 Processing stock: EXEL.O
# 214
#
# 🔁 Processing stock: RGLD.O
# 214
#
# 🔁 Processing stock: COHR.K
# 214
#
# 🔁 Processing stock: DOX.O
# 214
#
# 🔁 Processing stock: IPG
# 214
#
# 🔁 Processing stock: TECH.O
# 214
#
# 🔁 Processing stock: ATR
# 214
#
# 🔁 Processing stock: WBA.O
# 214
#
# 🔁 Processing stock: MTZ
# 214
#
# 🔁 Processing stock: SRPT.O
# 214
#
# 🔁 Processing stock: SAIA.O
# 214
#
# 🔁 Processing stock: SEIC.O
# 214
#
# 🔁 Processing stock: RRC
# 214
#
# 🔁 Processing stock: WYNN.O
# 214
#
# 🔁 Processing stock: CRS
# 214
#
# 🔁 Processing stock: CIEN.K
# 214
#
# 🔁 Processing stock: ALB
# 214
#
# 🔁 Processing stock: X
# 214
#
# 🔁 Processing stock: HSIC.O
# 214
#
# 🔁 Processing stock: LNW.O
# 214
#
# 🔁 Processing stock: CHE
# 214
#
# 🔁 Processing stock: CRL
# 214
#
# 🔁 Processing stock: DRS.O
# 214
#
# 🔁 Processing stock: RGEN.O
# 214
#
# 🔁 Processing stock: LSCC.O
# 214
#
# 🔁 Processing stock: EXAS.O
# 214
#
# 🔁 Processing stock: HAS.O
# 214
#
# 🔁 Processing stock: PARA.O
# 214
#
# 🔁 Processing stock: DCI
# 214
#
# 🔁 Processing stock: CHDN.O
# 214
#
# 🔁 Processing stock: MKTX.O
# 214
#
# 🔁 Processing stock: NYT
# 214
#
# 🔁 Processing stock: WCC
# 214
#
# 🔁 Processing stock: DLB
# 214
#
# 🔁 Processing stock: EVR
# 214
#
# 🔁 Processing stock: TTEK.O
# 214
#
# 🔁 Processing stock: RRX
# 214
#
# 🔁 Processing stock: SIRI.O
# 214
# 🔁 Processing stock: HALO.O
# 214
#
# 🔁 Processing stock: GAP
# 214
#
# 🔁 Processing stock: EXLS.O
# 214
#
# 🔁 Processing stock: ATI
# 214
#
# 🔁 Processing stock: TTC
# 214
#
# 🔁 Processing stock: ZION.O
# 214
#
# 🔁 Processing stock: BIO
# 214
#
# 🔁 Processing stock: MHK
# 214
#
# 🔁 Processing stock: APA.O
# 214
#
# 🔁 Processing stock: CVLT.O
# 214
#
# 🔁 Processing stock: AGCO.K
# 214
#
# 🔁 Processing stock: BRKR.O
# 214
#
# 🔁 Processing stock: RLI
# 214
#
# 🔁 Processing stock: IVZ
# 214
#
# 🔁 Processing stock: ONTO.K
# 214
#
# 🔁 Processing stock: CWST.O
# 214
#
# 🔁 Processing stock: QRVO.O
# 214
#
# 🔁 Processing stock: AAON.O
# 214
#
# 🔁 Processing stock: ALK
# 214
#
# 🔁 Processing stock: UFPI.O
# 214
#
# 🔁 Processing stock: FLS
# 214
#
# 🔁 Processing stock: SNV
# 214
#
# 🔁 Processing stock: TGTX.O
# 214
#
# 🔁 Processing stock: TFX
# 214
#
# 🔁 Processing stock: CELH.O
# 214
#
# 🔁 Processing stock: EAT
# 214
#
# 🔁 Processing stock: PEGA.O
# 214
#
# 🔁 Processing stock: OSK
# 214
#
# 🔁 Processing stock: LNC
# 214
#
# 🔁 Processing stock: AWI
# 214
#
# 🔁 Processing stock: CHH
# 214
#
# 🔁 Processing stock: WEX
# 214
#
# 🔁 Processing stock: CORT.O
# 214
#
# 🔁 Processing stock: MSA
# 214
#
# 🔁 Processing stock: RMBS.O
# 214
#
# 🔁 Processing stock: FCN
# 214
#
# 🔁 Processing stock: BMI
# 214
#
# 🔁 Processing stock: MMSI.O
# 214
#
# 🔁 Processing stock: MKSI.O
# 214
#
# 🔁 Processing stock: CACC.O
# 214
#
# 🔁 Processing stock: BYD
# 214
#
# 🔁 Processing stock: DDS
# 214
#
# 🔁 Processing stock: IDCC.O
# 214
#
# 🔁 Processing stock: ACIW.O
# 214
#
# 🔁 Processing stock: USM
# 214
#
# 🔁 Processing stock: CROX.O
# 214
#
# 🔁 Processing stock: GNTX.O
# 214
#
# 🔁 Processing stock: CRVL.O
# 214
#
# 🔁 Processing stock: ARW
# 214
#
# 🔁 Processing stock: NOV
# 214
#
# 🔁 Processing stock: RHI
# 214
#
# 🔁 Processing stock: SKY
# 214
#
# 🔁 Processing stock: CRK
# 214
#
# 🔁 Processing stock: OPCH.O
# 214
#
# 🔁 Processing stock: CGNX.O
# 214
#
# 🔁 Processing stock: LSTR.O
# 214
#
# 🔁 Processing stock: CRUS.O
# 214
#
# 🔁 Processing stock: CMC
# 214
#
# 🔁 Processing stock: CYTK.O
# 214
#
# 🔁 Processing stock: QXO
# 214
#
# 🔁 Processing stock: IONS.O
# 214
#
# 🔁 Processing stock: TKR
# 214
#
# 🔁 Processing stock: LFUS.O
# 214
#
# 🔁 Processing stock: NXST.O
# 214
#
# 🔁 Processing stock: LAZ
# 214
#
# 🔁 Processing stock: MTH
# 214
#
# 🔁 Processing stock: TXNM.K
# 214
#
# 🔁 Processing stock: LUMN.K
# 214
#
# 🔁 Processing stock: POR
# 214
#
# 🔁 Processing stock: AMKR.O
# 214
#
# 🔁 Processing stock: NSIT.O
# 214
#
# 🔁 Processing stock: AMG
# 214
#
# 🔁 Processing stock: ITRI.O
# 214
#
# 🔁 Processing stock: FSS
# 214
#
# 🔁 Processing stock: HXL
# 214
#
# 🔁 Processing stock: FELE.O
# 214
#
# 🔁 Processing stock: CNX
# 214
#
# 🔁 Processing stock: DY
# 214
#
# 🔁 Processing stock: URBN.O
# 214
#
# 🔁 Processing stock: PIPR.K
# 214
#
# 🔁 Processing stock: MOD
# 214
#
# 🔁 Processing stock: EEFT.O
# 214
#
# 🔁 Processing stock: BKH
# 214
#
# 🔁 Processing stock: KMPR.K
# 214
#
# 🔁 Processing stock: KBH
# 214
#
# 🔁 Processing stock: MSM
# 214
#
# 🔁 Processing stock: THO
# 214
#
# 🔁 Processing stock: EXPO.O
# 214
#
# 🔁 Processing stock: NNI
# 214
#
# 🔁 Processing stock: ESE
# 214
#
# 🔁 Processing stock: PBH
# 214
#
# 🔁 Processing stock: AVT.O
# 214
#
# 🔁 Processing stock: SANM.O
# 214
#
# 🔁 Processing stock: IPAR.O
# 214
#
# 🔁 Processing stock: BDC
# 214
#
# 🔁 Processing stock: CVCO.O
# 214
#
# 🔁 Processing stock: SLAB.O
# 214
#
# 🔁 Processing stock: AEIS.O
# 214
#
# 🔁 Processing stock: ANF
# 214
#
# 🔁 Processing stock: JWN
# 214
#
# 🔁 Processing stock: ITGR.K
# 214
#
# 🔁 Processing stock: SPR
# 214
#
# 🔁 Processing stock: DORM.O
# 214
#
# 🔁 Processing stock: ALE
# 214
#
# 🔁 Processing stock: MMS
# 214
#
# 🔁 Processing stock: FIZZ.O
# 214
#
# 🔁 Processing stock: TDS
# 214
#
# 🔁 Processing stock: CBZ
# 214
#
# 🔁 Processing stock: BCO
# 214
#
# 🔁 Processing stock: AVNT.K
# 214
#
# 🔁 Processing stock: AVAV.O
# 214
#
# 🔁 Processing stock: IESC.O
# 214
#
# 🔁 Processing stock: M
# 214
#
# 🔁 Processing stock: PRIM.K
# 214
#
# 🔁 Processing stock: SKYW.O
# 214
#
# 🔁 Processing stock: ICUI.O
# 214
#
# 🔁 Processing stock: KFY
# 214
#
# 🔁 Processing stock: RDNT.O
# 214
#
# 🔁 Processing stock: NWE.O
# 214
#
# 🔁 Processing stock: SM
# 214
#
# 🔁 Processing stock: SMTC.O
# 214
#
# 🔁 Processing stock: CCOI.O
# 214
#
# 🔁 Processing stock: PLXS.O
# 214
#
# 🔁 Processing stock: NSP
# 214
#
# 🔁 Processing stock: HAE
# 214
#
# 🔁 Processing stock: POWI.O
# 214
#
# 🔁 Processing stock: AVA
# 214
#
# 🔁 Processing stock: TNL
# 214
#
# 🔁 Processing stock: MHO
# 214
#
# 🔁 Processing stock: DXC
# 214
#
# 🔁 Processing stock: BLKB.O
# 214
#
# 🔁 Processing stock: XRAY.O
# 214
#
# 🔁 Processing stock: OSIS.O
# 214
#
# 🔁 Processing stock: HOG
# 214
#
# 🔁 Processing stock: PTEN.O
# 214
#
# 🔁 Processing stock: AMED.O
# 214
#
# 🔁 Processing stock: ASGN.K
# 214
#
# 🔁 Processing stock: CPK
# 214
#
# 🔁 Processing stock: ACAD.O
# 214
#
# 🔁 Processing stock: NOG
# 214
#
# 🔁 Processing stock: FUL
# 214
#
# 🔁 Processing stock: PATK.O
# 214
#
# 🔁 Processing stock: TGNA.K
# 214
#
# 🔁 Processing stock: MAN
# 214
#
# 🔁 Processing stock: MGRC.O
# 214
#
# 🔁 Processing stock: GNW
# 214
#
# 🔁 Processing stock: PDCO.O
# 214
#
# 🔁 Processing stock: NWL.O
# 214
#
# 🔁 Processing stock: GEF
# 214
#
# 🔁 Processing stock: GSAT.O
# 214
#
# 🔁 Processing stock: TEX
# 214
#
# 🔁 Processing stock: IPGP.O
# 214
#
# 🔁 Processing stock: PENN.O
# 214
#
# 🔁 Processing stock: JOE
# 214
#
# 🔁 Processing stock: HURN.O
# 214
#
# 🔁 Processing stock: JJSF.O
# 214
#
# 🔁 Processing stock: GT.O
# 214
#
# 🔁 Processing stock: SAM
# 214
#
# 🔁 Processing stock: HP
# 214
#
# 🔁 Processing stock: PSMT.O
# 214
#
# 🔁 Processing stock: CPRX.O
# 214
#
# 🔁 Processing stock: FORM.O
# 214
#
# 🔁 Processing stock: SYNA.O
# 214
#
# 🔁 Processing stock: QDEL.O
# 214
#
# 🔁 Processing stock: VIAV.O
# 214
#
# 🔁 Processing stock: VICR.O
# 214
#
# 🔁 Processing stock: BFH
# 214
#
# 🔁 Processing stock: PRGS.O
# 214
#
# 🔁 Processing stock: TRN
# 214
#
# 🔁 Processing stock: CAKE.O
# 214
#
# 🔁 Processing stock: WLY
# 214
#
# 🔁 Processing stock: PAR
# 214
#
# 🔁 Processing stock: VSEC.O
# 214
#
# 🔁 Processing stock: LCII.K
# 214
#
# 🔁 Processing stock: AIN
# 214
#
# 🔁 Processing stock: HUBG.O
# 214
#
# 🔁 Processing stock: VCEL.O
# 214
#
# 🔁 Processing stock: AAP
# 214
#
# 🔁 Processing stock: ALG
# 214
#
# 🔁 Processing stock: OII
# 214
#
# 🔁 Processing stock: TTMI.O
# 214
#
# 🔁 Processing stock: CXW
# 214
#
# 🔁 Processing stock: SSRM.O
# 214
#
# 🔁 Processing stock: DIOD.O
# 214
#
# 🔁 Processing stock: AEO
# 214
#
# 🔁 Processing stock: ARWR.O
# 214
#
# 🔁 Processing stock: WMK
# 214
#
# 🔁 Processing stock: AGYS.O
# 214
#
# 🔁 Processing stock: LGFa
# 214
#
# 🔁 Processing stock: LGND.O
# 214
#
# 🔁 Processing stock: HNI
# 214
#
# 🔁 Processing stock: JBLU.O
# 214
#
# 🔁 Processing stock: NEOG.O
# 214
#
# 🔁 Processing stock: HE
# 214
#
# 🔁 Processing stock: EXTR.O
# 214
#
# 🔁 Processing stock: ACLS.O
# 214
#
# 🔁 Processing stock: WERN.O
# 214
#
# 🔁 Processing stock: LMAT.O
# 214
#
# 🔁 Processing stock: CENX.O
# 214
#
# 🔁 Processing stock: BKE
# 214
#
# 🔁 Processing stock: CNMD.K
# 214
#
# 🔁 Processing stock: OI
# 214
#
# 🔁 Processing stock: CSGS.O
# 214
#
# 🔁 Processing stock: RAMP.K
# 214
#
# 🔁 Processing stock: IART.O
# 214
#
# 🔁 Processing stock: ZD.O
# 214
#
# 🔁 Processing stock: PBI
# 214
#
# 🔁 Processing stock: GBX
# 214
#
# 🔁 Processing stock: DVAX.O
# 214
#
# 🔁 Processing stock: PLUS.O
# 214
#
# 🔁 Processing stock: AZTA.O
# 214
#
# 🔁 Processing stock: KMT
# 214
#
# 🔁 Processing stock: ATRC.O
# 214
#
# 🔁 Processing stock: UFPT.O
# 214
#
# 🔁 Processing stock: UNFI.K
# 214
#
# 🔁 Processing stock: BCRX.O
# 214
#
# 🔁 Processing stock: STGW.O
# 214
#
# 🔁 Processing stock: WKC
# 214
#
# 🔁 Processing stock: MNKD.O
# 214
#
# 🔁 Processing stock: MCRI.O
# 214
#
# 🔁 Processing stock: APLD.O
# 214
#
# 🔁 Processing stock: SRCE.O
# 214
#
# 🔁 Processing stock: OMCL.O
# 214
#
# 🔁 Processing stock: INOD.O
# 214
#
# 🔁 Processing stock: FL
# 214
#
# 🔁 Processing stock: NTCT.O
# 214
#
# 🔁 Processing stock: EPC
# 214
#
# 🔁 Processing stock: ATSG.O
# 214
#
# 🔁 Processing stock: ADEA.O
# 214
#
# 🔁 Processing stock: ROG
# 214
#
# 🔁 Processing stock: NHC
# 214
#
# 🔁 Processing stock: LNN
# 214
#
# 🔁 Processing stock: PZZA.O
# 214
#
# 🔁 Processing stock: BHE
# 214
#
# 🔁 Processing stock: UPBD.O
# 214
#
# 🔁 Processing stock: ANIP.O
# 214
#
# 🔁 Processing stock: CLDX.O
# 214
#
# 🔁 Processing stock: VRNT.O
# 214
#
# 🔁 Processing stock: PLAB.O
# 214
#
# 🔁 Processing stock: VYX
# 214
#
# 🔁 Processing stock: DXPE.O
# 214
#
# 🔁 Processing stock: ATEC.O
# 214
#
# 🔁 Processing stock: NVAX.O
# 214
#
# 🔁 Processing stock: CTS
# 214
#
# 🔁 Processing stock: VSAT.O
# 214
#
# 🔁 Processing stock: NEO.O
# 214
#
# 🔁 Processing stock: WT
# 214
#
# 🔁 Processing stock: SCS
# 214
#
# 🔁 Processing stock: VECO.O
# 214
#
# 🔁 Processing stock: INVX.K
# 214
#
# 🔁 Processing stock: DCOM.O
# 214
#
# 🔁 Processing stock: EIG
# 214
#
# 🔁 Processing stock: HLIT.O
# 214
#
# 🔁 Processing stock: HLX
# 214
#
# 🔁 Processing stock: IDT
# 214
#
# 🔁 Processing stock: BLFS.O
# 214
#
# 🔁 Processing stock: GIII.O
# 214
#
# 🔁 Processing stock: CRAI.O
# 214
#
# 🔁 Processing stock: IMKTA.O
# 214
# 🔁 Processing stock: OPK.O
# 214
#
# 🔁 Processing stock: SAFT.O
# 214
#
# 🔁 Processing stock: RES
# 214
#
# 🔁 Processing stock: UCTT.O
# 214
#
# 🔁 Processing stock: GYRE.O
# 214
#
# 🔁 Processing stock: MODG.K
# 214
#
# 🔁 Processing stock: TILE.O
# 214
#
# 🔁 Processing stock: MSEX.O
# 214
#
# 🔁 Processing stock: MRTN.O
# 214
#
# 🔁 Processing stock: PRG
# 214
#
# 🔁 Processing stock: INVA.O
# 214
#
# 🔁 Processing stock: DGII.O
# 214
#
# 🔁 Processing stock: APOG.O
# 214
#
# 🔁 Processing stock: GERN.O
# 214
#
# 🔁 Processing stock: CLMT.O
# 214
#
# 🔁 Processing stock: BBSI.O
# 214
#
# 🔁 Processing stock: WGO
# 214
#
# 🔁 Processing stock: AMN
# 214
#
# 🔁 Processing stock: AORT.K
# 214
#
# 🔁 Processing stock: ALGT.O
# 214
#
# 🔁 Processing stock: SBGI.O
# 214
#
# 🔁 Processing stock: GRC
# 214
#
# 🔁 Processing stock: AMSF.O
# 214
#
# 🔁 Processing stock: KFRC.K
# 214
#
# 🔁 Processing stock: BELFA.O
# 214
#
# 🔁 Processing stock: THRM.O
# 214
#
# 🔁 Processing stock: LQDT.O
# 214
#
# 🔁 Processing stock: MYGN.O
# 214
#
# 🔁 Processing stock: NSSC.O
# 214
#
# 🔁 Processing stock: UTL
# 214
#
# 🔁 Processing stock: WOLF.K
# 214
#
# 🔁 Processing stock: KSS
# 214
#
# 🔁 Processing stock: CBRL.O
# 214
#
# 🔁 Processing stock: DCO
# 214
#
# 🔁 Processing stock: ATRO.O
# 214
#
# 🔁 Processing stock: HSII.O
# 214
#
# 🔁 Processing stock: GIC
# 214
#
# 🔁 Processing stock: PDFS.O
# 214
#
# 🔁 Processing stock: SCSC.O
# 214
#
# 🔁 Processing stock: STAA.O
# 214
#
# 🔁 Processing stock: ASTE.O
# 214
#
# 🔁 Processing stock: CECO.O
# 214
#
# 🔁 Processing stock: ECPG.O
# 214
#
# 🔁 Processing stock: PRA
# 214
#
# 🔁 Processing stock: AVXL.O
# 214
#
# 🔁 Processing stock: COHU.O
# 214
#
# 🔁 Processing stock: AMSC.O
# 214
#
# 🔁 Processing stock: HCKT.O
# 214
#
# 🔁 Processing stock: AIOT.O
# 214
#
# 🔁 Processing stock: PRAA.O
# 214
#
# 🔁 Processing stock: AXGN.O
# 214
#
# 🔁 Processing stock: OSBC.O
# 214
#
# 🔁 Processing stock: UFCS.O
# 214
#
# 🔁 Processing stock: BJRI.O
# 214
#
# 🔁 Processing stock: ADTN.O
# 214
#
# 🔁 Processing stock: XRX.O
# 214
#
# 🔁 Processing stock: OMI
# 214
#
# 🔁 Processing stock: PLPC.O
# 214
#
# 🔁 Processing stock: CLB
# 214
#
# 🔁 Processing stock: FCBC.O
# 214
#
# 🔁 Processing stock: SSYS.O
# 214
#
# 🔁 Processing stock: WRLD.O
# 214
#
# 🔁 Processing stock: RBBN.O
# 214
#
# 🔁 Processing stock: NTGR.O
# 214
#
# 🔁 Processing stock: MLAB.O
# 214
#
# 🔁 Processing stock: ETD
# 214
#
# 🔁 Processing stock: MAGN.K
# 214
#
# 🔁 Processing stock: SPTN.O
# 214
#
# 🔁 Processing stock: TRNS.O
# 214
#
# 🔁 Processing stock: SHEN.O
# 214
#
# 🔁 Processing stock: BXC
# 214
#
# 🔁 Processing stock: BZH
# 214
#
# 🔁 Processing stock: OFIX.O
# 214
#
# 🔁 Processing stock: HOV
# 214
#
# 🔁 Processing stock: OPY
# 214
#
# 🔁 Processing stock: REPX.K
# 214
#
# 🔁 Processing stock: CVLG.K
# 214
#
# 🔁 Processing stock: OSPN.O
# 214
#
# 🔁 Processing stock: FWRD.O
# 214
#
# 🔁 Processing stock: SCVL.O
# 214
#
# 🔁 Processing stock: JACK.O
# 214
#
# 🔁 Processing stock: SENEA.O
# 214
#
# 🔁 Processing stock: WLDN.O
# 214
#
# 🔁 Processing stock: CASS.O
# 214
#
# 🔁 Processing stock: SMP
# 214
#
# 🔁 Processing stock: CTLP.O
# 214
#
# 🔁 Processing stock: FARO.O
# 214
#
# 🔁 Processing stock: EBF
# 214
#
# 🔁 Processing stock: USNA.K
# 214
#
# 🔁 Processing stock: SCHL.O
# 214
#
# 🔁 Processing stock: DJCO.O
# 214
#
# 🔁 Processing stock: NPKI.K
# 214
#
# 🔁 Processing stock: AXL
# 214
#
# 🔁 Processing stock: CMCO.O
# 214
#
# 🔁 Processing stock: SLP.O
# 214
#
# 🔁 Processing stock: CRDb
# 214
#
# 🔁 Processing stock: TWI
# 214
#
# 🔁 Processing stock: HZO
# 214
#
# 🔁 Processing stock: CLMB.O
# 214
#
# 🔁 Processing stock: MLR
# 214
#
# 🔁 Processing stock: CCRN.O
# 214
#
# 🔁 Processing stock: YORW.O
# 214
#
# 🔁 Processing stock: BBW
# 214
#
# 🔁 Processing stock: VLGEA.O
# 214
#
# 🔁 Processing stock: LGTY.O
# 214
#
# 🔁 Processing stock: PBT
# 214
#
# 🔁 Processing stock: MYE
# 214
#
# 🔁 Processing stock: WNC
# 214
#
# 🔁 Processing stock: GTN
# 214
#
# 🔁 Processing stock: KELYA.O
# 214
#
# 🔁 Processing stock: ALRS.O
# 214
#
# 🔁 Processing stock: ALT.O
# 214
#
# 🔁 Processing stock: EGY
# 214
#
# 🔁 Processing stock: EYPT.O
# 214
#
# 🔁 Processing stock: SVRA.O
# 214
#
# 🔁 Processing stock: TTI
# 214
#
# 🔁 Processing stock: CLFD.O
# 214
#
# 🔁 Processing stock: NWPX.O
# 214
#
# 🔁 Processing stock: ORKA.O
# 214
#
# 🔁 Processing stock: DHIL.O
# 214
#
# 🔁 Processing stock: MITK.O
# 214
#
# 🔁 Processing stock: SRDX.O
# 214
#
# 🔁 Processing stock: FC
# 214
#
# 🔁 Processing stock: NUS
# 214
#
# 🔁 Processing stock: GCBC.O
# 214
#
# 🔁 Processing stock: TBRG.O
# 214
#
# 🔁 Processing stock: SIGA.O
# 214
#
# 🔁 Processing stock: ALNT.O
# 214
#
# 🔁 Processing stock: DIN
# 214
#
# 🔁 Processing stock: NATH.O
# 214
#
# 🔁 Processing stock: VALU.O
# 214
#
# 🔁 Processing stock: ZEUS.O
# 214
#
# 🔁 Processing stock: ANGO.O
# 214
#
# 🔁 Processing stock: RIGL.O
# 214
#
# 🔁 Processing stock: TRAK.K
# 214
#
# 🔁 Processing stock: HRTX.O
# 214
#
# 🔁 Processing stock: DDD
# 214
#
# 🔁 Processing stock: APPS.O
# 214
#
# 🔁 Processing stock: MSB
# 214
#
# 🔁 Processing stock: PNRG.O
# 214
#
# 🔁 Processing stock: ACTG.O
# 214
#
# 🔁 Processing stock: HVT
# 214
#
# 🔁 Processing stock: ATNI.O
# 214
#
# 🔁 Processing stock: MTW
# 214
#
# 🔁 Processing stock: MATV.K
# 214
#
# 🔁 Processing stock: SPOK.O
# 214
#
# 🔁 Processing stock: SHYF.O
# 214
#
# 🔁 Processing stock: NEWT.O
# 214
#
# 🔁 Processing stock: CYRX.O
# 214
#
# 🔁 Processing stock: NVEC.O
# 214
#
# 🔁 Processing stock: EBS
# 214
#
# 🔁 Processing stock: OIS
# 214
#
# 🔁 Processing stock: RLGT.K
# 214
#
# 🔁 Processing stock: BYON.K
# 214
#
# 🔁 Processing stock: MVIS.O
# 214
#
# 🔁 Processing stock: UIS
# 214
#
# 🔁 Processing stock: CDZI.O
# 214
#
# 🔁 Processing stock: VNDA.O
# 214
#
# 🔁 Processing stock: NGS
# 214
#
# 🔁 Processing stock: EGHT.O
# 214
#
# 🔁 Processing stock: PAMT.O
# 214
#
# 🔁 Processing stock: FNLC.O
# 214
#
# 🔁 Processing stock: AEHR.O
# 214
#
# 🔁 Processing stock: MOV
# 214
#
# 🔁 Processing stock: JAKK.O
# 214
#
# 🔁 Processing stock: FLIC.O
# 214
#
# 🔁 Processing stock: CERS.O
# 214
#
# 🔁 Processing stock: PKE
# 214
#
# 🔁 Processing stock: CRDF.O
# 214
#
# 🔁 Processing stock: LFMD.O
# 214
#
# 🔁 Processing stock: OSUR.O
# 214
#
# 🔁 Processing stock: JOUT.O
# 214
#
# 🔁 Processing stock: ASUR.O
# 214
#
# 🔁 Processing stock: PCYO.O
# 214
#
# 🔁 Processing stock: TCI
# 214
#
# 🔁 Processing stock: NC
# 214
#
# 🔁 Processing stock: IMMR.O
# 214
#
# 🔁 Processing stock: AVNW.O
# 214
#
# 🔁 Processing stock: XOMA.O
# 214
#
# 🔁 Processing stock: LFCR.O
# 214
#
# 🔁 Processing stock: ONIT.K
# 214
#
# 🔁 Processing stock: EHTH.O
# 214
#
# 🔁 Processing stock: ANIK.O
# 214
#
# 🔁 Processing stock: GCO
# 214
#
# 🔁 Processing stock: MEI
# 214
#
# 🔁 Processing stock: WTI
# 214
#
# 🔁 Processing stock: ABEO.O
# 214
#
# 🔁 Processing stock: SSP.O
# 214
#
# 🔁 Processing stock: RGP.O
# 214
#
# 🔁 Processing stock: KOPN.O
# 214
#
# 🔁 Processing stock: FSTR.O
# 214
#
# 🔁 Processing stock: RGCO.O
# 214
#
# 🔁 Processing stock: TSSI.O
# 214
#
# 🔁 Processing stock: LFVN.O
# 214
#
# 🔁 Processing stock: ESCA.O
# 214
#
# 🔁 Processing stock: SGMO.O
# 214
#
# 🔁 Processing stock: MPAA.O
# 214
#
# 🔁 Processing stock: DENN.O
# 214
#
# 🔁 Processing stock: FXNC.O
# 214
#
# 🔁 Processing stock: SWKH.O
# 214
#
# 🔁 Processing stock: UTMD.O
# 214
#
# 🔁 Processing stock: LAKE.O
# 214
#
# 🔁 Processing stock: GENC.K
# 214
#
# 🔁 Processing stock: LTBR.O
# 214
#
# 🔁 Processing stock: HQI.O
# 214
#
# 🔁 Processing stock: STRT.O
# 214
#
# 🔁 Processing stock: RELL.O
# 214
#
# 🔁 Processing stock: EVC
# 214
#
# 🔁 Processing stock: FENC.O
# 214
#
# 🔁 Processing stock: SMID.O
# 214
#
# 🔁 Processing stock: CATX.K
# 214
#
# 🔁 Processing stock: TBI
# 214
#
# 🔁 Processing stock: EPM
# 214
#
# 🔁 Processing stock: VOXX.O
# 214
#
# 🔁 Processing stock: DBI
# 214
#
# 🔁 Processing stock: NKTR.O
# 214
#
# 🔁 Processing stock: PLX
# 214
#
# 🔁 Processing stock: TTEC.O
# 214
#
# 🔁 Processing stock: PDEX.O
# 214
#
# 🔁 Processing stock: VIRC.O
# 214
#
# 🔁 Processing stock: ESOA.O
# 214
#
# 🔁 Processing stock: CXDO.O
# 214
#
# 🔁 Processing stock: CSPI.O
# 214
#
# 🔁 Processing stock: FRAF.O
# 214
#
# 🔁 Processing stock: STXS.K
# 214
#
# 🔁 Processing stock: CLAR.O
# 214
#
# 🔁 Processing stock: FEIM.O
# 214
#
# 🔁 Processing stock: OPOF.O
# 214
#
# 🔁 Processing stock: CCRD.K
# 214
#
# 🔁 Processing stock: PHX
# 214
#
# 🔁 Processing stock: STRS.O
# 214
#
# 🔁 Processing stock: INSG.O
# 214
#
# 🔁 Processing stock: FLL.O
# 214
#
# 🔁 Processing stock: OPRX.O
# 214
#
# 🔁 Processing stock: SRI
# 214
#
# 🔁 Processing stock: KEQU.O
# 214
#
# 🔁 Processing stock: SAVA.O
# 214
#
# 🔁 Processing stock: PESI.O
# 214
#
# 🔁 Processing stock: EGAN.O
# 214
#
# 🔁 Processing stock: BSET.O
# 214
#
# 🔁 Processing stock: LXRX.O
# 214
#
# 🔁 Processing stock: QVCGA.O
# 214
#
# 🔁 Processing stock: CSBR.O
# 214
#
# 🔁 Processing stock: KRMD.O
# 214
#
# 🔁 Processing stock: ACNT.O
# 214
#
# 🔁 Processing stock: RAIL.O
# 214
#
# 🔁 Processing stock: SNCR.O
# 214
#
# 🔁 Processing stock: VXRT.O
# 214
#
# 🔁 Processing stock: RCMT.O
# 214
#
# 🔁 Processing stock: CMT
# 214
#
# 🔁 Processing stock: LCTX.K
# 214
#
# 🔁 Processing stock: ISSC.O
# 214
#
# 🔁 Processing stock: INFU.K
# 214
#
# 🔁 Processing stock: AXR
# 214
# 🔁 Processing stock: IVAC.O
# 214
#
# 🔁 Processing stock: PLCE.O
# 214
#
# 🔁 Processing stock: LTRX.O
# 214
#
# 🔁 Processing stock: PPIH.O
# 214
#
# 🔁 Processing stock: GNSS.O
# 214
#
# 🔁 Processing stock: GALT.O
# 214
#
# 🔁 Processing stock: GAIA.O
# 214
#
# 🔁 Processing stock: KVHI.O
# 214
#
# 🔁 Processing stock: HURC.O
# 214
#
# 🔁 Processing stock: NOTV.O
# 214
#
# 🔁 Processing stock: DXLG.O
# 214
#
# 🔁 Processing stock: TAYD.O
# 214
#
# 🔁 Processing stock: PCG_pa
# 214
#
# 🔁 Processing stock: GEOS.O
# 214
#
# 🔁 Processing stock: SLNG.O
# 214
#
# 🔁 Processing stock: ORMP.O
# 214
#
# 🔁 Processing stock: INTT.K
# 214
#
# 🔁 Processing stock: ACHV.O
# 214
#
# 🔁 Processing stock: ANIX.O
# 214
#
# 🔁 Processing stock: ZYXI.O
# 214
#
# 🔁 Processing stock: QUIK.O
# 214
#
# 🔁 Processing stock: BRID.O
# 214
#
# 🔁 Processing stock: UEIC.O
# 214
#
# 🔁 Processing stock: QMCO.O
# 214
#
# 🔁 Processing stock: LPSN.O
# 214
#
# 🔁 Processing stock: FONR.O
# 214
#
# 🔁 Processing stock: MCHX.O
# 214
#
# 🔁 Processing stock: LPTH.O
# 214
#
# 🔁 Processing stock: HGBL.O
# 214
#
# 🔁 Processing stock: PETS.O
# 214
#
# 🔁 Processing stock: DIT
# 214
#
# 🔁 Processing stock: AXTI.O
# 214
#
# 🔁 Processing stock: FOSL.O
# 214
#
# 🔁 Processing stock: ALOT.O
# 214
#
# 🔁 Processing stock: HNNA.O
# 214
#
# 🔁 Processing stock: RRGB.O
# 214
#
# 🔁 Processing stock: UBCP.O
# 214
#
# 🔁 Processing stock: MNOV.O
# 214
#
# 🔁 Processing stock: INVE.O
# 214
#
# 🔁 Processing stock: SGA.O
# 214
#
# 🔁 Processing stock: ESP
# 214
#
# 🔁 Processing stock: OPTT.K
# 214
#
# 🔁 Processing stock: CODA.O
# 214
#
# 🔁 Processing stock: AUBN.O
# 214
#
# 🔁 Processing stock: INO.O
# 214
#
# 🔁 Processing stock: IOR
# 214
#
# 🔁 Processing stock: MLSS.K
# 214
#
# 🔁 Processing stock: AREN.K
# 214
#
# 🔁 Processing stock: VERU.O
# 214
#
# 🔁 Processing stock: ASYS.O
# 214
#
# 🔁 Processing stock: ARMP.K
# 214
#
# 🔁 Processing stock: ASRT.O
# 214
#
# 🔁 Processing stock: FKWL.O
# 214
#
# 🔁 Processing stock: DOMH.O
# 214
#
# 🔁 Processing stock: DLHC.O
# 214
#
# 🔁 Processing stock: PED
# 214
#
# 🔁 Processing stock: ALTS.O
# 214
#
# 🔁 Processing stock: CULP.K
# 214
#
# 🔁 Processing stock: SUP
# 214
#
# 🔁 Processing stock: CATO.K
# 214
#
# 🔁 Processing stock: CYCC.O
# 214
#
# 🔁 Processing stock: ICAD.O
# 214
#
# 🔁 Processing stock: WFCF.O
# 214
#
# 🔁 Processing stock: LINK.O
# 214
#
# 🔁 Processing stock: CTSO.O
# 214
#
# 🔁 Processing stock: CNVS.O
# 214
#
# 🔁 Processing stock: CNTY.O
# 214
#
# 🔁 Processing stock: MIND.O
# 214
#
# 🔁 Processing stock: SOTK.O
# 214
#
# 🔁 Processing stock: RMTI.O
# 214
#
# 🔁 Processing stock: CVGI.O
# 214
#
# 🔁 Processing stock: MBOT.O
# 214
#
# 🔁 Processing stock: LEE.O
# 214
#
# 🔁 Processing stock: CMTL.O
# 214
#
# 🔁 Processing stock: KOSS.O
# 214
#
# 🔁 Processing stock: BDL
# 214
#
# 🔁 Processing stock: UG.O
# 214
#
# 🔁 Processing stock: IDN.O
# 214
#
# 🔁 Processing stock: ICCC.O
# 214
#
# 🔁 Processing stock: CVU
# 214
#
# 🔁 Processing stock: AGEN.O
# 214
#
# 🔁 Processing stock: REFR.O
# 214
#
# 🔁 Processing stock: DWSN.O
# 214
#
# 🔁 Processing stock: AP
# 214
#
# 🔁 Processing stock: RFIL.O
# 214
#
# 🔁 Processing stock: USIO.O
# 214
#
# 🔁 Processing stock: CRWS.O
# 214
#
# 🔁 Processing stock: PXLW.O
# 214
#
# 🔁 Processing stock: APYX.O
# 214
#
# 🔁 Processing stock: TACT.O
# 214
#
# 🔁 Processing stock: SYPR.O
# 214
#
# 🔁 Processing stock: UONEK.O
# 214
#
# 🔁 Processing stock: ARKR.O
# 214
#
# 🔁 Processing stock: HHS.O
# 214
#
# 🔁 Processing stock: WYY
# 214
#
# 🔁 Processing stock: ACCS.K
# 214
#
# 🔁 Processing stock: AWRE.O
# 214
#
# 🔁 Processing stock: AIFF.O
# 214
#
# 🔁 Processing stock: SGRP.O
# 214
#
# 🔁 Processing stock: NTIP.K
# 214
#
# 🔁 Processing stock: VHC
# 214
#
# 🔁 Processing stock: FTEK.O
# 214
#
# 🔁 Processing stock: GROW.O
# 214
#
# 🔁 Processing stock: IRD.O
# 214
#
# 🔁 Processing stock: CMS_pb
# 214
#
# 🔁 Processing stock: KTCC.O
# 214
#
# 🔁 Processing stock: HSON.O
# 214
#
# 🔁 Processing stock: AXDX.O
# 214
#
# 🔁 Processing stock: HBIO.O
# 214
#
# 🔁 Processing stock: NSYS.O
# 214
#
# 🔁 Processing stock: OCC.O
# 214
#
# 🔁 Processing stock: NTWK.O
# 214
#
# 🔁 Processing stock: INTG.O
# 214
#
# 🔁 Processing stock: DRRX.O
# 214
#
# 🔁 Processing stock: IGC
# 214
#
# 🔁 Processing stock: TRT
# 214
#
# 🔁 Processing stock: ENZ
# 214
#
# 🔁 Processing stock: GTIM.O
# 214
#
# 🔁 Processing stock: TENX.O
# 214
#
# 🔁 Processing stock: CKX
# 214
#
# 🔁 Processing stock: CRIS.O
# 214
#
# 🔁 Processing stock: CVM
# 214
#
# 🔁 Processing stock: CYTH.O
# 214
#
# 🔁 Processing stock: DAIO.O
# 214
#
# 🔁 Processing stock: JOB
# 214
#
# 🔁 Processing stock: RVP
# 214
#
# 🔁 Processing stock: INTZ.O
# 214
#
# 🔁 Processing stock: NAII.O
# 214
#
# 🔁 Processing stock: CVV.O
# 214
#
# 🔁 Processing stock: LSTA.O
# 214
#
# 🔁 Processing stock: PTN
# 214
#
# 🔁 Processing stock: CREX.O
# 214
#
# 🔁 Processing stock: MXC
# 214
#
# 🔁 Processing stock: MTEX.O
# 214
#
# 🔁 Processing stock: NNVC.K
# 214
#
# 🔁 Processing stock: IRIX.O
# 214
#
# 🔁 Processing stock: AMS
# 214
#
# 🔁 Processing stock: SIF
# 214
#
# 🔁 Processing stock: BRN
# 214
#
# 🔁 Processing stock: NEPH.O
# 214
#
# 🔁 Processing stock: HUSA.K
# 214
#
# 🔁 Processing stock: CLRO.O
# 214
#
# 🔁 Processing stock: COHN.K
# 214
#
# 🔁 Processing stock: ELSE.O
# 214
#
# 🔁 Processing stock: MEIP.O
# 214
#
# 🔁 Processing stock: TAIT.O
# 214
#
# 🔁 Processing stock: JCTC.O
# 214
#
# 🔁 Processing stock: CLRB.O
# 214
#
# 🔁 Processing stock: GOVX.O
# 214
#
# 🔁 Processing stock: GPUS.K
# 214
#
# 🔁 Processing stock: ERNA.O
# 214
#
# 🔁 Processing stock: AIRI.K
# 214
#
# 🔁 Processing stock: SMSI.O
# 214
#
# 🔁 Processing stock: STRM.O
# 214
#
# 🔁 Processing stock: IMNN.O
# 214
#
# 🔁 Processing stock: AWX
# 214
#
# 🔁 Processing stock: BCDA.O
# 214
#
# 🔁 Processing stock: MTR
# 214
#
# 🔁 Processing stock: PRPH.O
# 214
#
# 🔁 Processing stock: SSKN.O
# 214
#
# 🔁 Processing stock: ASTC.O
# 214
#
# 🔁 Processing stock: PMCB.O
# 214
#
# 🔁 Processing stock: PRPO.O
# 214
#
# 🔁 Processing stock: BBGI.O
# 214
#
# 🔁 Processing stock: MSN
# 214
#
# 🔁 Processing stock: BCLI.O
# 214
#
# 🔁 Processing stock: NURO.O
# 214
#
# 🔁 Processing stock: SCKT.O
# 214
#
# 🔁 Processing stock: ARTW.O
# 214
#
# 🔁 Processing stock: AIMD.O
# 214
#
# 🔁 Processing stock: AIM
# 214
#
# 🔁 Processing stock: STRR.O
# 214
#
# 🔁 Processing stock: SSY
# 214
#
# 🔁 Processing stock: GTBP.O
# 214
#
# 🔁 Processing stock: SGMA.O
# 214
#
# 🔁 Processing stock: OGEN.K
# 214
#
# 🔁 Processing stock: RIME.O
# 214
#
# 🔁 Processing stock: SNGX.O
# 214
#
# 🔁 Processing stock: SNOA.O
# 214
#
# 🔁 Processing stock: AEMD.O
# 214
#
# 🔁 Processing stock: GBR
# 214
#
# 🔁 Processing stock: KNW
# 214
#
# 🔁 Processing stock: BKYI.O
# 214
#
# 🔁 Processing stock: UUU
# 214
#
# 🔁 Processing stock: PSTV.O
# 214
#
# 🔁 Processing stock: FORD.O
# 214
#
# 🔁 Processing stock: AYRO.O
# 214
#
# 🔁 Processing stock: TTNP.O
# 214
#
# 🔁 Processing stock: TOVX.K
# 214
#
# 🔁 Processing stock: PRSO.O
# 214
#
# 🔁 Processing stock: PALI.O
# 214
#
# 🔁 Processing stock: APDN.O
# 214
#
# 🔁 Processing stock: SBET.O
# 214
#
# 🔁 Processing stock: ASTI.O
# 214
#
# 🔁 Processing stock: AWH.O
# 214
#
# 🔁 Processing stock: SUNE.O
# 214
#
# 🔁 Processing stock: TCRT.O
# 214
#
# 🔁 Processing stock: WINT.O
# 214
#
# 🔁 Processing stock: DGLY.O
# 214
#
# ✅ Total Time: 29.26 minutes

# %%
predictions_df
# Out:
#         Stock       Date         Model     Actual  Predicted
# 0      AAPL.O 2024-01-31         Ridge  -1.999245   2.727184
# 1      AAPL.O 2024-01-31         Lasso  -1.999245   2.025251
# 2      AAPL.O 2024-01-31    ElasticNet  -1.999245   2.025251
# 3      AAPL.O 2024-01-31           SVR  -1.999245   3.228082
# 4      AAPL.O 2024-01-31  DecisionTree  -1.999245   1.916913
# ...       ...        ...           ...        ...        ...
# 75070  DGLY.O 2024-11-30    ElasticNet -39.532439  -2.695937
# 75071  DGLY.O 2024-11-30           SVR -39.532439  -2.580654
# 75072  DGLY.O 2024-11-30  DecisionTree -39.532439  -4.964388
# 75073  DGLY.O 2024-11-30       XGBoost -39.532439  -4.732873
# 75074  DGLY.O 2024-11-30           OLS -39.532439  -6.402238
#
# [75075 rows x 5 columns]

# %%
# Write results to Excel
rmse_df.to_excel("3ff_rmse_results.xlsx", index=False)
predictions_df.to_excel("3ff_predictions_results.xlsx", index=False)

# %%
# Identify the best model per stock (lowest RMSE)
best_models = rmse_df.loc[rmse_df.groupby("Stock")["RMSE"].idxmin()]

# Count how many times each model was selected as best
best_model_counts = best_models["Model"].value_counts().reset_index()
best_model_counts.columns = ["Model", "Count"]
best_model_counts.head(10)
# Out:
#           Model  Count
# 0           SVR    225
# 1         Lasso    205
# 2       XGBoost    165
# 3           OLS    162
# 4  DecisionTree    146
# 5         Ridge     46
# 6    ElasticNet     26

# %%
merged_data.head(4)
# Out:
#        Period     RIC  Closing Price  SIC Industry Code     SIC Industry Name  \
# 0  2025-01-31  AAPL.O         236.00             3571.0  Electronic Computers
# 1  2024-12-31  AAPL.O         250.42             3571.0  Electronic Computers
# 2  2024-11-30  AAPL.O         237.33             3571.0  Electronic Computers
# 3  2024-10-31  AAPL.O         225.91             3571.0  Electronic Computers
#
#    Company Market Cap Industry
# 0        3.210436e+12  Hi-Tech
# 1        3.210436e+12  Hi-Tech
# 2        3.210436e+12  Hi-Tech
# 3        3.210436e+12  Hi-Tech

# %%
rmse_df.head(3)
# Out:
#     Stock       Model      RMSE
# 0  AAPL.O       Ridge  5.358828
# 1  AAPL.O       Lasso  5.111489
# 2  AAPL.O  ElasticNet  5.111489

# %%
# Step 1: Get industry info per stock (use latest entry only to avoid duplication)
industry_info = merged_data[['RIC', 'Industry']].drop_duplicates(subset='RIC')

# Step 2: Merge with RMSE results
rmse_with_industry = rmse_df.merge(industry_info, left_on='Stock', right_on='RIC', how='left')

# Step 3: Group by Industry and Model to compute average RMSE
avg_rmse_by_industry = (
    rmse_with_industry
    .groupby(['Industry', 'Model'])['RMSE']
    .mean()
    .reset_index()
    .sort_values(['Industry', 'RMSE'])
)
avg_rmse_by_industry.to_excel("avg_rmse_3ff_by_industry.xlsx", index=False)

# %% [markdown]
# ### Read tuned model files for 5ff

# %%
# Preview the 3ff result
five_ff_cleaned_df = five_ff_cleaned_df.sort_values('Date').reset_index(drop=True)
five_ff_cleaned_df.head(3)
# Out:
#         Date    AAPL.O     NVDA.O    MSFT.O     AMZN.O       LLY       WMT  \
# 0 2007-02-28 -1.315037   1.135388 -9.120327   3.828094 -2.867782  1.291682
# 1 2007-03-31  9.357873  -7.430645 -1.070674   1.647066  2.107322 -2.855538
# 2 2007-04-30  7.153685  13.348787  7.164454  43.265350  9.613921  2.044975
#
#         XOM        MA       UNH  ...    SUNE.O    TCRT.O     WINT.O  \
# 0 -3.320376 -3.996326 -0.153198  ...  4.710145 -0.564442 -13.182539
# 1  5.125842 -0.880898  1.502644  ... -1.991531 -3.650742   7.443259
# 2  5.077626  4.993695  0.169763  ...  7.561204  4.776457  22.567200
#
#       DGLY.O  Mkt-RF   SMB   HML   RMW   CMA    RF
# 0 -16.907633   -1.96  1.29 -0.14 -0.51 -0.71  0.38
# 1  14.090545    0.68  0.20 -0.97  0.64 -0.65  0.43
# 2  31.585295    3.49 -2.04 -1.45  1.15  1.03  0.44
#
# [3 rows x 982 columns]

# %%
# Read the Excel file
tuned_5ff_df = pd.read_excel(r"Output\models\5ff_tuned_para.xlsx")
tuned_5ff_df.head(3)
# Out:
#     Stock    Ridge   Lasso      ElasticNet           SVR DecisionTree  \
# 0  AAPL.O  α=100.0  α=10.0  α=10.0, l1=0.5  C=10, ε=0.01      depth=2
# 1  NVDA.O  α=100.0   α=1.0   α=1.0, l1=0.9  C=10, ε=0.01      depth=2
# 2  MSFT.O  α=100.0   α=1.0   α=1.0, l1=0.9  C=0.1, ε=0.1      depth=2
#
#             XGBoost
# 0  est=200, lr=0.01
# 1    est=50, lr=0.1
# 2  est=100, lr=0.05

# %%
# --------------------
# Start global timer
# --------------------
start_time = time.time()

# Inputs
returns_df = five_ff_cleaned_df.copy()
params_df = tuned_5ff_df.copy()

# FF factors
ff_factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA', 'RF']
returns_df['Date'] = pd.to_datetime(returns_df['Date'])

# Outputs
rmse_results = []
all_predictions = []

# Get stock list
stock_columns = [col for col in returns_df.columns if col not in ['Date'] + ff_factors]

for idx, stock in enumerate(stock_columns, start=1):
    print(f"\n🔁 Processing stock: {stock}")
    
    stock_data = returns_df[['Date'] + ff_factors + [stock]].copy()
    stock_data['Stock_Return'] = stock_data[stock]
    stock_data['Excess_Mkt_Return'] = stock_data['Mkt-RF'] - stock_data['RF']

    stock_data = stock_data[['Date', 'Stock_Return', 'Excess_Mkt_Return', 'SMB', 'HML', 'RMW', 'CMA', 'RF']]
    stock_data['Stock_Return_Shifted'] = stock_data['Stock_Return'].shift(-1)
    stock_data = stock_data.dropna().reset_index(drop=True)

    X_full = stock_data[['Excess_Mkt_Return', 'SMB', 'HML', 'RMW', 'CMA', 'RF']].values
    y_full = stock_data['Stock_Return_Shifted'].values
    dates = stock_data['Date'].values

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_full)

    row = params_df[params_df['Stock'] == stock]
    if row.empty:
        continue

    try:
        models = {}

        # Tuned models
        models['Ridge'] = Ridge(alpha=float(re.findall(r"α=(\d+\.?\d*)", row['Ridge'].values[0])[0]))
        models['Lasso'] = Lasso(alpha=float(re.findall(r"α=(\d+\.?\d*)", row['Lasso'].values[0])[0]))
        
        en_alpha, en_l1 = re.findall(r"α=(\d+\.?\d*), l1=(\d+\.?\d*)", row['ElasticNet'].values[0])[0]
        models['ElasticNet'] = ElasticNet(alpha=float(en_alpha), l1_ratio=float(en_l1))
        
        svr_C, svr_eps = re.findall(r"C=(\d+\.?\d*), ε=([\d\.-]+)", row['SVR'].values[0])[0]
        models['SVR'] = SVR(C=float(svr_C), epsilon=float(svr_eps))
        
        dt_depth = int(re.findall(r"depth=(\d+)", row['DecisionTree'].values[0])[0])
        models['DecisionTree'] = DecisionTreeRegressor(max_depth=dt_depth)
        
        xgb_est, xgb_lr = re.findall(r"est=(\d+), lr=([\d\.]+)", row['XGBoost'].values[0])[0]
        models['XGBoost'] = XGBRegressor(n_estimators=int(xgb_est), learning_rate=float(xgb_lr), verbosity=0)

        # Benchmark model
        models['OLS'] = LinearRegression()

    except Exception as e:
        print(f"⚠️ Error parsing hyperparameters for {stock}: {e}")
        continue

    preds_by_model = {m: [] for m in models}
    actuals = []

    for i in range(len(stock_data)):
        current_date = stock_data.loc[i, 'Date']
        if test_start_date <= current_date <= test_end_date:
            train_mask = stock_data['Date'] < current_date
            test_mask = stock_data['Date'] == current_date

            X_train = X_scaled[train_mask]
            y_train = y_full[train_mask]
            X_test = X_scaled[test_mask]
            y_test = y_full[test_mask]

            if len(X_train) == 0 or X_test.shape[0] == 0:
                continue

            actual = y_test[0]

            for name, model in models.items():
                try:
                    model.fit(X_train, y_train)
                    pred = model.predict(X_test)[0]
                    preds_by_model[name].append(pred)
                    all_predictions.append({
                        'Stock': stock,
                        'Date': current_date,
                        'Model': name,
                        'Actual': actual,
                        'Predicted': pred
                    })
                except Exception as e:
                    print(f"⚠️ Prediction error for {stock} - {name}: {e}")
                    continue

            actuals.append(actual)

    for name in preds_by_model:
        pred_arr = np.array(preds_by_model[name])
        if len(pred_arr) == len(actuals) and len(actuals) > 0:
            rmse = mean_squared_error(actuals, pred_arr, squared=False)
            rmse_results.append({
                'Stock': stock,
                'Model': name,
                'RMSE': rmse
            })

# Convert results
rmse_5ff_df = pd.DataFrame(rmse_results)
predictions_5ff_df = pd.DataFrame(all_predictions)

# --------------------
# End global timer
# --------------------
end_time = time.time()
print(f"\n✅ Total Time: {(end_time - start_time)/60:.2f} minutes")
# Out:
# 🔁 Processing stock: AAPL.O
#
# 🔁 Processing stock: NVDA.O
#
# 🔁 Processing stock: MSFT.O
#
# 🔁 Processing stock: AMZN.O
#
# 🔁 Processing stock: LLY
#
# 🔁 Processing stock: WMT
#
# 🔁 Processing stock: XOM
#
# 🔁 Processing stock: MA
#
# 🔁 Processing stock: UNH
#
# 🔁 Processing stock: ORCL.K
#
# 🔁 Processing stock: COST.O
#
# 🔁 Processing stock: NFLX.O
#
# 🔁 Processing stock: HD
#
# 🔁 Processing stock: CVX
#
# 🔁 Processing stock: CRM
#
# 🔁 Processing stock: CSCO.O
#
# 🔁 Processing stock: MRK
#
# 🔁 Processing stock: ABT
#
# 🔁 Processing stock: MCD
#
# 🔁 Processing stock: TMO
#
# 🔁 Processing stock: ISRG.O
#
# 🔁 Processing stock: RTX
#
# 🔁 Processing stock: QCOM.O
#
# 🔁 Processing stock: ADBE.O
#
# 🔁 Processing stock: AMGN.O
#
# 🔁 Processing stock: INTU.O
#
# 🔁 Processing stock: AMD.O
#
# 🔁 Processing stock: CAT
#
# 🔁 Processing stock: TXN.O
#
# 🔁 Processing stock: NEE
#
# 🔁 Processing stock: DHR
#
# 🔁 Processing stock: PFE
#
# 🔁 Processing stock: BLK
#
# 🔁 Processing stock: UNP
#
# 🔁 Processing stock: BSX
#
# 🔁 Processing stock: SYK
#
# 🔁 Processing stock: GILD.O
#
# 🔁 Processing stock: HON.O
#
# 🔁 Processing stock: CMCSA.O
#
# 🔁 Processing stock: VRTX.O
#
# 🔁 Processing stock: DE
#
# 🔁 Processing stock: TJX
#
# 🔁 Processing stock: COP
#
# 🔁 Processing stock: LOW
#
# 🔁 Processing stock: BA
#
# 🔁 Processing stock: FI
#
# 🔁 Processing stock: BMY
#
# 🔁 Processing stock: ADP.O
#
# 🔁 Processing stock: MMC
#
# 🔁 Processing stock: MU.O
#
# 🔁 Processing stock: NKE
#
# 🔁 Processing stock: INTC.O
#
# 🔁 Processing stock: ADI.O
#
# 🔁 Processing stock: LRCX.O
#
# 🔁 Processing stock: ELV
#
# 🔁 Processing stock: KLAC.O
#
# 🔁 Processing stock: DUK
#
# 🔁 Processing stock: CI
#
# 🔁 Processing stock: AJG
#
# 🔁 Processing stock: CVS
#
# 🔁 Processing stock: MMM
#
# 🔁 Processing stock: MCK
#
# 🔁 Processing stock: APH
#
# 🔁 Processing stock: ORLY.O
#
# 🔁 Processing stock: REGN.O
#
# 🔁 Processing stock: CL
#
# 🔁 Processing stock: RSG
#
# 🔁 Processing stock: NOC
#
# 🔁 Processing stock: WMB
#
# 🔁 Processing stock: MSI
#
# 🔁 Processing stock: SNPS.O
#
# 🔁 Processing stock: EOG
#
# 🔁 Processing stock: CDNS.O
#
# 🔁 Processing stock: CMG
#
# 🔁 Processing stock: MAR.O
#
# 🔁 Processing stock: BDX
#
# 🔁 Processing stock: ROP.O
#
# 🔁 Processing stock: OKE
#
# 🔁 Processing stock: AZO
#
# 🔁 Processing stock: MRVL.O
#
# 🔁 Processing stock: BK
#
# 🔁 Processing stock: CSX.O
#
# 🔁 Processing stock: SLB
#
# 🔁 Processing stock: MET
#
# 🔁 Processing stock: ADSK.O
#
# 🔁 Processing stock: TFC
#
# 🔁 Processing stock: PCAR.O
#
# 🔁 Processing stock: COR
#
# 🔁 Processing stock: LNG
#
# 🔁 Processing stock: TGT
#
# 🔁 Processing stock: KR
#
# 🔁 Processing stock: D
#
# 🔁 Processing stock: HES
#
# 🔁 Processing stock: FICO.K
#
# 🔁 Processing stock: OXY
#
# 🔁 Processing stock: BKR.O
#
# 🔁 Processing stock: ROST.O
#
# 🔁 Processing stock: EW
#
# 🔁 Processing stock: VLO
#
# 🔁 Processing stock: AME
#
# 🔁 Processing stock: GLW
#
# 🔁 Processing stock: DHI
#
# 🔁 Processing stock: LHX
#
# 🔁 Processing stock: CTSH.O
#
# 🔁 Processing stock: PWR
#
# 🔁 Processing stock: F
#
# 🔁 Processing stock: EA.O
#
# 🔁 Processing stock: TTWO.O
#
# 🔁 Processing stock: A
#
# 🔁 Processing stock: ODFL.O
#
# 🔁 Processing stock: BRO
#
# 🔁 Processing stock: IDXX.O
#
# 🔁 Processing stock: CSGP.O
#
# 🔁 Processing stock: ALNY.O
#
# 🔁 Processing stock: HEI
#
# 🔁 Processing stock: LVS
#
# 🔁 Processing stock: CAH
#
# 🔁 Processing stock: WAB
#
# 🔁 Processing stock: HUM
#
# 🔁 Processing stock: NUE
#
# 🔁 Processing stock: EBAY.O
#
# 🔁 Processing stock: TPL
#
# 🔁 Processing stock: EQT
#
# 🔁 Processing stock: ROK
#
# 🔁 Processing stock: MPWR.O
#
# 🔁 Processing stock: MCHP.O
#
# 🔁 Processing stock: ANSS.O
#
# 🔁 Processing stock: DTE
#
# 🔁 Processing stock: DXCM.O
#
# 🔁 Processing stock: IP
#
# 🔁 Processing stock: AEE
#
# 🔁 Processing stock: PPG
#
# 🔁 Processing stock: PPL
#
# 🔁 Processing stock: MTD
#
# 🔁 Processing stock: WBD.O
#
# 🔁 Processing stock: TYL
#
# 🔁 Processing stock: EL
#
# 🔁 Processing stock: ATO
#
# 🔁 Processing stock: GPN
#
# 🔁 Processing stock: TDY
#
# 🔁 Processing stock: VRSN.O
#
# 🔁 Processing stock: DVN
#
# 🔁 Processing stock: WAT
#
# 🔁 Processing stock: ERIE.O
#
# 🔁 Processing stock: ZBH
#
# 🔁 Processing stock: DRI
#
# 🔁 Processing stock: HAL
#
# 🔁 Processing stock: NVR
#
# 🔁 Processing stock: TSN
#
# 🔁 Processing stock: CTRA.K
#
# 🔁 Processing stock: PHM
#
# 🔁 Processing stock: TROW.O
#
# 🔁 Processing stock: LII
#
# 🔁 Processing stock: BIIB.O
#
# 🔁 Processing stock: LH
#
# 🔁 Processing stock: STLD.O
#
# 🔁 Processing stock: NRG
#
# 🔁 Processing stock: DGX
#
# 🔁 Processing stock: LUV
#
# 🔁 Processing stock: PTC.O
#
# 🔁 Processing stock: NTAP.O
#
# 🔁 Processing stock: ON.O
#
# 🔁 Processing stock: CLX
#
# 🔁 Processing stock: DECK.K
#
# 🔁 Processing stock: FNF
#
# 🔁 Processing stock: BAX
#
# 🔁 Processing stock: EME
#
# 🔁 Processing stock: TRMB.O
#
# 🔁 Processing stock: GPC
#
# 🔁 Processing stock: GEN.O
#
# 🔁 Processing stock: WST
#
# 🔁 Processing stock: HRL
#
# 🔁 Processing stock: COO.O
#
# 🔁 Processing stock: EXPD.K
#
# 🔁 Processing stock: WDC.O
#
# 🔁 Processing stock: BBY
#
# 🔁 Processing stock: FFIV.O
#
# 🔁 Processing stock: RS
#
# 🔁 Processing stock: RPM
#
# 🔁 Processing stock: JBL
#
# 🔁 Processing stock: ENTG.O
#
# 🔁 Processing stock: BALL.K
#
# 🔁 Processing stock: BLDR.K
#
# 🔁 Processing stock: FSLR.O
#
# 🔁 Processing stock: GGG
#
# 🔁 Processing stock: TER.O
#
# 🔁 Processing stock: UNM
#
# 🔁 Processing stock: DLTR.O
#
# 🔁 Processing stock: INSM.O
#
# 🔁 Processing stock: UTHR.O
#
# 🔁 Processing stock: HOLX.O
#
# 🔁 Processing stock: ILMN.O
#
# 🔁 Processing stock: RVTY.K
#
# 🔁 Processing stock: BMRN.O
#
# 🔁 Processing stock: FLEX.O
#
# 🔁 Processing stock: INCY.O
#
# 🔁 Processing stock: JKHY.O
#
# 🔁 Processing stock: MORN.O
#
# 🔁 Processing stock: ALGN.O
#
# 🔁 Processing stock: EWBC.O
#
# 🔁 Processing stock: AKAM.O
#
# 🔁 Processing stock: FIX
#
# 🔁 Processing stock: JNPR.K
#
# 🔁 Processing stock: SJM
#
# 🔁 Processing stock: JLL
#
# 🔁 Processing stock: NDSN.O
#
# 🔁 Processing stock: CHRW.O
#
# 🔁 Processing stock: THC
#
# 🔁 Processing stock: JEF
#
# 🔁 Processing stock: COKE.O
#
# 🔁 Processing stock: TXRH.O
#
# 🔁 Processing stock: SWKS.O
#
# 🔁 Processing stock: NBIX.O
#
# 🔁 Processing stock: ITT
#
# 🔁 Processing stock: VTRS.O
#
# 🔁 Processing stock: SNX
#
# 🔁 Processing stock: AIZ
#
# 🔁 Processing stock: RBC
#
# 🔁 Processing stock: OVV
#
# 🔁 Processing stock: MANH.O
#
# 🔁 Processing stock: EMN
#
# 🔁 Processing stock: CCK
#
# 🔁 Processing stock: TOL
#
# 🔁 Processing stock: CLH
#
# 🔁 Processing stock: GME
#
# 🔁 Processing stock: EXEL.O
#
# 🔁 Processing stock: RGLD.O
#
# 🔁 Processing stock: COHR.K
#
# 🔁 Processing stock: DOX.O
#
# 🔁 Processing stock: IPG
#
# 🔁 Processing stock: TECH.O
#
# 🔁 Processing stock: ATR
#
# 🔁 Processing stock: WBA.O
#
# 🔁 Processing stock: MTZ
#
# 🔁 Processing stock: SRPT.O
#
# 🔁 Processing stock: SAIA.O
#
# 🔁 Processing stock: SEIC.O
#
# 🔁 Processing stock: RRC
#
# 🔁 Processing stock: WYNN.O
#
# 🔁 Processing stock: CRS
#
# 🔁 Processing stock: CIEN.K
#
# 🔁 Processing stock: ALB
#
# 🔁 Processing stock: X
#
# 🔁 Processing stock: HSIC.O
#
# 🔁 Processing stock: LNW.O
#
# 🔁 Processing stock: CHE
#
# 🔁 Processing stock: CRL
#
# 🔁 Processing stock: DRS.O
#
# 🔁 Processing stock: RGEN.O
#
# 🔁 Processing stock: LSCC.O
#
# 🔁 Processing stock: EXAS.O
#
# 🔁 Processing stock: HAS.O
#
# 🔁 Processing stock: PARA.O
#
# 🔁 Processing stock: DCI
#
# 🔁 Processing stock: CHDN.O
#
# 🔁 Processing stock: MKTX.O
#
# 🔁 Processing stock: NYT
#
# 🔁 Processing stock: WCC
#
# 🔁 Processing stock: DLB
#
# 🔁 Processing stock: EVR
#
# 🔁 Processing stock: TTEK.O
#
# 🔁 Processing stock: RRX
#
# 🔁 Processing stock: SIRI.O
#
# 🔁 Processing stock: HALO.O
#
# 🔁 Processing stock: GAP
#
# 🔁 Processing stock: EXLS.O
#
# 🔁 Processing stock: ATI
#
# 🔁 Processing stock: TTC
#
# 🔁 Processing stock: ZION.O
#
# 🔁 Processing stock: BIO
#
# 🔁 Processing stock: MHK
#
# 🔁 Processing stock: APA.O
#
# 🔁 Processing stock: CVLT.O
#
# 🔁 Processing stock: AGCO.K
#
# 🔁 Processing stock: BRKR.O
#
# 🔁 Processing stock: RLI
#
# 🔁 Processing stock: IVZ
#
# 🔁 Processing stock: ONTO.K
#
# 🔁 Processing stock: CWST.O
#
# 🔁 Processing stock: QRVO.O
#
# 🔁 Processing stock: AAON.O
#
# 🔁 Processing stock: ALK
#
# 🔁 Processing stock: UFPI.O
#
# 🔁 Processing stock: FLS
#
# 🔁 Processing stock: SNV
#
# 🔁 Processing stock: TGTX.O
#
# 🔁 Processing stock: TFX
#
# 🔁 Processing stock: CELH.O
#
# 🔁 Processing stock: EAT
#
# 🔁 Processing stock: PEGA.O
#
# 🔁 Processing stock: OSK
#
# 🔁 Processing stock: LNC
#
# 🔁 Processing stock: AWI
#
# 🔁 Processing stock: CHH
#
# 🔁 Processing stock: WEX
#
# 🔁 Processing stock: CORT.O
#
# 🔁 Processing stock: MSA
#
# 🔁 Processing stock: RMBS.O
#
# 🔁 Processing stock: FCN
#
# 🔁 Processing stock: BMI
#
# 🔁 Processing stock: MMSI.O
#
# 🔁 Processing stock: MKSI.O
# 🔁 Processing stock: CACC.O
#
# 🔁 Processing stock: BYD
#
# 🔁 Processing stock: DDS
#
# 🔁 Processing stock: IDCC.O
#
# 🔁 Processing stock: ACIW.O
#
# 🔁 Processing stock: USM
#
# 🔁 Processing stock: CROX.O
#
# 🔁 Processing stock: GNTX.O
#
# 🔁 Processing stock: CRVL.O
#
# 🔁 Processing stock: ARW
#
# 🔁 Processing stock: NOV
#
# 🔁 Processing stock: RHI
#
# 🔁 Processing stock: SKY
#
# 🔁 Processing stock: CRK
#
# 🔁 Processing stock: OPCH.O
#
# 🔁 Processing stock: CGNX.O
#
# 🔁 Processing stock: LSTR.O
#
# 🔁 Processing stock: CRUS.O
#
# 🔁 Processing stock: CMC
#
# 🔁 Processing stock: CYTK.O
#
# 🔁 Processing stock: QXO
#
# 🔁 Processing stock: IONS.O
#
# 🔁 Processing stock: TKR
#
# 🔁 Processing stock: LFUS.O
#
# 🔁 Processing stock: NXST.O
#
# 🔁 Processing stock: LAZ
#
# 🔁 Processing stock: MTH
#
# 🔁 Processing stock: TXNM.K
#
# 🔁 Processing stock: LUMN.K
#
# 🔁 Processing stock: POR
#
# 🔁 Processing stock: AMKR.O
#
# 🔁 Processing stock: NSIT.O
#
# 🔁 Processing stock: AMG
#
# 🔁 Processing stock: ITRI.O
#
# 🔁 Processing stock: FSS
#
# 🔁 Processing stock: HXL
#
# 🔁 Processing stock: FELE.O
#
# 🔁 Processing stock: CNX
#
# 🔁 Processing stock: DY
#
# 🔁 Processing stock: URBN.O
#
# 🔁 Processing stock: PIPR.K
#
# 🔁 Processing stock: MOD
#
# 🔁 Processing stock: EEFT.O
#
# 🔁 Processing stock: BKH
#
# 🔁 Processing stock: KMPR.K
#
# 🔁 Processing stock: KBH
#
# 🔁 Processing stock: MSM
#
# 🔁 Processing stock: THO
#
# 🔁 Processing stock: EXPO.O
#
# 🔁 Processing stock: NNI
#
# 🔁 Processing stock: ESE
#
# 🔁 Processing stock: PBH
#
# 🔁 Processing stock: AVT.O
#
# 🔁 Processing stock: SANM.O
#
# 🔁 Processing stock: IPAR.O
#
# 🔁 Processing stock: BDC
#
# 🔁 Processing stock: CVCO.O
#
# 🔁 Processing stock: SLAB.O
#
# 🔁 Processing stock: AEIS.O
#
# 🔁 Processing stock: ANF
#
# 🔁 Processing stock: JWN
#
# 🔁 Processing stock: ITGR.K
#
# 🔁 Processing stock: SPR
#
# 🔁 Processing stock: DORM.O
#
# 🔁 Processing stock: ALE
#
# 🔁 Processing stock: MMS
#
# 🔁 Processing stock: FIZZ.O
#
# 🔁 Processing stock: TDS
#
# 🔁 Processing stock: CBZ
#
# 🔁 Processing stock: BCO
#
# 🔁 Processing stock: AVNT.K
#
# 🔁 Processing stock: AVAV.O
#
# 🔁 Processing stock: IESC.O
#
# 🔁 Processing stock: M
#
# 🔁 Processing stock: PRIM.K
#
# 🔁 Processing stock: SKYW.O
#
# 🔁 Processing stock: ICUI.O
#
# 🔁 Processing stock: KFY
#
# 🔁 Processing stock: RDNT.O
#
# 🔁 Processing stock: NWE.O
#
# 🔁 Processing stock: SM
#
# 🔁 Processing stock: SMTC.O
#
# 🔁 Processing stock: CCOI.O
#
# 🔁 Processing stock: PLXS.O
#
# 🔁 Processing stock: NSP
#
# 🔁 Processing stock: HAE
#
# 🔁 Processing stock: POWI.O
#
# 🔁 Processing stock: AVA
#
# 🔁 Processing stock: TNL
#
# 🔁 Processing stock: MHO
#
# 🔁 Processing stock: DXC
#
# 🔁 Processing stock: BLKB.O
#
# 🔁 Processing stock: XRAY.O
#
# 🔁 Processing stock: OSIS.O
#
# 🔁 Processing stock: HOG
#
# 🔁 Processing stock: PTEN.O
#
# 🔁 Processing stock: AMED.O
#
# 🔁 Processing stock: ASGN.K
#
# 🔁 Processing stock: CPK
#
# 🔁 Processing stock: ACAD.O
#
# 🔁 Processing stock: NOG
#
# 🔁 Processing stock: FUL
#
# 🔁 Processing stock: PATK.O
#
# 🔁 Processing stock: TGNA.K
#
# 🔁 Processing stock: MAN
#
# 🔁 Processing stock: MGRC.O
#
# 🔁 Processing stock: GNW
#
# 🔁 Processing stock: PDCO.O
#
# 🔁 Processing stock: NWL.O
#
# 🔁 Processing stock: GEF
#
# 🔁 Processing stock: GSAT.O
#
# 🔁 Processing stock: TEX
#
# 🔁 Processing stock: IPGP.O
#
# 🔁 Processing stock: PENN.O
#
# 🔁 Processing stock: JOE
#
# 🔁 Processing stock: HURN.O
#
# 🔁 Processing stock: JJSF.O
#
# 🔁 Processing stock: GT.O
#
# 🔁 Processing stock: SAM
#
# 🔁 Processing stock: HP
#
# 🔁 Processing stock: PSMT.O
#
# 🔁 Processing stock: CPRX.O
#
# 🔁 Processing stock: FORM.O
#
# 🔁 Processing stock: SYNA.O
#
# 🔁 Processing stock: QDEL.O
#
# 🔁 Processing stock: VIAV.O
#
# 🔁 Processing stock: VICR.O
#
# 🔁 Processing stock: BFH
#
# 🔁 Processing stock: PRGS.O
#
# 🔁 Processing stock: TRN
#
# 🔁 Processing stock: CAKE.O
#
# 🔁 Processing stock: WLY
#
# 🔁 Processing stock: PAR
#
# 🔁 Processing stock: VSEC.O
#
# 🔁 Processing stock: LCII.K
#
# 🔁 Processing stock: AIN
#
# 🔁 Processing stock: HUBG.O
#
# 🔁 Processing stock: VCEL.O
#
# 🔁 Processing stock: AAP
#
# 🔁 Processing stock: ALG
#
# 🔁 Processing stock: OII
#
# 🔁 Processing stock: TTMI.O
#
# 🔁 Processing stock: CXW
#
# 🔁 Processing stock: SSRM.O
#
# 🔁 Processing stock: DIOD.O
#
# 🔁 Processing stock: AEO
#
# 🔁 Processing stock: ARWR.O
#
# 🔁 Processing stock: WMK
#
# 🔁 Processing stock: AGYS.O
#
# 🔁 Processing stock: LGFa
#
# 🔁 Processing stock: LGND.O
#
# 🔁 Processing stock: HNI
#
# 🔁 Processing stock: JBLU.O
#
# 🔁 Processing stock: NEOG.O
#
# 🔁 Processing stock: HE
#
# 🔁 Processing stock: EXTR.O
#
# 🔁 Processing stock: ACLS.O
#
# 🔁 Processing stock: WERN.O
#
# 🔁 Processing stock: LMAT.O
#
# 🔁 Processing stock: CENX.O
#
# 🔁 Processing stock: BKE
#
# 🔁 Processing stock: CNMD.K
#
# 🔁 Processing stock: OI
#
# 🔁 Processing stock: CSGS.O
#
# 🔁 Processing stock: RAMP.K
#
# 🔁 Processing stock: IART.O
#
# 🔁 Processing stock: ZD.O
#
# 🔁 Processing stock: PBI
#
# 🔁 Processing stock: GBX
#
# 🔁 Processing stock: DVAX.O
#
# 🔁 Processing stock: PLUS.O
#
# 🔁 Processing stock: AZTA.O
#
# 🔁 Processing stock: KMT
#
# 🔁 Processing stock: ATRC.O
#
# 🔁 Processing stock: UFPT.O
#
# 🔁 Processing stock: UNFI.K
#
# 🔁 Processing stock: BCRX.O
#
# 🔁 Processing stock: STGW.O
#
# 🔁 Processing stock: WKC
#
# 🔁 Processing stock: MNKD.O
#
# 🔁 Processing stock: MCRI.O
#
# 🔁 Processing stock: APLD.O
#
# 🔁 Processing stock: SRCE.O
#
# 🔁 Processing stock: OMCL.O
#
# 🔁 Processing stock: INOD.O
#
# 🔁 Processing stock: FL
#
# 🔁 Processing stock: NTCT.O
#
# 🔁 Processing stock: EPC
#
# 🔁 Processing stock: ATSG.O
#
# 🔁 Processing stock: ADEA.O
#
# 🔁 Processing stock: ROG
#
# 🔁 Processing stock: NHC
#
# 🔁 Processing stock: LNN
#
# 🔁 Processing stock: PZZA.O
#
# 🔁 Processing stock: BHE
#
# 🔁 Processing stock: UPBD.O
#
# 🔁 Processing stock: ANIP.O
#
# 🔁 Processing stock: CLDX.O
#
# 🔁 Processing stock: VRNT.O
#
# 🔁 Processing stock: PLAB.O
#
# 🔁 Processing stock: VYX
#
# 🔁 Processing stock: DXPE.O
#
# 🔁 Processing stock: ATEC.O
#
# 🔁 Processing stock: NVAX.O
#
# 🔁 Processing stock: CTS
#
# 🔁 Processing stock: VSAT.O
#
# 🔁 Processing stock: NEO.O
#
# 🔁 Processing stock: WT
#
# 🔁 Processing stock: SCS
#
# 🔁 Processing stock: VECO.O
#
# 🔁 Processing stock: INVX.K
#
# 🔁 Processing stock: DCOM.O
#
# 🔁 Processing stock: EIG
#
# 🔁 Processing stock: HLIT.O
#
# 🔁 Processing stock: HLX
#
# 🔁 Processing stock: IDT
#
# 🔁 Processing stock: BLFS.O
#
# 🔁 Processing stock: GIII.O
#
# 🔁 Processing stock: CRAI.O
#
# 🔁 Processing stock: IMKTA.O
#
# 🔁 Processing stock: OPK.O
#
# 🔁 Processing stock: SAFT.O
#
# 🔁 Processing stock: RES
#
# 🔁 Processing stock: UCTT.O
#
# 🔁 Processing stock: GYRE.O
#
# 🔁 Processing stock: MODG.K
#
# 🔁 Processing stock: TILE.O
#
# 🔁 Processing stock: MSEX.O
#
# 🔁 Processing stock: MRTN.O
#
# 🔁 Processing stock: PRG
#
# 🔁 Processing stock: INVA.O
#
# 🔁 Processing stock: DGII.O
#
# 🔁 Processing stock: APOG.O
#
# 🔁 Processing stock: GERN.O
#
# 🔁 Processing stock: CLMT.O
#
# 🔁 Processing stock: BBSI.O
#
# 🔁 Processing stock: WGO
#
# 🔁 Processing stock: AMN
#
# 🔁 Processing stock: AORT.K
#
# 🔁 Processing stock: ALGT.O
#
# 🔁 Processing stock: SBGI.O
#
# 🔁 Processing stock: GRC
#
# 🔁 Processing stock: AMSF.O
#
# 🔁 Processing stock: KFRC.K
#
# 🔁 Processing stock: BELFA.O
#
# 🔁 Processing stock: THRM.O
#
# 🔁 Processing stock: LQDT.O
#
# 🔁 Processing stock: MYGN.O
#
# 🔁 Processing stock: NSSC.O
#
# 🔁 Processing stock: UTL
#
# 🔁 Processing stock: WOLF.K
#
# 🔁 Processing stock: KSS
#
# 🔁 Processing stock: CBRL.O
#
# 🔁 Processing stock: DCO
#
# 🔁 Processing stock: ATRO.O
#
# 🔁 Processing stock: HSII.O
#
# 🔁 Processing stock: GIC
#
# 🔁 Processing stock: PDFS.O
#
# 🔁 Processing stock: SCSC.O
#
# 🔁 Processing stock: STAA.O
#
# 🔁 Processing stock: ASTE.O
#
# 🔁 Processing stock: CECO.O
#
# 🔁 Processing stock: ECPG.O
#
# 🔁 Processing stock: PRA
#
# 🔁 Processing stock: AVXL.O
#
# 🔁 Processing stock: COHU.O
#
# 🔁 Processing stock: AMSC.O
#
# 🔁 Processing stock: HCKT.O
#
# 🔁 Processing stock: AIOT.O
#
# 🔁 Processing stock: PRAA.O
#
# 🔁 Processing stock: AXGN.O
#
# 🔁 Processing stock: OSBC.O
#
# 🔁 Processing stock: UFCS.O
#
# 🔁 Processing stock: BJRI.O
#
# 🔁 Processing stock: ADTN.O
#
# 🔁 Processing stock: XRX.O
#
# 🔁 Processing stock: OMI
#
# 🔁 Processing stock: PLPC.O
#
# 🔁 Processing stock: CLB
#
# 🔁 Processing stock: FCBC.O
#
# 🔁 Processing stock: SSYS.O
#
# 🔁 Processing stock: WRLD.O
#
# 🔁 Processing stock: RBBN.O
#
# 🔁 Processing stock: NTGR.O
#
# 🔁 Processing stock: MLAB.O
#
# 🔁 Processing stock: ETD
#
# 🔁 Processing stock: MAGN.K
#
# 🔁 Processing stock: SPTN.O
#
# 🔁 Processing stock: TRNS.O
#
# 🔁 Processing stock: SHEN.O
#
# 🔁 Processing stock: BXC
#
# 🔁 Processing stock: BZH
#
# 🔁 Processing stock: OFIX.O
#
# 🔁 Processing stock: HOV
# 🔁 Processing stock: OPY
#
# 🔁 Processing stock: REPX.K
#
# 🔁 Processing stock: CVLG.K
#
# 🔁 Processing stock: OSPN.O
#
# 🔁 Processing stock: FWRD.O
#
# 🔁 Processing stock: SCVL.O
#
# 🔁 Processing stock: JACK.O
#
# 🔁 Processing stock: SENEA.O
#
# 🔁 Processing stock: WLDN.O
#
# 🔁 Processing stock: CASS.O
#
# 🔁 Processing stock: SMP
#
# 🔁 Processing stock: CTLP.O
#
# 🔁 Processing stock: FARO.O
#
# 🔁 Processing stock: EBF
#
# 🔁 Processing stock: USNA.K
#
# 🔁 Processing stock: SCHL.O
#
# 🔁 Processing stock: DJCO.O
#
# 🔁 Processing stock: NPKI.K
#
# 🔁 Processing stock: AXL
#
# 🔁 Processing stock: CMCO.O
#
# 🔁 Processing stock: SLP.O
#
# 🔁 Processing stock: CRDb
#
# 🔁 Processing stock: TWI
#
# 🔁 Processing stock: HZO
#
# 🔁 Processing stock: CLMB.O
#
# 🔁 Processing stock: MLR
#
# 🔁 Processing stock: CCRN.O
#
# 🔁 Processing stock: YORW.O
#
# 🔁 Processing stock: BBW
#
# 🔁 Processing stock: VLGEA.O
#
# 🔁 Processing stock: LGTY.O
#
# 🔁 Processing stock: PBT
#
# 🔁 Processing stock: MYE
#
# 🔁 Processing stock: WNC
#
# 🔁 Processing stock: GTN
#
# 🔁 Processing stock: KELYA.O
#
# 🔁 Processing stock: ALRS.O
#
# 🔁 Processing stock: ALT.O
#
# 🔁 Processing stock: EGY
#
# 🔁 Processing stock: EYPT.O
#
# 🔁 Processing stock: SVRA.O
#
# 🔁 Processing stock: TTI
#
# 🔁 Processing stock: CLFD.O
#
# 🔁 Processing stock: NWPX.O
#
# 🔁 Processing stock: ORKA.O
#
# 🔁 Processing stock: DHIL.O
#
# 🔁 Processing stock: MITK.O
#
# 🔁 Processing stock: SRDX.O
#
# 🔁 Processing stock: FC
#
# 🔁 Processing stock: NUS
#
# 🔁 Processing stock: GCBC.O
#
# 🔁 Processing stock: TBRG.O
#
# 🔁 Processing stock: SIGA.O
#
# 🔁 Processing stock: ALNT.O
#
# 🔁 Processing stock: DIN
#
# 🔁 Processing stock: NATH.O
#
# 🔁 Processing stock: VALU.O
#
# 🔁 Processing stock: ZEUS.O
#
# 🔁 Processing stock: ANGO.O
#
# 🔁 Processing stock: RIGL.O
#
# 🔁 Processing stock: TRAK.K
#
# 🔁 Processing stock: HRTX.O
#
# 🔁 Processing stock: DDD
#
# 🔁 Processing stock: APPS.O
#
# 🔁 Processing stock: MSB
#
# 🔁 Processing stock: PNRG.O
#
# 🔁 Processing stock: ACTG.O
#
# 🔁 Processing stock: HVT
#
# 🔁 Processing stock: ATNI.O
#
# 🔁 Processing stock: MTW
#
# 🔁 Processing stock: MATV.K
#
# 🔁 Processing stock: SPOK.O
#
# 🔁 Processing stock: SHYF.O
#
# 🔁 Processing stock: NEWT.O
#
# 🔁 Processing stock: CYRX.O
#
# 🔁 Processing stock: NVEC.O
#
# 🔁 Processing stock: EBS
#
# 🔁 Processing stock: OIS
#
# 🔁 Processing stock: RLGT.K
#
# 🔁 Processing stock: BYON.K
#
# 🔁 Processing stock: MVIS.O
#
# 🔁 Processing stock: UIS
#
# 🔁 Processing stock: CDZI.O
#
# 🔁 Processing stock: VNDA.O
#
# 🔁 Processing stock: NGS
#
# 🔁 Processing stock: EGHT.O
#
# 🔁 Processing stock: PAMT.O
#
# 🔁 Processing stock: FNLC.O
#
# 🔁 Processing stock: AEHR.O
#
# 🔁 Processing stock: MOV
#
# 🔁 Processing stock: JAKK.O
#
# 🔁 Processing stock: FLIC.O
#
# 🔁 Processing stock: CERS.O
#
# 🔁 Processing stock: PKE
#
# 🔁 Processing stock: CRDF.O
#
# 🔁 Processing stock: LFMD.O
#
# 🔁 Processing stock: OSUR.O
#
# 🔁 Processing stock: JOUT.O
#
# 🔁 Processing stock: ASUR.O
#
# 🔁 Processing stock: PCYO.O
#
# 🔁 Processing stock: TCI
#
# 🔁 Processing stock: NC
#
# 🔁 Processing stock: IMMR.O
#
# 🔁 Processing stock: AVNW.O
#
# 🔁 Processing stock: XOMA.O
#
# 🔁 Processing stock: LFCR.O
#
# 🔁 Processing stock: ONIT.K
#
# 🔁 Processing stock: EHTH.O
#
# 🔁 Processing stock: ANIK.O
#
# 🔁 Processing stock: GCO
#
# 🔁 Processing stock: MEI
#
# 🔁 Processing stock: WTI
#
# 🔁 Processing stock: ABEO.O
#
# 🔁 Processing stock: SSP.O
#
# 🔁 Processing stock: RGP.O
#
# 🔁 Processing stock: KOPN.O
#
# 🔁 Processing stock: FSTR.O
#
# 🔁 Processing stock: RGCO.O
#
# 🔁 Processing stock: TSSI.O
#
# 🔁 Processing stock: LFVN.O
#
# 🔁 Processing stock: ESCA.O
#
# 🔁 Processing stock: SGMO.O
#
# 🔁 Processing stock: MPAA.O
#
# 🔁 Processing stock: DENN.O
#
# 🔁 Processing stock: FXNC.O
#
# 🔁 Processing stock: SWKH.O
#
# 🔁 Processing stock: UTMD.O
#
# 🔁 Processing stock: LAKE.O
#
# 🔁 Processing stock: GENC.K
#
# 🔁 Processing stock: LTBR.O
#
# 🔁 Processing stock: HQI.O
#
# 🔁 Processing stock: STRT.O
#
# 🔁 Processing stock: RELL.O
#
# 🔁 Processing stock: EVC
#
# 🔁 Processing stock: FENC.O
#
# 🔁 Processing stock: SMID.O
#
# 🔁 Processing stock: CATX.K
#
# 🔁 Processing stock: TBI
#
# 🔁 Processing stock: EPM
#
# 🔁 Processing stock: VOXX.O
#
# 🔁 Processing stock: DBI
#
# 🔁 Processing stock: NKTR.O
#
# 🔁 Processing stock: PLX
#
# 🔁 Processing stock: TTEC.O
#
# 🔁 Processing stock: PDEX.O
#
# 🔁 Processing stock: VIRC.O
#
# 🔁 Processing stock: ESOA.O
#
# 🔁 Processing stock: CXDO.O
#
# 🔁 Processing stock: CSPI.O
#
# 🔁 Processing stock: FRAF.O
#
# 🔁 Processing stock: STXS.K
#
# 🔁 Processing stock: CLAR.O
#
# 🔁 Processing stock: FEIM.O
#
# 🔁 Processing stock: OPOF.O
#
# 🔁 Processing stock: CCRD.K
#
# 🔁 Processing stock: PHX
#
# 🔁 Processing stock: STRS.O
#
# 🔁 Processing stock: INSG.O
#
# 🔁 Processing stock: FLL.O
#
# 🔁 Processing stock: OPRX.O
#
# 🔁 Processing stock: SRI
#
# 🔁 Processing stock: KEQU.O
#
# 🔁 Processing stock: SAVA.O
#
# 🔁 Processing stock: PESI.O
#
# 🔁 Processing stock: EGAN.O
#
# 🔁 Processing stock: BSET.O
#
# 🔁 Processing stock: LXRX.O
#
# 🔁 Processing stock: QVCGA.O
#
# 🔁 Processing stock: CSBR.O
#
# 🔁 Processing stock: KRMD.O
#
# 🔁 Processing stock: ACNT.O
#
# 🔁 Processing stock: RAIL.O
#
# 🔁 Processing stock: SNCR.O
#
# 🔁 Processing stock: VXRT.O
#
# 🔁 Processing stock: RCMT.O
#
# 🔁 Processing stock: CMT
#
# 🔁 Processing stock: LCTX.K
#
# 🔁 Processing stock: ISSC.O
#
# 🔁 Processing stock: INFU.K
#
# 🔁 Processing stock: AXR
#
# 🔁 Processing stock: IVAC.O
#
# 🔁 Processing stock: PLCE.O
#
# 🔁 Processing stock: LTRX.O
#
# 🔁 Processing stock: PPIH.O
#
# 🔁 Processing stock: GNSS.O
#
# 🔁 Processing stock: GALT.O
#
# 🔁 Processing stock: GAIA.O
#
# 🔁 Processing stock: KVHI.O
#
# 🔁 Processing stock: HURC.O
#
# 🔁 Processing stock: NOTV.O
#
# 🔁 Processing stock: DXLG.O
#
# 🔁 Processing stock: TAYD.O
#
# 🔁 Processing stock: PCG_pa
#
# 🔁 Processing stock: GEOS.O
#
# 🔁 Processing stock: SLNG.O
#
# 🔁 Processing stock: ORMP.O
#
# 🔁 Processing stock: INTT.K
#
# 🔁 Processing stock: ACHV.O
#
# 🔁 Processing stock: ANIX.O
#
# 🔁 Processing stock: ZYXI.O
#
# 🔁 Processing stock: QUIK.O
#
# 🔁 Processing stock: BRID.O
#
# 🔁 Processing stock: UEIC.O
#
# 🔁 Processing stock: QMCO.O
#
# 🔁 Processing stock: LPSN.O
#
# 🔁 Processing stock: FONR.O
#
# 🔁 Processing stock: MCHX.O
#
# 🔁 Processing stock: LPTH.O
#
# 🔁 Processing stock: HGBL.O
#
# 🔁 Processing stock: PETS.O
#
# 🔁 Processing stock: DIT
#
# 🔁 Processing stock: AXTI.O
#
# 🔁 Processing stock: FOSL.O
#
# 🔁 Processing stock: ALOT.O
#
# 🔁 Processing stock: HNNA.O
#
# 🔁 Processing stock: RRGB.O
#
# 🔁 Processing stock: UBCP.O
#
# 🔁 Processing stock: MNOV.O
#
# 🔁 Processing stock: INVE.O
#
# 🔁 Processing stock: SGA.O
#
# 🔁 Processing stock: ESP
#
# 🔁 Processing stock: OPTT.K
#
# 🔁 Processing stock: CODA.O
#
# 🔁 Processing stock: AUBN.O
#
# 🔁 Processing stock: INO.O
#
# 🔁 Processing stock: IOR
#
# 🔁 Processing stock: MLSS.K
#
# 🔁 Processing stock: AREN.K
#
# 🔁 Processing stock: VERU.O
#
# 🔁 Processing stock: ASYS.O
#
# 🔁 Processing stock: ARMP.K
#
# 🔁 Processing stock: ASRT.O
#
# 🔁 Processing stock: FKWL.O
#
# 🔁 Processing stock: DOMH.O
#
# 🔁 Processing stock: DLHC.O
#
# 🔁 Processing stock: PED
#
# 🔁 Processing stock: ALTS.O
#
# 🔁 Processing stock: CULP.K
#
# 🔁 Processing stock: SUP
#
# 🔁 Processing stock: CATO.K
#
# 🔁 Processing stock: CYCC.O
#
# 🔁 Processing stock: ICAD.O
#
# 🔁 Processing stock: WFCF.O
#
# 🔁 Processing stock: LINK.O
#
# 🔁 Processing stock: CTSO.O
#
# 🔁 Processing stock: CNVS.O
#
# 🔁 Processing stock: CNTY.O
#
# 🔁 Processing stock: MIND.O
#
# 🔁 Processing stock: SOTK.O
#
# 🔁 Processing stock: RMTI.O
#
# 🔁 Processing stock: CVGI.O
#
# 🔁 Processing stock: MBOT.O
#
# 🔁 Processing stock: LEE.O
#
# 🔁 Processing stock: CMTL.O
#
# 🔁 Processing stock: KOSS.O
#
# 🔁 Processing stock: BDL
#
# 🔁 Processing stock: UG.O
#
# 🔁 Processing stock: IDN.O
#
# 🔁 Processing stock: ICCC.O
#
# 🔁 Processing stock: CVU
#
# 🔁 Processing stock: AGEN.O
#
# 🔁 Processing stock: REFR.O
#
# 🔁 Processing stock: DWSN.O
#
# 🔁 Processing stock: AP
#
# 🔁 Processing stock: RFIL.O
#
# 🔁 Processing stock: USIO.O
#
# 🔁 Processing stock: CRWS.O
#
# 🔁 Processing stock: PXLW.O
#
# 🔁 Processing stock: APYX.O
#
# 🔁 Processing stock: TACT.O
#
# 🔁 Processing stock: SYPR.O
#
# 🔁 Processing stock: UONEK.O
#
# 🔁 Processing stock: ARKR.O
#
# 🔁 Processing stock: HHS.O
#
# 🔁 Processing stock: WYY
#
# 🔁 Processing stock: ACCS.K
#
# 🔁 Processing stock: AWRE.O
#
# 🔁 Processing stock: AIFF.O
#
# 🔁 Processing stock: SGRP.O
#
# 🔁 Processing stock: NTIP.K
#
# 🔁 Processing stock: VHC
#
# 🔁 Processing stock: FTEK.O
#
# 🔁 Processing stock: GROW.O
#
# 🔁 Processing stock: IRD.O
#
# 🔁 Processing stock: CMS_pb
#
# 🔁 Processing stock: KTCC.O
#
# 🔁 Processing stock: HSON.O
#
# 🔁 Processing stock: AXDX.O
#
# 🔁 Processing stock: HBIO.O
# 🔁 Processing stock: NSYS.O
#
# 🔁 Processing stock: OCC.O
#
# 🔁 Processing stock: NTWK.O
#
# 🔁 Processing stock: INTG.O
#
# 🔁 Processing stock: DRRX.O
#
# 🔁 Processing stock: IGC
#
# 🔁 Processing stock: TRT
#
# 🔁 Processing stock: ENZ
#
# 🔁 Processing stock: GTIM.O
#
# 🔁 Processing stock: TENX.O
#
# 🔁 Processing stock: CKX
#
# 🔁 Processing stock: CRIS.O
#
# 🔁 Processing stock: CVM
#
# 🔁 Processing stock: CYTH.O
#
# 🔁 Processing stock: DAIO.O
#
# 🔁 Processing stock: JOB
#
# 🔁 Processing stock: RVP
#
# 🔁 Processing stock: INTZ.O
#
# 🔁 Processing stock: NAII.O
#
# 🔁 Processing stock: CVV.O
#
# 🔁 Processing stock: LSTA.O
#
# 🔁 Processing stock: PTN
#
# 🔁 Processing stock: CREX.O
#
# 🔁 Processing stock: MXC
#
# 🔁 Processing stock: MTEX.O
#
# 🔁 Processing stock: NNVC.K
#
# 🔁 Processing stock: IRIX.O
#
# 🔁 Processing stock: AMS
#
# 🔁 Processing stock: SIF
#
# 🔁 Processing stock: BRN
#
# 🔁 Processing stock: NEPH.O
#
# 🔁 Processing stock: HUSA.K
#
# 🔁 Processing stock: CLRO.O
#
# 🔁 Processing stock: COHN.K
#
# 🔁 Processing stock: ELSE.O
#
# 🔁 Processing stock: MEIP.O
#
# 🔁 Processing stock: TAIT.O
#
# 🔁 Processing stock: JCTC.O
#
# 🔁 Processing stock: CLRB.O
#
# 🔁 Processing stock: GOVX.O
#
# 🔁 Processing stock: GPUS.K
#
# 🔁 Processing stock: ERNA.O
#
# 🔁 Processing stock: AIRI.K
#
# 🔁 Processing stock: SMSI.O
#
# 🔁 Processing stock: STRM.O
#
# 🔁 Processing stock: IMNN.O
#
# 🔁 Processing stock: AWX
#
# 🔁 Processing stock: BCDA.O
#
# 🔁 Processing stock: MTR
#
# 🔁 Processing stock: PRPH.O
#
# 🔁 Processing stock: SSKN.O
#
# 🔁 Processing stock: ASTC.O
#
# 🔁 Processing stock: PMCB.O
#
# 🔁 Processing stock: PRPO.O
#
# 🔁 Processing stock: BBGI.O
#
# 🔁 Processing stock: MSN
#
# 🔁 Processing stock: BCLI.O
#
# 🔁 Processing stock: NURO.O
#
# 🔁 Processing stock: SCKT.O
#
# 🔁 Processing stock: ARTW.O
#
# 🔁 Processing stock: AIMD.O
#
# 🔁 Processing stock: AIM
#
# 🔁 Processing stock: STRR.O
#
# 🔁 Processing stock: SSY
#
# 🔁 Processing stock: GTBP.O
#
# 🔁 Processing stock: SGMA.O
#
# 🔁 Processing stock: OGEN.K
#
# 🔁 Processing stock: RIME.O
#
# 🔁 Processing stock: SNGX.O
#
# 🔁 Processing stock: SNOA.O
#
# 🔁 Processing stock: AEMD.O
#
# 🔁 Processing stock: GBR
#
# 🔁 Processing stock: KNW
#
# 🔁 Processing stock: BKYI.O
#
# 🔁 Processing stock: UUU
#
# 🔁 Processing stock: PSTV.O
#
# 🔁 Processing stock: FORD.O
#
# 🔁 Processing stock: AYRO.O
#
# 🔁 Processing stock: TTNP.O
#
# 🔁 Processing stock: TOVX.K
#
# 🔁 Processing stock: PRSO.O
#
# 🔁 Processing stock: PALI.O
#
# 🔁 Processing stock: APDN.O
#
# 🔁 Processing stock: SBET.O
#
# 🔁 Processing stock: ASTI.O
#
# 🔁 Processing stock: AWH.O
#
# 🔁 Processing stock: SUNE.O
#
# 🔁 Processing stock: TCRT.O
#
# 🔁 Processing stock: WINT.O
#
# 🔁 Processing stock: DGLY.O
#
# ✅ Total Time: 26.72 minutes

# %%
# Write results to Excel
rmse_5ff_df.to_excel("5ff_rmse_results.xlsx", index=False)
predictions_5ff_df.to_excel("5ff_predictions_results.xlsx", index=False)

# %%
# Step 1: Get industry info per stock (use latest entry only to avoid duplication)
industry_info = merged_data[['RIC', 'Industry']].drop_duplicates(subset='RIC')

# Step 2: Merge with RMSE results
rmse_with_industry = rmse_5ff_df.merge(industry_info, left_on='Stock', right_on='RIC', how='left')

# Step 3: Group by Industry and Model to compute average RMSE
avg_rmse_5ff_by_industry = (
    rmse_with_industry
    .groupby(['Industry', 'Model'])['RMSE']
    .mean()
    .reset_index()
    .sort_values(['Industry', 'RMSE'])
)
avg_rmse_5ff_by_industry.to_excel("avg_rmse_5ff_by_industry.xlsx", index=False)


#Doing by avg rmse by industry for all models

# Step 1: Rename RMSE columns to identify the factor model
avg_rmse_by_industry_3f_renamed = avg_rmse_by_industry.rename(columns={'RMSE': 'RMSE (3FF)'})
avg_rmse_5ff_by_industry_renamed = avg_rmse_5ff_by_industry.rename(columns={'RMSE': 'RMSE (5FF)'})

# Step 2: Merge on Industry and Model
rmse_comparison = pd.merge(
    avg_rmse_by_industry_3f_renamed,
    avg_rmse_5ff_by_industry_renamed,
    on=['Industry', 'Model'],
    how='outer'  # in case one side is missing models
)
rmse_comparison
# Step 3: Sort and display
rmse_comparison = rmse_comparison.sort_values(by=['Industry', 'Model'])
rmse_comparison.to_excel("rmse_comparison.xlsx", index=False)

# %%
# doing by count here

# Step 1: Get best model per stock for 3FF
best_3ff = rmse_df.loc[rmse_df.groupby("Stock")["RMSE"].idxmin()]
count_3ff = best_3ff["Model"].value_counts().reset_index()
count_3ff.columns = ["Model", "Count (3FF)"]

# Step 2: Get best model per stock for 5FF
best_5ff = rmse_5ff_df.loc[rmse_5ff_df.groupby("Stock")["RMSE"].idxmin()]
count_5ff = best_5ff["Model"].value_counts().reset_index()
count_5ff.columns = ["Model", "Count (5FF)"]

# Step 3: Merge the two counts side-by-side
best_model_counts_combined = pd.merge(count_3ff, count_5ff, on="Model", how="outer").fillna(0)
best_model_counts_combined[["Count (3FF)", "Count (5FF)"]] = best_model_counts_combined[["Count (3FF)", "Count (5FF)"]].astype(int)

# Optional: Sort by total count or model name
best_model_counts_combined = best_model_counts_combined.sort_values(by="Model")
best_model_counts_combined
# Out:
#           Model  Count (3FF)  Count (5FF)
# 4  DecisionTree          146          133
# 6    ElasticNet           26           23
# 1         Lasso          205          178
# 3           OLS          162          209
# 5         Ridge           46           59
# 0           SVR          225          213
# 2       XGBoost          165          160

# %%
# doing by size here

# Step 1: Categorize Market Cap
def categorize_market_cap(value):
    if value >= 10_000_000_000:
        return 'Large Cap'
    elif value >= 2_000_000_000:
        return 'Mid Cap'
    elif value >= 300_000_000:
        return 'Small Cap'
    else:
        return 'Micro Cap'  # Optional catch-all

# Extract unique market cap info
marketcap_info = merged_data[['RIC', 'Company Market Cap']].drop_duplicates(subset='RIC')
marketcap_info['MarketCapCategory'] = marketcap_info['Company Market Cap'].apply(categorize_market_cap)

# Step 2: Merge with 3FF and 5FF RMSE data
rmse_3f = rmse_df.merge(marketcap_info, left_on='Stock', right_on='RIC', how='left')
rmse_5f = rmse_5ff_df.merge(marketcap_info, left_on='Stock', right_on='RIC', how='left')

# Step 3: Compute average RMSE by model and market cap
avg_rmse_3f = (
    rmse_3f.groupby(['MarketCapCategory', 'Model'])['RMSE']
    .mean().reset_index().rename(columns={'RMSE': 'RMSE (3FF)'})
)

avg_rmse_5f = (
    rmse_5f.groupby(['MarketCapCategory', 'Model'])['RMSE']
    .mean().reset_index().rename(columns={'RMSE': 'RMSE (5FF)'})
)

# Step 4: Merge 3FF and 5FF side-by-side
rmse_by_cap = pd.merge(avg_rmse_3f, avg_rmse_5f, on=['MarketCapCategory', 'Model'], how='outer')
rmse_by_cap = rmse_by_cap.sort_values(['MarketCapCategory', 'Model']).reset_index(drop=True)
rmse_by_cap
# Out:
#    MarketCapCategory         Model  RMSE (3FF)  RMSE (5FF)
# 0          Large Cap  DecisionTree    8.910442    8.570150
# 1          Large Cap    ElasticNet    7.924144    7.924070
# 2          Large Cap         Lasso    7.925102    7.928441
# 3          Large Cap           OLS    8.079037    8.041491
# 4          Large Cap         Ridge    7.986602    7.959748
# 5          Large Cap           SVR    8.052720    7.999660
# 6          Large Cap       XGBoost    8.532621    8.281921
# 7          Micro Cap  DecisionTree   22.823438   23.040080
# 8          Micro Cap    ElasticNet   19.474120   19.450079
# 9          Micro Cap         Lasso   19.465708   19.462350
# 10         Micro Cap           OLS   19.799552   19.791347
# 11         Micro Cap         Ridge   19.593688   19.563691
# 12         Micro Cap           SVR   19.481995   19.489360
# 13         Micro Cap       XGBoost   21.995426   21.708488
# 14           Mid Cap  DecisionTree   11.169631   11.430387
# 15           Mid Cap    ElasticNet   10.282474   10.315522
# 16           Mid Cap         Lasso   10.285305   10.301484
# 17           Mid Cap           OLS   10.537389   10.416818
# 18           Mid Cap         Ridge   10.401876   10.327186
# 19           Mid Cap           SVR   10.405732   10.392653
# 20           Mid Cap       XGBoost   11.297414   11.325209
# 21         Small Cap  DecisionTree   14.513575   14.676420
# 22         Small Cap    ElasticNet   13.183496   13.121163
# 23         Small Cap         Lasso   13.167985   13.111116
# 24         Small Cap           OLS   13.422427   13.326396
# 25         Small Cap         Ridge   13.277917   13.198498
# 26         Small Cap           SVR   13.177988   13.116308
# 27         Small Cap       XGBoost   14.292153   14.269494
